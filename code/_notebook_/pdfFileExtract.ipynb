# %%
# Run on first instance to install required libraries
# %pip install PyPDF2
# %pip install bs4
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s eta 0:00:011
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61085 sha256=54f89d59a34af2d0556f4eb6e5383f8764740be87a563f686fd46651f610cc39
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/97/28/4b/142b7d8c98eeeb73534b9c5b6558ddd3bab3c2c8192aa7ab30
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# console and directory access
import os
import re
import time 
import json
import urllib
import datetime

# interacting with Amazon AWS
import boto3
from sagemaker.session import Session

# data reading and exporting  
import pandas as pd
import numpy as np

# parsing SEC website for data  
import requests
from bs4 import BeautifulSoup

# pdf manipulation
from PyPDF2 import PdfFileReader, PdfFileWriter, utils

# %% [markdown]
# ## PDF File Extraction
# Extract URL links per company filing to download accompaning X-17A-5 files from SEC EDGAR site

# %%
def baseURL(cik:str, file_type:str='X-17A-5') -> str:
    """
    Constructs a base URL for searching for a paritcular SEC filing  
    ------------------------------------------------------------------------------------------
    Input:
        :param: cik (type str)
            The CIK number for a registreed broker-dealer (e.g. 1904)
        :param: file_type (type str)
            The file type looking to parse for a given broker-dealer (e.g. default X-17A-5)
            
    Return:
        :param: url (type str)
            A URL string that points to the EDGAR webpage of a registred broker dealer
            (e.g. https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1904&type=X-17A-5&dateb=20201231)
    """
    
    # forming the SEC search URLs from the select CIK, file type and date range
    secFormat = 'https://www.sec.gov/cgi-bin/browse-edgar?'     # SEC base url
    dataSelect = 'action=getcompany&CIK={}&type={}&dateb={}'    # select params.

    # build lookup URLs for the SEC level data (base url)
    url = secFormat + dataSelect.format(cik, file_type, datetime.datetime.today().year)
    
    return url

# %%
def edgarParse(url:str):
    """
    Parses the EDGAR webpage of a provided URL and returns a tuple of arrays/lists
    ------------------------------------------------------------------------------------------
    Input:
        :param: url (type str) 
            URL is a string representing a SEC website URL pointing to a CIK for X-17A-5 filings
            e.g. https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1904&type=X-17A-5&dateb=20201231
    
    Return:
        :param: filing_dates (type numpy array)
            A vector of date strings for all X-17A-5 filings in chronological order, from newest
            to oldest in filing date (e.g. ['2020-02-26', '2019-02-28', '2018-03-02'])
        :param: archives (type list)
            A vector of strings for all sec.gov URL links for each filings in chronological order
    """
    
    response = requests.Response()
    
    # we try requesting the URL and break only if response object returns status of 200
    for _ in range(100):
        # requesting HTML data link from the EDGAR search results 
        response = requests.get(url, allow_redirects=True)
        if response.status_code == 200:
            break
    
    # last check to see if response object is "problamatic" e.g. 403
    if response.status_code != 200:
        return None
    
    # parse the HTML doc string from the response object
    soup = BeautifulSoup(response.text, 'html.parser') 
    
    # read in HTML tables from the url link provided 
    try:
        # due to web-scrapping non-constant behavior (check against 100 tries)
        for _ in range(100):
            try: 
                filings = pd.read_html(url) 
                break
            except urllib.error.HTTPError: pass
        
        filing_table = filings[2]                           # select the filings (IndexError Flag)
        filing_dates = filing_table['Filing Date'].values   # select the filing dates columns

        # parse the html-doc string for all instance of < a href= > from the URL 
        href = [link.get('href') for link in soup.find_all('a')]

        # search for all links with Archive in handle, these are the search links for the X-17A-5 filings
        archives = ['https://www.sec.gov' + link for link in href if str.find(link, 'Archives') > 0]
        
        # return a tuple of vectors, the filings dates and the corresponding urls
        return filing_dates, archives
        
    # if there exists no active reports for a given CIK, we flag the error
    except IndexError:
        print('Currently no filings are present for the firm\n')
        return None

# %%
def fileExtract(archive:str) -> list:
    """
    Parses through the pdf links X-17A-5 pdf files to be saved in an s3 bucket
    ------------------------------------------------------------------------------------------
    Input:
        :param: archive (type str)
            A vector of strings for all sec.gov URL links for each filings in chronological order

    Return:
        This function returns a list of pdf url links that point to the EDGAR filing for a specific
        broker-dealer at a particular year
    
    NOTE:   This script makes no effort to weed out amended releases, rather it will default to retaining 
            information on first published releases via iterative selection from the most recent filing 
    """
    
    pdf_storage = requests.Response()
    
    # we try requesting the URL and break only if response object returns status of 200
    for _ in range(100):
        # data is organized linearly by most recent issue first, we request data from document links
        pdf_storage = requests.get(archive, allow_redirects=True)
        if pdf_storage.status_code == 200:
            break
    
    # last check to see if response object is "problamatic" e.g. 403
    if pdf_storage.status_code != 200:
        return None

    # table from filing detail Edgar table 
    soup = BeautifulSoup(pdf_storage.text, 'html.parser') 

    # extracts all link within the filing table, filtering for pdfs
    extract_link = [file.get('href') for file in soup.find_all('a')]

    # filter for all pdf links from the extracted file links  
    pdf_files = [string for string in extract_link if str.find(string, 'pdf') > 0]

    return pdf_files

# %%
def mergePdfs(files:list) -> PdfFileWriter:
    """
    Combines pdfs files iteratively by page for each of the accompanying SEC filings 
    ------------------------------------------------------------------------------------------
    Input:
        :param: files (type List)
            A list of pdfs retrieved from filing details for each broker-detal in Edgar's website
            e.g. https://www.sec.gov/Archives/edgar/data/1904/000000190420000002/0000001904-20-000002-index.htm

    Return:
        :param: pdfWriter (type PdfFileWriter)
            A PdfFileWriter object that serves as a container to store each of the select pdf files from our
            list into a larger merged pdf 
    """
    
    # initialize a pdf object to be store pdf pages
    pdfWriter = PdfFileWriter()
    
    for pdf in files:
        pdf_file = 'https://www.sec.gov' + pdf 
        
        # we try requesting the URL and break only if response object returns status of 200
        for _ in range(100):
            # request the specific pdf file from the the SEC
            pdf_storage = requests.get(pdf_file, allow_redirects=True)
            if pdf_storage.status_code == 200:
                break

        # last check to see if response object is "problamatic" e.g. 403
        if pdf_storage.status_code != 200:
            continue
        
        # save PDF contents to local file location 
        open('temp.pdf', 'wb').write(pdf_storage.content)
        
        # read pdf file as PyPDF2 object
        pdf = PdfFileReader('temp.pdf', strict=False) 
        nPages = pdf.getNumPages()          # detemine the number of pages in pdf
        
        # add the pages from the document as specified 
        for page_num in np.arange(nPages):
            pdfWriter.addPage(pdf.getPage(page_num))
    
    # remove temporary file on local directory
    if os.path.isfile('./temp.pdf'):
        os.remove('temp.pdf')
    
    return pdfWriter

# %%
# CIK naming conventions for broker-dealers in order of total asset, we run these in batches
# (according to https://www.auditanalytics.com/products/sec/broker-dealers)
top_9_big_banks = ['782124', '42352', '68136', '91154', '72267', '1224385', '851376', '853784', '58056']
top_18_big_banks = ['318336', '356628', '895502', '877559', '922792', '230611', '890203', '920417', '87634']
top_27_big_banks = ['26617', '1616344', '803012', '1591458', '1215680', '1146184', '867626', '1261467', '29648']

# %% [markdown]
# ## Main File Execution

# %%
if __name__ == "__main__":
    
    # Amazon Textract client and Sagemaker session
    s3 = boto3.client('s3')
    session = Session()
    
    bucket = 'ran-s3-systemic-risk'
    output_folder = 'Input/X-17A-5/'
    
    # ==============================================================================
    # check available pdfs stored within desired output-folder
    s3_path = session.list_s3_files(bucket, output_folder)
    
    # retrieving CIK-Dealers JSON file from s3 bucket
    s3.download_file(bucket, 'Temp/CIKandDealers.json', 'temp.json')

    # read all CIK and Dealer name information from storage
    with open('temp.json', 'r') as f: cik2brokers = json.loads(f.read())

    # remove local file after it has been created (variable is stored in memory)
    os.remove('temp.json')
    # ==============================================================================
    
    # iterate through a list of CIKs
    for cik_id in top_27_big_banks:
        companyName = cik2brokers['broker-dealers'][cik_id]
        
        # build lookup URLs for the SEC level data (base url)
        url = baseURL(cik_id)
        
        # return the filing dates and archived url's for each SEC company (TypeError if return None)
        response = edgarParse(url)
        
        if type(response) is not None:
            filing_dates, archives = response

            # logging info for when files are being downloaded
            print('Downloading X-17A-5 files for {} - CIK ({})'.format(companyName, cik_id))
            print('\t{}'.format(url))

             # itterate through each of the pdf URLs corresponding to archived contents
            for i, pdf_url in enumerate(archives):

                # filing date in full yyyy-MM-dd format
                date = filing_dates[i]

                # Construct filename & pdf file naming convention (e.g. filename = 1904-2020-02-26.pdf) 
                file_name = str(cik_id) + '-' + date + '.pdf'
                pdf_name = output_folder + file_name

                if pdf_name in s3_path: 
                    print('\tAll files for {} are downloaded'.format(companyName))
                    break

                else:
                    # extract all acompanying pdf files, merging all to one large pdf
                    pdf_files = fileExtract(pdf_url)
                    
                    if type(pdf_files) is not None:
                        concatPdf = mergePdfs(pdf_files)

                        # open file and save to local instance
                        with open(file_name, 'wb') as f:
                            concatPdf.write(f)
                            f.close()

                        # save contents to AWS S3 bucket
                        with open(file_name, 'rb') as data:
                            s3.upload_fileobj(data, bucket, pdf_name)

                        # remove local file after it has been created
                        os.remove(file_name)
                        print('\tSaved X-17A-5 files for {} on {}'.format(companyName, date))
                    
                    else:
                        print('\tNo files found for {} on {}'.format(companyName, date))
        
        # identify error in the event edgar parse (web-scrapping returns None)
        else: print('ERROR: Unable to download X-17A-5 files for {} - CIK ({})'.format(companyName, cik_id))
# Out:
# Downloading X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  - CIK (26617)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=26617&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2020-06-01
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2019-05-30
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2018-05-30
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2017-05-30
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2016-05-31
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2015-06-01
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2014-05-29
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2013-05-30
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2012-05-30
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2011-05-31
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2010-05-28
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2009-06-08
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2009-05-29
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2008-05-29
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2007-05-29
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2006-05-26
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2005-05-26
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2004-05-27
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2003-06-02
# 	Saved X-17A-5 files for DAIWA CAPITAL MARKETS AMERICA INC.  on 2002-05-30
# Downloading X-17A-5 files for CITADEL CLEARING LLC  - CIK (1616344)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1616344&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for CITADEL CLEARING LLC  on 2021-02-25
# 	Saved X-17A-5 files for CITADEL CLEARING LLC  on 2020-02-27
# 	Saved X-17A-5 files for CITADEL CLEARING LLC  on 2019-02-28
# 	Saved X-17A-5 files for CITADEL CLEARING LLC  on 2018-02-27
# 	Saved X-17A-5 files for CITADEL CLEARING LLC  on 2017-02-24
# 	Saved X-17A-5 files for CITADEL CLEARING LLC  on 2016-02-24
# Downloading X-17A-5 files for TD SECURITIES (USA) LLC  - CIK (803012)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=803012&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2020-12-22
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2019-12-20
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2018-12-19
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2018-03-22
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2016-12-22
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2015-12-22
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2014-12-30
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2013-12-26
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2012-12-26
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2012-01-30
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2011-12-21
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2010-12-27
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2009-12-29
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2008-12-30
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2007-12-28
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2007-01-29
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2006-01-03
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2005-01-03
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2003-12-31
# 	Saved X-17A-5 files for TD SECURITIES (USA) LLC  on 2002-12-31
# Downloading X-17A-5 files for CURVATURE SECURITIES LLC  - CIK (1591458)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1591458&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2021-02-26
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2020-02-28
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2019-02-28
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2018-02-28
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2017-01-23
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2016-02-18
# 	Saved X-17A-5 files for CURVATURE SECURITIES LLC  on 2015-02-20
# Downloading X-17A-5 files for SOUTH STREET SECURITIES LLC  - CIK (1215680)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1215680&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2021-03-02
# PdfReadWarning: Invalid stream (index 14) within object 39 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 38) within object 73 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 10) within object 247 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 97 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 100 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 27) within object 133 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 136 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 139 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 7) within object 147 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 150 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 153 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 156 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 159 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 162 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 165 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 14) within object 121 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 7) within object 56 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 59 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 62 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 65 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 9) within object 84 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 68 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 71 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 74 0: Stream has ended unexpectedly [pdf.py:1573]
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2020-03-02
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2019-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2018-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2017-03-07
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2016-06-16
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2015-02-27
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2014-02-28
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2013-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2012-02-29
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2011-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2010-02-26
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2009-03-04
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2008-02-29
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2007-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2006-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2005-03-01
# 	Saved X-17A-5 files for SOUTH STREET SECURITIES LLC  on 2004-03-01
# Downloading X-17A-5 files for CITADEL SECURITIES LLC  - CIK (1146184)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1146184&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2021-02-25
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2020-02-28
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2019-02-28
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2018-02-27
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2017-02-24
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2016-02-24
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2015-02-25
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2014-02-28
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2013-02-26
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2012-02-28
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2011-02-25
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2010-03-09
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2010-02-25
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2009-03-02
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2008-02-29
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2007-02-26
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2006-03-01
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2005-03-02
# 	Saved X-17A-5 files for CITADEL SECURITIES LLC  on 2004-03-01
# Downloading X-17A-5 files for MUFG SECURITIES AMERICAS INC.  - CIK (867626)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=867626&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2021-02-26
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2020-02-27
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2019-02-27
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2018-02-27
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2017-02-28
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2016-02-26
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2015-02-27
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2014-03-04
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2013-02-28
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2012-02-29
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2011-03-01
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2010-03-01
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2009-03-02
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2008-02-29
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2007-04-26
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2006-04-28
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2005-04-29
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2004-04-28
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2003-04-25
# 	Saved X-17A-5 files for MUFG SECURITIES AMERICAS INC.  on 2002-04-29
# Downloading X-17A-5 files for SG AMERICAS SECURITIES, LLC  - CIK (1261467)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=1261467&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2021-03-01
# PdfReadWarning: Invalid stream (index 5) within object 402 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 182 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 185 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 188 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 191 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 194 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 197 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 200 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 203 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 206 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 209 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 212 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 215 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 218 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 221 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 224 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 227 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 230 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 233 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 236 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 239 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 242 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 245 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 248 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 251 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 254 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 257 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 260 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 263 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 266 0: Stream has ended unexpectedly [pdf.py:1573]
# PdfReadWarning: Invalid stream (index 2) within object 269 0: Stream has ended unexpectedly [pdf.py:1573]
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2020-03-02
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2019-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2018-04-13
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2018-02-28
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2017-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2016-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2015-03-02
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2014-03-04
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2013-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2012-02-29
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2011-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2010-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2009-03-02
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2008-02-29
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2007-03-02
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2006-03-01
# 	Saved X-17A-5 files for SG AMERICAS SECURITIES, LLC  on 2005-03-08
# Downloading X-17A-5 files for PERSHING LLC  - CIK (29648)
# 	https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=29648&type=X-17A-5&dateb=2021
# 	Saved X-17A-5 files for PERSHING LLC  on 2021-02-26
# 	Saved X-17A-5 files for PERSHING LLC  on 2019-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2018-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2017-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2016-02-29
# 	Saved X-17A-5 files for PERSHING LLC  on 2015-03-02
# 	Saved X-17A-5 files for PERSHING LLC  on 2014-02-28
# 	Saved X-17A-5 files for PERSHING LLC  on 2013-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2012-02-29
# 	Saved X-17A-5 files for PERSHING LLC  on 2011-03-30
# 	Saved X-17A-5 files for PERSHING LLC  on 2011-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2010-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2009-03-02
# 	Saved X-17A-5 files for PERSHING LLC  on 2008-05-13
# 	Saved X-17A-5 files for PERSHING LLC  on 2008-04-07
# 	Saved X-17A-5 files for PERSHING LLC  on 2008-02-29
# 	Saved X-17A-5 files for PERSHING LLC  on 2007-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2006-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2005-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2004-03-01
# 	Saved X-17A-5 files for PERSHING LLC  on 2003-03-03
