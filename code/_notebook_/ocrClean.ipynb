# %%
# Run on first instance to install required libraries
# %pip install smart_open
# %pip install minecart
# %pip install textract-trp
# Out:
# Requirement already satisfied: smart_open in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (5.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: minecart in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.3.0)
# Requirement already satisfied: pdfminer3k in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from minecart) (1.3.4)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from minecart) (1.15.0)
# Requirement already satisfied: ply in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pdfminer3k->minecart) (3.11)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: textract-trp in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import time 
import re
import os
import trp
import boto3
import minecart
import json
import logging 

import numpy as np
import pandas as pd

from smart_open import open
from sagemaker.session import Session

# %% [markdown]
# ## Table Shaving
# **Removing blank/empty rows that are reported in the line items**

# %%
def column_purge(df:pd.DataFrame) -> pd.DataFrame:
    """
    Column designed to filter out rows that are NaN (empty) and reduce dataframe size
    ------------------------------------------------------------------------------------
    Input
        :param data: (type pandas.DataFrame)
            A dataframe object that corresponds to the X-17A-5 filings
    
    Output
        :return: (type pandas.DataFrame)
            Returns a dataframe of size less than or equal to the original input 
    """
    # begin by filtering out the NaN rows present in the first column
    first_col = df.columns[0]
    new_df = df[np.isin(df[first_col], df[first_col].dropna())]    # select subset of rows 
    
    # replace any missing NaN values with an empty string
    new_df = new_df.fillna('')
    
    return new_df

# %% [markdown]
# ## Table column merging
# **For tables with three columns we merge the last two columns into a once unique column**

# %%
def merge(df:pd.DataFrame) -> pd.DataFrame:
    """
    Function passes a special dataframe, and reduces its dimensions accordingly. 
    Example releases include, but are note limited to, 1224385-2016 and 72267-2003
    ------------------------------------------------------------------------------------
    Input
        :param data: (type pandas.DataFrame)
            A dataframe object that corresponds to the X-17A-5 filings
    
    Output
        :return: (type pandas.DataFrame)
            Returns a dataframe of of size (Nx3) -> (Nx2)
    
    e.g.
    
    Converts a wide dataframe, balance sheet into a smaller rectangular form
                  0                                                 1                 2
            ====================================================================================
        0   Assets                                          | NaN            | NaN  
        1   Cash and cash equivalents                       | $ 606,278      |     
        2   Cash and securities segregated pursuant         | 273,083        | 
        3   Collateralized short-term financing agreements: | NaN            | $ 1,345
    
    
    Rectangular form of the the dataframe ->
                   0                                                 1          
            =====================================================================
        0   Assets                      
        1   Cash and cash equivalents                       | $ 606,278        
        2   Cash and securities segregated pursuant         | 273,083        
        3   Collateralized short-term financing agreements: | $ 1,345            
    """
    # work on itterative merging for rows, check left/right and top/bottom
    n = df.shape[0]
    trans = []

    for i in range(n):
        row = df.iloc[i]         # index into the row

        name = row.iloc[0]       # the line item name (e.g. Total Assets)
        col1 = row.iloc[1]       # the first value(s) column
        col2 = row.iloc[2]       # the second value(s) column 
        
        # ----------------------------------------------
        # NOTE: We say nothing if both col 1 and 2 are 
        #       both populated with a value
        # ----------------------------------------------
        
        if col1 is not np.nan:
            trans.append([name, col1])  # if column 1 has a value we take it by default
        elif col2 is not np.nan:
            trans.append([name, col2])  # if column 1 has no value, but column 2 does, we take it
            
        # ----------------------------------------------
        
        # we want to check if there exists two NaNs - is it real or false flag
        if (col1 is np.nan) and (col2 is np.nan): 
            
            # look up one row (if possible to see if col1 and col2 are populated)
            try:
                # check the information for the above row
                prior_row = df.iloc[i-1]                     # previous dataframe row 
                prior_col1 = prior_row.iloc[1]               # first column from previous row
                prior_col2 = prior_row.iloc[2]               # second column from previous row
                
                # if both values present then we simply use the right hand side value above  
                if (prior_col1 is not np.nan) and (prior_col2 is not np.nan):
                    trans.append([name, prior_col2])
            
            # IndexError if not possible to look up one row       
            except IndexError: pass
    
    return pd.DataFrame(trans)

# %%
def column_merge(df:pd.DataFrame) -> pd.DataFrame:
    """
    Function determines whether a Balance Sheet should be merged or simply filtered. 
    Our two cases are determined as follows:
        * If the second column present in the balance sheet is mostly empty we assume that 
          the second column is an aggregated column, and we can merge it
        * However, if the second column is mostly filled with values, we assume that this
          represents accounting figures from the previous year 
    ------------------------------------------------------------------------------------
    Input
        :param data: (type pandas.DataFrame)
            A dataframe object that corresponds to the X-17A-5 filings
    
    Output
        :return: (type pandas.DataFrame)
            Returns a dataframe of of size (Nx3) -> (Nx2)
    """
    # two events could occur at this point (either the column represents totals, or values from a prior-year)
    arr = df[df.columns[2]].values

    # check the scope of the second column 
    n = arr.size
    k = arr.tolist().count(np.nan)

    # k-check: if more than half the arr size is np.nan we assume this is a "fake column"
    # we merge these columns since there are many blank rows, otherwise we assume year split 
    if k/n >= 0.50:
        new_df = merge(df)            # merge rows by merge function
    else:
        new_df = df[df.columns[:2]]   # return the most recent year 
    
    return new_df

# %% [markdown]
# ## Table Row Split
# **Since many of the existing tables run the risk of overlapping rows we work to split these rows to appropriate values**

# %%
def row_split(df:pd.DataFrame, text_file:dict) -> pd.DataFrame:
    """
    Function designed to split conjoined rows from Balance sheet dataframes into individual rows.
    Example releases include, but are note limited to, 42352-2015, 58056-2009, 58056-2013, 58056-2019
    ------------------------------------------------------------------------------------
    Input:
        :param df: (type pandas dataframe)
            References the balance sheet dataframe read in from AWS Textract
        :param text_file: (type dictionary)
            Stores text values with corresponding confidence level for balance sheet pages
    
    Output:
        :param return: (type pandas dataframe) 
            A processed dataframe of size greater than or equal to the inputed dataframe
    """
    
    # ##############################################################
    # NESTED HELPER FUNCTIONS
    # ##############################################################
    
    def find_row_splits(val) -> bool:
        """
        Compute a boolean measure to assess whether a row is conjoined or not. We make
        the assumption that a row is conjoined or merged if there exists a space in the 
        first value column (omiting the dollar sign $)
        """
        try:
            # split the data figures for each balance sheet figure
            arr = val.split(' ')
            
            # remove the $ sign if present in the list (this helps avoid false pasitives) 
            arr = list(filter(lambda x: x != '$', arr))
            
            # if length of read list exceeds 1 then we know there exists a multi-row bunch
            if len(arr) > 1:
                return True
            else: return False
        
        # handle exception for NaN (no attribute to split) 
        except AttributeError: return False
    
    def extract_lineitems(line:list, value:list, dictionary:dict) -> list:
        """
        Extract the appropriate line items from each line value.
        """
        splits = []
        
        # iterate through each line item
        for i in dictionary.keys():
    
            # we check for real key-value names avoiding single character keys
            if len(i) > 1: 
                idx = line.find(i)    # find the index of key-value (if possible) in line item array

                # if we find such a value we append the series (failure to find results idx = -1)
                if idx >= 0: splits.append(i)
        
        # check whether we have a one-to-one mapping between line items and line values, 
        # e.g. ['Assets', 'Cash', 'Recievables'] -> ['1,233', '4,819'] (3x2 mapping)
        n = len(splits) - len(value)
        
        # there exists a mismatch (more line items terms)
        if n > 0: 
            return splits[n:]
        # we assume there doesn't exist a negative mismatch (more values than items)
        else: 
            return splits
    
    def recursive_splits(values:list, lineName:list, sub=[]) -> pd.DataFrame:
        """
        Recursively breaks up merged rows for each split until no merged row is left
        """
        # if our list exceeds 1 in length, we continue to split
        if len(values) > 1:
            # construct a dataframe row of the first split term to append to sub list
            row = pd.DataFrame([lineName[0], values[0]]).T
            sub.append(row)
            
            # we pass the +1 index splits and line name, appending the first-most layer 
            return recursive_splits(values[1:], lineName[1:], sub=sub)
        else:
            row = pd.DataFrame([lineName[0], values[0]]).T
            sub.append(row)
            
            # we concatenate all DataFrames vertically to form a large DataFrame 
            return pd.concat(sub)
        
    # ##############################################################
    # ##############################################################    
    
    # select all the rows that match our description, where a space exists = row merge 
    selections = df[df[df.columns[1]].apply(lambda x: find_row_splits(x))]
    idxs = selections.index
    
    # iterate through each row that is determined to be conjoined
    for i in idxs:
        
        # slice dataframe according to the idx selection (we search for all periods were a break occurs)
        top = df.loc[:i-1]
        bottom = df.loc[i+1:]
        
        # divide the identified term from the selection e.g. "$ 9,112,943 13,151,663" -> ["$", "9,112,943", "13,151,663"] 
        # and filter out the $ sign in the list e.g. ["$", "9,112,943", "13,151,663"] -> [9,112,943", "13,151,663"]
        values = df[df.columns[1]].loc[i].split(' ')
        values = list(filter(lambda x: x != '$', values))
        
        # extract line names according to Text parsed list (requires parsed TEXT JSON)
        # e.g. ['Securities Held Total Assets'] -> ['Securities Held', 'Total Assets']
        lineName = df[df.columns[0]].loc[i]
        lineName = extract_lineitems(lineName, values, text_file)
        
        # determine the splits for the corresponding row
        mid = recursive_splits(values, lineName, sub=[])
        mid.columns = df.columns

        # reassign the value of df2 to update across each iteration
        df = pd.concat([top, mid, bottom])
        
    return df

# %% [markdown]
# ## Numeric Conversion
# **Work on converting all string and poor formating quantities to numerical type**

# %%
def num_scale(text_dict:dict) -> float:
    """
    Function used for scaling accounting figures by reported unites
    """
    scalar = {'thousands': 1e3, 'hundreds':1e2, 'millions':1e6, 'billions': 1e9}
    
    # iterate through each of the text values from dictionary map
    for text_value in text_dict.keys():
        
        # we check to see whether the text is found in our scalar dictionary
        for scale_type in scalar.keys():
            
            # search for the presence of the scale identifier (e.g. millions) 
            scale_search = re.search(scale_type, text_value, flags=re.I)
            if scale_search is not None:
                return scalar[scale_type]              # if found we simply return the multiplier
    
    # if failure reached then assume no multiplier (1)
    return 1

# %%
def num_strip(number):
    """
    This function converts a string to a numeric quantity, handles weird string format. 
    We handle input arguments of a string, integer or numpy.ndarray
    """
    
    numType = type(number)

    # if provided a non-empty string, perform regex operation 
    if (numType is str) and (len(number) > 0):

        # check for accounting formats that use parenthesis to signal losses 
        if number[0] == '(': number = '-' + number

        # case replacing to handle poor textract reading of numbers
        number = number.replace('I', '1').replace('l', '1')

        # --------------------------------------------------------------
        # Explanation of the Regex Expression:
        #      [^0-9|.|-]     = match all elements that are not numeric 0-9, periods "." or hyphens "-"
        #      (?<!^)-        = match all elements that are hyphens "-" not in the first index position
        #      \.(?=[^.]*\.)  = match all elements that are periods "." except the last instance
        # --------------------------------------------------------------

        check1 = re.sub("[^0-9|.|-]", "", number)         # remove all the non-numeric, periods "." or hyphens "-"
        check2 = re.sub("(?<!^)-", "", check1)            # removes all "-" that aren't in the first index 
        check3 = re.sub("\.(?=[^.]*\.)", "", check2)      # removes all periods except the last instance of "." 

        # --------------------------------------------------------------

        # we consider weird decimal values that exceed 2 spaces to the right (e.g. 432.2884)
        period_check = check3.find('.')                         # returns the location of the period 
        right_tail_length = len(check3) - period_check - 1      # right-tail length should not exceed 2

        # if more than 2 trailing digits to decimal point we assume incorrect placement
        if right_tail_length > 2:
            check3 = check3.replace('.', '')

        # last check against poor lagging formats e.g. "." or "-" to return nan or floating-point number
        if (check3 == '-') or (check3 == '.'):
            return 0.0
        else:
            # try to cast to floating point value, else flat NaN
            try: 
                return float(check3)
            except ValueError: 
                return np.nan

    # if operator is an integer or float then simply return the value
    elif (numType is int) or (numType is float):
        return number

    else:
        return np.nan

# %%
def cleanNumeric(value):
    """
    This function is a wrapper for calling the numerical extraction function 
    ------------------------------------------------------------------------------------
    Input:
        :param value:
            String with hidden numeric quanity (e.g. $ 19,225 = 19255)  
        :param text_file: (type dictionary)
            Stores text values with corresponding confidence level for balance sheet pages
            
    Output:
        :param return:
            A processed numeric quantiity or numpy.nan value depending on string issues  
    """
    
    assert type(value) is str or int or np.ndarray, 'Value must be of type string, integer, float or numpy array'
    
    # checks to see what type of value is being provided
    operator = type(value)
    
    # if provided a string, perform regex operation 
    if (operator is str) and (len(value) > 0):
        return num_strip(value)
    
    # if operator is integer then simply return the value, no need to modify 
    elif (operator is int) or (operator is float):
        return value 
    
    # if operator is numpy array then we perform a extraction per element in array
    elif (operator is np.ndarray):
        vFunc = np.vectorize(num_strip)      # vectorize function to apply to numpy array
        cleanValue = vFunc(value)            # apply vector function
        return cleanValue

# %% [markdown]
# ### Final Main Execution

# %%
if __name__ == "__main__":
    
    # initiate s3 bucket and corresponding data folder
    bucket = 'ran-s3-systemic-risk'
    data_folder = 'Output/X-17A-5-BS/'
    temp_folder = 'Temp/'

    # Amazon Textract client and Sagemaker session
    textract = boto3.client('textract')
    s3 = boto3.client('s3')
    session = Session()
    
    # retrieving text JSON file from s3 bucket and store to temp 
    s3.download_file(bucket, 'Temp/X17A5-TEXT.json', 'temp2.json')

    # read data on TEXT-Confidence dictionary
    with open('temp2.json', 'r') as f: text_dictionary = json.loads(f.read())  

    # remove local files for JSON
    os.remove('temp2.json')
    
    # csv directory with all X-17A-5 balance sheet information 
    paths = np.array(session.list_s3_files(bucket, data_folder))[1:]
    
    # iterate through each csv path
    for csv in paths:
        
        fileName = csv.split('/')[-1]         # strip filename from each csv
        base_file = fileName.split('.')[0]    # CIK-YYYY-MM-DD base name

        # download X-17A-5 csv file as a temporary csv file  
        s3.download_file(bucket, csv, 'temp.csv')
        df = pd.read_csv('temp.csv')

        # re-assign dataframe of balance sheet after cleanse
        df = column_purge(df)
        
        # --------------------------------------------------------------------------------------------------
        # COLUMN MERGING (IF NECESSARY)
        # --------------------------------------------------------------------------------------------------
        
        # if columns greater than 2, we have a weird data table that needs to be "merged"
        # NOTE: By construction we never have more than 3 columns present, thanks to our Textract check 
        if df.columns.size > 2:
            df = merge(df)
            print('We merged the columns of {}'.format(fileName))
        
        # --------------------------------------------------------------------------------------------------
        # ROW SPLIT FOR MERGED ROWS (IF NECESSARY)
        # --------------------------------------------------------------------------------------------------
        
        # check for presence of row splits and correct any if found 
        tempDF = row_split(df, text_dictionary[base_file])
        
        # if difference is found in shape, then a transformation was done 
        if tempDF.shape != df.shape:
            print("Fixed the merged rows for {}".format(fileName))
        
        # --------------------------------------------------------------------------------------------------
        # NUMERIC CONVERSION
        # --------------------------------------------------------------------------------------------------
        
        # pass numeric converter to the column to convert string to numerics
        tempDF[tempDF.columns[1]] = tempDF[tempDF.columns[1]].apply(cleanNumeric)
        
        # remove any NaN rows post numeric-conversion
        postDF = tempDF.dropna().copy()
        
        # check for potential scaler multipler on cash flows (adjust multiplier if possible)
        scale = num_scale(text_dictionary[base_file])
        postDF[postDF.columns[1]] = postDF[postDF.columns[1]].apply(lambda x: x * scale)
        
        print('We converted to numeric figures for {}\n'.format(fileName))
        
        # --------------------------------------------------------------------------------------------------
        # BALANCE SHEET STORAGE
        # --------------------------------------------------------------------------------------------------

        print(postDF)
#         # writing data frame to .csv file
#         postDF.to_csv(fileName, index=False)

#         # save contents to AWS S3 bucket
#         with open(fileName, 'rb') as data:
#             s3.put_object(Bucket=bucket, Key=data_folder + fileName, Body=data)

#         # remove local file after it has been used
#         os.remove(fileName)
#         os.remove('temp.pdf')

    print('\nAll .csv files are cleaned and primed')
# Out:
# We converted to numeric figures for 1224385-2004-03-01.csv
#
#                                                     0             1
# 0                                                Cash  1.760000e+05
# 1     Cash segregated pursuant to federal regulations  7.500000e+07
# 2     Securities purchased under agreements to resell  7.944113e+09
# 3   Securities owned, at market value ($8,769,300 ...  9.075170e+09
# 4   Receivable from broker-dealers and clearing or...  4.049708e+09
# 5                           Receivable from customers  5.124600e+07
# 6                         Accrued interest receivable  4.445700e+07
# 7   Property, equipment, and leasehold improvement...  1.106700e+07
# 8                                       Goodwill, net  6.112000e+06
# 9                                        Other assets  2.527380e+08
# 10                                       Total assets  2.150979e+10
# 13     Securities sold under agreements to repurchase  1.360247e+10
# 14  Securities sold, not yet purchased, at market ...  3.686980e+09
# 15  Payable to broker-dealers and clearing organiz...  1.886438e+09
# 16                               Payable to customers  4.498400e+07
# 17                           Accrued interest payable  2.759500e+07
# 18                                  Other liabilities  4.669010e+08
# 19                                  Total liabilities  1.971537e+10
# 20                            Subordinated borrowings  5.385000e+08
# 22                             Member's contributions  1.216068e+09
# 23                               Accumulated earnings  3.984900e+07
# 24                              Total member's equity  1.255917e+09
# 25              Total liabilities and member's equity  2.150979e+10
# We converted to numeric figures for 1224385-2005-03-01.csv
#
#                                                     0             1
# 0                                                Cash  1.007700e+07
# 1     Securities purchased under agreements to resell  1.192898e+10
# 2   Securities owned, at market value ($14,878,096...  1.598734e+10
# 3   Receivable from broker-dealers and clearing or...  7.080574e+09
# 4                           Receivable from customers  1.165720e+08
# 5                         Accrued interest receivable  1.529670e+08
# 6   Property, equipment, and leasehold improvement...  1.026700e+07
# 7                                       Goodwill, net  6.112000e+06
# 8                                        Other assets  3.187630e+08
# 9                                        Total assets  3.561166e+10
# 12     Securities sold under agreements to repurchase  2.143051e+10
# 13  Securities sold, not yet purchased, at market ...  6.775259e+09
# 14  Payable to broker-dealers and clearing organiz...  3.316738e+09
# 15                               Payable to customers  7.526600e+07
# 16                           Accrued interest payable  8.379900e+07
# 17                                  Other liabilities  6.388790e+08
# 18                                  Total liabilities  3.232045e+10
# 19                            Subordinated borrowings  1.183500e+09
# 21                              Total member's equity  2.107707e+09
# 22              Total liabilities and member's equity  3.561166e+10
# We converted to numeric figures for 1224385-2006-03-01.csv
#
#                                                     0             1
# 0                                                Cash  2.565500e+07
# 1     Securities purchased under agreements to resell  6.812438e+09
# 2   Securities owned, at market value ($10,215,308...  1.166421e+10
# 3   Receivable from broker-dealers and clearing or...  4.909150e+09
# 4                           Receivable from customers  1.121510e+08
# 5                         Accrued interest receivable  1.129070e+08
# 6   Property, equipment, and leasehold improvement...  1.284500e+07
# 7                                       Goodwill, net  6.112000e+06
# 8                                        Other assets  3.740250e+08
# 9                                        Total assets  2.402949e+10
# 12     Securities sold under agreements to repurchase  1.202697e+10
# 13  Securities sold, not yet purchased, at market ...  5.059406e+09
# 14  Payable to broker-dealers and clearing organiz...  2.199031e+09
# 15                               Payable to customers  1.138800e+07
# 16                           Accrued interest payable  5.932100e+07
# 17                                  Other liabilities  7.619370e+08
# 18                                  Total liabilities  2.011806e+10
# 19                            Subordinated borrowings  1.183500e+09
# 21                              Total member's equity  2.727933e+09
# 22              Total liabilities and member's equity  2.402949e+10
# We converted to numeric figures for 1224385-2007-03-01.csv
#
#                                                     0             1
# 0                                                Cash  7.480000e+05
# 1     Securities purchased under agreements to resell  4.249897e+09
# 2   Securities owned, at market value ($10,253,591...  1.154806e+10
# 3   Receivable from broker-dealers and clearing or...  4.451402e+09
# 4                           Receivable from customers  2.199900e+07
# 5                         Accrued interest receivable  1.165430e+08
# 6   Property, equipment, and leasehold improvement...  1.146400e+07
# 7                                       Goodwill, net  6.112000e+06
# 8                                        Other assets  4.737010e+08
# 9                                        Total assets  2.087992e+10
# 12     Securities sold under agreements to repurchase  9.294056e+09
# 13  Securities sold, not yet purchased, at market ...  4.241568e+09
# 14  Payable to broker-dealers and clearing organiz...  1.885365e+09
# 15                                   Payable to banks  2.536000e+06
# 16                               Payable to customers  1.435400e+07
# 17                           Accrued interest payable  7.549700e+07
# 18                                  Other liabilities  9.854950e+08
# 19                                  Total liabilities  1.649887e+10
# 20                            Subordinated borrowings  1.183500e+09
# 22                             Member's contributions  2.295102e+09
# 23                               Accumulated earnings  9.024500e+08
# 24                              Total member's equity  3.197552e+09
# 25              Total liabilities and member's equity  2.087992e+10
# We converted to numeric figures for 1224385-2008-02-29.csv
#
#                                                     0             1
# 0                                                Cash  1.052500e+07
# 1   Securities owned, at market value ($11,000,065...  1.267048e+10
# 2     Securities purchased under agreements to resell  4.607831e+09
# 3   Receivable from broker-dealers and clearing or...  3.712403e+09
# 4                         Accrued interest receivable  1.027060e+08
# 5                           Receivable from customers  1.165200e+07
# 6   Property, equipment, and leasehold improvement...  1.023000e+07
# 7                                        Other assets  5.349850e+08
# 8                                        Total assets  2.166082e+10
# 11     Securities sold under agreements to repurchase  1.187068e+10
# 12  Securities sold, not yet purchased, at market ...  3.605979e+09
# 13  Payable to broker-dealers and clearing organiz...  8.821360e+08
# 14                           Accrued interest payable  9.247700e+07
# 15                               Payable to customers  1.903400e+07
# 16                                  Other liabilities  8.369780e+08
# 17                                  Total liabilities  1.730728e+10
# 18                            Subordinated borrowings  1.333500e+09
# 20                             Member's contributions  2.295102e+09
# 21                               Accumulated earnings  7.249330e+08
# 22                              Total member's equity  3.020035e+09
# 23              Total liabilities and member's equity  2.166082e+10
# We converted to numeric figures for 1224385-2009-03-02.csv
#
#                                                     0             1
# 0                                                Cash  8.235000e+06
# 1   Securities owned, at market value ($3,198,593 ...  4.608275e+09
# 2   Receivable from broker-dealers and clearing or...  2.929755e+09
# 3     Securities purchased under agreements to resell  1.754258e+09
# 4                         Accrued interest receivable  6.616000e+07
# 5                           Receivable from customers  1.559500e+07
# 6   Property, equipment, and leasehold improvement...  5.075000e+06
# 7                                        Other assets  1.931820e+08
# 8                                        Total assets  9.580535e+09
# 11     Securities sold under agreements to repurchase  2.650005e+09
# 12  Securities sold, not yet purchased, at market ...  2.640934e+09
# 13  Payable to broker-dealers and clearing organiz...  3.194610e+08
# 14                           Accrued interest payable  3.953300e+07
# 15                               Payable to customers  2.445000e+06
# 16                                  Other liabilities  6.593660e+08
# 17                                  Total liabilities  6.311744e+09
# 18                            Subordinated borrowings  1.983500e+09
# 19                                    Member's equity  1.285291e+09
# 20              Total liabilities and member's equity  9.580535e+09
# We converted to numeric figures for 1224385-2010-03-12.csv
#
#                                                     0             1
# 0                                                Cash  3.083100e+07
# 1     Cash segregated pursuant to federal regulations  2.500000e+07
# 2   Financial instruments owned, at fair value ($7...  9.048848e+09
# 3   Receivable from broker-dealers and clearing or...  4.674419e+09
# 4     Securities purchased under agreements to resell  3.465845e+09
# 5                                            Goodwill  7.968700e+07
# 6                           Receivable from customers  5.034900e+07
# 7   Property, equipment, and leasehold improvement...  1.119000e+06
# 8                                        Other assets  1.235600e+08
# 9                                        Total assets  1.749966e+10
# 12     Securities sold under agreements to repurchase  7.675431e+09
# 13  Financial instruments sold, not yet purchased,...  4.339193e+09
# 14  Payable to broker-dealers and clearing organiz...  9.460120e+08
# 15                               Payable to customers  1.568000e+07
# 16                                  Other liabilities  7.775750e+08
# 17                                  Total liabilities  1.375389e+10
# 18                            Subordinated borrowings  1.483500e+09
# 20                             Member's contributions  2.396991e+09
# 21                                   Accumulated loss -1.347240e+08
# 22                              Total member's equity  2.262267e+09
# 23              Total liabilities and member's equity  1.749966e+10
# We converted to numeric figures for 1224385-2011-03-01.csv
#
#                                                     0             1
# 0                                                Cash  1.342900e+07
# 1   Financial instruments owned, at fair value ($1...  2.063521e+10
# 2   Receivable from broker-dealers and clearing or...  9.224518e+09
# 3     Securities purchased under agreements to resell  6.792762e+09
# 4                           Receivable from customers  7.310440e+08
# 5                                            Goodwill  7.968700e+07
# 6   Property, equipment, and leasehold improvement...  2.660000e+05
# 7                                        Other assets  1.330140e+08
# 8                                        Total assets  3.760993e+10
# 11     Securities sold under agreements to repurchase  2.204047e+10
# 12  Financial instruments sold, not yet purchased,...  6.849177e+09
# 13  Payable to broker-dealers and clearing organiz...  2.925217e+09
# 14                               Payable to customers  5.146810e+08
# 15                                  Other liabilities  1.016081e+09
# 16                                  Total liabilities  3.334562e+10
# 17                            Subordinated borrowings  1.483500e+09
# 19                             Member's contributions  1.529736e+09
# 20                               Accumulated earnings  1.251074e+09
# 21                              Total member's equity  2.780810e+09
# 22              Total liabilities and member's equity  3.760993e+10
# We converted to numeric figures for 1224385-2012-02-29.csv
#
#                                                     0             1
# 0                                                Cash  3.964000e+06
# 1   Financial instruments owned, at fair value ($2...  2.492131e+10
# 2   Receivable from broker-dealers and clearing or...  8.917080e+09
# 3     Securities purchased under agreements to resell  5.407174e+09
# 4                           Receivable from customers  1.245070e+08
# 5                                            Goodwill  7.968700e+07
# 6   Property, equipment, and leasehold improvement...  1.012000e+06
# 7                                        Other assets  7.933600e+07
# 8                                        Total assets  3.953407e+10
# 11     Securities sold under agreements to repurchase  2.395095e+10
# 12  Financial instruments sold, not yet purchased,...  7.582787e+09
# 13  Payable to broker-dealers and clearing organiz...  2.207509e+09
# 14                               Payable to customers  7.852000e+07
# 15                                  Other liabilities  5.594280e+08
# 16                                  Total liabilities  3.437920e+10
# 17                            Subordinated borrowings  2.323500e+09
# 19                             Member's contributions  1.529736e+09
# 20                               Accumulated earnings  1.301634e+09
# 21                              Total member's equity  2.831370e+09
# 22              Total liabilities and member's equity  3.953407e+10
# We converted to numeric figures for 1224385-2013-03-01.csv
#
#                                                     0             1
# 0                                                Cash  1.107000e+06
# 1     Cash segregated pursuant to federal regulations  2.511200e+07
# 2   Financial instruments owned, at fair value ($2...  2.518956e+10
# 3   Receivable from broker-dealers and clearing or...  8.163067e+09
# 4     Securities purchased under agreements to resell  9.486351e+09
# 5                           Receivable from customers  4.951490e+08
# 6                                            Goodwill  7.968700e+07
# 7   Property, equipment, and leasehold improvement...  4.587000e+06
# 8                                        Other assets  7.946900e+07
# 9                                        Total assets  4.352408e+10
# 12     Securities sold under agreements to repurchase  2.637892e+10
# 13  Financial instruments sold, not yet purchased,...  8.200937e+09
# 14  Payable to broker-dealers and clearing organiz...  2.220845e+09
# 15                               Payable to customers  3.965540e+08
# 16                                  Other liabilities  6.920830e+08
# 17                                  Total liabilities  3.788934e+10
# 18                            Subordinated borrowings  2.323500e+09
# 20                             Member's contributions  1.529736e+09
# 21                               Accumulated earnings  1.781507e+09
# 22                              Total member's equity  3.311243e+09
# 23              Total liabilities and member's equity  4.352408e+10
# Fixed the merged rows for 1224385-2014-03-04.csv
# We converted to numeric figures for 1224385-2014-03-04.csv
#
#                                                     0             1
# 0                                                Cash  3.116870e+08
# 1     Cash segregated pursuant to federal regulations  2.930510e+08
# 2   Financial instruments owned, at fair value ($2...  2.951165e+10
# 3   Receivable from broker-dealers and clearing or...  8.930828e+09
# 4     Securities purchased under agreements to resell  8.655983e+09
# 5                           Receivable from customers  8.781100e+07
# 6                                            Goodwill  7.968700e+07
# 0   Property, equipment, and leasehold improvement...  3.566000e+06
# 0                                        Other assets  2.706290e+08
# 8                                        Total assets  4.814490e+10
# 11     Securities sold under agreements to repurchase  2.721210e+10
# 12  Financial instruments sold, not yet purchased,...  9.929539e+09
# 13  Payable to broker-dealers and clearing organiz...  3.263343e+09
# 14                               Payable to customers  6.525420e+08
# 15                                  Other liabilities  8.759970e+08
# 16                                  Total liabilities  4.193352e+10
# 17                            Subordinated borrowings  2.323500e+09
# 19                             Member's contributions  1.529736e+09
# 20                               Accumulated earnings  2.358138e+09
# 21                              Total member's equity  3.887874e+09
# 22              Total liabilities and member's equity  4.814490e+10
# We converted to numeric figures for 1224385-2015-03-02.csv
#
#                                                     0             1
# 0                                                Cash  1.507140e+08
# 1     Cash segregated pursuant to federal regulations  1.038246e+09
# 2   Financial instruments owned, at fair value ($3...  3.523607e+10
# 3   Receivable from broker-dealers and clearing or...  2.017848e+10
# 4     Securities purchased under agreements to resell  7.743114e+09
# 5                           Receivable from customers  1.542170e+08
# 6                                            Goodwill  7.968700e+07
# 7   Property, equipment, and leasehold improvement...  3.290000e+06
# 8                                        Other assets  2.519170e+08
# 9                                        Total assets  6.483574e+10
# 12     Securities sold under agreements to repurchase  3.713772e+10
# 13  Financial instruments sold, not yet purchased,...  1.381542e+10
# 14  Payable to broker-dealers and clearing organiz...  4.099997e+09
# 15                               Payable to customers  2.369579e+09
# 16                                  Other liabilities  8.147750e+08
# 17                                  Total liabilities  5.823748e+10
# 18                            Subordinated borrowings  2.323500e+09
# 20                             Member's contributions  1.529736e+09
# 21                               Accumulated earnings  2.745023e+09
# 22                              Total member's equity  4.274759e+09
# 23              Total liabilities and member's equity  6.483574e+10
# We merged the columns of 1224385-2016-02-29.csv
# We converted to numeric figures for 1224385-2016-02-29.csv
#
#                                                     0             1
# 5                                                Cash  2.065950e+08
# 6     Cash segregated pursuant to federal regulations  1.673201e+09
# 7   Financial instruments owned, at fair value ($4...  4.339006e+10
# 8                                 Securities borrowed  1.885912e+10
# 9     Securities purchased under agreements to resell  1.369153e+10
# 10  Receivable from broker-dealers and clearing or...  9.219333e+09
# 11                          Receivable from customers  2.980786e+09
# 12                                           Goodwill  7.968700e+07
# 13  Property, equipment, and leasehold improvement...  1.694000e+06
# 14                                       Other assets  4.298470e+08
# 15                                       Total assets  9.053186e+10
# 18     Securities sold under agreements to repurchase  5.356417e+10
# 19  Financial instruments sold, not yet purchased,...  1.392259e+10
# 20                                  Securities loaned  7.301543e+09
# 21                               Payable to customers  7.279930e+09
# 22  Payable to broker-dealers and clearing organiz...  7.020900e+08
# 23                                  Other liabilities  9.063250e+08
# 24                                  Total liabilities  8.367665e+10
# 25                            Subordinated borrowings  2.323500e+09
# 27                             Member's contributions  1.565244e+09
# 28                               Accumulated earnings  2.966463e+09
# 29                              Total member's equity  4.531707e+09
# 30              Total liabilities and member's equity  9.053186e+10
# We converted to numeric figures for 1224385-2017-03-01.csv
#
#                                                     0             1
# 0                                                Cash  1.705750e+08
# 1     Cash segregated pursuant to federal regulations  5.699890e+08
# 2   Financial instruments owned, at fair value ($2...  4.529348e+10
# 3                                 Securities borrowed  1.853297e+10
# 4     Securities purchased under agreements to resell  2.230535e+10
# 5   Receivable from broker-dealers and clearing or...  2.163268e+10
# 6                           Receivable from customers  4.093015e+09
# 7                                            Goodwill  7.968700e+07
# 8   Property, equipment, and leasehold improvement...  5.850000e+05
# 9                                        Other assets  2.621580e+08
# 10                                       Total assets  1.129405e+11
# 13     Securities sold under agreements to repurchase  6.113130e+10
# 14  Financial instruments sold, not yet purchased,...  1.506928e+10
# 15                                  Securities loaned  4.687608e+09
# 16                               Payable to customers  1.255428e+10
# 17  Payable to broker-dealers and clearing organiz...  2.233994e+09
# 18                                  Other liabilities  4.944049e+09
# 19                                  Total liabilities  1.006205e+11
# 20                            Subordinated borrowings  7.300000e+09
# 22                             Member's contributions  1.565244e+09
# 23                               Accumulated earnings  3.454727e+09
# 24                              Total member's equity  5.019971e+09
# 25              Total liabilities and member's equity  1.129405e+11
# We converted to numeric figures for 1224385-2018-02-28.csv
#
#                                                     0             1
# 0                                                Cash  2.466460e+08
# 1     Cash segregated pursuant to federal regulations  1.493144e+09
# 2                                 Securities borrowed  3.852755e+10
# 3     Securities purchased under agreements to resell  1.434480e+10
# 4   Receivable from broker-dealers and clearing or...  2.489979e+10
# 5                      Receivable from customers, net  4.179195e+09
# 6   Financial instruments owned, at fair value ($4...  4.715217e+10
# 7   Property, equipment, and leasehold improvement...  7.400000e+05
# 8                                            Goodwill  7.968700e+07
# 9                                        Other assets  4.784850e+08
# 10                                       Total assets  1.314022e+11
# 13     Securities sold under agreements to repurchase  7.075811e+10
# 14                                  Securities loaned  1.007754e+10
# 15                               Payable to customers  1.211610e+10
# 16  Payable to broker-dealers and clearing organiz...  4.878750e+08
# 17                           Payable to non-customers  7.743610e+08
# 18  Financial instruments sold, not yet purchased,...  1.590572e+10
# 19                                         Borrowings  8.000000e+09
# 20                                  Other liabilities  8.848370e+08
# 21                                  Total liabilities  1.190045e+11
# 22                            Subordinated borrowings  7.300000e+09
# 24                             Member's contributions  1.565244e+09
# 25                               Accumulated earnings  3.532418e+09
# 26                              Total member's equity  5.097662e+09
# 27              Total liabilities and member's equity  1.314022e+11
# We converted to numeric figures for 1224385-2019-02-28.csv
#
#                                                     0             1
# 0                                                Cash  2.011910e+08
# 1     Cash segregated pursuant to federal regulations  1.240025e+09
# 2                                 Securities borrowed  3.233609e+10
# 3     Securities purchased under agreements to resell  1.302523e+10
# 4   Receivable from broker-dealers and clearing or...  2.217528e+10
# 5                      Receivable from customers, net  5.278221e+09
# 6   Financial instruments owned, at fair value ($4...  5.893448e+10
# 7   Property, equipment, and leasehold improvement...  3.140000e+05
# 8                                            Goodwill  7.968700e+07
# 9                          Receivable from affiliates  5.068610e+08
# 10                                       Other assets  5.465820e+08
# 11                                       Total assets  1.343240e+11
# 14     Securities sold under agreements to repurchase  7.795778e+10
# 15                                  Securities loaned  8.066178e+09
# 16                               Payable to customers  1.239626e+10
# 17  Payable to broker-dealers and clearing organiz...  6.088140e+08
# 18                           Payable to non-customers  3.372150e+08
# 19  Financial instruments sold, not yet purchased,...  1.544902e+10
# 20                                         Borrowings  6.126313e+09
# 21                              Payable to affiliates  3.268100e+07
# 22                                  Other liabilities  7.049460e+08
# 23                                  Total liabilities  1.216792e+11
# 24                            Subordinated borrowings  7.300000e+09
# 26                             Member's contributions  1.565244e+09
# 27                               Accumulated earnings  3.779517e+09
# 28                              Total member's equity  5.344761e+09
# 29              Total liabilities and member's equity  1.343240e+11
# We converted to numeric figures for 1224385-2020-02-28.csv
#
#                                                     0             1
# 0                                                Cash  1.114240e+08
# 1   Cash segregated under federal and other regula...  2.361878e+09
# 2                                 Securities borrowed  3.192683e+10
# 3     Securities purchased under agreements to resell  2.135012e+10
# 4   Receivable from broker-dealers and clearing or...  1.871794e+10
# 5                      Receivable from customers, net  7.125995e+09
# 6   Financial instruments owned, at fair value ($4...  5.963727e+10
# 7   Property, equipment and leasehold improvements...  6.261000e+06
# 8                                            Goodwill  7.968700e+07
# 9                          Receivable from affiliates  2.110200e+07
# 10                                       Other assets  4.960400e+08
# 11                                       Total assets  1.418345e+11
# 14     Securities sold under agreements to repurchase  8.824780e+10
# 15                                  Securities loaned  4.391948e+09
# 16                               Payable to customers  1.281805e+10
# 17  Payable to broker-dealers and clearing organiz...  3.254250e+08
# 18                           Payable to non-customers  4.608400e+08
# 19  Financial instruments sold, not yet purchased,...  1.539156e+10
# 20                                         Borrowings  6.145224e+09
# 21                              Payable to affiliates  5.704000e+07
# 22                                  Other liabilities  1.095075e+09
# 23                                  Total liabilities  1.289330e+11
# 24                            Subordinated borrowings  7.300000e+09
# 26                             Member's contributions  1.565244e+09
# 27                               Accumulated earnings  4.036335e+09
# 28                              Total member's equity  5.601579e+09
# 29              Total liabilities and member's equity  1.418345e+11
# We converted to numeric figures for 1224385-2021-02-26.csv
#
#                                                     0             1
# 0                                                Cash  1.030540e+08
# 1   Cash segregated under federal and other regula...  8.598260e+08
# 2                                 Securities borrowed  2.644899e+10
# 3     Securities purchased under agreements to resell  1.905476e+10
# 4   Receivable from broker-dealers and clearing or...  2.493942e+10
# 5                      Receivable from customers, net  8.748357e+09
# 6   Financial instruments owned, at fair value ($3...  5.185267e+10
# 7   Property, equipment and leasehold improvements...  4.110000e+06
# 8                                            Goodwill  7.968700e+07
# 9                          Receivable from affiliates  5.078000e+06
# 10                                       Other assets  6.623230e+08
# 11                                       Total assets  1.327583e+11
# 14     Securities sold under agreements to repurchase  7.215968e+10
# 15                                  Securities loaned  4.736230e+09
# 16                               Payable to customers  1.277442e+10
# 17  Payable to broker-dealers and clearing organiz...  6.097320e+08
# 18                           Payable to non-customers  4.970960e+08
# 19  Financial instruments sold, not yet purchased,...  2.007370e+10
# 20                                         Borrowings  7.309220e+09
# 21                              Payable to affiliates  2.283000e+07
# 22                                  Other liabilities  7.950450e+08
# 23                                  Total liabilities  1.189780e+11
# 24                            Subordinated borrowings  4.650000e+09
# 26                             Member's contributions  4.565244e+09
# 27                               Accumulated earnings  4.565073e+09
# 28                              Total member's equity  9.130317e+09
# 29              Total liabilities and member's equity  1.327583e+11
# We converted to numeric figures for 42352-2002-01-30.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  5.666498e+09
# 1   Cash and securities segregated in compliance w...  1.859211e+10
# 2   Receivables from brokers, dealers and clearing...  4.408164e+09
# 3       Receivables from customers and counterparties  1.316551e+10
# 4                                 Securities borrowed  9.985780e+10
# 5     Securities purchased under agreements to resell  1.471373e+10
# 6          Financial instruments owned, at fair value  2.906175e+10
# 7   Financial instruments owned and pledged as col...  2.568717e+09
# 9                                        Other assets  1.941781e+09
# 12                              Short-term borrowings  3.223388e+10
# 13  Payables to brokers, dealers and clearing orga...  3.419440e+09
# 14           Payables to customers and counterparties  5.369711e+10
# 15                                  Securities loaned  4.216942e+10
# 16     Securities sold under agreements to repurchase  2.869155e+10
# 17  Financial instruments sold, but not yet purcha...  1.668440e+10
# 18             Other liabilities and accrued expenses  2.638903e+09
# 19                               Long-term borrowings  1.435830e+08
# 22                 Long-term subordinated liabilities  5.822497e+09
# 24                                  Partners' capital  4.486307e+09
# 25               Accumulated other comprehensive loss -1.103300e+07
# We converted to numeric figures for 42352-2003-01-28.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  2.816419e+09
# 2                               and other regulations  1.656822e+10
# 3   Receivables from brokers, dealers and clearing...  3.964833e+09
# 4       Receivables from customers and counterparties  1.026552e+10
# 5                                 Securities borrowed  1.057280e+11
# 6     Securities purchased under agreements to resell  3.239469e+10
# 7          Financial instruments owned, at fair value  3.204794e+10
# 8   Financial instruments owned and pledged as col...  8.480307e+09
# 9    Total financial instruments owned, at fair value  4.052825e+10
# 10                                       Other assets  1.716894e+09
# 13                              Short-term borrowings  3.435200e+10
# 14  Payables to brokers, dealers and clearing orga...  3.122873e+09
# 15           Payables to customers and counterparties  5.100825e+10
# 16                                  Securities loaned  4.801852e+10
# 17     Securities sold under agreements to repurchase  4.886392e+10
# 18  Financial instruments sold, but not yet purcha...  1.517343e+10
# 19             Other liabilities and accrued expenses  2.483230e+09
# 20                               Long-term borrowings  3.863800e+08
# 23                            Subordinated borrowings  6.522936e+09
# 25                                  Partners' capital  4.029610e+09
# 26             Accumulated other comprehensive income  2.166300e+07
# We converted to numeric figures for 42352-2004-01-27.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  4.604370e+09
# 2                               and other regulations  2.196929e+10
# 3   Receivables from brokers, dealers and clearing...  7.976880e+09
# 4       Receivables from customers and counterparties  1.028912e+10
# 5                                 Securities borrowed  1.513402e+11
# 6     Securities purchased under agreements to resell  1.626435e+10
# 7          Financial instruments owned, at fair value  4.111061e+10
# 8   Financial instruments owned and pledged as col...  1.221086e+10
# 9    Total financial instruments owned, at fair value  5.332147e+10
# 10                                       Other assets  1.981583e+09
# 13                              Short-term borrowings  3.817633e+10
# 14  Payables to brokers, dealers and clearing orga...  6.280957e+09
# 15           Payables to customers and counterparties  6.260715e+10
# 16                                  Securities loaned  8.484427e+10
# 17     Securities sold under agreements to repurchase  3.324604e+10
# 18  Financial instruments sold, but not yet purcha...  2.549029e+10
# 19             Other liabilities and accrued expenses  3.230412e+09
# 20                               Long-term borrowings  1.079186e+09
# 23                            Subordinated borrowings  8.805358e+09
# 25                                  Partners' capital  3.978040e+09
# 26             Accumulated other comprehensive income  9.280000e+06
# We converted to numeric figures for 42352-2005-01-25.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  6.655320e+08
# 2                               and other regulations  3.366520e+10
# 3   Receivables from brokers, dealers and clearing...  8.974752e+09
# 4       Receivables from customers and counterparties  1.234291e+10
# 5                                 Securities borrowed  1.937840e+11
# 6     Securities purchased under agreements to resell  3.037642e+10
# 7          Financial instruments owned, at fair value  5.025786e+10
# 8   Financial instruments owned and pledged as col...  1.519492e+10
# 9    Total financial instruments owned, at fair value  6.545278e+10
# 10                                       Other assets  3.329362e+09
# 11                                       Total assets  3.485910e+11
# 13                              Short-term borrowings  4.401177e+10
# 14  Payables to brokers, dealers and clearing orga...  7.844614e+09
# 15           Payables to customers and counterparties  8.604220e+10
# 16                                  Securities loaned  1.007016e+11
# 17     Securities sold under agreements to repurchase  4.731368e+10
# 18  Financial instruments sold, but not yet purcha...  4.040481e+10
# 19             Other liabilities and accrued expenses  4.542417e+09
# 20                               Long-term borrowings  1.519157e+09
# 23                            Subordinated borrowings  1.200000e+10
# 25                                  Partners' capital  4.207332e+09
# 26             Accumulated other comprehensive income  3.419000e+06
# 27                            Total partners' capital  4.210751e+09
# 28            Total liabilities and partners' capital  3.485910e+11
# We converted to numeric figures for 42352-2006-01-24.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  7.376930e+09
# 2                               and other regulations  3.567681e+10
# 3   Receivables from brokers, dealers and clearing...  9.648246e+09
# 4       Receivables from customers and counterparties  1.464212e+10
# 5                                 Securities borrowed  2.439286e+11
# 6     Securities purchased under agreements to resell  5.288691e+10
# 7          Financial instruments owned, at fair value  8.299349e+10
# 8   Financial instruments owned and pledged as col...  2.336140e+10
# 9    Total financial instruments owned, at fair value  1.063549e+11
# 10                                       Other assets  5.357602e+09
# 11                                       Total assets  4.758721e+11
# 13                              Short-term borrowings  4.288862e+10
# 14  Payables to brokers, dealers and clearing orga...  1.083327e+10
# 15           Payables to customers and counterparties  9.045834e+10
# 16                                  Securities loaned  1.344223e+11
# 17     Securities sold under agreements to repurchase  1.181531e+11
# 18  Financial instruments sold, but not yet purcha...  5.494621e+10
# 19             Other liabilities and accrued expenses  5.303491e+09
# 20                               Long-term borrowings  1.830898e+09
# 23                            Subordinated borrowings  1.250000e+10
# 25                                  Partners' capital  4.526743e+09
# 26             Accumulated other comprehensive income  9.156000e+06
# 27                            Total partners' capital  4.535899e+09
# 28            Total liabilities and partners' capital  4.758721e+11
# Fixed the merged rows for 42352-2007-01-23.csv
# We converted to numeric figures for 42352-2007-01-23.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  2.008168e+09
# 1   Cash and securities segregated for regulatory ...  5.323661e+10
# 2   Receivables from brokers, dealers and clearing...  9.551828e+09
# 3       Receivables from customers and counterparties  1.613905e+10
# 5                                 Securities borrowed  2.587133e+11
# 6   Financial instruments purchased under agreemen...  5.642668e+10
# 7          Financial instruments owned, at fair value  8.191529e+10
# 8   Financial instruments owned and pledged as col...  2.398528e+10
# 9    Total financial instruments owned, at fair value  1.059006e+11
# 10                                       Other assets  7.274550e+09
# 11                                       Total assets  5.092507e+11
# 0   Unsecured short-term borrowings, including the...  9.112943e+09
# 0   Payables to brokers, dealers and clearing orga...  1.315166e+10
# 14           Payables to customers and counterparties  1.082352e+11
# 16                                  Securities loaned  1.375256e+11
# 17  Financial instruments sold under agreements to...  1.152235e+11
# 18                           Other secured financings  3.965256e+10
# 19  Financial instruments sold, but not yet purcha...  5.878867e+10
# 20             Other liabilities and accrued expenses  9.008488e+09
# 21                     Unsecured long-term borrowings  1.366357e+09
# 22          Commitments, contingencies and guarantees  4.920650e+11
# 23                            Subordinated borrowings  1.250000e+10
# 25                                  Partners' capital  4.705058e+09
# 26             Accumulated other comprehensive income -1.937100e+07
# 27                            Total partners' capital  4.685687e+09
# 28            Total liabilities and partners' capital  5.092507e+11
# We converted to numeric figures for 42352-2008-01-29.csv
#
#                                                     0             1
# 1                           Cash and cash equivalents  3.815314e+09
# 2   Cash and securities segregated for regulatory ...  8.527477e+10
# 3   Receivables from brokers, dealers and clearing...  2.040238e+10
# 4       Receivables from customers and counterparties  2.273971e+10
# 6   Securities borrowed (includes $79,312,735 at f...  3.259736e+11
# 7   Financial instruments purchased under agreemen...  5.042743e+10
# 8          Financial instruments owned, at fair value  9.613541e+10
# 9   Financial instruments owned and pledged as col...  2.260637e+10
# 10   Total financial instruments owned, at fair value  1.187418e+11
# 12                                       Other assets  5.483735e+09
# 13                                       Total assets  6.328588e+11
# 15  Unsecured short-term borrowings, including the...  2.079573e+10
# 16  Payables to brokers, dealers and clearing orga...  2.001451e+10
# 17           Payables to customers and counterparties  1.798942e+11
# 19  Securities loaned (includes $6,541 at fair value)  1.545165e+11
# 20  Financial instruments sold under agreements to...  1.183138e+11
# 21  Other secured financings (includes $2,076,473 ...  2.772741e+10
# 22  Financial instruments sold, but not yet purcha...  7.555660e+10
# 23             Other liabilities and accrued expenses  9.981939e+09
# 24  Unsecured long-term borrowings (includes $347,...  1.560215e+09
# 27                            Subordinated borrowings  1.825000e+10
# 29                                  Partners' capital  6.193908e+09
# 30             Accumulated other comprehensive income  5.402900e+07
# 31                            Total partners' capital  6.247937e+09
# 32            Total liabilities and partners' capital  6.328588e+11
# We converted to numeric figures for 42352-2010-03-01.csv
#
#                                                     0             1
# 0                           Cash and cash equivalents  3.273000e+09
# 1   Cash and securities segregated for regulatory ...  1.145900e+10
# 3   Securities borrowed (includes $79,137 at fair ...  2.124910e+11
# 4   Financial instruments purchased under agreemen...  7.049900e+10
# 5   Receivables from brokers, dealers and clearing...  8.193000e+09
# 6   Receivables from customers and counterparties ...  2.020300e+10
# 7          Financial instruments owned, at fair value  1.131040e+11
# 8   Financial instruments owned and pledged as col...  1.963900e+10
# 9    Total financial instruments owned, at fair value  1.327430e+11
# 10                                       Other assets  4.894000e+09
# 11                                       Total assets  4.637550e+11
# 14   long-term borrowings (includes $3 at fair value)  1.527600e+10
# 16  Securities loaned (includes $23,810 at fair va...  6.668200e+10
# 17  Financial instruments sold under agreements to...  1.175160e+11
# 18  Other secured financings (includes $853 at fai...  5.219700e+10
# 19  Payables to brokers, dealers and clearing orga...  1.442900e+10
# 20           Payables to customers and counterparties  1.215590e+11
# 21  Financial instruments sold, but not yet purcha...  4.020100e+10
# 22  Other liabilities and accrued expenses (includ...  9.972000e+09
# 23  Unsecured long-term borrowings (includes $221 ...  4.740000e+08
# 24                                  Total liabilities  4.383060e+11
# 26                            Subordinated borrowings  1.825000e+10
# 28                                  Partners' capital  7.111000e+09
# 29             Accumulated other comprehensive income  8.800000e+07
# 30                            Total partners' capital  7.199000e+09
# 31            Total liabilities and partners' capital  4.637550e+11
# We converted to numeric figures for 42352-2011-03-01.csv
#
#                                                     0             1
# 0    Total financial instruments owned. at fair value  1.393210e+11
# 4   Unsecured short-term borrowings, including the...  1.001600e+10
# 6   Securities loaned (includes $28,083 at fair va...  6.451100e+10
# 7   Securities sold under agreements to repurchase...  1.542450e+11
# 8   Other secured financings (includes $2,598 at f...  6.170800e+10
# 9   Payables to brokers, dealers and clearing orga...  1.213200e+10
# 10           Payables to customers and counterparties  1.358020e+11
# 11  Financial Instruments sold,bu t not yet purcha...  4.987900e+10
# 12  Other liabilities and accrued expenses (includ...  7.058000e+09
# 13  Unsecured long-term borrowings (includes $227 ...  8.680000e+08
# 14                                  Total liabilities  4.962160e+11
# 16                            Subordinated borrowings  2.150000e+10
# 18                                  Partners' capital  9.164000e+09
# 19             Accumulated other comprehensive income  1.220000e+08
# 20                            Total partners' capital  9.286000e+09
# 21            Total liabilities and partners' capital  6.270010e+11
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-188eecdbe335> in <module>
#      51
#      52         # check for presence of row splits and correct any if found
# ---> 53         tempDF = row_split(df, text_dictionary[base_file])
#      54
#      55         # if difference is found in shape, then a transformation was done
#
# <ipython-input-81-a24b66dfb6af> in row_split(df, text_file)
#     111
#     112         # determine the splits for the corresponding row
# --> 113         mid = recursive_splits(values, lineName, sub=[])
#     114         mid.columns = df.columns
#     115
#
# <ipython-input-81-a24b66dfb6af> in recursive_splits(values, lineName, sub)
#      78
#      79             # we pass the +1 index splits and line name, appending the first-most layer
# ---> 80             return recursive_splits(values[1:], lineName[1:], sub=sub)
#      81         else:
#      82             row = pd.DataFrame([lineName[0], values[0]]).T
#
# <ipython-input-81-a24b66dfb6af> in recursive_splits(values, lineName, sub)
#      74         if len(values) > 1:
#      75             # construct a dataframe row of the first split term to append to sub list
# ---> 76             row = pd.DataFrame([lineName[0], values[0]]).T
#      77             sub.append(row)
#      78
#
# IndexError: list index out of range
