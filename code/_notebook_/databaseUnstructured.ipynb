# %%
import os
import re
import boto3
import json
import time
import requests
import datetime

import pandas as pd
import numpy as np

from sagemaker.session import Session
from bs4 import BeautifulSoup

# %% [markdown]
# ## Accounting term matching
# **Check to see if we report totals (e.g. Total Liability & Shareholder Equity) or sub-totals (e.g. Total Financial Instruments), these figure are not needed for construction of the unstructured database (avoid classification issue)**

# %%
def totals_check(df:pd.DataFrame) -> pd.DataFrame:
    """
    Checks to see if a line row meets the conditon of a total, if true we remove these rows as we make 
    have checked the terms before have meet our conditions (these include major and minor totals)
    ------------------------------------------------------------------------------------
    :param: (type pandas.DataFrame)
        A DataFrame that represents the Asset or Liability & Equity portion of the balance sheet
        
    :return: (type tuple)
        Return a cleaned DataFrame that strips the rows that represent totals
    """
    m, n = df.shape    # unpack the shape of dataframe
    
    # numpy exception for handling invalid log10 RunTime error (we opt to not show)
    # switch 'ignore' to 'warn', if you would like to flag the RunTime error 
    np.seterr(invalid = 'ignore') 
    
    def multiple_check(x1:float, x2:float):
        """
        Determine whether the two values are the same number scaled by 10
        """
        # prevent zero division error since x1 is the denominator and log10 zero division error
        if (x1 == 0) or (x2 == 0): return False
        else:
            # if our backward sum is a multiple of 10, we return True 
            # (e.g. Total Assets (x1) 745.2322 vs Backward Sum (x2) 7452322)
            check1 = np.log10(x2 / x1).is_integer()
             
            # if our backward sum is a substring of a line item, with a difference of one in length, we return True 
            # (e.g. Total Assets (x1) 174182935 vs Backward Sum (x2) 74182935)
            check2 = (str(x2) in str(x1) ) & (len(str(x2)) == len(str(x1)) - 1)
            
            if check1 or check2: 
                return True
            else: 
                return False
    
    def epsilon_error(x1:float, x2:float, tol:float=0.01):
        """
        Determine whether the two values are within a similar epsilon bound. We default our error tolerance
        to 0.01, implying that if two numbers are within a specified toleracnce (default 1% ) of one another 
        """
        if (x1 == 0) or (x2 == 0): return False
        else:
            # first we convert the numeric quantities into strings
            current = str(x1)
            lookback = str(x2)
            
            # we only want to check against the relative difference if one element in the number is read wrong
            if len(current) == len(lookback):

                # we iterate linearly through each string and check to see the positional match 
                # if we catch and mismatch we flag it with a 1, othewise skip with 0
                changes = [0 if (current[i] == lookback[i]) else 1 for i in range(len(current))]
                
                # check set differences produce a set with exactly 1 in length
                if sum(changes) == 1:
                
                    diff = abs(x1 - x2)      # compute numeric differences

                    # check to see whether an accounting condition was met wihtin a boundary condition
                    if abs(diff / x1) <= tol:
                        return True
            
            return False
    
    data_col = df.columns[1]         # the values column for balance sheet
    
    # iterate through each of the line items
    for i in range(m):
        # check the value of line items at a given index (forward index)
        item1 = df.loc[i].values[1]
        name = df.loc[i].values[0]
        
        # compute backward sum (lookback index) 
        for j in range(i):
            
            # check whether dataframe empty (if so we skip to avoid fitting errors)
            # NOTE: Index position (i-1)   = line above current line
            #                      (i-j-1) = trailing look up line 'j' lines above the line above current line
            lookback = df.loc[i-j-1:i-1][data_col]
            
            # we check whether the lookback period is empty (if so we most likely deleted the row)
            if not lookback.empty:
                # backward sum for line items (index minus j-periods before)
                item2 = lookback.sum()

                # if we achieve this then we strip totals and break, no need to continue backward sum
                if (item1 == item2) or multiple_check(item1, item2) or epsilon_error(item1, item2, tol=0.0004):
                    df = df.drop(index=i)
                    
                    # Error Handling for row deletions (uncomment for when not in use)
                    print('We dropped row {}, {}, with lookback window of {}.'.format(i, name, j+1))
                    print('\tOur row is valued at {}, our lookback sum is {}'.format(item1, item2))
                    
                    # we break from inner loop to avoid key error flag 
                    break     
                
    return df

# %% [markdown]
# ## Unstructured Database construction
# **We develop our unstructured database from each of the non-total rows (concating the line items)**

# %%
def unstructured_data(df, filing_d, fiscal_y, cik, cik2name:dict) -> pd.DataFrame:
    """
    Forms unstructured row for larger database to be stored in s3 bucket
    ------------------------------------------------------------------------------------------
    Input:
        :param: df (type pandas.DataFrame)
            The balance sheet for a particular  
        :paran: filing_d (type str)
            The filing date for release of X-17A-5 filings for a broker dealer e.g. 2013-03-21
        :paran: fiscal_y (type str)
            The fiscal year for the balance sheet to cover e.g. 2012 (usually 1-year prior to filing date)
        :paran: cik (type str)
            The CIK number for a broker dealer e.g. 887767
        :paran: cik2name (type dict)
            A dictionary that maps CIK to Broker Deale names 
    Output:  
        :return: (type pandas.DataFrame)
             Return a transposed dataframe with additional columns corresponding to filing data
    """
    
    # intialize the first column (line items)
    first_column = df.columns[0]
    
    # clean dataframe should be of size greater than 1
    if len(df.columns) > 1:
        
        # transpose split balance sheet figure (our line items are now columns)
        # we first groupby the first column (this become index) and sum to group congruent names
        row = df.groupby(first_column).sum().T

        # creating additional columns in row
        row['CIK'] = cik                                  # CIK number for firm 
        row['Filing Date'] = filing_d                     # Filing Date for firm filing
        row['Filing Year'] = fiscal_y                     # Year for balance sheet filing
        row['Name'] = cik2name['broker-dealers'][cik]     # returns the name of associated with the CIK
        
        return row
    
    else:
        print('{}-{}.csv - encountered issue reading PDF'.format(cik, filing_d))
        return None

# %%
def totals_flag(df:pd.DataFrame):
    """
    Check to see whether their exists the presence of a total term from the line items
    ------------------------------------------------------------------------------------------
    """
    # perform regex search 
    selection = [i for i in df.columns if re.search('total|totals', i, flags=re.I) is not None]
    
    # if there exists some mention of the word total in a line item
    # we know to re-run structuring on PNG rather than PDF
    if len(selection) > 0:
        return True
    
    return False

# %%
def reorder_columns(df:pd.DataFrame) -> pd.DataFrame:
    """
    Re-order the completed DataFrame by ordering the CIK, Name, Filing Data and Filing Year 
    ------------------------------------------------------------------------------------------
    Input:
        :param: df (type pandas.DataFrame)
            The unstructured database for balance sheet figures
    Output:  
        :return: (type pandas.DataFrame)
            Return a dataframe with dimensions less than or equal to input dataframe (MxN) -> (MxK), 
            where K <= N
    """
    # re-order the CIK and Year columns to appear as the first two columns
    remap = df.columns[~np.isin(df.columns, ['CIK', 'Name', 'Filing Date', 'Filing Year'])]   # select all other columns
    df = df[np.insert(remap, [0, 0, 0, 0], ['CIK', 'Name', 'Filing Date', 'Filing Year'])]    # insert new order

    # filter out columns with NaN values
    filterNaN = df.isnull().all()                      # find if any column is all NaN 
    cleanCols = filterNaN[filterNaN == False].index    # select columns with at least one value

    # clean dataframe for unstructured asset terms
    return df[cleanCols]

# %% [markdown]
# ## Final Main Execution

# %%
if __name__ == "__main__":
    
    # initiate s3 bucket and corresponding data folder
    bucket = "ran-s3-systemic-risk"
    
    pdf_asset_folder = "Output/X-17A-5-SPLIT-PDFS/Assets/"
    pdf_liable_folder = "Output/X-17A-5-SPLIT-PDFS/Liability & Equity/"
    
    png_asset_folder = "Output/X-17A-5-SPLIT-PNGS/Assets/"
    png_liable_folder = "Output/X-17A-5-SPLIT-PNGS/Liability & Equity/"
    
    out_folder = "Output/"

    # Amazon Textract client and Sagemaker session
    textract = boto3.client('textract')
    s3 = boto3.client('s3')
    session = Session()
    
    # ==============================================================================
    # retrieving CIK-Dealers JSON file from s3 bucket
    s3.download_file(bucket, 'Temp/CIKandDealers.json', 'temp.json')

    # read all CIK and Dealer name information from storage
    with open('temp.json', 'r') as f: cik2brokers = json.loads(f.read())

    # remove local file after it has been created (variable is stored in memory)
    os.remove('temp.json')
    # ==============================================================================
    
    # s3 paths where asset and liability paths are stored
    asset_paths = session.list_s3_files(bucket, pdf_asset_folder)[1:]
    liable_paths = session.list_s3_files(bucket, pdf_liable_folder)[1:]
    
    # intialize list to store dataframes for asset and liability & equity
    asset_concat = [0] * len(asset_paths)
    liable_concat = [0] * len(liable_paths)
    
    # --------------------------------------------
    # Asset Unstructured Database
    # --------------------------------------------
    print('Assets Unstructured Database')
    for idx, csv in enumerate(asset_paths):
        fileName = csv.split('/')[-1]        # e.g. '1224385-2005-03-01.csv'
        csv_strip = fileName[:-4]            # ignore last four elements from the back (i.e. .csv)
        
        # construct a string measure of important data measures 
        data_split = csv_strip.split('-')              
        filing_date = '-'.join(data_split[1:])         # join YYYY-mm-dd component for filing date
        fiscal_year = int(data_split[1]) - 1           # fiscal year are generally the previous year of filing
        cik = data_split[0]                            # extract the CIK number  
        
        # work on combining columns that are issued seperately
        s3.download_file(bucket, csv, 'temp.csv')
        df = pd.read_csv('temp.csv')

        # process balance sheet dataframes
        temp_df = totals_check(df)                  # run an accounting check removing any total rows
        export_df = unstructured_data(temp_df,      # construct row of unstructured data frame 
                                      filing_date, 
                                      fiscal_year, cik, cik2brokers)
        
        # if a totals category was found then we look to run data on PNG (if possible)
        if totals_flag(export_df):
            try:
                # work on combining columns that are issued seperately
                s3.download_file(bucket, png_asset_folder + fileName, 'temp.csv')
                df = pd.read_csv('temp.csv')

                # process balance sheet dataframes
                temp_df = totals_check(df)                 
                export_df = unstructured_data(temp_df, filing_date, fiscal_year, cik, cik2brokers)
            
            # in event PNG can't be read
            except:
                pass
        
        # stores the reported data frame 
        asset_concat[idx] = export_df
        
        # remove local file after it has been created
        os.remove('temp.csv')
        
        if ((idx + 1) % 10) == 0:
            print('\tWe have completed {} - asset rows'.format(idx + 1))
        
    # --------------------------------------------
    # Liability & Equity Unstructured Database
    # --------------------------------------------
    print('\nLiability & Equity Unstructured Database')
    for idx, csv in enumerate(liable_paths):
        fileName = csv.split('/')[-1]        # e.g. '1224385-2005-03-01.csv'
        csv_strip = fileName[:-4]            # ignore last four elements from the back (i.e. .csv)
        
        # construct a string measure of important data measures 
        data_split = csv_strip.split('-')              
        filing_date = '-'.join(data_split[1:])         # join YYYY-mm-dd component for filing date
        fiscal_year = int(data_split[1]) - 1           # fiscal year are generally the previous year of filing
        cik = data_split[0]                            # extract the CIK number  
        
        # work on combining columns that are issued seperately
        s3.download_file(bucket, csv, 'temp.csv')
        df = pd.read_csv('temp.csv')
        
        # process balance sheet dataframes
        temp_df = totals_check(df)                 # run an accounting check removing any total rows
        export_df = unstructured_data(temp_df,     # construct row of unstructured data frame 
                                      filing_date, 
                                      fiscal_year, cik, cik2brokers)
        
        # if a totals category was found then we look to run data on PNG (if possible)
        if totals_flag(export_df):
            try:
                # work on combining columns that are issued seperately
                s3.download_file(bucket, png_liable_folder + fileName, 'temp.csv')
                df = pd.read_csv('temp.csv')

                # process balance sheet dataframes
                temp_df = totals_check(df)                 
                export_df = unstructured_data(temp_df, filing_date, fiscal_year, cik, cik2brokers)
            
            # in event PNG can't be read
            except:
                pass
        
        # stores the reported data frame 
        liable_concat[idx] = export_df

        # remove local file after it has been created
        os.remove('temp.csv')
        
        if ((idx + 1) % 10) == 0:
            print('\tWe have completed {} - liability & equity rows'.format(idx + 1))
    
    # --------------------------------------------
    # Database exportation
    # --------------------------------------------
    
    asset_df = pd.concat(asset_concat)        # asset dataframe combining all rows from 
    asset_df = reorder_columns(asset_df)      # re-order columns for dataframe
    
    # writing data frame to .csv file
    filename1 = 'unstructured_assets.csv'
    asset_df.to_csv(filename1, index=False)
    
    # write .csv file to s3
    with open(filename1, 'rb') as data:
        s3.put_object(Bucket=bucket, Key=out_folder + filename1, Body=data)
    
    liable_df = pd.concat(liable_concat)      # liablity & equity dataframe combining all rows from 
    liable_df = reorder_columns(liable_df)    # re-order columns for dataframe
    
    # writing data frame to .csv file
    filename2 = 'unstructured_liable.csv'
    liable_df.to_csv(filename2, index=False)
    
    # write .csv file to s3
    with open(filename2, 'rb') as data:
        s3.put_object(Bucket=bucket, Key=out_folder + filename2, Body=data)
    
    # remove local file after it has been created
    os.remove(filename1)
    os.remove(filename2)
    
    print('\nWe created an unstructured asset and liability & equity')
# Out:
# Assets Unstructured Database
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 35611655000.0, our lookback sum is 35611655000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 24029490000.0, our lookback sum is 24029490000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 20879923000.0, our lookback sum is 20879923000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 21660817000.0, our lookback sum is 21660817000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 9580535000.0, our lookback sum is 9580535000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 17499658000.0, our lookback sum is 17499658000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 37609933000.0, our lookback sum is 37609933000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 39534067000.0, our lookback sum is 39534067000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 43524084000.0, our lookback sum is 43524084000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 48144895000.0, our lookback sum is 48144895000.0
# 	We have completed 10 - asset rows
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 64835741000.0, our lookback sum is 64835741000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 90531855000.0, our lookback sum is 90531855000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 112940487000.0, our lookback sum is 112940487000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 131402200000.0, our lookback sum is 131402200000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 134323969000.0, our lookback sum is 134323969000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 141834542000.0, our lookback sum is 141834542000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 132758281000.0, our lookback sum is 132758281000.0
# We dropped row 7, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 40528247000.0, our lookback sum is 40528247000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 53321469000.0, our lookback sum is 53321469000.0
# 	We have completed 20 - asset rows
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 65452780000.0, our lookback sum is 65452780000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 348590977000.0, our lookback sum is 348590977000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 106354891000.0, our lookback sum is 106354891000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 475872139000.0, our lookback sum is 475872139000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 105900570000.0, our lookback sum is 105900570000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 509250736000.0, our lookback sum is 509250736000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 118741785000.0, our lookback sum is 118741785000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 632858770000.0, our lookback sum is 632858770000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 132743000000.0, our lookback sum is 132743000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 463755000000.0, our lookback sum is 463755000000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 139321000000.0, our lookback sum is 139321000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 527001000000.0, our lookback sum is 527001000000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 	Our row is valued at 143357000000.0, our lookback sum is 143357000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 504694000000.0, our lookback sum is 504694000000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 501095000000.0, our lookback sum is 501095000000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 524526000000.0, our lookback sum is 524516000000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 477076000000.0, our lookback sum is 477076000000.0
# 	We have completed 30 - asset rows
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 454751000000.0, our lookback sum is 454751000000.0
# We dropped row 7, Total assets, with lookback window of 7.
# 	Our row is valued at 424649000000.0, our lookback sum is 424649000000.0
# We dropped row 7, Total assets, with lookback window of 7.
# 	Our row is valued at 453927000000.0, our lookback sum is 453927000000.0
# We dropped row 7, Total assets, with lookback window of 7.
# 	Our row is valued at 416665000000.0, our lookback sum is 416665000000.0
# We dropped row 7, Total assets, with lookback window of 7.
# 	Our row is valued at 507647000000.0, our lookback sum is 507647000000.0
# We dropped row 15, Total assets, with lookback window of 15.
# 	Our row is valued at 253278304000.0, our lookback sum is 253278304000.0
# 	We have completed 40 - asset rows
# We dropped row 14, Total assets, with lookback window of 14.
# 	Our row is valued at 264444724000.0, our lookback sum is 264444714000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 317870722000.0, our lookback sum is 317870722000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 519780630000.0, our lookback sum is 519780630000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 244413278000.0, our lookback sum is 244413278000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 249693066000.0, our lookback sum is 249693066000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 244079398000.0, our lookback sum is 244079398000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 240046000000.0, our lookback sum is 240046000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 227451000000.0, our lookback sum is 227451000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 173638000000.0, our lookback sum is 173638000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 160325000000.0, our lookback sum is 160325000000.0
# 	We have completed 50 - asset rows
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 136083000000.0, our lookback sum is 136083000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 108091000000.0, our lookback sum is 108091000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 90946000000.0, our lookback sum is 90946000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 90946000000.0, our lookback sum is 90946000000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 80071000000.0, our lookback sum is 80071000000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 72130000000.0, our lookback sum is 72130000000.0
# We dropped row 15, Total assets, with lookback window of 15.
# 	Our row is valued at 267625461000.0, our lookback sum is 267625461000.0
# We dropped row 15, Total assets, with lookback window of 15.
# 	Our row is valued at 265334256000.0, our lookback sum is 265334256000.0
# We dropped row 15, Total assets, with lookback window of 15.
# 	Our row is valued at 310888679000.0, our lookback sum is 310888679000.0
# We dropped row 15, Total assets, with lookback window of 15.
# 	Our row is valued at 412415148000.0, our lookback sum is 412415148000.0
# 	We have completed 60 - asset rows
# We dropped row 16, Total assets, with lookback window of 16.
# 	Our row is valued at 501699713000.0, our lookback sum is 501699713000.0
# We dropped row 16, Total assets, with lookback window of 16.
# 	Our row is valued at 583404825000.0, our lookback sum is 583404825000.0
# We dropped row 19, Total assets, with lookback window of 19.
# 	Our row is valued at 604395450000.0, our lookback sum is 604395450000.0
# We dropped row 19, Total assets, with lookback window of 19.
# 	Our row is valued at 297422286000.0, our lookback sum is 297422286000.0
# We dropped row 8, Total financial instruments owned. at fair value, with lookback window of 6.
# 	Our row is valued at 86343225000.0, our lookback sum is 86343225000.0
# We dropped row 20, Total assets, with lookback window of 20.
# 	Our row is valued at 413032207000.0, our lookback sum is 413032207000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 6.
# 	Our row is valued at 99110027000.0, our lookback sum is 99110027000.0
# We dropped row 20, Total assets, with lookback window of 20.
# 	Our row is valued at 372537340000.0, our lookback sum is 372537340000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 6.
# 	Our row is valued at 94766842000.0, our lookback sum is 94766842000.0
# We dropped row 20, Total assets, with lookback window of 20.
# 	Our row is valued at 352293126000.0, our lookback sum is 352293126000.0
# We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 6.
# 	Our row is valued at 90227260000.0, our lookback sum is 90227260000.0
# We dropped row 20, Section Total assets, with lookback window of 20.
# 	Our row is valued at 369066424000.0, our lookback sum is 369066424000.0
# We dropped row 14, Total assets, with lookback window of 14.
# 	Our row is valued at 367496000000.0, our lookback sum is 367496000000.0
# We dropped row 14, Total assets, with lookback window of 14.
# 	Our row is valued at 345134000000.0, our lookback sum is 345134000000.0
# 	We have completed 70 - asset rows
# We dropped row 13, Total assets, with lookback window of 13.
# 	Our row is valued at 301341000000.0, our lookback sum is 301341000000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 308038000000.0, our lookback sum is 308038000000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 305281000000.0, our lookback sum is 305281000000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 303806000000.0, our lookback sum is 303806000000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 409239000000.0, our lookback sum is 409239000000.0
# We dropped row 8, Receivables:, with lookback window of 4.
# 	Our row is valued at 15993366000.0, our lookback sum is 15993366000.0
# We dropped row 15, Total assets, with lookback window of 15.
# 	Our row is valued at 57702809000.0, our lookback sum is 57702809000.0
# We dropped row 4, Financial instruments owned (approximately $10,900,474 were, with lookback window of 2.
# 	Our row is valued at 44343153000.0, our lookback sum is 44343153000.0
# We dropped row 9, Receivables:, with lookback window of 4.
# 	Our row is valued at 17731470000.0, our lookback sum is 17731470000.0
# We dropped row 13, Furniture, equipment and leasehold improvements, net of, with lookback window of 3.
# 	Our row is valued at 535815000.0, our lookback sum is 535815000.0
# We dropped row 16, Total assets, with lookback window of 16.
# 	Our row is valued at 63951218000.0, our lookback sum is 63951218000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 78732111000.0, our lookback sum is 78732111000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 74182935000.0, our lookback sum is 74182935000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 87542832000.0, our lookback sum is 87542832000.0
# 	We have completed 80 - asset rows
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 16266635000.0, our lookback sum is 16266635000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 14279792000.0, our lookback sum is 14279792000.0
# We dropped row 4, Trading assets ($7,567,059 were pledged to, with lookback window of 2.
# 	Our row is valued at 36294531000.0, our lookback sum is 36294531000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 68102304000.0, our lookback sum is 68102304000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 104827762000.0, our lookback sum is 104827762000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 114059495000.0, our lookback sum is 114059495000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 121701814000.0, our lookback sum is 121701814000.0
# We dropped row 4, Trading assets ($19,918,091 were pledged to various parties and $335,455 related to, with lookback window of 2.
# 	Our row is valued at 76177986000.0, our lookback sum is 76177986000.0
# We dropped row 4, Trading assets ($19,918,091 were pledged to various parties and $335,455 related to, with lookback window of 2.
# 	Our row is valued at 76177986000.0, our lookback sum is 76177986000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 127385456000.0, our lookback sum is 127385456000.0
# We dropped row 4, Trading assets ($16,658,256 were pledged to various parties and $437,502 related, with lookback window of 2.
# 	Our row is valued at 61224030000.0, our lookback sum is 61224030000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 108960337000.0, our lookback sum is 108960337000.0
# We dropped row 4, Trading assets ($14,976,358 were pledged to various parties and $497,099 related, with lookback window of 2.
# 	Our row is valued at 60908405000.0, our lookback sum is 60908405000.0
# We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 	Our row is valued at 2548556000.0, our lookback sum is 2548556000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 117925405000.0, our lookback sum is 117925405000.0
# We dropped row 4, Trading assets ($6,815,721 were pledged to various parties and $15,802 related, with lookback window of 2.
# 	Our row is valued at 81225612000.0, our lookback sum is 81225612000.0
# We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 	Our row is valued at 2230458000.0, our lookback sum is 2230458000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 141510330000.0, our lookback sum is 141510330000.0
# 	We have completed 90 - asset rows
# We dropped row 8, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 	Our row is valued at 3117334000.0, our lookback sum is 3117334000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 141073948000.0, our lookback sum is 141073948000.0
# We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 	Our row is valued at 2620041000.0, our lookback sum is 2620041000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 127542303000.0, our lookback sum is 127542303000.0
# We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 	Our row is valued at 5258229000.0, our lookback sum is 5258229000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 142473148000.0, our lookback sum is 142473148000.0
# We dropped row 10, TOTAL ASSETS, with lookback window of 10.
# 	Our row is valued at 140655621000.0, our lookback sum is 140655621000.0
# We dropped row 11, TOTAL ASSETS, with lookback window of 11.
# 	Our row is valued at 150559829000.0, our lookback sum is 150559829000.0
# We dropped row 11, TOTAL ASSETS, with lookback window of 11.
# 	Our row is valued at 164601243000.0, our lookback sum is 164601243000.0
# We dropped row 8, Net property and equipment, with lookback window of 3.
# 	Our row is valued at 107603.0, our lookback sum is 107603.0
# We dropped row 9, TOTAL ASSETS, with lookback window of 9.
# 	Our row is valued at 25673078.0, our lookback sum is 25673078.0
# We dropped row 11, TOTAL ASSETS, with lookback window of 11.
# 	Our row is valued at 193433468000.0, our lookback sum is 193433468000.0
# We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 	Our row is valued at 191806579000.0, our lookback sum is 191806579000.0
# We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 	Our row is valued at 236190719000.0, our lookback sum is 236190719000.0
# 	We have completed 100 - asset rows
# We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 	Our row is valued at 258125104000.0, our lookback sum is 258125104000.0
# We dropped row 14, Total assets, with lookback window of 14.
# 	Our row is valued at 399544757000.0, our lookback sum is 399544757000.0
# We dropped row 13, Total assets, with lookback window of 13.
# 	Our row is valued at 329205000000.0, our lookback sum is 329205000000.0
# We dropped row 12, Total assets (*), with lookback window of 12.
# 	Our row is valued at 362019000000.0, our lookback sum is 362019000000.0
# We dropped row 23, Total liabilities (*), with lookback window of 10.
# 	Our row is valued at 351776000000.0, our lookback sum is 351776000000.0
# We dropped row 25, Total liabilities and member's equity, with lookback window of 12.
# 	Our row is valued at 362019000000.0, our lookback sum is 362019000000.0
# We dropped row 28, Total Assets, with lookback window of 2.
# 	Our row is valued at 3767000000.0, our lookback sum is 3767000000.0
# We dropped row 12, Total assets (a), with lookback window of 12.
# 	Our row is valued at 371293000000.0, our lookback sum is 371294000000.0
# We dropped row 12, Total assets (a), with lookback window of 12.
# 	Our row is valued at 451412000000.0, our lookback sum is 451412000000.0
# We dropped row 23, Total liabilities (a), with lookback window of 10.
# 	Our row is valued at 437466000000.0, our lookback sum is 437466000000.0
# We dropped row 25, Total liabilities and member's equity, with lookback window of 12.
# 	Our row is valued at 451412000000.0, our lookback sum is 451412000000.0
# We dropped row 28, Total Assets, with lookback window of 2.
# 	Our row is valued at 920000000.0, our lookback sum is 920000000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 372319000000.0, our lookback sum is 372319000000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 397361000000.0, our lookback sum is 397361000000.0
# We dropped row 10, Total assets(i, with lookback window of 10.
# 	Our row is valued at 369680000000.0, our lookback sum is 369680000000.0
# We dropped row 10, Total assets(², with lookback window of 10.
# 	Our row is valued at 379355000000.0, our lookback sum is 379355000000.0
# 	We have completed 110 - asset rows
# We dropped row 9, Total assets(a, with lookback window of 9.
# 	Our row is valued at 351170000000.0, our lookback sum is 351170000000.0
# We dropped row 9, Total assets(a, with lookback window of 9.
# 	Our row is valued at 351170000000.0, our lookback sum is 351170000000.0
# We dropped row 9, Total assets(a, with lookback window of 9.
# 	Our row is valued at 460265000000.0, our lookback sum is 460265000000.0
# We dropped row 9, Total assets(a, with lookback window of 9.
# 	Our row is valued at 490945000000.0, our lookback sum is 490945000000.0
# We dropped row 9, Total assets (a), with lookback window of 9.
# 	Our row is valued at 609782000000.0, our lookback sum is 609782000000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 72638615000.0, our lookback sum is 72638615000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 103369408000.0, our lookback sum is 103369408000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 113650937000.0, our lookback sum is 113650937000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 174937091000.0, our lookback sum is 174937091000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 194436796000.0, our lookback sum is 194436796000.0
# 	We have completed 120 - asset rows
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 236022658000.0, our lookback sum is 236022658000.0
# We dropped row 12, Total assets, with lookback window of 12.
# 	Our row is valued at 297821416000.0, our lookback sum is 297821416000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 240429127000.0, our lookback sum is 240429127000.0
# We dropped row 11, Total assets, with lookback window of 11.
# 	Our row is valued at 326876000000.0, our lookback sum is 326876000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 330107000000.0, our lookback sum is 330107000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 306476000000.0, our lookback sum is 306476000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 309063000000.0, our lookback sum is 309063000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 303606000000.0, our lookback sum is 303606000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 248026000000.0, our lookback sum is 248026000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 172089000000.0, our lookback sum is 172089000000.0
# 	We have completed 130 - asset rows
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 152511000000.0, our lookback sum is 152511000000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 106460000000.0, our lookback sum is 106460000000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 105666000000.0, our lookback sum is 105666000000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 99167000000.0, our lookback sum is 99167000000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 112591.0, our lookback sum is 112591.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 35226132000.0, our lookback sum is 35226132000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 13457826000.0, our lookback sum is 13457826000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 16229970000.0, our lookback sum is 16229970000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 36210678000.0, our lookback sum is 36210678000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 50025689000.0, our lookback sum is 50025689000.0
# 	We have completed 140 - asset rows
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 81435436000.0, our lookback sum is 81435436000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 81435436000.0, our lookback sum is 81435436000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 68835607000.0, our lookback sum is 68835607000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 61543858000.0, our lookback sum is 61543858000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 60683961000.0, our lookback sum is 60683961000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 83850980000.0, our lookback sum is 83850980000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 55704086000.0, our lookback sum is 55704086000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 77900039000.0, our lookback sum is 77900039000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 74314954000.0, our lookback sum is 74314954000.0
# We dropped row 10, Total assets, with lookback window of 10.
# 	Our row is valued at 81418513000.0, our lookback sum is 81418513000.0
# 	We have completed 150 - asset rows
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 71580510000.0, our lookback sum is 71580510000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 71759167000.0, our lookback sum is 71759167000.0
# We dropped row 9, Total assets, with lookback window of 9.
# 	Our row is valued at 91308598000.0, our lookback sum is 91308598000.0
# We dropped row 10, Total assets, with lookback window of 9.
# 	Our row is valued at 105062000000.0, our lookback sum is 105062000000.0
# We dropped row 9, Total assets, with lookback window of 8.
# 	Our row is valued at 77321000000.0, our lookback sum is 77321000000.0
# We dropped row 8, Total assets, with lookback window of 8.
# 	Our row is valued at 47166000000.0, our lookback sum is 47166000000.0
# We dropped row 18, Total assets, with lookback window of 18.
# 	Our row is valued at 225279000000.0, our lookback sum is 225279000000.0
# We dropped row 13, Receivables:, with lookback window of 9.
# 	Our row is valued at 63048000000.0, our lookback sum is 63048000000.0
# We dropped row 21, Total assets, with lookback window of 21.
# 	Our row is valued at 197117000000.0, our lookback sum is 197117000000.0
# We dropped row 13, Receivables:, with lookback window of 9.
# 	Our row is valued at 93634000000.0, our lookback sum is 93634000000.0
# We dropped row 21, Total assets, with lookback window of 21.
# 	Our row is valued at 231204000000.0, our lookback sum is 231204000000.0
# We dropped row 13, Receivables:, with lookback window of 9.
# 	Our row is valued at 92322000000.0, our lookback sum is 92322000000.0
# We dropped row 21, Total assets, with lookback window of 21.
# 	Our row is valued at 278859000000.0, our lookback sum is 278859000000.0
# 	We have completed 160 - asset rows
# We dropped row 20, Total assets, with lookback window of 20.
# 	Our row is valued at 377951000000.0, our lookback sum is 377951000000.0
# We dropped row 4, Financial instruments owned and contractual commitments, at fair value:, with lookback window of 2.
# 	Our row is valued at 200500000000.0, our lookback sum is 200500000000.0
# We dropped row 14, Receivables:, with lookback window of 9.
# 	Our row is valued at 109682000000.0, our lookback sum is 109682000000.0
# We dropped row 22, Total assets, with lookback window of 22.
# 	Our row is valued at 363162000000.0, our lookback sum is 363162000000.0
# We dropped row 4, Financial instruments owned and contractual commitments, at fair value:, with lookback window of 2.
# 	Our row is valued at 163491000000.0, our lookback sum is 163491000000.0
# We dropped row 21, Total assets, with lookback window of 21.
# 	Our row is valued at 286825000000.0, our lookback sum is 286825000000.0
# We dropped row 4, Trading account assets (approximately $17 billion were pledged to various parties at December 31, 2009):, with lookback window of 2.
# 	Our row is valued at 183429000000.0, our lookback sum is 183429000000.0
# We dropped row 21, Total assets, with lookback window of 21.
# 	Our row is valued at 314356000000.0, our lookback sum is 314356000000.0
# We dropped row 4, Trading account assets (approximately $20 billion were pledged to various parties at December 31, 2010):, with lookback window of 2.
# 	Our row is valued at 156385000000.0, our lookback sum is 156385000000.0
# We dropped row 18, Property, equipment and leasehold improvements, net of, with lookback window of 3.
# 	Our row is valued at 22540000000.0, our lookback sum is 22540000000.0
# We dropped row 23, Total assets, with lookback window of 23.
# 	Our row is valued at 288409000000.0, our lookback sum is 288409000000.0
# We dropped row 4, Trading account assets (approximately $18 billion were pledged to, with lookback window of 2.
# 	Our row is valued at 157348000000.0, our lookback sum is 157348000000.0
# We dropped row 14, Receivables:, with lookback window of 9.
# 	Our row is valued at 71397000000.0, our lookback sum is 71397000000.0
# We dropped row 18, Property, equipment and leasehold improvements, net of, with lookback window of 3.
# 	Our row is valued at 23953000000.0, our lookback sum is 23953000000.0
# We dropped row 23, Total assets, with lookback window of 23.
# 	Our row is valued at 269150000000.0, our lookback sum is 269150000000.0
# We dropped row 4, Trading account assets (approximately $14 billion were pledged to various parties at December 31, 2012):, with lookback window of 2.
# 	Our row is valued at 153747000000.0, our lookback sum is 153747000000.0
# We dropped row 14, Receivables:, with lookback window of 9.
# 	Our row is valued at 70257000000.0, our lookback sum is 70257000000.0
# We dropped row 18, Property, equipment and leasehold improvements, net of, with lookback window of 3.
# 	Our row is valued at 11683000000.0, our lookback sum is 11683000000.0
# We dropped row 22, Total assets, with lookback window of 22.
# 	Our row is valued at 251522000000.0, our lookback sum is 251522000000.0
# We dropped row 19, Total assets, with lookback window of 19.
# 	Our row is valued at 253600000000.0, our lookback sum is 253600000000.0
# We dropped row 18, Total assets, with lookback window of 18.
# 	Our row is valued at 253416000000.0, our lookback sum is 253416000000.0
# We dropped row 19, Total assets, with lookback window of 19.
# 	Our row is valued at 261644000000.0, our lookback sum is 261644000000.0
# 	We have completed 170 - asset rows
# We dropped row 18, Total assets, with lookback window of 18.
# 	Our row is valued at 272544000000.0, our lookback sum is 272544000000.0
# We dropped row 17, Total assets, with lookback window of 17.
# 	Our row is valued at 298908000000.0, our lookback sum is 298908000000.0
# We dropped row 17, Total assets, with lookback window of 17.
# 	Our row is valued at 289445000000.0, our lookback sum is 289445000000.0
#
# Liability & Equity Unstructured Database
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 32320448000.0, our lookback sum is 32320448000.0
# We dropped row 9, Total liabilities and member's equity, with lookback window of 9.
# 	Our row is valued at 35611655000.0, our lookback sum is 35611655000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 32320448000.0, our lookback sum is 32320448000.0
# We dropped row 9, Total liabilities and member's equity, with lookback window of 9.
# 	Our row is valued at 35611655000.0, our lookback sum is 35611655000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 20118057000.0, our lookback sum is 20118057000.0
# We dropped row 9, Total liabilities and member's equity, with lookback window of 9.
# 	Our row is valued at 24029490000.0, our lookback sum is 24029490000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 20118057000.0, our lookback sum is 20118057000.0
# We dropped row 9, Total liabilities and member's equity, with lookback window of 9.
# 	Our row is valued at 24029490000.0, our lookback sum is 24029490000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 16498871000.0, our lookback sum is 16498871000.0
# We dropped row 11, Total member's equity, with lookback window of 2.
# 	Our row is valued at 3197552000.0, our lookback sum is 3197552000.0
# We dropped row 12, Total liabilities and member's equity, with lookback window of 12.
# 	Our row is valued at 20879923000.0, our lookback sum is 20879923000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 17307282000.0, our lookback sum is 17307282000.0
# We dropped row 10, Total member's equity, with lookback window of 2.
# 	Our row is valued at 3020035000.0, our lookback sum is 3020035000.0
# We dropped row 11, Total liabilities and member's equity, with lookback window of 11.
# 	Our row is valued at 21660817000.0, our lookback sum is 21660817000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 6311744000.0, our lookback sum is 6311744000.0
# We dropped row 9, Total liabilities and member's equity, with lookback window of 9.
# 	Our row is valued at 9580535000.0, our lookback sum is 9580535000.0
# We dropped row 5, Total liabilities, with lookback window of 5.
# 	Our row is valued at 13753891000.0, our lookback sum is 13753891000.0
# We dropped row 9, Total member's equity, with lookback window of 2.
# 	Our row is valued at 2262267000.0, our lookback sum is 2262267000.0
# We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 	Our row is valued at 17499658000.0, our lookback sum is 17499658000.0
# We dropped row 5, Total liabilities, with lookback window of 5.
# 	Our row is valued at 33345623000.0, our lookback sum is 33345623000.0
# We dropped row 9, Total member's equity, with lookback window of 2.
# 	Our row is valued at 2780810000.0, our lookback sum is 2780810000.0
# We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 	Our row is valued at 37609933000.0, our lookback sum is 37609933000.0
# We dropped row 5, Total liabilities, with lookback window of 5.
# 	Our row is valued at 34379197000.0, our lookback sum is 34379197000.0
# We dropped row 9, Total member's equity, with lookback window of 2.
# 	Our row is valued at 2831370000.0, our lookback sum is 2831370000.0
# We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 	Our row is valued at 39534067000.0, our lookback sum is 39534067000.0
# We dropped row 5, Total liabilities, with lookback window of 5.
# 	Our row is valued at 37889341000.0, our lookback sum is 37889341000.0
# We dropped row 9, Total member's equity, with lookback window of 2.
# 	Our row is valued at 3311243000.0, our lookback sum is 3311243000.0
# We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 	Our row is valued at 43524084000.0, our lookback sum is 43524084000.0
# We dropped row 5, Total liabilities, with lookback window of 5.
# 	Our row is valued at 41933521000.0, our lookback sum is 41933521000.0
# We dropped row 9, Total member's equity, with lookback window of 2.
# 	Our row is valued at 3887874000.0, our lookback sum is 3887874000.0
# We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 	Our row is valued at 48144895000.0, our lookback sum is 48144895000.0
# 	We have completed 10 - liability & equity rows
# We dropped row 5, Total liabilities, with lookback window of 5.
# 	Our row is valued at 58237482000.0, our lookback sum is 58237482000.0
# We dropped row 9, Total member's equity, with lookback window of 2.
# 	Our row is valued at 4274759000.0, our lookback sum is 4274759000.0
# We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 	Our row is valued at 64835741000.0, our lookback sum is 64835741000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 83676648000.0, our lookback sum is 83676648000.0
# We dropped row 10, Total member's equity, with lookback window of 2.
# 	Our row is valued at 4531707000.0, our lookback sum is 4531707000.0
# We dropped row 11, Total liabilities and member's equity, with lookback window of 11.
# 	Our row is valued at 90531855000.0, our lookback sum is 90531855000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 100620516000.0, our lookback sum is 100620516000.0
# We dropped row 10, Total member's equity, with lookback window of 2.
# 	Our row is valued at 5019971000.0, our lookback sum is 5019971000.0
# We dropped row 11, Total liabilities and member's equity, with lookback window of 11.
# 	Our row is valued at 112940487000.0, our lookback sum is 112940487000.0
# We dropped row 8, Total liabilities, with lookback window of 8.
# 	Our row is valued at 119004538000.0, our lookback sum is 119004538000.0
# We dropped row 12, Total member's equity, with lookback window of 2.
# 	Our row is valued at 5097662000.0, our lookback sum is 5097662000.0
# We dropped row 13, Total liabilities and member's equity, with lookback window of 13.
# 	Our row is valued at 131402200000.0, our lookback sum is 131402200000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 121679208000.0, our lookback sum is 121679208000.0
# We dropped row 13, Total member's equity, with lookback window of 2.
# 	Our row is valued at 5344761000.0, our lookback sum is 5344761000.0
# We dropped row 14, Total liabilities and member's equity, with lookback window of 14.
# 	Our row is valued at 134323969000.0, our lookback sum is 134323969000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 128932963000.0, our lookback sum is 128932963000.0
# We dropped row 13, Total member's equity, with lookback window of 2.
# 	Our row is valued at 5601579000.0, our lookback sum is 5601579000.0
# We dropped row 14, Total liabilities and member's equity, with lookback window of 14.
# 	Our row is valued at 141834542000.0, our lookback sum is 141834542000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 118977964000.0, our lookback sum is 118977964000.0
# We dropped row 13, Total member's equity, with lookback window of 2.
# 	Our row is valued at 9130317000.0, our lookback sum is 9130317000.0
# We dropped row 14, Total liabilities and member's equity, with lookback window of 14.
# 	Our row is valued at 132758281000.0, our lookback sum is 132758281000.0
# 	We have completed 20 - liability & equity rows
# We dropped row 11, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 4210751000.0, our lookback sum is 4210751000.0
# We dropped row 12, Total liabilities and partners' capital, with lookback window of 12.
# 	Our row is valued at 348590977000.0, our lookback sum is 348590977000.0
# We dropped row 11, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 4535899000.0, our lookback sum is 4535899000.0
# We dropped row 12, Total liabilities and partners' capital, with lookback window of 12.
# 	Our row is valued at 475872139000.0, our lookback sum is 475872139000.0
# We dropped row 12, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 4685687000.0, our lookback sum is 4685687000.0
# We dropped row 13, Total liabilities and partners' capital, with lookback window of 13.
# 	Our row is valued at 509250736000.0, our lookback sum is 509250736000.0
# We dropped row 12, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 6247937000.0, our lookback sum is 6247937000.0
# We dropped row 13, Total liabilities and partners' capital, with lookback window of 13.
# 	Our row is valued at 632858770000.0, our lookback sum is 632858770000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 438306000000.0, our lookback sum is 438306000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 7199000000.0, our lookback sum is 7199000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 14.
# 	Our row is valued at 463755000000.0, our lookback sum is 463755000000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 496216000000.0, our lookback sum is 496219000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 9286000000.0, our lookback sum is 9286000000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 496215000000.0, our lookback sum is 496215000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 9286000000.0, our lookback sum is 9286000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 14.
# 	Our row is valued at 527001000000.0, our lookback sum is 527001000000.0
# We dropped row 12, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 6598000000.0, our lookback sum is 6598000000.0
# We dropped row 13, Total liabilities and partners' capital, with lookback window of 13.
# 	Our row is valued at 504694000000.0, our lookback sum is 504694000000.0
# We dropped row 8, Total liabilities, with lookback window of 8.
# 	Our row is valued at 471520000000.0, our lookback sum is 471520000000.0
# We dropped row 12, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 8075000000.0, our lookback sum is 8075000000.0
# We dropped row 13, Total liabilities and partners' capital, with lookback window of 13.
# 	Our row is valued at 501095000000.0, our lookback sum is 501095000000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 493128000000.0, our lookback sum is 493128000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 9898000000.0, our lookback sum is 9898000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 14.
# 	Our row is valued at 524526000000.0, our lookback sum is 524526000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 11377000000.0, our lookback sum is 11377000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 4.
# 	Our row is valued at 477078000000.0, our lookback sum is 477076000000.0
# We dropped row 10, Total liabilities, with lookback window of 10.
# 	Our row is valued at 465699000000.0, our lookback sum is 465699000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 11377000000.0, our lookback sum is 11377000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 14.
# 	Our row is valued at 477076000000.0, our lookback sum is 477076000000.0
# 	We have completed 30 - liability & equity rows
# We dropped row 10, Total liabilities, with lookback window of 10.
# 	Our row is valued at 444847000000.0, our lookback sum is 444848000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 9904000000.0, our lookback sum is 9904000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 14.
# 	Our row is valued at 454751000000.0, our lookback sum is 454752000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 11609000000.0, our lookback sum is 11609000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 4.
# 	Our row is valued at 424649000000.0, our lookback sum is 424649000000.0
# We dropped row 10, Total liabilities, with lookback window of 10.
# 	Our row is valued at 413040000000.0, our lookback sum is 413040000000.0
# We dropped row 13, Total partners' capital, with lookback window of 2.
# 	Our row is valued at 11609000000.0, our lookback sum is 11609000000.0
# We dropped row 14, Total liabilities and partners' capital, with lookback window of 14.
# 	Our row is valued at 424649000000.0, our lookback sum is 424649000000.0
# We dropped row 9, Total liabilities, with lookback window of 9.
# 	Our row is valued at 442913000000.0, our lookback sum is 442913000000.0
# We dropped row 12, Total member's equity, with lookback window of 2.
# 	Our row is valued at 11014000000.0, our lookback sum is 11014000000.0
# We dropped row 13, Total liabilities and member's equity, with lookback window of 13.
# 	Our row is valued at 453927000000.0, our lookback sum is 453927000000.0
# We dropped row 10, Total liabilities, with lookback window of 10.
# 	Our row is valued at 406148000000.0, our lookback sum is 406148000000.0
# We dropped row 12, Total liabilities and member's equity, with lookback window of 12.
# 	Our row is valued at 416665000000.0, our lookback sum is 416665000000.0
# We dropped row 10, Total liabilities, with lookback window of 10.
# 	Our row is valued at 495653000000.0, our lookback sum is 495653000000.0
# We dropped row 11, Total liabilities, with lookback window of 11.
# 	Our row is valued at 248468415000.0, our lookback sum is 248468415000.0
# We dropped row 13, Total liabilities and stockholder's equity, with lookback window of 13.
# 	Our row is valued at 253278304000.0, our lookback sum is 253278304000.0
# We dropped row 11, Total liabilities, with lookback window of 11.
# 	Our row is valued at 248468415000.0, our lookback sum is 248468415000.0
# We dropped row 13, Total liabilities and stockholder's equity, with lookback window of 13.
# 	Our row is valued at 253278304000.0, our lookback sum is 253278304000.0
# 	We have completed 40 - liability & equity rows
# We dropped row 10, Total liabilities, with lookback window of 10.
# 	Our row is valued at 255495717000.0, our lookback sum is 255495717000.0
# We dropped row 15, Total stockholder's equity, with lookback window of 2.
# 	Our row is valued at 4675607000.0, our lookback sum is 4675605000.0
# We dropped row 16, Total liabilities and stockholder's equity, with lookback window of 16.
# 	Our row is valued at 264444724000.0, our lookback sum is 264444724000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 306258803000.0, our lookback sum is 306258803000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 317870722000.0, our lookback sum is 317870722000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 501757063000.0, our lookback sum is 501757063000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 519780630000.0, our lookback sum is 519780630000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 229275201000.0, our lookback sum is 229275201000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 244413278000.0, our lookback sum is 244413278000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 232082804000.0, our lookback sum is 232082804000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 249693066000.0, our lookback sum is 249693066000.0
# We dropped row 8, Total liabilities, with lookback window of 8.
# 	Our row is valued at 225973793000.0, our lookback sum is 225973793000.0
# We dropped row 11, Total liabilities and stockholder's equity, with lookback window of 11.
# 	Our row is valued at 244079398000.0, our lookback sum is 244079398000.0
# We dropped row 8, Total liabilities, with lookback window of 8.
# 	Our row is valued at 221339000000.0, our lookback sum is 221339000000.0
# We dropped row 11, Total liabilities and stockholder's equity, with lookback window of 11.
# ...
# We dropped row 11, Total liabilities and stockholders' equity, with lookback window of 11.
# 	Our row is valued at 83850980000.0, our lookback sum is 83850980000.0
# We dropped row 8, Total liabilities, with lookback window of 8.
# 	Our row is valued at 54161306000.0, our lookback sum is 54161306000.0
# We dropped row 11, Total liabilities and stockholder's equity, with lookback window of 11.
# 	Our row is valued at 55704086000.0, our lookback sum is 55704086000.0
# We dropped row 8, Total liabilities, with lookback window of 8.
# 	Our row is valued at 54161306000.0, our lookback sum is 54161306000.0
# We dropped row 11, Total liabilities and stockholder's equity, with lookback window of 11.
# 	Our row is valued at 55704086000.0, our lookback sum is 55704086000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 76340920000.0, our lookback sum is 76340920000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 77900039000.0, our lookback sum is 77900039000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 72839292000.0, our lookback sum is 72839292000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 74314954000.0, our lookback sum is 74314954000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 80024434000.0, our lookback sum is 80024434000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 81418513000.0, our lookback sum is 81418513000.0
# We dropped row 7, Total liabilities, with lookback window of 7.
# 	Our row is valued at 80024434000.0, our lookback sum is 80024434000.0
# We dropped row 10, Total liabilities and stockholder's equity, with lookback window of 10.
# 	Our row is valued at 81418513000.0, our lookback sum is 81418513000.0
# 	We have completed 150 - liability & equity rows
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 70097715000.0, our lookback sum is 70097715000.0
# We dropped row 9, Total liabilities and stockholder's equity, with lookback window of 9.
# 	Our row is valued at 71580510000.0, our lookback sum is 71580510000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 70097715000.0, our lookback sum is 70097715000.0
# We dropped row 9, Total liabilities and stockholder's equity, with lookback window of 9.
# 	Our row is valued at 71580510000.0, our lookback sum is 71580510000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 70269822000.0, our lookback sum is 70269822000.0
# We dropped row 9, Total liabilities and shareholder's equity, with lookback window of 9.
# 	Our row is valued at 71759167000.0, our lookback sum is 71759167000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 70269822000.0, our lookback sum is 70269822000.0
# We dropped row 9, Total liabilities and shareholder's equity, with lookback window of 9.
# 	Our row is valued at 71759167000.0, our lookback sum is 71759167000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 89723445000.0, our lookback sum is 89723445000.0
# We dropped row 12, Shareholder's equity, with lookback window of 3.
# 	Our row is valued at 835153000.0, our lookback sum is 835153000.0
# We dropped row 13, Total liabilities and shareholder's equity, with lookback window of 13.
# 	Our row is valued at 91308598000.0, our lookback sum is 91308598000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 103306000000.0, our lookback sum is 103306000000.0
# We dropped row 12, Shareholder's equity, with lookback window of 3.
# 	Our row is valued at 781000000.0, our lookback sum is 781000000.0
# We dropped row 13, Total liabilities and shareholder's equity, with lookback window of 13.
# 	Our row is valued at 105062000000.0, our lookback sum is 105062000000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 75479000000.0, our lookback sum is 75479000000.0
# We dropped row 12, Shareholder's equity, with lookback window of 3.
# 	Our row is valued at 942000000.0, our lookback sum is 942000000.0
# We dropped row 13, Total liabilities and shareholder's equity, with lookback window of 13.
# 	Our row is valued at 77321000000.0, our lookback sum is 77321000000.0
# We dropped row 6, Total liabilities, with lookback window of 6.
# 	Our row is valued at 45452000000.0, our lookback sum is 45452000000.0
# We dropped row 12, Shareholder's equity, with lookback window of 3.
# 	Our row is valued at 914000000.0, our lookback sum is 914000000.0
# We dropped row 13, Total liabilities and shareholder's equity, with lookback window of 13.
# 	Our row is valued at 47166000000.0, our lookback sum is 47166000000.0
# We dropped row 10, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 25226000000.0, our lookback sum is 25226000000.0
# We dropped row 16, Total liabilities, with lookback window of 16.
# 	Our row is valued at 218419000000.0, our lookback sum is 218419000000.0
# We dropped row 21, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 6860000000.0, our lookback sum is 6860000000.0
# We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 	Our row is valued at 225279000000.0, our lookback sum is 225279000000.0
# We dropped row 4, Financial instruments sold, not yet purchased,, with lookback window of 2.
# 	Our row is valued at 114159000000.0, our lookback sum is 114159000000.0
# We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 18012000000.0, our lookback sum is 18012000000.0
# We dropped row 18, Total liabilities, with lookback window of 18.
# 	Our row is valued at 189981000000.0, our lookback sum is 189981000000.0
# We dropped row 23, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 7136000000.0, our lookback sum is 7136000000.0
# We dropped row 24, Total liabilities and stockholder's equity, with lookback window of 24.
# 	Our row is valued at 197117000000.0, our lookback sum is 197117000000.0
# We dropped row 10, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 24756000000.0, our lookback sum is 24756000000.0
# We dropped row 17, Total liabilities, with lookback window of 17.
# 	Our row is valued at 223965000000.0, our lookback sum is 223965000000.0
# We dropped row 22, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 7239000000.0, our lookback sum is 7239000000.0
# We dropped row 23, Total liabilities and stockholder's equity, with lookback window of 23.
# 	Our row is valued at 231204000000.0, our lookback sum is 231204000000.0
# We dropped row 4, Financial instruments sold, not yet purchased,, with lookback window of 2.
# 	Our row is valued at 138285000000.0, our lookback sum is 138285000000.0
# We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 30788000000.0, our lookback sum is 30788000000.0
# We dropped row 17, Total liabilities, with lookback window of 17.
# 	Our row is valued at 270455000000.0, our lookback sum is 270455000000.0
# We dropped row 22, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 8404000000.0, our lookback sum is 8404000000.0
# We dropped row 23, Total liabilities and stockholder's equity, with lookback window of 23.
# 	Our row is valued at 278859000000.0, our lookback sum is 278859000000.0
# 	We have completed 160 - liability & equity rows
# We dropped row 10, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 29668000000.0, our lookback sum is 29668000000.0
# We dropped row 16, Total liabilities, with lookback window of 16.
# 	Our row is valued at 367118000000.0, our lookback sum is 367118000000.0
# We dropped row 21, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 10833000000.0, our lookback sum is 10833000000.0
# We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 	Our row is valued at 377951000000.0, our lookback sum is 377951000000.0
# We dropped row 4, Financial instruments sold, not yet purchased, and, with lookback window of 2.
# 	Our row is valued at 205309000000.0, our lookback sum is 205309000000.0
# We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 26313000000.0, our lookback sum is 26313000000.0
# We dropped row 16, Total liabilities, with lookback window of 16.
# 	Our row is valued at 354820000000.0, our lookback sum is 354820000000.0
# We dropped row 21, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 8342000000.0, our lookback sum is 8342000000.0
# We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 	Our row is valued at 363162000000.0, our lookback sum is 363162000000.0
# We dropped row 4, Financial instruments sold, not yet purchased, and, with lookback window of 2.
# 	Our row is valued at 167462000000.0, our lookback sum is 167462000000.0
# We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 20582000000.0, our lookback sum is 20582000000.0
# We dropped row 16, Total liabilities, with lookback window of 16.
# 	Our row is valued at 280442000000.0, our lookback sum is 280442000000.0
# We dropped row 21, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 6383000000.0, our lookback sum is 6383000000.0
# We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 	Our row is valued at 286825000000.0, our lookback sum is 286825000000.0
# We dropped row 2, Collateralized short-term financing agreements:, with lookback window of 2.
# 	Our row is valued at 56832000000.0, our lookback sum is 56832000000.0
# We dropped row 12, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 27328000000.0, our lookback sum is 27328000000.0
# We dropped row 18, Total liabilities, with lookback window of 18.
# 	Our row is valued at 296359000000.0, our lookback sum is 296359000000.0
# We dropped row 23, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 17997000000.0, our lookback sum is 17997000000.0
# We dropped row 24, Total liabilities and stockholder's equity, with lookback window of 24.
# 	Our row is valued at 314356000000.0, our lookback sum is 314356000000.0
# We dropped row 2, Collateralized short-term financing agreements:, with lookback window of 2.
# 	Our row is valued at 15835000000.0, our lookback sum is 15835000000.0
# We dropped row 5, Trading account liabilities:, with lookback window of 2.
# 	Our row is valued at 131419000000.0, our lookback sum is 131419000000.0
# We dropped row 12, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 27875000000.0, our lookback sum is 27875000000.0
# We dropped row 18, Total liabilities, with lookback window of 18.
# 	Our row is valued at 272389000000.0, our lookback sum is 272389000000.0
# We dropped row 23, Total stockholder's equity, with lookback window of 4.
# 	Our row is valued at 16020000000.0, our lookback sum is 16020000000.0
# We dropped row 24, Total liabilities and stockholder's equity, with lookback window of 24.
# 	Our row is valued at 288409000000.0, our lookback sum is 288409000000.0
# We dropped row 4, Trading account liabilities:, with lookback window of 2.
# 	Our row is valued at 133872000000.0, our lookback sum is 133872000000.0
# We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 25871000000.0, our lookback sum is 25871000000.0
# We dropped row 17, Total liabilities, with lookback window of 17.
# 	Our row is valued at 261317000000.0, our lookback sum is 261317000000.0
# We dropped row 21, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 7833000000.0, our lookback sum is 7833000000.0
# We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 	Our row is valued at 269150000000.0, our lookback sum is 269150000000.0
# We dropped row 2, Collateralized short-term financing agreements:, with lookback window of 2.
# 	Our row is valued at 19943000000.0, our lookback sum is 19943000000.0
# We dropped row 5, Trading account liabilities:, with lookback window of 2.
# 	Our row is valued at 136775000000.0, our lookback sum is 136775000000.0
# We dropped row 12, Payables and accrued liabilities:, with lookback window of 6.
# 	Our row is valued at 20694000000.0, our lookback sum is 20694000000.0
# We dropped row 18, Total liabilities, with lookback window of 18.
# 	Our row is valued at 242830000000.0, our lookback sum is 242830000000.0
# We dropped row 22, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 8692000000.0, our lookback sum is 8692000000.0
# We dropped row 23, Total liabilities and stockholder's equity, with lookback window of 23.
# 	Our row is valued at 251522000000.0, our lookback sum is 251522000000.0
# We dropped row 14, Total liabilities, with lookback window of 14.
# 	Our row is valued at 235464000000.0, our lookback sum is 235464000000.0
# We dropped row 19, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 9691000000.0, our lookback sum is 9691000000.0
# We dropped row 20, Total liabilities and stockholder's equity, with lookback window of 20.
# 	Our row is valued at 253600000000.0, our lookback sum is 253600000000.0
# We dropped row 13, Total liabilities, with lookback window of 13.
# 	Our row is valued at 234329000000.0, our lookback sum is 234329000000.0
# We dropped row 18, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 9142000000.0, our lookback sum is 9142000000.0
# We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 	Our row is valued at 253416000000.0, our lookback sum is 253416000000.0
# We dropped row 14, Total liabilities, with lookback window of 14.
# 	Our row is valued at 252450000000.0, our lookback sum is 252450000000.0
# We dropped row 18, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 9194000000.0, our lookback sum is 9194000000.0
# We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 	Our row is valued at 261644000000.0, our lookback sum is 261644000000.0
# 	We have completed 170 - liability & equity rows
# We dropped row 14, Total liabilities, with lookback window of 14.
# 	Our row is valued at 263529000000.0, our lookback sum is 263529000000.0
# We dropped row 18, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 9015000000.0, our lookback sum is 9015000000.0
# We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 	Our row is valued at 272544000000.0, our lookback sum is 272544000000.0
# We dropped row 14, Total liabilities, with lookback window of 14.
# 	Our row is valued at 290048000000.0, our lookback sum is 290048000000.0
# We dropped row 18, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 8860000000.0, our lookback sum is 8860000000.0
# We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 	Our row is valued at 298908000000.0, our lookback sum is 298908000000.0
# We dropped row 14, Total liabilities, with lookback window of 14.
# 	Our row is valued at 280372000000.0, our lookback sum is 280372000000.0
# We dropped row 18, Total stockholder's equity, with lookback window of 3.
# 	Our row is valued at 9073000000.0, our lookback sum is 9073000000.0
# We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 	Our row is valued at 289445000000.0, our lookback sum is 289445000000.0
#
# We created an unstructured asset and liability & equity

# %%
[i for i in asset_df.columns if re.search('total|totals', i, flags=re.I) is not None]
# Out:
# []

# %%
[i for i in liable_df.columns if re.search('total|totals', i, flags=re.I) is not None]
# Out:
# ["Total member's equity",
#  "Total stockholder's equity",
#  "Total liabilities and stockholder's equity",
#  "Total Stockholders' equity:",
#  "Total shareholder's equity"]

# %%
liable_df[~np.isnan(liable_df["Total liabilities and stockholder's equity"])]
# Out:
#       CIK                    Name Filing Date  Filing Year  \
# 1  851376  BARCLAYS CAPITAL INC.   2014-03-04         2013
#
#    Accrued interest payable  Other liabilities  \
# 1                       NaN       1.847000e+09
#
#    Payable to broker-dealers and clearing organizations  Payable to customers  \
# 1                                                NaN                      NaN
#
#    Securities sold under agreements to repurchase  \
# 1                                    1.582140e+11
#
#    Securities sold, not yet purchased, at market value  ...  \
# 1                                                NaN    ...
#
#    Commitments, contingencies and guarantees: Subordinated indebtedness  \
# 1                                                NaN
#
#    Common stock ($10,000 par value, 1,000 shares authorized, issued and outstanding)  \
# 1                                                NaN
#
#    Obligations to return securities received as collateral, at fair value  \
# 1                                                NaN
#
#    Securities loaned or sold under agreements to repurchase (including $13,083 at fair value)  \
# 1                                                NaN
#
#    U.S. Treasury and federal agency securities  \
# 1                                          NaN
#
#    Securities loaned or sold under agreements to repurchase (including $8,793 at fair value)  \
# 1                                                NaN
#
#    Securities loaned or sold under agreements to repurchase (including $10,611 at fair value)  \
# 1                                                NaN
#
#    Securities loaned or sold under agreements to repurchase (including $8,810 at fair value)  \
# 1                                                NaN
#
#    Securities loaned and sold under agreements to repurchase (including $6,521 at fair value)  \
# 1                                                NaN
#
#    Securities loaned and sold under agreements to repurchase (including $5,207 at fair value)
# 1                                                NaN
#
# [1 rows x 385 columns]

# %%
# work on combining columns that are issued seperately
s3.download_file(bucket, 'Output/X-17A-5-SPLIT-PDFS/Liability & Equity/851376-2014-03-04.csv', 'temp.csv')
df = pd.read_csv('temp.csv')
os.remove('temp.csv')

# process balance sheet dataframes
temp_df = totals_check(df)                  # run an accounting check removing any total rows
print(temp_df)
# Out:
#                                                     0             1
# 0      Securities sold under agreements to repurchase  1.582140e+11
# 1                                   Securities loaned  3.491900e+10
# 2   Obligation to return securities received as co...  2.716300e+10
# 3   Financial instruments sold, but not yet purcha...  2.980300e+10
# 4   Payables to brokers, dealers and clearing orga...  3.391000e+09
# 5                               Payables to customers  2.304800e+10
# 6                               Short-term borrowings  6.983000e+09
# 7              Accrued interest and dividend payables  2.030000e+08
# 8                                   Other liabilities  1.847000e+09
# 9                                Long-term borrowings  7.900000e+09
# 10                                  Subordinated debt  2.500000e+09
# 11  Common stock - no par value, 5,000 shares auth...  0.000000e+00
# 12                         Additional paid-in capital  6.281000e+09
# 13   Accumulated other comprehensive loss, net of tax -4.000000e+06
# 14                         Total stockholder's equity  7.635000e+09
# 15         Total liabilities and stockholder's equity  3.036060e+11
