# %%
# %pip install fuzzywuzzy
# %pip install python-Levenshtein
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 3.2 MB/s eta 0:00:011
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-Levenshtein) (49.6.0.post20210108)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp36-cp36m-linux_x86_64.whl size=155932 sha256=af338f00ba765a62f9b6e87c8e7bb7aa0d37491075d6215ecc927f42ef62d643
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4a/a4/bf/d761b0899395c75fa76d003d607b3869ee47f5035b8afc30a2
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import botocore
import boto3
import json
import time
import requests
import datetime

import pandas as pd
import numpy as np

from sagemaker.session import Session
from difflib import SequenceMatcher
from bs4 import BeautifulSoup
from fuzzywuzzy import fuzz

# %% [markdown]
# ## Accounting term matching
# **Check to see if we report totals (e.g. Total Liability & Shareholder Equity) or sub-totals (e.g. Total Financial Instruments), these figure are not needed for construction of the unstructured database (avoid classification issue)**

# %%
# numpy exception for handling invalid log10 RunTime error (we opt to not show)
# switch 'ignore' to 'warn', if you would like to flag the RunTime error 
np.seterr(invalid = 'ignore') 

def multiple_check(x1:float, x2:float):
    """
    Determine whether the two values are the same number scaled by 10
    """
    # prevent zero division error since x1 is the denominator and log10 zero division error
    if (x1 == 0) or (x2 == 0): return (x1, False)
    else:
        # if our backward sum is a multiple of 10, we return True 
        # (e.g. Total Assets (x1) 745.2322 vs Backward Sum (x2) 7452322)
        check1 = np.log10(x2 / x1).is_integer()

        # if our backward sum is a substring of a line item, with a difference of one in length, we return True 
        # (e.g. Total Assets (x1) 174182935 vs Backward Sum (x2) 74182935)
        check2 = (str(x2) in str(x1) ) & (len(str(x2)) == len(str(x1)) - 1)

        if check1 or check2:
            return (x2, True)
        else: 
            return (x1, False)

def epsilon_error(x1:float, x2:float, tol:float=0.01):
    """
    Determine whether the two values are within a similar epsilon bound. We default our error tolerance
    to 0.01, implying that if two numbers are within a specified toleracnce (default 1% ) of one another 
    """
    if (x1 == 0) or (x2 == 0): return False
    else:
        # first we convert the numeric quantities into strings
        current = str(x1)
        lookback = str(x2)

        # we only want to check against the relative difference if one element in the number is read wrong
        if len(current) == len(lookback):
            
            # we iterate linearly through each string and check to see the positional match 
            # if we catch a mismatch we flag it with a 1, othewise skip with 0
            changes = [0 if (current[i] == lookback[i]) else 1 for i in range(len(current))]

            # check set differences produce a set with exactly 1 in length
            if sum(changes) == 1:

                diff = abs(x1 - x2)      # compute numeric differences

                # check to see whether an accounting condition was met wihtin a boundary condition
                if abs(diff / x1) <= tol:
                    return True

        return False

# %%
def totals_check(df:pd.DataFrame) -> tuple:
    """
    Checks to see if a line row meets the conditon of a total, if true we remove these rows as we make 
    have checked the terms before have meet our conditions (these include major and minor totals)
    ------------------------------------------------------------------------------------
    :param: (type pandas.DataFrame)
        A DataFrame that represents the Asset or Liability & Equity portion of the balance sheet
        
    :return: (type tuple)
        Return a cleaned DataFrame that strips the rows that represent totals
    """
    m, n = df.shape                  # unpack the shape of dataframe
    data_col = df.columns[1]         # the values column for balance sheet
    
    total_flag = 2       # default 2 (no measure found), 1 (sum is correct), 0 (sum is not correct)
    total_amt = np.nan
    
    # iterate through each of the line items
    for i in range(m):
        
        # check the value of line items at a given index (forward index)
        item1 = df.loc[i].values[1]
        name = df.loc[i].values[0]
        
        # ------------------------------------------------------------------
        # Perform regex search to determine "special" total rows
        # ------------------------------------------------------------------
        a_check = re.search('total assets', name, flags=re.I)
        le_check = re.search('(?=.*(liability|liabilities))(?=.*(equity|deficit|capital))', 
                             name, flags=re.I)
        # ------------------------------------------------------------------
        
        # if we find either total measure we re-write indicators
        if a_check is not None or le_check is not None:
            total_flag = 0; total_amt = item1;
        
        # compute backward sum (lookback index) 
        for j in range(i):
            
            # check whether dataframe empty (if so we skip to avoid fitting errors)
            # NOTE: Index position (i-1)   = line above current line
            #                      (i-j-1) = trailing look up line 'j' lines above the line above current line
            lookback = df.loc[i-j-1:i-1][data_col]
            
            # we check whether the lookback period is empty (if so we most likely deleted the row)
            if not lookback.empty:
                # backward sum for line items (index minus j-periods before)
                item2 = lookback.sum()

                # if we achieve this then we strip totals and break, no need to continue backward sum
                check1 = item1 == item2
                val, check2 = multiple_check(item1, item2)
                check3 = epsilon_error(item1, item2, tol=0.01)
                
                if check1 or check2 or check3:
                    df = df.drop(index=i)
                    
                    # if we drop the "Total" line-item then we re-assign flag to 1
                    if a_check is not None or le_check is not None:
                        total_flag = 1
                        total_amt = val
                    
                    # Error Handling for row deletions (uncomment for when not in use)
                    print('\tWe dropped row {}, {}, with lookback window of {}.'.format(i, name, j+1))
                    print('\t\tOur row is valued at {}, our lookback sum is {}'.format(item1, item2))
                    
                    # we break from inner loop to avoid key error flag 
                    break     
                
    return (df, total_flag, total_amt)

# %% [markdown]
# ## Merging PDFs and PNGs
# **Functions to combine PDFs and PNGs where rows may be omitted**

# %%
def special_merge(df1:pd.DataFrame, df2:pd.DataFrame, col:str) -> pd.DataFrame:
    """
    Special type of merge for dataframes, combining all unique row items for a specified column. 
    This is designed to combine PDF and PNG balance sheets that differ in one or more rows.
    ------------------------------------------------------------------------------------
    :param: (type pandas.DataFrame)
        A DataFrame that represents either the PDF or PNG retreived from Balance Sheet
    :param: (type pandas.DataFrame)
        A DataFrame that represents either the PDF or PNG retreived from Balance Sheet
    :param: (type str)
        A shared column name that exists in both pandas.DataFrames (i.e. df1, df2)
        
    :return: (type pandas.DataFrame)
        Return a cleaned DataFrame that merges any row that was omitted, changed or missing
    """
    arr1 = df1[col].values
    arr2 = df2[col].values
    concat_pdf = []
    
    # find the sequences that match between either lineitems
    sm = SequenceMatcher(a=arr1, b=arr2)
    
    # The SequenceMathcer returns a 5-tupled for each correspond "obj"
    # 'replace'     a[i1:i2] should be replaced by b[j1:j2].
    # 'delete'      a[i1:i2] should be deleted. Note that j1 == j2 in this case.
    # 'insert'      b[j1:j2] should be inserted at a[i1:i1]. Note that i1 == i2 in this case.
    # 'equal'       a[i1:i2] == b[j1:j2] (the sub-sequences are equal)
    for (obj, i1, i2, j1, j2) in sm.get_opcodes():
        
        # implies that we want to "replace" the left side elment with the corresponding
        # right side element at the same index position (we perseve both)
        if obj == 'replace':
            
            # check the value of a fuzzy match, only insert both rows if they vastly different
            left_names = arr1[i1:i2]
            right_names = arr2[j1:j2]
            
            # iterate through each of the checks
            for it, (left, right) in enumerate(zip(left_names, right_names)):
                
                # compute the fuzz match between string (how close are these values)
                score = fuzz.partial_ratio(left.lower(), right.lower())

                # if not close in match then we append both values
                if score < 90:
                    concat_pdf.append(df1.iloc[i1:i1+it+1])
                    concat_pdf.append(df2.iloc[j1:j1+it+1])
                else:
                    print(df1.iloc[i1:i1+it+1])
                    concat_pdf.append(df1.iloc[i1:i1+it+1])
        
        # implies that we want to "delete" the left side element (we preserve this side)
        elif obj == 'delete':
            concat_pdf.append(df1.iloc[i1:i2])
        
        # implied that we want to "insert" the right side element (we preserve this side)
        elif obj == 'insert':
            concat_pdf.append(df2.iloc[j1:j2])
            
        elif obj == 'equal':
            concat_pdf.append(df1.iloc[i1:i2])
    
    # return concated pandas.DataFrame and reset index, removing old index
    return pd.concat(concat_pdf).reset_index(drop=True)

# %% [markdown]
# ## Unstructured Database construction
# **We develop our unstructured database from each of the non-total rows (concating the line items)**

# %%
def unstructured_data(df, filing_d, fiscal_y, cik, cik2name:dict) -> pd.DataFrame:
    """
    Forms unstructured row for larger database to be stored in s3 bucket
    ------------------------------------------------------------------------------------------
    Input:
        :param: df (type pandas.DataFrame)
            The balance sheet for a particular  
        :paran: filing_d (type str)
            The filing date for release of X-17A-5 filings for a broker dealer e.g. 2013-03-21
        :paran: fiscal_y (type str)
            The fiscal year for the balance sheet to cover e.g. 2012 (usually 1-year prior to filing date)
        :paran: cik (type str)
            The CIK number for a broker dealer e.g. 887767
        :paran: cik2name (type dict)
            A dictionary that maps CIK to Broker Deale names 
    Output:  
        :return: (type pandas.DataFrame)
             Return a transposed dataframe with additional columns corresponding to filing data
    """
    
    # intialize the first column (line items)
    first_column = df.columns[0]
    
    # clean dataframe should be of size greater than 1
    if len(df.columns) > 1:
        
        # transpose split balance sheet figure (our line items are now columns for DataFrame)
        # we first groupby the first column (this become index) and sum to group congruent names
        row = df.groupby(first_column).sum(min_count=1).T
        
        # creating additional columns in row
        row['CIK'] = cik                                  # CIK number for firm 
        row['Filing Date'] = filing_d                     # Filing Date for firm filing
        row['Filing Year'] = fiscal_y                     # Year for balance sheet filing
        row['Name'] = cik2name['broker-dealers'][cik]     # returns the name of associated with the CIK
        
        return row
    
    else:
        print('{}-{}.csv - encountered issue reading PDF'.format(cik, filing_d))
        return None

# %%
def extra_cols(csv_name:str):
    """
    Check to see whether their exists the presence of a total term from the line items
    ------------------------------------------------------------------------------------------
    Input:
        :param: csv_name (type str)
            The file directory on the s3 where data is stored (e.g. )
    Output:  
        :return: (type tuple)
            Returns a tuple for corresponding (file_name, filing_date, fiscal_year, cik)
    """
    
    file_name = csv_name.split('/')[-1]        # e.g. '1224385-2005-03-01.csv'
    csv_strip = file_name[:-4]                 # ignore last four elements from the back (i.e. .csv)

    # construct a string measure of important data measures 
    data_split = csv_strip.split('-')              
    filing_date = '-'.join(data_split[1:])         # join YYYY-mm-dd component for filing date
    fiscal_year = int(data_split[1]) - 1           # fiscal year are generally the previous year of filing
    cik = data_split[0]                            # extract the CIK number  
    
    return (file_name, filing_date, fiscal_year, cik)

# %%
def reorder_columns(df:pd.DataFrame, col_preserve:list) -> pd.DataFrame:
    """
    Re-order the completed DataFrame by ordering the CIK, Name, Filing Data and Filing Year 
    ------------------------------------------------------------------------------------------
    Input:
        :param: df (type pandas.DataFrame)
            The unstructured database for balance sheet figures
    Output:  
        :return: (type pandas.DataFrame)
            Return a dataframe with dimensions less than or equal to input dataframe (MxN) -> (MxK), 
            where K <= N
    """
    # re-order the CIK and Year columns to appear as the first two columns
    remap = df.columns[~np.isin(df.columns, col_preserve)]                             
    df = df[np.insert(remap,                                       # pass all other columns, not in preserve list
                      np.zeros(len(col_preserve), dtype=int),      # map the location to the first index (i.e. 0)
                      col_preserve)]                               # insert columns we wished to preserve 

    filterNaN = df.isnull().all()                      # find if any column is all NaN 
    cleanCols = filterNaN[filterNaN == False].index    # select columns with at least one value

    # clean dataframe for unstructured asset terms
    return df[cleanCols]

# %% [markdown]
# ## Final Main Execution

# %%
if __name__ == "__main__":
    
    # initiate s3 bucket and corresponding data folder
    bucket = "ran-s3-systemic-risk"
    
    pdf_asset_folder = "Output/X-17A-5-SPLIT-PDFS/Assets/"
    pdf_liable_folder = "Output/X-17A-5-SPLIT-PDFS/Liability & Equity/"
    
    png_asset_folder = "Output/X-17A-5-SPLIT-PNGS/Assets/"
    png_liable_folder = "Output/X-17A-5-SPLIT-PNGS/Liability & Equity/"
    
    out_folder = "Output/"

    # Amazon Textract client and Sagemaker session
    s3 = boto3.client('s3')
    session = Session()
    
    # ==============================================================================
    # ALL TEMPORARY FILE INFORMATION 
    # ==============================================================================
    # retrieving CIK-Dealers JSON file from s3 bucket
    s3.download_file(bucket, 'Temp/CIKandDealers.json', 'temp.json')
    with open('temp.json', 'r') as f: cik2brokers = json.loads(f.read())

    # remove local file after it has been created (variable is stored in memory)
    os.remove('temp.json')
    # ==============================================================================
    
    # s3 paths where asset and liability paths are stored
    asset_paths = session.list_s3_files(bucket, pdf_asset_folder)
    liable_paths = session.list_s3_files(bucket, pdf_liable_folder)
    
    # intialize list to store dataframes for asset and liability & equity
    asset_concat = [0] * len(asset_paths)
    liable_concat = [0] * len(liable_paths)
    
    # --------------------------------------------
    # Asset Unstructured Database
    # --------------------------------------------
    print('Assets Unstructured Database')
    for idx, csv in enumerate(asset_paths):
        
        # decompose csv name into corresponding terms
        fileName, filing_date, fiscal_year, cik = extra_cols(csv)
        
        # first load in both the PNG and PDF split balance sheets
        # NOTE: All these balance sheets are cleaned numerical values
        try:
            s3.download_file(bucket, csv, 'temp.csv')
            pdf_df = pd.read_csv('temp.csv')
            s3.download_file(bucket, png_asset_folder + fileName, 'temp.csv')
            png_df = pd.read_csv('temp.csv')
            os.remove('temp.csv')

            print('Working on {}-{}'.format(cik, filing_date))

            # do a special merge that combines unique line items names between PDF & PNG
            temp_df1 = special_merge(pdf_df, png_df, '0')

            # run accounting check to remove sub-totals for each respective line-item
            df, total_flag, total_amt = totals_check(temp_df1)
            
            # construct row for the unstructured data frame 
            export_df = unstructured_data(df, filing_date, fiscal_year, cik, cik2brokers)
            
            # we have that no "total asset" figure was found
            if total_flag == 2:
                export_df["Total asset check"] = "Total asset not found"
                export_df["Total asset"] = total_amt

            # we have that "total asset" was found and matches
            elif total_flag == 1:
                export_df["Total asset check"] = "Total asset found & match"
                export_df["Total asset"] = total_amt

            # we have that "total asset" was found, but did not match correctly
            elif total_flag == 0:
                export_df["Total asset check"] = "Total asset found & no match"

            # stores the reported data frame 
            asset_concat[idx] = export_df
        
        # in the event we can't download file from s3 (i.e. does not exist, we ignore the )
        except botocore.exceptions.ClientError:
            
            # assign an empty DataFrame and print out error
            asset_concat[idx] = pd.DataFrame()
            
            print('\nCLIENT-ERROR: WE COULD NOT DOWNLOAD SPLIT DATA FOR {}\n'.format(fileName))
     
    print('\n\n\n\n')
        
    # --------------------------------------------
    # Liability & Equity Unstructured Database
    # --------------------------------------------
    print('\nLiability & Equity Unstructured Database')
    for idx, csv in enumerate(liable_paths):
        
        # decompose csv name into corresponding terms
        fileName, filing_date, fiscal_year, cik = extra_cols(csv)
        
        try:
            # first load in both the PNG and PDF split balance sheets
            # NOTE: All these balance sheets are cleaned numerical values
            s3.download_file(bucket, csv, 'temp.csv')
            pdf_df = pd.read_csv('temp.csv')
            s3.download_file(bucket, png_liable_folder + fileName, 'temp.csv')
            png_df = pd.read_csv('temp.csv')
            os.remove('temp.csv')

            print('Working on {}-{}'.format(cik, filing_date))

            # do a special merge that combines unique line items names between PDF & PNG
            temp_df1 = special_merge(pdf_df, png_df, '0')

            # run accounting check to remove sub-totals for each respective line-item
            df, total_flag, total_amt = totals_check(temp_df1)
            
            # construct row for the unstructured data frame 
            export_df = unstructured_data(df, filing_date, fiscal_year, cik, cik2brokers)
            
            # we have that no "total asset" figure was found
            if total_flag == 2:
                export_df["Total liabilities & shareholder's equity check"] = "Total liabilities & shareholder's equity not found"
                export_df["Total liabilities & shareholder's equity"] = total_amt

            # we have that "total asset" was found and matches
            elif total_flag == 1:
                export_df["Total liabilities & shareholder's equity check"] = "Total liabilities & shareholder's equity found & match"
                export_df["Total liabilities & shareholder's equity"] = total_amt
        
            # we have that "total asset" was found, but did not match correctly
            elif total_flag == 0:
                export_df["Total liabilities & shareholder's equity check"] = "Total liabilities & shareholder's equity found & no match"
                
            # stores the reported data frame 
            liable_concat[idx] = export_df
        
        # in the event we can't download file from s3 (i.e. does not exist, we ignore the )
        except botocore.exceptions.ClientError:
            
            # assign an empty DataFrame and print out error
            liable_concat[idx] = pd.DataFrame()
            
            print('\nCLIENT-ERROR: WE COULD NOT DOWNLOAD SPLIT DATA FOR {}\n'.format(fileName))
    
    # --------------------------------------------
    # Database exportation
    # --------------------------------------------
    
    # writing data frame to .csv file
    asset_df = pd.concat(asset_concat)        # asset dataframe combining all rows from 
    asset_df = reorder_columns(asset_df,      # re-order columns for dataframe
                               col_preserve=['CIK', 'Name', 'Filing Date', 'Filing Year', 
                                             'Total asset check'])      
    
    filename1 = 'unstructured_assets.csv'
    asset_df.to_csv(filename1, index=False)
    with open(filename1, 'rb') as data:
        s3.put_object(Bucket=bucket, Key=out_folder + filename1, Body=data)
    
    
    # writing data frame to .csv file
    liable_df = pd.concat(liable_concat)     
    liable_df = reorder_columns(liable_df, 
                                col_preserve=['CIK', 'Name', 'Filing Date', 'Filing Year', 
                                              "Total liabilities & shareholder's equity check"])    
    
    filename2 = 'unstructured_liable.csv'
    liable_df.to_csv(filename2, index=False)
    with open(filename2, 'rb') as data:
        s3.put_object(Bucket=bucket, Key=out_folder + filename2, Body=data)
    
    # remove local file after it has been created
    os.remove(filename1)
    os.remove(filename2)
    
    print('\nWe created an unstructured asset and liability & equity')
# Out:
# Assets Unstructured Database
# Working on 1146184-2004-03-01
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 1987636228.0, our lookback sum is 1987636228.0
# Working on 1146184-2006-03-01
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 5769615468.0, our lookback sum is 5769615468.0
# Working on 1146184-2007-02-26
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 5691263000.0, our lookback sum is 5691263000.0
# Working on 1146184-2008-02-29
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 6762481000.0, our lookback sum is 6762481000.0
# Working on 1146184-2009-03-02
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 12991558000.0, our lookback sum is 12991558000.0
#
# CLIENT-ERROR: WE COULD NOT DOWNLOAD SPLIT DATA FOR 1146184-2010-02-25.csv
#
#
# CLIENT-ERROR: WE COULD NOT DOWNLOAD SPLIT DATA FOR 1146184-2011-02-25.csv
#
# Working on 1146184-2012-02-28
# 	We dropped row 13, Total assets, with lookback window of 13.
# 		Our row is valued at 33246026000.0, our lookback sum is 33246026000.0
# Working on 1146184-2015-02-25
# 	We dropped row 13, Total assets, with lookback window of 13.
# 		Our row is valued at 45458849000.0, our lookback sum is 45458849000.0
# Working on 1146184-2016-02-24
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 8853632000.0, our lookback sum is 8853632000.0
# Working on 1146184-2017-02-24
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 12110284000.0, our lookback sum is 12110284000.0
# Working on 1146184-2019-02-28
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 34932000000.0, our lookback sum is 34932000000.0
# Working on 1146184-2021-02-25
# Working on 1215680-2004-03-01
# 	We dropped row 4, Total assets, with lookback window of 4.
# 		Our row is valued at 660165.0, our lookback sum is 660165.0
# Working on 1215680-2005-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 6833103845.0, our lookback sum is 6833103845.0
# Working on 1215680-2006-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 10164674966.0, our lookback sum is 10164674966.0
# Working on 1215680-2007-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 1189531821.0, our lookback sum is 1189531821.0
# Working on 1215680-2008-02-29
# 	We dropped row 5, Total assets, with lookback window of 5.
# 		Our row is valued at 2027297075.0, our lookback sum is 2027297075.0
# Working on 1215680-2009-03-04
# 	We dropped row 5, Total assets, with lookback window of 5.
# 		Our row is valued at 4875259611.0, our lookback sum is 4875259611.0
# Working on 1215680-2010-02-26
# 	We dropped row 6, Total assets, with lookback window of 6.
# 		Our row is valued at 5770112344.0, our lookback sum is 5770112344.0
# Working on 1215680-2011-03-01
# 	We dropped row 5, Total assets, with lookback window of 5.
# 		Our row is valued at 8377662236.0, our lookback sum is 8377662236.0
# Working on 1215680-2012-02-29
# 	We dropped row 5, Total assets, with lookback window of 5.
# 		Our row is valued at 12172524773.0, our lookback sum is 12172524773.0
# Working on 1215680-2013-03-01
# 	We dropped row 4, Total assets, with lookback window of 4.
# 		Our row is valued at 13703935385.0, our lookback sum is 13703935385.0
# Working on 1215680-2014-02-28
# 	We dropped row 6, Total assets, with lookback window of 6.
# 		Our row is valued at 19280252621.0, our lookback sum is 19280252621.0
# Working on 1215680-2015-02-27
# 	We dropped row 6, Total assets, with lookback window of 6.
# 		Our row is valued at 21364270780.0, our lookback sum is 21364270780.0
# Working on 1215680-2016-06-16
# 	We dropped row 6, Total assets, with lookback window of 6.
# 		Our row is valued at 25345649106.0, our lookback sum is 25345649106.0
# Working on 1215680-2017-03-07
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 29267976468.0, our lookback sum is 29267976468.0
# Working on 1215680-2018-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 32007204693.0, our lookback sum is 32007204693.0
# Working on 1215680-2019-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 35316268917.0, our lookback sum is 35316268917.0
# Working on 1215680-2020-03-02
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 39779281667.0, our lookback sum is 39779281667.0
# Working on 1215680-2021-03-02
# 	We dropped row 6, Total assets, with lookback window of 6.
# 		Our row is valued at 35824538684.0, our lookback sum is 35824538684.0
# Working on 1224385-2004-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 21509787000.0, our lookback sum is 21509787000.0
# Working on 1224385-2005-03-01
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 35611655000.0, our lookback sum is 35611655000.0
# Working on 1224385-2006-03-01
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 24029490000.0, our lookback sum is 24029490000.0
# Working on 1224385-2007-03-01
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 20879923000.0, our lookback sum is 20879923000.0
# Working on 1224385-2008-02-29
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 21660817000.0, our lookback sum is 21660817000.0
# Working on 1224385-2009-03-02
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 9580535000.0, our lookback sum is 9580535000.0
# Working on 1224385-2010-03-12
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 17499658000.0, our lookback sum is 17499658000.0
# Working on 1224385-2011-03-01
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 37609933000.0, our lookback sum is 37609933000.0
# Working on 1224385-2012-02-29
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 39534067000.0, our lookback sum is 39534067000.0
# Working on 1224385-2013-03-01
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 43524084000.0, our lookback sum is 43524084000.0
# Working on 1224385-2014-03-04
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 48144895000.0, our lookback sum is 48144895000.0
# Working on 1224385-2015-03-02
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 64835741000.0, our lookback sum is 64835741000.0
# Working on 1224385-2016-02-29
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 90531855000.0, our lookback sum is 90531855000.0
# Working on 1224385-2017-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 112940487000.0, our lookback sum is 112940487000.0
# Working on 1224385-2018-02-28
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 131402200000.0, our lookback sum is 131402200000.0
# Working on 1224385-2019-02-28
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 134323969000.0, our lookback sum is 134323969000.0
# Working on 1224385-2020-02-28
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 141834542000.0, our lookback sum is 141834542000.0
# Working on 1224385-2021-02-26
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 132758281000.0, our lookback sum is 132758281000.0
# Working on 1261467-2005-03-08
# 	We dropped row 4, Total securities owned, with lookback window of 2.
# 		Our row is valued at 556328000.0, our lookback sum is 556328000.0
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 28698599000.0, our lookback sum is 28698599000.0
# Working on 1261467-2006-03-01
# 	We dropped row 14, Total assets, with lookback window of 14.
# 		Our row is valued at 36936239000.0, our lookback sum is 36936239000.0
# Working on 1261467-2007-03-02
# 	We dropped row 4, Total securities owned, with lookback window of 2.
# 		Our row is valued at 6369731000.0, our lookback sum is 6369731000.0
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 31397420000.0, our lookback sum is 31397420000.0
# Working on 1261467-2008-02-29
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 8289560000.0, our lookback sum is 8289560000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 26950162000.0, our lookback sum is 26950162000.0
# Working on 1261467-2009-03-02
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 2950385000.0, our lookback sum is 2950385000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 11333700000.0, our lookback sum is 11333700000.0
# Working on 1261467-2010-03-01
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 6662217000.0, our lookback sum is 6662217000.0
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 22195196000.0, our lookback sum is 22195196000.0
# Working on 1261467-2011-03-01
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 10402497000.0, our lookback sum is 10402497000.0
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 30724823000.0, our lookback sum is 30724823000.0
# Working on 1261467-2012-02-29
# 	We dropped row 10, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 9204567000.0, our lookback sum is 9204567000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 35194155000.0, our lookback sum is 35194155000.0
# Working on 1261467-2013-03-01
# 	We dropped row 10, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 10318858000.0, our lookback sum is 10318858000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 36449925000.0, our lookback sum is 36449925000.0
# Working on 1261467-2014-03-04
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 15475995000.0, our lookback sum is 15475995000.0
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 54564461000.0, our lookback sum is 54564461000.0
# Working on 1261467-2015-03-02
# 	We dropped row 10, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 21121732000.0, our lookback sum is 21121732000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 58687129000.0, our lookback sum is 58687129000.0
# Working on 1261467-2016-03-01
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 5658215000.0, our lookback sum is 5658215000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 138124790000.0, our lookback sum is 38124790000.0
# Working on 1261467-2017-03-01
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 5253851000.0, our lookback sum is 5253851000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 36077236000.0, our lookback sum is 36077236000.0
# Working on 1261467-2018-02-28
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 5544847000.0, our lookback sum is 5544847000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 37009152000.0, our lookback sum is 37009152000.0
# Working on 1261467-2018-04-13
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 5544847000.0, our lookback sum is 5544847000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 37009152000.0, our lookback sum is 37009152000.0
# Working on 1261467-2019-03-01
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 6038317000.0, our lookback sum is 6038317000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 33307686000.0, our lookback sum is 33307686000.0
# Working on 1261467-2021-03-01
# 	We dropped row 9, Total financial instruments owned - at fair value, with lookback window of 2.
# 		Our row is valued at 2751127000.0, our lookback sum is 2751127000.0
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 28853311000.0, our lookback sum is 28853311000.0
# Working on 1591458-2015-02-20
# 	We dropped row 3, Total assets, with lookback window of 3.
# 		Our row is valued at 269774.0, our lookback sum is 269774.0
# Working on 1591458-2018-02-28
# 	We dropped row 5, Total assets, with lookback window of 5.
# 		Our row is valued at 14104502591.0, our lookback sum is 14104502591.0
# Working on 1591458-2019-02-28
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 35680380911.0, our lookback sum is 35680380911.0
# Working on 1591458-2020-02-28
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 43693577132.0, our lookback sum is 43693577132.0
# Working on 1591458-2021-02-26
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 15489295354.0, our lookback sum is 15489295354.0
# Working on 1616344-2016-02-24
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 33570642000.0, our lookback sum is 33570642000.0
# Working on 1616344-2017-02-24
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 35298086000.0, our lookback sum is 35298086000.0
# Working on 1616344-2019-02-28
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 40109749000.0, our lookback sum is 40109749000.0
# Working on 1616344-2020-02-27
# Working on 1616344-2021-02-25
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 15555929000.0, our lookback sum is 15555929000.0
# Working on 230611-2002-03-01
# Working on 230611-2003-03-03
# Working on 230611-2004-03-01
# Working on 230611-2005-03-01
# Working on 230611-2006-03-01
# Working on 230611-2007-03-01
# 	We dropped row 7, Total securities owned, with lookback window of 2.
# 		Our row is valued at 153341587000.0, our lookback sum is 153341587000.0
# Working on 230611-2008-02-29
# 	We dropped row 7, Total securities owned, with lookback window of 2.
# 		Our row is valued at 156300052000.0, our lookback sum is 156300052000.0
# Working on 230611-2009-03-02
# 	We dropped row 7, Total securities owned, with lookback window of 2.
# 		Our row is valued at 54970626000.0, our lookback sum is 54970626000.0
# Working on 230611-2009-03-09
# 	We dropped row 7, Total securities owned, with lookback window of 2.
# 		Our row is valued at 54970626000.0, our lookback sum is 54970626000.0
# Working on 230611-2011-03-01
# 	We dropped row 7, Total securities owned, with lookback window of 2.
# 		Our row is valued at 49539508000.0, our lookback sum is 49539508000.0
# Working on 230611-2012-02-29
# 	We dropped row 7, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 40538873000.0, our lookback sum is 40538873000.0
# Working on 230611-2014-03-06
# 	We dropped row 8, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 12378935000.0, our lookback sum is 12378935000.0
# Working on 230611-2015-03-02
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 8512314000.0, our lookback sum is 8512314000.0
# Working on 230611-2016-02-29
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 6997687000.0, our lookback sum is 6997687000.0
# Working on 230611-2017-03-03
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 10651430000.0, our lookback sum is 10651430000.0
# Working on 230611-2018-03-01
# 	We dropped row 9, Total securities owned, at fair value, with lookback window of 2.
# 		Our row is valued at 10339029000.0, our lookback sum is 10339029000.0
# Working on 230611-2020-03-03
# 	We dropped row 9, Total financial instruments, at fair value, with lookback window of 2.
# 		Our row is valued at 7354824000.0, our lookback sum is 7354824000.0
# Working on 230611-2021-03-01
# 	We dropped row 9, Total financial instruments, at fair value, with lookback window of 2.
# 		Our row is valued at 9424271000.0, our lookback sum is 9424271000.0
# Working on 26617-2002-05-30
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 12964589.0, our lookback sum is 12964589.0
# Working on 26617-2003-06-02
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 14870817000.0, our lookback sum is 14870817000.0
# Working on 26617-2004-05-27
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 17911077000.0, our lookback sum is 17911077000.0
# Working on 26617-2005-05-26
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 19437929000.0, our lookback sum is 19437929000.0
# Working on 26617-2006-05-26
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 23998473000.0, our lookback sum is 23998473000.0
# Working on 26617-2007-05-29
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 28323064000.0, our lookback sum is 28323064000.0
# Working on 26617-2008-05-29
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 29338110000.0, our lookback sum is 29338110000.0
# Working on 26617-2009-05-29
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 22727925000.0, our lookback sum is 22727925000.0
# Working on 26617-2009-06-08
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 22727925000.0, our lookback sum is 22727925000.0
# Working on 26617-2010-05-28
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 24996117000.0, our lookback sum is 24996117000.0
# Working on 26617-2011-05-31
# 	We dropped row 13, Total assets, with lookback window of 13.
# 		Our row is valued at 38578500000.0, our lookback sum is 38578500000.0
# Working on 26617-2012-05-30
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 36092691000.0, our lookback sum is 36092691000.0
# Working on 26617-2013-05-30
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 43433164000.0, our lookback sum is 43433164000.0
# Working on 26617-2014-05-29
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 36925152000.0, our lookback sum is 36925152000.0
# Working on 26617-2015-06-01
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 42113496000.0, our lookback sum is 42113496000.0
# Working on 26617-2016-05-31
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 43278888000.0, our lookback sum is 43278888000.0
# Working on 26617-2017-05-30
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 39072121000.0, our lookback sum is 39072121000.0
# Working on 26617-2018-05-30
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 40167338000.0, our lookback sum is 40167338000.0
# Working on 26617-2019-05-30
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 49857320000.0, our lookback sum is 49857320000.0
# Working on 26617-2020-06-01
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 48687833000.0, our lookback sum is 48687833000.0
# Working on 29648-2003-03-03
# 	We dropped row 14, Total Assets, with lookback window of 14.
# 		Our row is valued at 10048000000.0, our lookback sum is 10048000000.0
# Working on 29648-2004-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 14323000000.0, our lookback sum is 14323000000.0
# Working on 29648-2005-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 12274000000.0, our lookback sum is 12274000000.0
# Working on 29648-2006-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 12201000000.0, our lookback sum is 12201000000.0
# Working on 29648-2007-03-01
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 11467000000.0, our lookback sum is 11467000000.0
# Working on 29648-2008-02-29
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 12186000000.0, our lookback sum is 12186000000.0
# Working on 29648-2008-04-07
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 12186000000.0, our lookback sum is 12186000000.0
# Working on 29648-2008-05-13
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 12186000000.0, our lookback sum is 12186000000.0
# Working on 29648-2009-03-02
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 15801000000.0, our lookback sum is 15801000000.0
# Working on 29648-2010-03-01
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 16950000000.0, our lookback sum is 16950000000.0
# Working on 29648-2011-03-01
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 18752000000.0, our lookback sum is 18752000000.0
# Working on 29648-2011-03-30
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 18752000000.0, our lookback sum is 18752000000.0
# Working on 29648-2012-02-29
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 21808000000.0, our lookback sum is 21808000000.0
# Working on 29648-2013-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 26494000000.0, our lookback sum is 26494000000.0
# Working on 29648-2014-02-28
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 26509000000.0, our lookback sum is 26509000000.0
# Working on 29648-2015-03-02
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 33626000000.0, our lookback sum is 33626000000.0
# Working on 29648-2016-02-29
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 32138000000.0, our lookback sum is 32138000000.0
# Working on 29648-2017-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 32450000000.0, our lookback sum is 32450000000.0
# Working on 29648-2018-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 32411000000.0, our lookback sum is 32411000000.0
# Working on 29648-2019-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 33005000000.0, our lookback sum is 33005000000.0
# Working on 29648-2021-02-26
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 36226000000.0, our lookback sum is 36226000000.0
# Working on 318336-2003-03-03
# 	We dropped row 16, Total Assets, with lookback window of 16.
# 		Our row is valued at 185695000000.0, our lookback sum is 185695000000.0
# Working on 318336-2004-02-27
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 202633000000.0, our lookback sum is 202633000000.0
# Working on 318336-2004-04-07
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 202603000000.0, our lookback sum is 202603000000.0
# Working on 318336-2005-03-01
# 	We dropped row 9, Commercial paper, with lookback window of 1.
# 		Our row is valued at 1171000000.0, our lookback sum is 1172000000.0
# Working on 318336-2006-03-01
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 238894000000.0, our lookback sum is 238894000000.0
# Working on 318336-2007-03-01
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 269834000000.0, our lookback sum is 269834000000.0
# Working on 318336-2008-03-26
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 326437000000.0, our lookback sum is 326437000000.0
# Working on 318336-2009-03-02
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 326348000000.0, our lookback sum is 326348000000.0
# Working on 318336-2010-03-03
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 292388000000.0, our lookback sum is 292388000000.0
# Working on 318336-2011-03-01
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 312685000000.0, our lookback sum is 312685000000.0
# Working on 318336-2012-02-29
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 309495000000.0, our lookback sum is 309495000000.0
# Working on 318336-2013-03-01
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 292165000000.0, our lookback sum is 292165000000.0
# Working on 318336-2014-03-05
# 	We dropped row 13, Total assets, with lookback window of 13.
# 		Our row is valued at 275929000000.0, our lookback sum is 275929000000.0
# Working on 318336-2015-03-02
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 272892000000.0, our lookback sum is 272892000000.0
# Working on 318336-2016-02-29
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 204426000000.0, our lookback sum is 204426000000.0
# Working on 318336-2017-03-06
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 175116000000.0, our lookback sum is 175116000000.0
# Working on 318336-2018-03-01
# 	We dropped row 7, Customers, with lookback window of 3.
# 		Our row is valued at 13482000000.0, our lookback sum is 13489000000.0
# Working on 318336-2019-03-08
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 87452000000.0, our lookback sum is 87452000000.0
# Working on 318336-2020-02-28
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 81039000000.0, our lookback sum is 81039000000.0
# Working on 318336-2021-03-01
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 85954000000.0, our lookback sum is 85954000000.0
# Working on 356628-2002-02-25
# 	We dropped row 9, TOTAL ASSETS, with lookback window of 9.
# 		Our row is valued at 16547927000.0, our lookback sum is 16547927000.0
# Working on 356628-2003-02-24
# 	We dropped row 9, TOTAL ASSETS, with lookback window of 9.
# 		Our row is valued at 14238465000.0, our lookback sum is 14238465000.0
# Working on 356628-2004-03-01
# 	We dropped row 9, TOTAL ASSETS, with lookback window of 9.
# 		Our row is valued at 17280613000.0, our lookback sum is 17280613000.0
# Working on 356628-2005-03-01
# 	We dropped row 9, TOTAL ASSETS, with lookback window of 9.
# 		Our row is valued at 20668315000.0, our lookback sum is 20668315000.0
# Working on 356628-2006-03-02
# Working on 356628-2007-03-01
# Working on 356628-2008-02-29
# Working on 356628-2009-03-02
# 	We dropped row 10, TOTAL ASSETS, with lookback window of 10.
# 		Our row is valued at 31035621000.0, our lookback sum is 31035621000.0
# Working on 356628-2010-06-11
# 	We dropped row 10, TOTAL ASSETS, with lookback window of 10.
# 		Our row is valued at 34306797000.0, our lookback sum is 34306797000.0
# Working on 356628-2011-03-02
# 	We dropped row 7, Total receivables, with lookback window of 3.
# 		Our row is valued at 10322075000.0, our lookback sum is 10322075000.0
# 	We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 		Our row is valued at 43615653000.0, our lookback sum is 43615653000.0
# Working on 356628-2012-02-27
# 	We dropped row 7, Total Receivables, with lookback window of 3.
# 		Our row is valued at 10358000000.0, our lookback sum is 10358000000.0
# 	We dropped row 11, Total Assets, with lookback window of 11.
# 		Our row is valued at 54948000000.0, our lookback sum is 54948000000.0
# Working on 356628-2013-02-25
# 	We dropped row 7, Total receivables, with lookback window of 2.
# 		Our row is valued at 11907000000.0, our lookback sum is 11907000000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 68698000000.0, our lookback sum is 68698000000.0
# Working on 356628-2014-02-21
# 	We dropped row 7, Total receivables, with lookback window of 2.
# 		Our row is valued at 13860000000.0, our lookback sum is 13860000000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 77187000000.0, our lookback sum is 77187000000.0
# Working on 356628-2015-02-26
# 	We dropped row 8, Total receivables, with lookback window of 3.
# 		Our row is valued at 16229000000.0, our lookback sum is 16229000000.0
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 86919000000.0, our lookback sum is 86919000000.0
# Working on 356628-2016-02-24
# 	We dropped row 7, Total receivables, with lookback window of 3.
# 		Our row is valued at 17012000000.0, our lookback sum is 17012000000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 94086000000.0, our lookback sum is 94086000000.0
# Working on 356628-2017-02-24
# 	We dropped row 7, Total receivables, with lookback window of 2.
# 		Our row is valued at 17446000000.0, our lookback sum is 17446000000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 93659000000.0, our lookback sum is 93659000000.0
# Working on 356628-2019-02-25
# 	We dropped row 6, Total receivables, with lookback window of 2.
# 		Our row is valued at 23235000000.0, our lookback sum is 23235000000.0
# 	We dropped row 9, Total Assets, with lookback window of 9.
# 		Our row is valued at 73211000000.0, our lookback sum is 73211000000.0
# Working on 356628-2021-02-25
# 	We dropped row 6, Total receivables, with lookback window of 2.
# 		Our row is valued at 32137000000.0, our lookback sum is 32137000000.0
# 	We dropped row 9, Total Assets, with lookback window of 9.
# 		Our row is valued at 89437000000.0, our lookback sum is 89437000000.0
# Working on 42352-2002-01-30
# Working on 42352-2003-01-28
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 40528247000.0, our lookback sum is 40528247000.0
# Working on 42352-2004-01-27
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 53321469000.0, our lookback sum is 53321469000.0
# Working on 42352-2005-01-25
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 65452780000.0, our lookback sum is 65452780000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 348590977000.0, our lookback sum is 348590977000.0
# Working on 42352-2006-01-24
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 106354891000.0, our lookback sum is 106354891000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 475872139000.0, our lookback sum is 475872139000.0
# Working on 42352-2007-01-23
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 105900570000.0, our lookback sum is 105900570000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 509250736000.0, our lookback sum is 509250736000.0
# Working on 42352-2008-01-29
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 118741785000.0, our lookback sum is 118741785000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 632858770000.0, our lookback sum is 632858770000.0
# Working on 42352-2010-03-01
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 132743000000.0, our lookback sum is 132743000000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 463755000000.0, our lookback sum is 463755000000.0
# Working on 42352-2011-03-01
# Working on 42352-2012-02-29
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 2.
# 		Our row is valued at 143357000000.0, our lookback sum is 143357000000.0
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 504694000000.0, our lookback sum is 504694000000.0
# Working on 42352-2013-03-01
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 501095000000.0, our lookback sum is 501095000000.0
# Working on 42352-2014-07-31
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 524526000000.0, our lookback sum is 524516000000.0
# Working on 42352-2015-03-10
# Working on 42352-2016-02-23
# 	We dropped row 8, Total assets, with lookback window of 8.
# 		Our row is valued at 454751000000.0, our lookback sum is 454751000000.0
# Working on 42352-2017-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 424849000000.0, our lookback sum is 424649000000.0
# Working on 42352-2018-02-27
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 453927000000.0, our lookback sum is 453927000000.0
# Working on 42352-2019-03-01
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 416665000000.0, our lookback sum is 416665000000.0
# Working on 42352-2021-02-25
# 	We dropped row 7, Total assets, with lookback window of 7.
# 		Our row is valued at 507647000000.0, our lookback sum is 507647000000.0
# Working on 58056-2002-03-01
# Working on 58056-2003-03-03
# Working on 58056-2004-02-27
# Working on 58056-2004-03-26
# Working on 58056-2005-02-25
# 	We dropped row 15, Total assets, with lookback window of 15.
# 		Our row is valued at 253278304000.0, our lookback sum is 253278304000.0
# Working on 58056-2006-03-24
# 	We dropped row 14, Total assets, with lookback window of 14.
# 		Our row is valued at 264444724000.0, our lookback sum is 264444714000.0
# Working on 58056-2007-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 317870722000.0, our lookback sum is 317870722000.0
# Working on 58056-2008-02-29
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 519780630000.0, our lookback sum is 519780630000.0
# Working on 58056-2009-03-16
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 244413278000.0, our lookback sum is 244413278000.0
# Working on 58056-2010-06-04
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 249693066000.0, our lookback sum is 249693066000.0
# Working on 58056-2012-02-29
# Working on 58056-2013-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 240046000000.0, our lookback sum is 240046000000.0
# Working on 58056-2014-03-04
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 227451000000.0, our lookback sum is 227451000000.0
# Working on 58056-2015-03-02
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 173638000000.0, our lookback sum is 173638000000.0
# Working on 58056-2016-02-29
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 160325000000.0, our lookback sum is 160325000000.0
# Working on 58056-2017-03-03
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 136083000000.0, our lookback sum is 136083000000.0
# Working on 58056-2018-03-12
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 108091000000.0, our lookback sum is 108091000000.0
# Working on 58056-2019-03-01
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 90946000000.0, our lookback sum is 90946000000.0
# Working on 58056-2019-09-30
# 	We dropped row 10, Total assets, with lookback window of 10.
# 		Our row is valued at 90946000000.0, our lookback sum is 90946000000.0
# Working on 58056-2020-03-02
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 80071000000.0, our lookback sum is 80071000000.0
# Working on 58056-2021-03-01
# 	We dropped row 9, Total assets, with lookback window of 9.
# 		Our row is valued at 72130000000.0, our lookback sum is 72130000000.0
# Working on 68136-2002-01-29
# 	We dropped row 15, Total assets, with lookback window of 15.
# 		Our row is valued at 267625461000.0, our lookback sum is 267625461000.0
# Working on 68136-2003-01-30
# 	We dropped row 15, Total assets, with lookback window of 15.
# 		Our row is valued at 265334256000.0, our lookback sum is 265334256000.0
# Working on 68136-2004-01-30
# 	We dropped row 15, Total assets, with lookback window of 15.
# 		Our row is valued at 310888679000.0, our lookback sum is 310888679000.0
# Working on 68136-2005-01-31
# Working on 68136-2006-01-30
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 501699713000.0, our lookback sum is 501699713000.0
# Working on 68136-2007-01-29
# 	We dropped row 16, Total assets, with lookback window of 16.
# 		Our row is valued at 583404825000.0, our lookback sum is 583404825000.0
# Working on 68136-2008-01-31
# 	We dropped row 19, Total assets, with lookback window of 19.
# 		Our row is valued at 604395450000.0, our lookback sum is 604395450000.0
# Working on 68136-2009-01-29
# 	We dropped row 19, Total assets, with lookback window of 19.
# 		Our row is valued at 297422286000.0, our lookback sum is 297422286000.0
# Working on 68136-2010-03-02
# 	We dropped row 8, Total financial instruments owned. at fair value, with lookback window of 6.
# 		Our row is valued at 86343225000.0, our lookback sum is 86343225000.0
# 	We dropped row 20, Total assets, with lookback window of 20.
# 		Our row is valued at 413032207000.0, our lookback sum is 413032207000.0
# Working on 68136-2011-03-02
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 6.
# 		Our row is valued at 99110027000.0, our lookback sum is 99110027000.0
# 	We dropped row 20, Total assets, with lookback window of 20.
# 		Our row is valued at 372537340000.0, our lookback sum is 372537340000.0
# Working on 68136-2012-02-29
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 6.
# 		Our row is valued at 94766842000.0, our lookback sum is 94766842000.0
# 	We dropped row 20, Total assets, with lookback window of 20.
# 		Our row is valued at 352293126000.0, our lookback sum is 352293126000.0
# Working on 68136-2013-03-01
# 	We dropped row 8, Total financial instruments owned, at fair value, with lookback window of 6.
# 		Our row is valued at 90227260000.0, our lookback sum is 90227260000.0
# 	We dropped row 20, Section Total assets, with lookback window of 20.
# 		Our row is valued at 369066424000.0, our lookback sum is 369066424000.0
# Working on 68136-2014-03-04
# 	We dropped row 14, Total assets, with lookback window of 14.
# 		Our row is valued at 367496000000.0, our lookback sum is 367496000000.0
# Working on 68136-2015-03-02
# 	We dropped row 14, Total assets, with lookback window of 14.
# 		Our row is valued at 345134000000.0, our lookback sum is 345134000000.0
# Working on 68136-2016-02-29
# 	We dropped row 13, Total assets, with lookback window of 13.
# 		Our row is valued at 301341000000.0, our lookback sum is 301341000000.0
# Working on 68136-2017-03-01
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 308038000000.0, our lookback sum is 308038000000.0
# Working on 68136-2018-03-01
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 305281000000.0, our lookback sum is 305281000000.0
# Working on 68136-2019-03-01
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 303806000000.0, our lookback sum is 303806000000.0
# Working on 68136-2021-02-26
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 409239000000.0, our lookback sum is 409239000000.0
# Working on 72267-2003-05-30
# 	We dropped row 8, Receivables:, with lookback window of 4.
# 		Our row is valued at 15993366000.0, our lookback sum is 15993366000.0
# 	We dropped row 15, Total assets, with lookback window of 15.
# 		Our row is valued at 57702809000.0, our lookback sum is 57702809000.0
# Working on 72267-2004-05-28
# 	We dropped row 4, Financial instruments owned (approximately $10,900,474 were, with lookback window of 2.
# 		Our row is valued at 44343153000.0, our lookback sum is 44343153000.0
# 	We dropped row 9, Receivables:, with lookback window of 4.
# 		Our row is valued at 17731470000.0, our lookback sum is 17731470000.0
# 	We dropped row 13, Furniture, equipment and leasehold improvements, net of, with lookback window of 3.
# 		Our row is valued at 535815000.0, our lookback sum is 535815000.0
# Working on 72267-2005-05-31
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 78732111000.0, our lookback sum is 78732111000.0
# Working on 72267-2006-05-30
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 74182935000.0, our lookback sum is 74182935000.0
# Working on 72267-2007-05-29
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 87542832000.0, our lookback sum is 87542832000.0
# Working on 72267-2008-05-30
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 16266635000.0, our lookback sum is 16266635000.0
# Working on 72267-2009-06-03
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 14279792000.0, our lookback sum is 14279792000.0
# Working on 72267-2010-06-01
# 	We dropped row 4, Trading assets ($7,567,059 were pledged to, with lookback window of 2.
# 		Our row is valued at 36294531000.0, our lookback sum is 36294531000.0
# Working on 72267-2012-03-15
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 104827762000.0, our lookback sum is 104827762000.0
# Working on 72267-2012-05-30
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 114059495000.0, our lookback sum is 114059495000.0
# Working on 72267-2013-05-30
# Working on 72267-2014-05-30
# 	We dropped row 1, Cash and cash equivalents, with lookback window of 1.
# 		Our row is valued at 1426073000.0, our lookback sum is 1426073000.0
# 	We dropped row 5, Trading assets ($19,918,091 were pledged to various parties and $335,455 related to, with lookback window of 2.
# 		Our row is valued at 76177986000.0, our lookback sum is 76177986000.0
# Working on 72267-2015-06-01
# 	We dropped row 4, Trading assets ($16,658,256 were pledged to various parties and $437,502 related, with lookback window of 2.
# 		Our row is valued at 61224030000.0, our lookback sum is 61224030000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 108960337000.0, our lookback sum is 108960337000.0
# Working on 72267-2016-05-31
# 	We dropped row 4, Trading assets ($14,976,358 were pledged to various parties and $497,099 related, with lookback window of 2.
# 		Our row is valued at 60908405000.0, our lookback sum is 60908405000.0
# 	We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 		Our row is valued at 2548556000.0, our lookback sum is 2548556000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 117925405000.0, our lookback sum is 117925405000.0
# Working on 72267-2017-05-30
# 	We dropped row 4, Trading assets ($6,815,721 were pledged to various parties and $15,802 related, with lookback window of 2.
# 		Our row is valued at 81225612000.0, our lookback sum is 81225612000.0
# 	We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 		Our row is valued at 2230458000.0, our lookback sum is 2230458000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 141510330000.0, our lookback sum is 141510330000.0
# Working on 72267-2018-05-25
# 	We dropped row 8, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 		Our row is valued at 3117334000.0, our lookback sum is 3117334000.0
# 	We dropped row 11, Total assets, with lookback window of 11.
# 		Our row is valued at 141073948000.0, our lookback sum is 141073948000.0
# Working on 72267-2019-05-28
# 	We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 		Our row is valued at 2620041000.0, our lookback sum is 2620041000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 127542303000.0, our lookback sum is 127542303000.0
# Working on 72267-2020-06-01
# 	We dropped row 9, Furniture, equipment, leasehold improvements and software, net (includes, with lookback window of 3.
# 		Our row is valued at 5258229000.0, our lookback sum is 5258229000.0
# 	We dropped row 12, Total assets, with lookback window of 12.
# 		Our row is valued at 142473148000.0, our lookback sum is 142473148000.0
# Working on 782124-2002-01-29
# 	We dropped row 10, TOTAL ASSETS, with lookback window of 10.
# 		Our row is valued at 140655621000.0, our lookback sum is 140655621000.0
# Working on 782124-2003-01-30
# 	We dropped row 11, TOTAL ASSETS, with lookback window of 11.
# 		Our row is valued at 150559829000.0, our lookback sum is 150559829000.0
# Working on 782124-2004-01-30
# 	We dropped row 11, TOTAL ASSETS, with lookback window of 11.
# 		Our row is valued at 164601243000.0, our lookback sum is 164601243000.0
# Working on 782124-2004-05-07
# 	We dropped row 8, Net property and equipment, with lookback window of 3.
# 		Our row is valued at 107603000.0, our lookback sum is 107603000.0
# 	We dropped row 9, TOTAL ASSETS, with lookback window of 9.
# 		Our row is valued at 25673078000.0, our lookback sum is 25673078000.0
# Working on 782124-2005-01-31
# 	We dropped row 11, TOTAL ASSETS, with lookback window of 11.
# 		Our row is valued at 193433468000.0, our lookback sum is 193433468000.0
# Working on 782124-2006-01-30
# 	We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 		Our row is valued at 191806579000.0, our lookback sum is 191806579000.0
# Working on 782124-2007-01-29
# 	We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 		Our row is valued at 236190719000.0, our lookback sum is 236190719000.0
# Working on 782124-2008-01-31
# 	We dropped row 12, TOTAL ASSETS, with lookback window of 12.
# 		Our row is valued at 258125104000.0, our lookback sum is 258125104000.0
# Working on 782124-2009-03-02
# 	We dropped row 14, Total assets, with lookback window of 14.
# 		Our row is valued at 399544757000.0, our lookback sum is 399544757000.0
# Working on 782124-2010-03-01
# 	We dropped row 13, Total assets, with lookback window of 13.
# 		Our row is valued at 329205000000.0, our lookback sum is 329205000000.0
# Working on 782124-2011-03-02
# 	We dropped row 12, Total assets (*), with lookback window of 12.
# 		Our row is valued at 362019000000.0, our lookback sum is 362019000000.0
# Working on 782124-2012-02-29
# 	We dropped row 12, Total assets (a), with lookback window of 12.
# 		Our row is valued at 371293000000.0, our lookback sum is 371294000000.0
# Working on 782124-2013-03-01
# 	We dropped row 12, Total assets (a), with lookback window of 12.
# ...
# 	We dropped row 21, Total stockholder's equity, with lookback window of 3.
# 		Our row is valued at 10833000000.0, our lookback sum is 10823000000.0
# 	We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 		Our row is valued at 377951000000.0, our lookback sum is 377951000000.0
# Working on 91154-2008-02-29
# 	We dropped row 4, Financial instruments sold, not yet purchased, and, with lookback window of 2.
# 		Our row is valued at 205309000000.0, our lookback sum is 205309000000.0
# 	We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 		Our row is valued at 26313000000.0, our lookback sum is 26313000000.0
# 	We dropped row 16, Total liabilities, with lookback window of 16.
# 		Our row is valued at 354820000000.0, our lookback sum is 354820000000.0
# 	We dropped row 21, Total stockholder's equity, with lookback window of 3.
# 		Our row is valued at 8342000000.0, our lookback sum is 8332000000.0
# 	We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 		Our row is valued at 363162000000.0, our lookback sum is 363162000000.0
# Working on 91154-2009-03-02
# 	We dropped row 4, Financial instruments sold, not yet purchased, and, with lookback window of 2.
# 		Our row is valued at 167462000000.0, our lookback sum is 167462000000.0
# 	We dropped row 10, Other financial instruments, with lookback window of 1.
# 		Our row is valued at 125000000.0, our lookback sum is 124000000.0
# 	We dropped row 21, Total stockholder's equity, with lookback window of 3.
# 		Our row is valued at 6383000000.0, our lookback sum is 6373000000.0
# 	We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 6.
# 		Our row is valued at 286825000000.0, our lookback sum is 286825000000.0
# Working on 91154-2010-03-02
# 	We dropped row 2, Collateralized short-term financing agreements:, with lookback window of 2.
# 		Our row is valued at 56832000000.0, our lookback sum is 56832000000.0
# 	We dropped row 12, Payables and accrued liabilities:, with lookback window of 6.
# 		Our row is valued at 27328000000.0, our lookback sum is 27328000000.0
# 	We dropped row 18, Total liabilities, with lookback window of 18.
# 		Our row is valued at 296359000000.0, our lookback sum is 296359000000.0
# 	We dropped row 23, Total stockholder's equity, with lookback window of 3.
# 		Our row is valued at 17997000000.0, our lookback sum is 17987000000.0
# 	We dropped row 24, Total liabilities and stockholder's equity, with lookback window of 24.
# 		Our row is valued at 314356000000.0, our lookback sum is 314356000000.0
# Working on 91154-2011-03-01
# 	We dropped row 2, Collateralized short-term financing agreements:, with lookback window of 2.
# 		Our row is valued at 15835000000.0, our lookback sum is 15835000000.0
# 	We dropped row 5, Trading account liabilities:, with lookback window of 2.
# 		Our row is valued at 131419000000.0, our lookback sum is 131419000000.0
# 	We dropped row 12, Payables and accrued liabilities:, with lookback window of 6.
# 		Our row is valued at 27875000000.0, our lookback sum is 27875000000.0
# 	We dropped row 18, Total liabilities, with lookback window of 18.
# 		Our row is valued at 272389000000.0, our lookback sum is 272389000000.0
# 	We dropped row 23, Total stockholder's equity, with lookback window of 3.
# 		Our row is valued at 16020000000.0, our lookback sum is 16010000000.0
# 	We dropped row 24, Total liabilities and stockholder's equity, with lookback window of 24.
# 		Our row is valued at 288409000000.0, our lookback sum is 288409000000.0
# Working on 91154-2012-02-29
# 	We dropped row 4, Trading account liabilities:, with lookback window of 2.
# 		Our row is valued at 133872000000.0, our lookback sum is 133872000000.0
# 	We dropped row 11, Payables and accrued liabilities:, with lookback window of 6.
# 		Our row is valued at 25871000000.0, our lookback sum is 25871000000.0
# 	We dropped row 17, Total liabilities, with lookback window of 17.
# 		Our row is valued at 261317000000.0, our lookback sum is 261317000000.0
# 	We dropped row 21, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 7833000000.0, our lookback sum is 7823000000.0
# 	We dropped row 22, Total liabilities and stockholder's equity, with lookback window of 22.
# 		Our row is valued at 269150000000.0, our lookback sum is 269150000000.0
# Working on 91154-2013-03-01
# 	We dropped row 2, Collateralized short-term financing agreements:, with lookback window of 2.
# 		Our row is valued at 19943000000.0, our lookback sum is 19943000000.0
# 	We dropped row 5, Trading account liabilities:, with lookback window of 2.
# 		Our row is valued at 136775000000.0, our lookback sum is 136775000000.0
# 	We dropped row 12, Payables and accrued liabilities:, with lookback window of 6.
# 		Our row is valued at 20694000000.0, our lookback sum is 20694000000.0
# 	We dropped row 18, Total liabilities, with lookback window of 18.
# 		Our row is valued at 242830000000.0, our lookback sum is 242830000000.0
# 	We dropped row 22, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 8692000000.0, our lookback sum is 8682000000.0
# 	We dropped row 23, Total liabilities and stockholder's equity, with lookback window of 23.
# 		Our row is valued at 251522000000.0, our lookback sum is 251522000000.0
# Working on 91154-2014-03-04
# 	We dropped row 14, Total liabilities, with lookback window of 14.
# 		Our row is valued at 235464000000.0, our lookback sum is 235464000000.0
# 	We dropped row 19, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 9691000000.0, our lookback sum is 9681000000.0
# 	We dropped row 20, Total liabilities and stockholder's equity, with lookback window of 20.
# 		Our row is valued at 253600000000.0, our lookback sum is 253600000000.0
# Working on 91154-2016-03-01
# 	We dropped row 13, Total liabilities, with lookback window of 13.
# 		Our row is valued at 234329000000.0, our lookback sum is 234329000000.0
# 	We dropped row 18, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 9142000000.0, our lookback sum is 9132000000.0
# 	We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 		Our row is valued at 253416000000.0, our lookback sum is 253416000000.0
# Working on 91154-2017-03-02
# 	We dropped row 14, Total liabilities, with lookback window of 14.
# 		Our row is valued at 252450000000.0, our lookback sum is 252450000000.0
# 	We dropped row 18, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 9194000000.0, our lookback sum is 9184000000.0
# 	We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 		Our row is valued at 261644000000.0, our lookback sum is 261644000000.0
# Working on 91154-2018-03-05
# 	We dropped row 14, Total liabilities, with lookback window of 14.
# 		Our row is valued at 263529000000.0, our lookback sum is 263529000000.0
# 	We dropped row 18, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 9015000000.0, our lookback sum is 9005000000.0
# 	We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 		Our row is valued at 272544000000.0, our lookback sum is 272544000000.0
# Working on 91154-2019-03-05
# 	We dropped row 14, Total liabilities, with lookback window of 14.
# 		Our row is valued at 290048000000.0, our lookback sum is 290048000000.0
# 	We dropped row 18, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 8860000000.0, our lookback sum is 8850000000.0
# 	We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 		Our row is valued at 298908000000.0, our lookback sum is 298908000000.0
# Working on 91154-2020-03-02
# 	We dropped row 14, Total liabilities, with lookback window of 14.
# 		Our row is valued at 280372000000.0, our lookback sum is 280372000000.0
# 	We dropped row 18, Total stockholder's equity, with lookback window of 2.
# 		Our row is valued at 9073000000.0, our lookback sum is 9063000000.0
# 	We dropped row 19, Total liabilities and stockholder's equity, with lookback window of 19.
# 		Our row is valued at 289445000000.0, our lookback sum is 289445000000.0
# Working on 920417-2015-03-02
# 	We dropped row 8, Total liabilities, with lookback window of 8.
# 		Our row is valued at 29420949000.0, our lookback sum is 29420949000.0
# 	We dropped row 10, Total liabilities and partners' capital, with lookback window of 10.
# 		Our row is valued at 32452777000.0, our lookback sum is 32452777000.0
# Working on 920417-2016-02-29
# 	We dropped row 8, Total liabilities, with lookback window of 8.
# 		Our row is valued at 27903087000.0, our lookback sum is 27903087000.0
# 	We dropped row 10, Total liabilities and partners' capital, with lookback window of 10.
# 		Our row is valued at 31810325000.0, our lookback sum is 31810325000.0
# Working on 920417-2017-03-01
# 	We dropped row 8, Total liabilities, with lookback window of 8.
# 		Our row is valued at 26854961000.0, our lookback sum is 26854961000.0
# 	We dropped row 10, Total liabilities and partners' capital, with lookback window of 10.
# 		Our row is valued at 29809441000.0, our lookback sum is 29809441000.0
# Working on 920417-2018-02-27
# 	We dropped row 8, Total liabilities, with lookback window of 8.
# 		Our row is valued at 34672926000.0, our lookback sum is 34672926000.0
# 	We dropped row 10, Total liabilities and partners' capital, with lookback window of 10.
# 		Our row is valued at 38170352000.0, our lookback sum is 38170352000.0
# Working on 920417-2019-02-28
# 	We dropped row 7, Total liabilities, with lookback window of 7.
# 		Our row is valued at 38346263000.0, our lookback sum is 38346263000.0
# 	We dropped row 9, Total liabilities and partners' capital, with lookback window of 9.
# 		Our row is valued at 42507970000.0, our lookback sum is 42507970000.0
# Working on 920417-2020-02-28
# 	We dropped row 8, Total liabilities, with lookback window of 8.
# 		Our row is valued at 39466270000.0, our lookback sum is 39466270000.0
# 	We dropped row 10, Total liabilities and member's equity, with lookback window of 10.
# 		Our row is valued at 44032681000.0, our lookback sum is 44032681000.0
# Working on 920417-2021-03-01
# 	We dropped row 9, Total liabilities, with lookback window of 9.
# 		Our row is valued at 83173930000.0, our lookback sum is 83173930000.0
# 	We dropped row 11, Total liabilities and member's equity, with lookback window of 11.
# 		Our row is valued at 88247203000.0, our lookback sum is 88247203000.0
# Working on 922792-2002-03-04
# 	We dropped row 3, Total liabilities, with lookback window of 3.
# 		Our row is valued at 246399753.0, our lookback sum is 246399753.0
# 	We dropped row 5, TOTAL LIABILITIES AND MEMBERS' CAPITAL, with lookback window of 5.
# 		Our row is valued at 313922089.0, our lookback sum is 313922089.0
# Working on 922792-2003-03-03
# 	We dropped row 5, Total liabilities, with lookback window of 5.
# 		Our row is valued at 558604237.0, our lookback sum is 558604237.0
# 	We dropped row 7, TOTAL LIABILITIES AND MEMBERS' CAPITAL, with lookback window of 7.
# 		Our row is valued at 664292626.0, our lookback sum is 664292626.0
# Working on 922792-2004-03-01
# 	We dropped row 5, Total liabilities, with lookback window of 5.
# 		Our row is valued at 1097272438.0, our lookback sum is 1097272438.0
# 	We dropped row 7, TOTAL LIABILITIES AND MEMBERS' CAPITAL, with lookback window of 7.
# 		Our row is valued at 1247968829.0, our lookback sum is 1247968829.0
# Working on 922792-2005-03-01
# 	We dropped row 4, Total liabilities, with lookback window of 4.
# 		Our row is valued at 1569877542.0, our lookback sum is 1569877542.0
# 	We dropped row 6, TOTAL LIABILITIES AND MEMBERS' CAPITAL, with lookback window of 6.
# 		Our row is valued at 1764275076.0, our lookback sum is 1764275076.0
# Working on 922792-2006-03-01
# 	We dropped row 4, Total liabilities, with lookback window of 4.
# 		Our row is valued at 2509137371.0, our lookback sum is 2509137371.0
# 	We dropped row 6, TOTAL LIABILITIES AND MEMBERS' CAPITAL, with lookback window of 6.
# 		Our row is valued at 2759809118.0, our lookback sum is 2759809118.0
# Working on 922792-2007-03-01
# 	We dropped row 6, Total liabilities and members' capital, with lookback window of 6.
# 		Our row is valued at 4536097237.0, our lookback sum is 4536097237.0
# Working on 922792-2008-02-29
# 	We dropped row 9, Total liabilities and members' capital, with lookback window of 9.
# 		Our row is valued at 8676028952.0, our lookback sum is 8676028952.0
# Working on 922792-2009-03-02
# 	We dropped row 8, Total liabilities and members' capital, with lookback window of 8.
# 		Our row is valued at 7996500333.0, our lookback sum is 7996500333.0
# Working on 922792-2010-03-02
# 	We dropped row 7, Total liabilities and members' capital, with lookback window of 7.
# 		Our row is valued at 12069674947.0, our lookback sum is 12069674947.0
# Working on 922792-2012-02-29
# 	We dropped row 8, Total liabilities and members' capital, with lookback window of 8.
# 		Our row is valued at 20362705552.0, our lookback sum is 20362705552.0
# Working on 922792-2014-03-04
# 	We dropped row 8, Total liabilities and members' capital, with lookback window of 8.
# 		Our row is valued at 29450361000.0, our lookback sum is 29450361000.0
# Working on 922792-2015-03-02
# 	We dropped row 8, Total liabilities and members' capital, with lookback window of 8.
# 		Our row is valued at 36189624000.0, our lookback sum is 36189624000.0
# Working on 922792-2016-02-29
# 	We dropped row 7, Total liabilities and members' capital, with lookback window of 7.
# 		Our row is valued at 40188000000.0, our lookback sum is 40188000000.0
# Working on 922792-2017-03-01
# 	We dropped row 9, Total liabilities and members' capital, with lookback window of 9.
# 		Our row is valued at 44185000000.0, our lookback sum is 44185000000.0
# Working on 922792-2018-03-01
# 	We dropped row 9, Total liabilities and members' capital, with lookback window of 9.
# 		Our row is valued at 51613000000.0, our lookback sum is 51613000000.0
# Working on 922792-2019-02-28
# 	We dropped row 7, Accounts payable, accrued expenses and other liabilities, with lookback window of 1.
# 		Our row is valued at 59000000.0, our lookback sum is 59000000.0
# 	We dropped row 10, Total other payables, with lookback window of 5.
# 		Our row is valued at 354000000.0, our lookback sum is 354000000.0
# 	We dropped row 11, Total liabilities, with lookback window of 11.
# 		Our row is valued at 45591000000.0, our lookback sum is 45591000000.0
# 	We dropped row 13, Total liabilities and members' capital, with lookback window of 13.
# 		Our row is valued at 50852000000.0, our lookback sum is 50852000000.0
# Working on 922792-2019-03-01
# 	We dropped row 9, Total other payables, with lookback window of 4.
# 		Our row is valued at 354000000.0, our lookback sum is 354000000.0
# 	We dropped row 10, Total liabilities, with lookback window of 10.
# 		Our row is valued at 45591000000.0, our lookback sum is 45591000000.0
# 	We dropped row 12, Total liabilities and members' capital, with lookback window of 12.
# 		Our row is valued at 50852000000.0, our lookback sum is 50852000000.0
# Working on 922792-2020-02-28
# 	We dropped row 9, Total other payables, with lookback window of 4.
# 		Our row is valued at 282000000.0, our lookback sum is 282000000.0
# 	We dropped row 10, Total liabilities, with lookback window of 10.
# 		Our row is valued at 54636000000.0, our lookback sum is 54636000000.0
# 	We dropped row 12, Total liabilities and members' capital, with lookback window of 12.
# 		Our row is valued at 60395000000.0, our lookback sum is 60395000000.0
# Working on 922792-2021-02-26
# 	We dropped row 9, Total other payables, with lookback window of 4.
# 		Our row is valued at 294000000.0, our lookback sum is 294000000.0
# 	We dropped row 10, Total liabilities, with lookback window of 10.
# 		Our row is valued at 71756000000.0, our lookback sum is 71756000000.0
# 	We dropped row 12, Total liabilities and members' capital, with lookback window of 12.
# 		Our row is valued at 77404000000.0, our lookback sum is 77404000000.0
#
# We created an unstructured asset and liability & equity

# %%
# work on combining columns that are issued seperately
s3 = boto3.client('s3')
session = Session()
bucket = "ran-s3-systemic-risk"

# e.g. file name = 1224385-2004-03-01, 42352-2003-01-28
s3.download_file(bucket, 'Output/X-17A-5-SPLIT-PDFS/Assets/72267-2004-05-28.csv', 'temp.csv')
pdf_df = pd.read_csv('temp.csv')
s3.download_file(bucket, 'Output/X-17A-5-SPLIT-PNGS/Assets/72267-2004-05-28.csv', 'temp.csv')
png_df = pd.read_csv('temp.csv')
os.remove('temp.csv')

# do a special merge that combines unique line items names between PDF & PNG
temp_df1 = special_merge(pdf_df, png_df, '0')

# run accounting check to remove sub-totals for each respective line-item
df, total_flag, total_amt = totals_check(temp_df1)
# Out:
# 	We dropped row 4, Financial instruments owned (approximately $10,900,474 were, with lookback window of 2.
# 		Our row is valued at 44343153000.0, our lookback sum is 44343153000.0
# 	We dropped row 9, Receivables:, with lookback window of 4.
# 		Our row is valued at 17731470000.0, our lookback sum is 17731470000.0
# 	We dropped row 13, Furniture, equipment and leasehold improvements, net of, with lookback window of 3.
# 		Our row is valued at 535815000.0, our lookback sum is 535815000.0

# %%
pdf_df
# Out:
#                                                     0             1
# 0                           Cash and cash equivalents  9.182030e+08
# 1   Cash and securities segregated pursuant to fed...  3.651780e+08
# 2     Securities purchased under agreements to resell  2.566025e+10
# 3                                 Securities borrowed  1.868290e+10
# 4   Financial instruments owned (approximately $10...  4.434315e+10
# 5                                   Equity securities  7.965816e+09
# 6               U.S. government and agency securities  7.277881e+09
# 7   Corporate debt and collateralized mortgage obl...  2.446369e+09
# 8                                             Options  4.140400e+07
# 9                                        Receivables:  1.773147e+10
# 10        Brokers, dealers and clearing organizations  3.985370e+08
# 11                             Interest and dividends  1.007450e+08
# 12                                          Customers  3.653300e+07
# 13  Furniture, equipment and leasehold improvement...  5.358150e+08
# 14  accumulated depreciation and amortization of $...  1.709300e+07
# 15                                       Other assets  4.030600e+07
# 16                                       Total assets  6.395122e+10

# %%
special_merge(pdf_df, png_df, '0')
# Out:
# ['U.S. government and agency securities'] ['U. S. government and agency securities']
#                                        0             1
# 6  U.S. government and agency securities  7.277881e+09
# ['Furniture, equipment and leasehold improvements, net of'
#  'accumulated depreciation and amortization of $40,523'] ['Furniture, equipment and leasehold improvements, net of accumulated depreciation and amortization of $40,523']
#                                                     0            1
# 13  Furniture, equipment and leasehold improvement...  535815000.0
#                                                     0             1
# 0                           Cash and cash equivalents  9.182030e+08
# 1   Cash and securities segregated pursuant to fed...  3.651780e+08
# 2     Securities purchased under agreements to resell  2.566025e+10
# 3                                 Securities borrowed  1.868290e+10
# 4   Financial instruments owned (approximately $10...  4.434315e+10
# 5                                   Equity securities  7.965816e+09
# 6               U.S. government and agency securities  7.277881e+09
# 7   Corporate debt and collateralized mortgage obl...  2.446369e+09
# 8                                             Options  4.140400e+07
# 9                                        Receivables:  1.773147e+10
# 10        Brokers, dealers and clearing organizations  3.985370e+08
# 11                             Interest and dividends  1.007450e+08
# 12                                          Customers  3.653300e+07
# 13  Furniture, equipment and leasehold improvement...  5.358150e+08
# 14                                       Other assets  4.030600e+07
# 15                                       Total assets  6.395122e+10

# %%
a = ['Furniture, equipment and leasehold improvements, net of', 'accumulated depreciation and amortization of $40,523'] 
b = ['Furniture, equipment and leasehold improvements, net of accumulated depreciation and amortization of $40,523']

# %%
for idx, i in enumerate(zip(a, b)):
    print(idx, i)
# Out:
# 0 ('Furniture, equipment and leasehold improvements, net of', 'Furniture, equipment and leasehold improvements, net of accumulated depreciation and amortization of $40,523')

# %%
i
# Out:
# ('Furniture, equipment and leasehold improvements, net of',
#  'Furniture, equipment and leasehold improvements, net of accumulated depreciation and amortization of $40,523')
