# %%
# # Run on first instance to install required libraries
# %pip install PyPDF2

# %%
import os
import boto3
import numpy as np 

from sagemaker.session import Session
from PyPDF2 import PdfFileReader, PdfFileWriter, utils

# %% [markdown]
# ## PDF Slicing for X-17A-5 Files
# We slice the first 15 pages from the merged X-17A-5 files retrieved from the SEC

# %%
def selectPages(pdf:PdfFileReader, pageSelection:list) -> PdfFileWriter:
    """
    Extracts pages from a pdf and returns a PdfFileWriter object 
    ------------------------------------------------------------------------------------------
    Input:
        :param: pdf (type PdfFileReader)
            A PdfFileReader object that represents a pdf file that has been read and interpreted
        :param: pageSelection (type list)   
            The page numbers to be selected from the pdf. NOTE, these page numbers do not hav to be sequential, 
            but often times are read as such
    Return:
        :param: pdfWriter (type PdfFileWriter)
            Returns a truncated PdfFile object that is smaller than or equal to the original parsed pdf
    """
    # initialize a pdf object to store pdf pages
    pdfWriter = PdfFileWriter()
    nPages = pdf.getNumPages()

    # to manage pdfs that don't contain as many pages as listed  
    if nPages > max(pageSelection):
        
        # add the first n-pages from the document as specified in pageSelection 
        for page_num in pageSelection:
            pdfWriter.addPage(pdf.getPage(page_num))
        return pdfWriter
    
    else:   
        
        # add all pages from the document provided
        for page_num in np.arange(nPages):
            pdfWriter.addPage(pdf.getPage(page_num))
        return pdfWriter

# %%
def extractSubset(pages:list, export_file:str):
    """
    Extracts a subset of pages from a pdf, provided the page numbers are specified
    ------------------------------------------------------------------------------------------
    Input:
        :param: pages (type list)
            A list of page numbers to extract from a given pdf (e.g. [1, 2, 3, 4, 5, 6]) 
        :param: export_file (type str)   
            The name for the pdf file to be exported, we traditional keep the orignal pdf name, with the 
            accompanying subset tag (e.g. 'CITI-2020-02-22-subset.pdf')
    Return:
        This is a void function, we return no value(s) as we interface with AWS s3 bucket to store pdfs
    """
    
    try:
        # read pdf file and initialize empty pdf file to create subset
        pdf = PdfFileReader('temp.pdf')
        subset = selectPages(pdf, pages)

        try:
            # open file and save to local instance
            with open(export_file, 'wb') as f:
                subset.write(f)
                f.close()
        except:
            print('Not able to save local file {}'.format(export_file))

    except utils.PdfReadError:
        print('EOF marker not found - reject {}'.format(export_file))

# %%
if __name__ == "__main__":
    
    bucket = "ran-s3-systemic-risk"
    import_folder = 'Input/X-17A-5/'
    export_folder = "Input/X-17A-5-Subsets/"

    # Amazon Textract client and Sagemaker session
    textract = boto3.client('textract')
    s3 = boto3.client('s3')
    session = Session()
    
    # pages to keep from each pdf
    pages = np.arange(15) 
    
    # import paths for all the subset files 
    # (NOTE: we take the 1+ index, since the the zero position is folder directory)
    importPaths = np.array(session.list_s3_files(bucket, import_folder))[1:]

    # export file paths to document subfolder
    exportPaths = session.list_s3_files(bucket, export_folder)

    for pdf_file_path in importPaths:

        # check to see if values are downloaded to s3 sub-bin
        baseFile = pdf_file_path.split('/')[-1].split('.')[0]
        export_file = '{}-subset.pdf'.format(baseFile)

        # if our subset is not found in our s3 bucket we look to extract it 
        if export_folder + exportFile not in exportPaths:

            # retrieving downloaded files from s3 bucket
            s3.download_file(bucket, pdf_file_path, 'temp.pdf')
            
            # run the subset function to save a local subset file (void-function)
            extractSubset(pages, export_file)
            
            # save contents to AWS S3 bucket as specified
            with open(export_file, 'rb') as data:
                s3.upload_fileobj(data, bucket, export_folder + export_file)
                
            print('Saved file -> {}'.format(export_file))
            
            # remove local file after it has been created
            os.remove(export_file)
            os.remove('temp.pdf')
            
        else:
            print('{} already saved'.format(exportFile))
# Out:
# Saved file -> 1224385-2004-03-01-subset.pdf
# Saved file -> 1224385-2005-03-01-subset.pdf
# Saved file -> 1224385-2006-03-01-subset.pdf
# Saved file -> 1224385-2007-03-01-subset.pdf
# Saved file -> 1224385-2008-02-29-subset.pdf
# Saved file -> 1224385-2009-03-02-subset.pdf
# Saved file -> 1224385-2010-03-12-subset.pdf
# Saved file -> 1224385-2011-03-01-subset.pdf
# Saved file -> 1224385-2012-02-29-subset.pdf
# Saved file -> 1224385-2013-03-01-subset.pdf
# Saved file -> 1224385-2014-03-04-subset.pdf
# Saved file -> 1224385-2015-03-02-subset.pdf
# Saved file -> 1224385-2016-02-29-subset.pdf
# Saved file -> 1224385-2017-03-01-subset.pdf
# Saved file -> 1224385-2018-02-28-subset.pdf
# Saved file -> 1224385-2019-02-28-subset.pdf
# Saved file -> 1224385-2020-02-28-subset.pdf
# Saved file -> 1224385-2021-02-26-subset.pdf
# Saved file -> 42352-2002-01-30-subset.pdf
# Saved file -> 42352-2003-01-28-subset.pdf
# Saved file -> 42352-2004-01-27-subset.pdf
# Saved file -> 42352-2005-01-25-subset.pdf
# Saved file -> 42352-2006-01-24-subset.pdf
# Saved file -> 42352-2007-01-23-subset.pdf
# Saved file -> 42352-2008-01-29-subset.pdf
# Saved file -> 42352-2009-01-27-subset.pdf
# Saved file -> 42352-2010-03-01-subset.pdf
# Saved file -> 42352-2010-03-03-subset.pdf
# Saved file -> 42352-2011-03-01-subset.pdf
# Saved file -> 42352-2012-02-29-subset.pdf
# Saved file -> 42352-2013-03-01-subset.pdf
# Saved file -> 42352-2014-07-31-subset.pdf
# Saved file -> 42352-2015-03-10-subset.pdf
# Saved file -> 42352-2016-02-23-subset.pdf
# Saved file -> 42352-2017-03-01-subset.pdf
# Saved file -> 42352-2018-02-27-subset.pdf
# Saved file -> 42352-2019-03-01-subset.pdf
# Saved file -> 42352-2020-02-28-subset.pdf
# Saved file -> 42352-2021-02-25-subset.pdf
# Saved file -> 58056-2002-03-01-subset.pdf
# Saved file -> 58056-2003-03-03-subset.pdf
# Saved file -> 58056-2004-02-27-subset.pdf
# Saved file -> 58056-2004-03-26-subset.pdf
# Saved file -> 58056-2005-02-25-subset.pdf
# Saved file -> 58056-2006-03-24-subset.pdf
# Saved file -> 58056-2007-03-01-subset.pdf
# Saved file -> 58056-2008-02-29-subset.pdf
# Saved file -> 58056-2009-03-16-subset.pdf
# Saved file -> 58056-2010-06-04-subset.pdf
# Saved file -> 58056-2012-02-29-subset.pdf
# Saved file -> 58056-2013-03-01-subset.pdf
# Saved file -> 58056-2014-03-04-subset.pdf
# Saved file -> 58056-2015-03-02-subset.pdf
# Saved file -> 58056-2016-02-29-subset.pdf
# Saved file -> 58056-2017-03-03-subset.pdf
# Saved file -> 58056-2018-03-12-subset.pdf
# Saved file -> 58056-2019-03-01-subset.pdf
# Saved file -> 58056-2019-09-30-subset.pdf
# Saved file -> 58056-2020-03-02-subset.pdf
# Saved file -> 58056-2021-03-01-subset.pdf
# Saved file -> 68136-2002-01-29-subset.pdf
# Saved file -> 68136-2003-01-30-subset.pdf
# Saved file -> 68136-2004-01-30-subset.pdf
# Saved file -> 68136-2005-01-31-subset.pdf
# Saved file -> 68136-2006-01-30-subset.pdf
# Saved file -> 68136-2007-01-29-subset.pdf
# Saved file -> 68136-2008-01-31-subset.pdf
# Saved file -> 68136-2009-01-29-subset.pdf
# Saved file -> 68136-2009-02-10-subset.pdf
# Saved file -> 68136-2010-03-02-subset.pdf
# Saved file -> 68136-2011-03-02-subset.pdf
# Saved file -> 68136-2012-02-29-subset.pdf
# Saved file -> 68136-2013-03-01-subset.pdf
# Saved file -> 68136-2014-03-04-subset.pdf
# Saved file -> 68136-2015-03-02-subset.pdf
# Saved file -> 68136-2016-02-29-subset.pdf
# Saved file -> 68136-2017-03-01-subset.pdf
# Saved file -> 68136-2018-03-01-subset.pdf
# Saved file -> 68136-2019-03-01-subset.pdf
# Saved file -> 68136-2020-03-02-subset.pdf
# Saved file -> 68136-2021-02-26-subset.pdf
# Saved file -> 72267-2003-05-30-subset.pdf
# Saved file -> 72267-2004-05-28-subset.pdf
# Saved file -> 72267-2005-05-31-subset.pdf
# Saved file -> 72267-2006-05-30-subset.pdf
# Saved file -> 72267-2007-05-29-subset.pdf
# Saved file -> 72267-2008-05-30-subset.pdf
# Saved file -> 72267-2009-06-03-subset.pdf
# Saved file -> 72267-2010-06-01-subset.pdf
# Saved file -> 72267-2012-03-15-subset.pdf
# Saved file -> 72267-2012-05-30-subset.pdf
# Saved file -> 72267-2013-05-30-subset.pdf
# Saved file -> 72267-2014-05-30-subset.pdf
# Saved file -> 72267-2015-06-01-subset.pdf
# Saved file -> 72267-2016-05-31-subset.pdf
# Saved file -> 72267-2017-05-30-subset.pdf
# Saved file -> 72267-2018-05-25-subset.pdf
# Saved file -> 72267-2019-05-28-subset.pdf
# Saved file -> 72267-2020-06-01-subset.pdf
# Saved file -> 782124-2002-01-29-subset.pdf
# Saved file -> 782124-2003-01-30-subset.pdf
# Saved file -> 782124-2004-01-30-subset.pdf
# Saved file -> 782124-2004-05-07-subset.pdf
# Saved file -> 782124-2005-01-31-subset.pdf
# Saved file -> 782124-2006-01-30-subset.pdf
# Saved file -> 782124-2007-01-29-subset.pdf
# Saved file -> 782124-2008-01-31-subset.pdf
# Saved file -> 782124-2009-03-02-subset.pdf
# Saved file -> 782124-2010-03-01-subset.pdf
# Saved file -> 782124-2010-03-02-subset.pdf
# Saved file -> 782124-2011-03-02-subset.pdf
# Saved file -> 782124-2012-02-29-subset.pdf
# Saved file -> 782124-2013-03-01-subset.pdf
# Saved file -> 782124-2014-03-05-subset.pdf
# Saved file -> 782124-2015-02-27-subset.pdf
# Saved file -> 782124-2016-02-29-subset.pdf
# Saved file -> 782124-2017-03-01-subset.pdf
# Saved file -> 782124-2018-02-27-subset.pdf
# Saved file -> 782124-2018-02-28-subset.pdf
# Saved file -> 782124-2019-02-28-subset.pdf
# Saved file -> 782124-2020-04-01-subset.pdf
# Saved file -> 782124-2021-03-01-subset.pdf
# Saved file -> 851376-2002-03-01-subset.pdf
# Saved file -> 851376-2003-03-03-subset.pdf
# Saved file -> 851376-2004-03-01-subset.pdf
# Saved file -> 851376-2005-03-02-subset.pdf
# Saved file -> 851376-2006-03-01-subset.pdf
# Saved file -> 851376-2007-03-14-subset.pdf
# Saved file -> 851376-2008-02-29-subset.pdf
# Saved file -> 851376-2009-03-02-subset.pdf
# Saved file -> 851376-2010-03-01-subset.pdf
# Saved file -> 851376-2011-03-15-subset.pdf
# Saved file -> 851376-2012-02-29-subset.pdf
# Saved file -> 851376-2013-03-01-subset.pdf
# Saved file -> 851376-2014-03-04-subset.pdf
# Saved file -> 851376-2015-03-02-subset.pdf
# Saved file -> 851376-2016-02-29-subset.pdf
# Saved file -> 851376-2017-03-01-subset.pdf
# Saved file -> 851376-2018-02-28-subset.pdf
# Saved file -> 851376-2019-03-01-subset.pdf
# Saved file -> 851376-2020-03-06-subset.pdf
# Saved file -> 851376-2021-03-01-subset.pdf
# Saved file -> 853784-2002-03-01-subset.pdf
# Saved file -> 853784-2003-02-28-subset.pdf
# Saved file -> 853784-2004-03-01-subset.pdf
# Saved file -> 853784-2005-02-28-subset.pdf
# Saved file -> 853784-2006-03-01-subset.pdf
# Saved file -> 853784-2007-03-01-subset.pdf
# Saved file -> 853784-2007-03-09-subset.pdf
# Saved file -> 853784-2008-02-29-subset.pdf
# Saved file -> 853784-2009-03-02-subset.pdf
# Saved file -> 853784-2010-03-01-subset.pdf
# Saved file -> 853784-2011-03-01-subset.pdf
# Saved file -> 853784-2012-02-29-subset.pdf
# Saved file -> 853784-2013-03-01-subset.pdf
# Saved file -> 853784-2014-03-04-subset.pdf
# Saved file -> 853784-2015-03-09-subset.pdf
# Saved file -> 853784-2016-03-01-subset.pdf
# Saved file -> 853784-2017-03-01-subset.pdf
# Saved file -> 853784-2018-03-05-subset.pdf
# Saved file -> 853784-2019-03-01-subset.pdf
# Saved file -> 853784-2020-03-02-subset.pdf
# Saved file -> 853784-2021-03-01-subset.pdf
# Saved file -> 91154-2002-03-01-subset.pdf
# Saved file -> 91154-2003-03-03-subset.pdf
# Saved file -> 91154-2004-02-27-subset.pdf
# Saved file -> 91154-2005-03-01-subset.pdf
# Saved file -> 91154-2006-03-01-subset.pdf
# Saved file -> 91154-2007-03-01-subset.pdf
# Saved file -> 91154-2008-02-29-subset.pdf
# Saved file -> 91154-2009-03-02-subset.pdf
# Saved file -> 91154-2010-03-02-subset.pdf
# Saved file -> 91154-2011-03-01-subset.pdf
# Saved file -> 91154-2012-02-29-subset.pdf
# Saved file -> 91154-2013-03-01-subset.pdf
# Saved file -> 91154-2014-03-04-subset.pdf
# Saved file -> 91154-2015-03-02-subset.pdf
# Saved file -> 91154-2016-03-01-subset.pdf
# Saved file -> 91154-2017-03-02-subset.pdf
# Saved file -> 91154-2018-03-05-subset.pdf
# Saved file -> 91154-2019-03-05-subset.pdf
# Saved file -> 91154-2020-03-02-subset.pdf
