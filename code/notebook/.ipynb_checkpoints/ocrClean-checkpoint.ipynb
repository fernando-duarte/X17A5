# %%
# Run on first instance to install required libraries
# %pip install smart_open
# %pip install minecart
# %pip install textract-trp
# %pip install python-Levenshtein
# %pip install fuzzywuzzy
# Out:
# Collecting smart_open
#   Downloading smart_open-5.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.3 MB/s eta 0:00:011
# Installing collected packages: smart-open
# Successfully installed smart-open-5.1.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting minecart
#   Downloading minecart-0.3.0-py3-none-any.whl (23 kB)
# Collecting pdfminer3k
#   Downloading pdfminer3k-1.3.4-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 2.1 MB/s ta 0:00:011
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from minecart) (1.15.0)
# Requirement already satisfied: ply in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pdfminer3k->minecart) (3.11)
# Installing collected packages: pdfminer3k, minecart
# Successfully installed minecart-0.3.0 pdfminer3k-1.3.4
# Note: you may need to restart the kernel to use updated packages.
# Collecting textract-trp
#   Downloading textract_trp-0.1.3-py3-none-any.whl (5.8 kB)
# Installing collected packages: textract-trp
# Successfully installed textract-trp-0.1.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 3.2 MB/s eta 0:00:011
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-Levenshtein) (49.6.0.post20210108)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp36-cp36m-linux_x86_64.whl size=155939 sha256=7753b0b24a8702e4b9908c261ffacb15124268c438cab3a22ab41264e88287fe
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4a/a4/bf/d761b0899395c75fa76d003d607b3869ee47f5035b8afc30a2
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time 
import re
import os
import trp
import boto3
import minecart
import json
import logging 

import numpy as np
import pandas as pd

from fuzzywuzzy import fuzz
from smart_open import open
from sagemaker.session import Session

# %%
def num_strip(number):
    """
    This function converts a string to a numeric quantity, handles weird string format. 
    We handle input arguments of a string, integer or numpy.ndarray
    """
    
    numType = type(number)

    # if provided a non-empty string, perform regex operation 
    if (numType is str) and (len(number) > 0):

        # check for accounting formats that use parenthesis to signal losses 
        if number[0] == '(': number = '-' + number

        # case replacing to handle poor textract reading of numbers
        number = number.replace('I', '1').replace('l', '1')

        # --------------------------------------------------------------
        # Explanation of the Regex Expression:
        #      [^0-9|.|-]     = match all elements that are not numeric 0-9, periods "." or hyphens "-"
        #      (?<!^)-        = match all elements that are hyphens "-" not in the first index position
        #      \.(?=[^.]*\.)  = match all elements that are periods "." except the last instance
        # --------------------------------------------------------------

        check1 = re.sub("[^0-9|.|-]", "", number)         # remove all the non-numeric, periods "." or hyphens "-"
        check2 = re.sub("(?<!^)-", "", check1)            # removes all "-" that aren't in the first index 
        check3 = re.sub("\.(?=[^.]*\.)", "", check2)      # removes all periods except the last instance of "." 

        # --------------------------------------------------------------

        # we consider weird decimal values that exceed 2 spaces to the right (e.g. 432.2884)
        period_check = check3.find('.')                         # returns the location of the period 
        right_tail_length = len(check3) - period_check - 1      # right-tail length should not exceed 2

        # if more than 2 trailing digits to decimal point we assume incorrect placement
        if right_tail_length > 2:
            check3 = check3.replace('.', '')

        # last check against poor lagging formats e.g. "." or "-" to return nan or floating-point number
        if (check3 == '-') or (check3 == '.'):
            return 0.0
        else:
            # try to cast to floating point value, else flat NaN
            try: 
                return float(check3)
            except ValueError: 
                return np.nan

    # if operator is an integer or float then simply return the value
    elif (numType is int) or (numType is float):
        return number

    else:
        return np.nan

# %% [markdown]
# ## Table Shaving
# **Removing blank/empty rows that are reported in the line items**

# %%
def column_purge(df:pd.DataFrame) -> pd.DataFrame:
    """
    Column designed to filter out rows that are NaN (empty) and reduce dataframe size
    ------------------------------------------------------------------------------------
    Input
        :param data: (type pandas.DataFrame)
            A dataframe object that corresponds to the X-17A-5 filings
    
    Output
        :return: (type pandas.DataFrame)
            Returns a dataframe of size less than or equal to the original input 
    """
    # begin by filtering out the NaN rows present in the first column
    first_col = df.columns[0]
    new_df = df[np.isin(df[first_col], df[first_col].dropna())]    # select subset of rows 
    
    # we reset the index of our new_df to recoup a consecutive index count
    new_df = new_df.reset_index()
    new_df = new_df[new_df.columns[1:]]    # skip the first column since we reset the index
    
    return new_df

# %% [markdown]
# ## Table column merging
# **For tables with three columns we merge the last two columns into a once unique column**

# %%
def merge(df:pd.DataFrame) -> pd.DataFrame:
    """
    Function passes a special dataframe, and reduces its dimensions accordingly. 
    Example releases include, but are note limited to, 1224385-2016 and 72267-2003
    ------------------------------------------------------------------------------------
    Input
        :param data: (type pandas.DataFrame)
            A dataframe object that corresponds to the X-17A-5 filings
    
    Output
        :return: (type pandas.DataFrame)
            Returns a dataframe of of size (Nx3) -> (Nx2)
    
    e.g.
    
    Converts a wide dataframe, balance sheet into a smaller rectangular form
                  0                                                 1                 2
            ====================================================================================
        0   Assets                                          | NaN            | NaN  
        1   Cash and cash equivalents                       | $ 606,278      |     
        2   Cash and securities segregated pursuant         | 273,083        | 
        3   Collateralized short-term financing agreements: | NaN            | $ 1,345
    
    
    Rectangular form of the the dataframe ->
                   0                                                 1          
            =====================================================================
        0   Assets                      
        1   Cash and cash equivalents                       | $ 606,278        
        2   Cash and securities segregated pursuant         | 273,083        
        3   Collateralized short-term financing agreements: | $ 1,345            
    """
    # work on itterative merging for rows, check left/right and top/bottom
    n = df.shape[0]
    trans = []

    for i in range(n):
        row = df.iloc[i]         # index into the row

        name = row.iloc[0]       # the line item name (e.g. Total Assets)
        col1 = row.iloc[1]       # the first value(s) column
        col2 = row.iloc[2]       # the second value(s) column 
        
        # ----------------------------------------------
        # NOTE: We say nothing if both col 1 and 2 are 
        #     both populated with a numeric value
        # ----------------------------------------------
        
        if num_strip(col1) is not np.nan:
            trans.append([name, col1])     # if column 1 has a numeric value we take it by default
        elif num_strip(col2) is not np.nan:
            trans.append([name, col2])     # if column 1 has no numeric value, but column 2 does, we take it
            
        # ----------------------------------------------
        
        # we want to check if there exists two NaNs - is it real or false flag
        if (col1 is np.nan) and (col2 is np.nan): 
            
            # look up one row (if possible to see if col1 and col2 are populated)
            try:
                # check the information for the above row
                prior_row = df.iloc[i-1]                     # previous dataframe row 
                prior_col1 = prior_row.iloc[1]               # first column from previous row
                prior_col2 = prior_row.iloc[2]               # second column from previous row
                
                # if both values present then we simply use the right hand side value above  
                if (prior_col1 is not np.nan) and (prior_col2 is not np.nan):
                    trans.append([name, prior_col2])
            
            # IndexError if not possible to look up one row       
            except IndexError: pass
    
    return pd.DataFrame(trans)

# %%
def column_merge(df:pd.DataFrame) -> pd.DataFrame:
    """
    Function determines whether a Balance Sheet should be merged or simply filtered. 
    Our two cases are determined as follows:
        * If the second column present in the balance sheet is mostly empty we assume that 
          the second column is an aggregated column, and we can merge it
        * However, if the second column is mostly filled with values, we assume that this
          represents accounting figures from the previous year 
    ------------------------------------------------------------------------------------
    Input
        :param data: (type pandas.DataFrame)
            A dataframe object that corresponds to the X-17A-5 filings
    
    Output
        :return: (type pandas.DataFrame)
            Returns a dataframe of of size (Nx3) -> (Nx2)
    """
    # two events could occur at this point (either the column represents totals, or values from a prior-year)
    arr = df[df.columns[2]].values

    # check the scope of the second column 
    n = arr.size
    k = arr.tolist().count(np.nan)

    # k-check: if more than half the arr size is np.nan we assume this is a "fake column"
    # we merge these columns since there are many blank rows, otherwise we assume year split 
    if k/n >= 0.50:
        new_df = merge(df)            # merge rows by merge function
    else:
        new_df = df[df.columns[:2]]   # return the most recent year 
    
    return new_df

# %% [markdown]
# ## Table Row Split
# **Since many of the existing tables run the risk of overlapping rows we work to split these rows to appropriate values**

# %%
def dollar_check(num):
    """
    A function to check the presence of a '$' or 'S'. This function is used to 
    complement our row splits function to determine "True splits"
    """
    if num not in ['$', 'S']:
        return True
    else: return False

# %%
def row_split(df:pd.DataFrame, text_file:dict) -> pd.DataFrame:
    """
    Function designed to split conjoined rows from Balance sheet dataframes into individual rows.
    Example releases include, but are note limited to, 42352-2015, 58056-2009, 58056-2013, 58056-2019
    ------------------------------------------------------------------------------------
    Input:
        :param df: (type pandas.DataFrame)
            References the balance sheet dataframe read in from AWS Textract
        :param text_file: (type dictionary)
            Stores text values with corresponding confidence level for balance sheet pages
    
    Output:
        :param return: (type pandas.DataFrame) 
            A processed dataframe of size greater than or equal to the inputed dataframe
    """
    
    # ##############################################################
    # NESTED HELPER FUNCTIONS
    # ##############################################################
    
    def find_row_splits(val) -> bool:
        """
        Compute a boolean measure to assess whether a row is conjoined or not. We make
        the assumption that a row is conjoined or merged if there exists a space in the 
        first value column (omiting the dollar sign $ and S which may be read in)
        """
        try:
            # split the data figures for each balance sheet figure
            arr = val.split(' ')
            
            # remove the '$' sign or 'S' if present in the list (this helps avoid false pasitives) 
            arr = list(filter(dollar_check, arr))
            
            # if length of read list exceeds 1 then we know there exists a multi-row bunch
            if len(arr) > 1:
                return True
            else: return False
        
        # handle exception for NaN (no attribute to split) 
        except AttributeError: return False
    
    def extract_lineitems(line:list, value:list, dictionary:dict) -> list:
        """
        Extract the appropriate line items from each line value.
        """
        splits = []
        
        # iterate through each line item
        for i in dictionary.keys():
    
            # we check for real key-value names avoiding single character keys
            if len(i) > 1: 
                idx = line.find(i)    # find the index of key-value (if possible) in line item array

                # if we find such a value we append the series (failure to find results idx = -1)
                if idx >= 0: splits.append(i)
        
        # check whether we have a one-to-one mapping between line items and line values, 
        # e.g. ['Assets', 'Cash', 'Recievables'] -> ['1,233', '4,819'] (3x2 mapping)
        n = len(splits) - len(value)
        
        # if n is equal to zero we have a "perfect" match
        if n == 0:
            return (splits, value)
        elif n > 0:
            return (splits[n:], value)       # more line items terms, assume values is right
        elif n == -1:                        
            return (splits, values[1:])      # more value terms, assume value is wrong only if difference is 1 in size
        else: 
            return None                      # no specific rule paradigm (more values than items)
    
    def recursive_splits(values:list, lineName:list, sub=[]) -> pd.DataFrame:
        """
        Recursively breaks up merged rows for each split until no merged row is left
        """
        # if our list exceeds 1 in length, we continue to split
        if len(values) > 1:
            # construct a dataframe row of the first split term to append to sub list
            row = pd.DataFrame([lineName[0], values[0]]).T
            sub.append(row)
            
            # we pass the +1 index splits and line name, appending the first-most layer 
            return recursive_splits(values[1:], lineName[1:], sub=sub)
        else:
            row = pd.DataFrame([lineName[0], values[0]]).T
            sub.append(row)
            
            # we concatenate all DataFrames vertically to form a large DataFrame 
            return pd.concat(sub)
        
    # ##############################################################
    # ##############################################################    
    
    # select all the rows that match our description, where a space exists = row merge 
    selections = df[df[df.columns[1]].apply(lambda x: find_row_splits(x))]
    idxs = selections.index
    
    # iterate through each row that is determined to be conjoined
    for i in idxs:
        
        # find the index location od merged row
        row_idx = np.argmax(df.index == i)
        
        # slice dataframe according to the idx selection (we search for all periods were a break occurs)
        top = df.iloc[:row_idx]
        bottom = df.iloc[row_idx+1:]

        # divide the identified term from the selection e.g. "$ 9,112,943 13,151,663" -> ["$", "9,112,943", "13,151,663"] 
        # and filter out the $ sign in the list e.g. ["$", "9,112,943", "13,151,663"] -> [9,112,943", "13,151,663"]
        values = df[df.columns[1]].loc[i].split(' ')
        values = list(filter(dollar_check, values))
        
        # extract line names and corresponding values according to Text parsed list (requires parsed TEXT JSON)
        # e.g. ['Securities Held Total Assets'] -> ['Securities Held', 'Total Assets']
        lineName = df[df.columns[0]].loc[i]
        
        # return line items and values that should match in size
        response_extraction = extract_lineitems(lineName, values, text_file)
        
        # if we retun a lineitem then we can perform recursive splits (otherwise avoid)
        if type(response_extraction) is not type(None):
            
            clean_lineitems, clean_values = response_extraction
            
            # determine the splits for the corresponding row
            mid = recursive_splits(clean_values, clean_lineitems, sub=[])
            mid.columns = df.columns

            # re-assign the value of df2 to update across each iteration
            df = pd.concat([top, mid, bottom])
            
        else:
            # no need for mid, since we have removed it from existence
            df = pd.concat([top, bottom])
        
    return df

# %% [markdown]
# ## Numeric Conversion
# **Work on converting all string and poor formating quantities to numerical type**

# %%
def num_scale(text_dict:dict, key_value:str, old_cik:int, old_scale:float) -> float:
    """
    Function used for scaling accounting figures by reported unites
    """
    scalar = {'thousands': 1e3, 'hundreds':1e2, 'millions':1e6, 'billions': 1e9}
    
    text_data = text_dict[key_value]
    
    # iterate through each of the text values from dictionary map
    for text_value in text_data.keys():
        
        # we check to see whether the text is found in our scalar dictionary
        for scale_type in scalar.keys():
            
            # search for the presence of the scale identifier (e.g. millions) 
            # we use a "fuzzy-ratio" on string splits to handle embeeded keyes (e.g. Dollar in Millions)
            scale_search = [fuzz.ratio(scale_type.lower(), elm.lower()) for elm in text_value.lower().split(' ')]
            
            # we make the assumption that a score of 90 or greater, signals a match
            if max(scale_search) >= 90:
                print(scale_type, text_value.lower())
                return scalar[scale_type]              # if found we simply return the multiplier
    
    if old_cik == key_value.split('-')[0]:
        return old_scale
    
    # default to no multiplier (1)
    return 1

# %%
def cleanNumeric(value):
    """
    This function is a wrapper for calling the numerical extraction function 
    ------------------------------------------------------------------------------------
    Input:
        :param value:
            String with hidden numeric quanity (e.g. $ 19,225 = 19255)  
        :param text_file: (type dictionary)
            Stores text values with corresponding confidence level for balance sheet pages
            
    Output:
        :param return:
            A processed numeric quantiity or numpy.nan value depending on string issues  
    """
    
    assert type(value) is str or int or np.ndarray, 'Value must be of type string, integer, float or numpy array'
    
    # checks to see what type of value is being provided
    operator = type(value)
    
    # if provided a string, perform regex operation 
    if (operator is str) and (len(value) > 0):
        return num_strip(value)
    
    # if operator is integer then simply return the value, no need to modify 
    elif (operator is int) or (operator is float):
        return value 
    
    # if operator is numpy array then we perform a extraction per element in array
    elif (operator is np.ndarray):
        vFunc = np.vectorize(num_strip)      # vectorize function to apply to numpy array
        cleanValue = vFunc(value)            # apply vector function
        return cleanValue

# %% [markdown]
# ## J.P Morgan Handle
# **Dealing with the weird formating issue present within the J.P. Morgan X-17A-5 series**

# %%
def jpm_check(df:pd.DataFrame) -> pd.DataFrame:
    """
    A wrapper function that reduces the amount of rows present within special J.P. Morgan
    releases that contain a special sub-balance sheet for VIE figures
    ------------------------------------------------------------------------------------
    Input:
        :param df:
            Original unfiltered pandas.DataFrame object representing balance sheet figures
            
    Output:
        :param return:
            A strucutred DataFrame that has been uniformly created from the raw Textract table
    """
    arr = df[df.columns[0]]
    
    # iterate through each line item, looking for cut off naming convention
    for idx, line_item in enumerate(arr):
        
        try:
            # our key phrase is "(a) The following table..." found in J.P. Morgan filings with VIE
            check1 = re.search('\(a\) The following table', line_item, flags=re.I)
            check2 = re.search('\(a\) The follow', line_item, flags=re.I)
            
            if check1 is not None or check2 is not None:
                # remove all the line below the condition being met
                return df.iloc[:idx] 
            
        # trying to perform regex on a NaN object (not-compatible)
        except TypeError:
            pass
        
    return df

# %% [markdown]
# # Wrapper Functions

# %%
def clean_wrapper(df: pd.DataFrame, textract_text: dict, key: str, file: str, 
                  old_scaler: str, old_cik: str) -> pd.DataFrame:
    """
    A wrapper function that sequentially calls each cleaning function to fix issues that may arise
    post Textract reading (i.e. Column Merging, Row Splitting, Numeric Conversion)
    ------------------------------------------------------------------------------------
    Input:
        :param df:
            Original unfiltered pandas.DataFrame object representing balance sheet figures
            
    Output:
        :param return:
            A strucutred DataFrame that has been uniformly created from the raw Textract table
    """
    
    # re-assign dataframe of balance sheet after cleanse
    df = column_purge(df)
    
    # --------------------------------------------------------------------------------------------------
    # J.P. Morgan Special Case Handle
    # --------------------------------------------------------------------------------------------------
    
    # performs a check to remove uncessary rows for specific J.P. Morgan releases
    df = jpm_check(df)
    
    # --------------------------------------------------------------------------------------------------
    # COLUMN MERGING (IF NECESSARY)
    # --------------------------------------------------------------------------------------------------

    # if columns greater than 2, we have a weird data table that needs to be "merged"
    # NOTE: By construction we never have more than 3 columns present, thanks to our Textract check 
    if df.columns.size > 2:
        df = merge(df)
        print('\tWe merged the columns of {}'.format(file))

    # --------------------------------------------------------------------------------------------------
    # ROW SPLIT FOR MERGED ROWS (IF NECESSARY)
    # --------------------------------------------------------------------------------------------------

    # check for presence of row splits and correct any if found 
    tempDF = row_split(df, textract_text[key])

    # if difference is found in shape, then a transformation was done 
    if tempDF.shape != df.shape:
        print("\tFixed the merged rows for {}".format(file))

    # --------------------------------------------------------------------------------------------------
    # NUMERIC CONVERSION
    # --------------------------------------------------------------------------------------------------

    # pass numeric converter to the column to convert string to numerics
    tempDF[tempDF.columns[1]] = tempDF[tempDF.columns[1]].apply(cleanNumeric)

    # remove any NaN rows post numeric-conversion
    postDF = tempDF.dropna().copy()

    # check for potential scaler multipler on cash flows (adjust multiplier if possible)
    scale = num_scale(textract_text, key, old_cik, old_scaler)
    postDF[postDF.columns[1]] = postDF[postDF.columns[1]].apply(lambda x: x * scale)

    print('\tWe converted to numeric figures for {}'.format(file))
    
    # --------------------------------------------------------------------------------------------------
    # BALANCE SHEET EXPORTATION
    # --------------------------------------------------------------------------------------------------
    
    print(postDF)
    return postDF, scale, key.split('-')[0]

# %% [markdown]
# ## Final Main Execution

# %%
if __name__ == "__main__":
    
    # initiate s3 bucket and corresponding data folder
    bucket = 'ran-s3-systemic-risk'
    
    pdf_data_folder = 'Output/X-17A-5-PDF-RAW/'
    png_data_folder = 'Output/X-17A-5-PNG-RAW/'
    
    pdf_output_folder = 'Output/X-17A-5-CLEAN-PDFS/'
    png_output_folder = 'Output/X-17A-5-CLEAN-PNGS/'

    # Amazon Textract client and Sagemaker session
    s3 = boto3.client('s3')
    session = Session()
    
    # retrieving text JSON file from s3 bucket and store to temp 
    s3.download_file(bucket, 'Temp/X17A5-TEXT.json', 'temp2.json')

    # read data on TEXT-Confidence dictionary
    with open('temp2.json', 'r') as f: text_dictionary = json.loads(f.read())  

    # remove local files for JSON
    os.remove('temp2.json')
    
    # csv directory with all X-17A-5 balance sheet information 
    pdf_paths = np.array(session.list_s3_files(bucket, pdf_data_folder))[1:]
    png_paths = np.array(session.list_s3_files(bucket, png_data_folder))[1:]
    
    # ==============================================================================================
    
    # trailing scaler for firms who forgot to add "in amounts"
    prior_scaler = 1.0
    prior_cik = np.nan
    
    # iterate through each csv path e.g. ['Output/X-17A-5-PDF-RAW/58056-2014-03-04.csv']
    for pdf_csv in pdf_paths:
        
        fileName = pdf_csv.split('/')[-1]                  # strip filename from each csv
        base_file = fileName.split('.')[0]                 # CIK-YYYY-MM-DD base name
        print('\nCleaning the {} file'.format(fileName))
        
        # download X-17A-5 csv file as a temporary csv file  
        s3.download_file(bucket, pdf_csv, 'temp.csv')
        df = pd.read_csv('temp.csv')
        
        # perform cleaning operations on read dataframe
        out_df, prior_scaler, prior_cik = clean_wrapper(df, text_dictionary, base_file, fileName, 
                                                        prior_scaler, prior_cik)
        
        # writing data frame to .csv file
        out_df.to_csv(fileName, index=False)

        # save contents to AWS S3 bucket
        with open(fileName, 'rb') as data:
            s3.put_object(Bucket=bucket, Key=pdf_output_folder + fileName, Body=data)

        # remove local file after it has been used
        os.remove(fileName)
        os.remove('temp.csv')
    
    # ==============================================================================================
    
    # trailing scaler for firms who forgot to add "in amounts"
    prior_scaler = 1.0
    prior_cik = np.nan
    
    # iterate through each csv path e.g. ['Output/X-17A-5-PNG-RAW/58056-2014-03-04.csv']
    for png_csv in png_paths:
        
        fileName = png_csv.split('/')[-1]                  # strip filename from each csv
        base_file = fileName.split('.')[0]                 # CIK-YYYY-MM-DD base name
        print('\nCleaning the {} file'.format(fileName))
        
        # download X-17A-5 csv file as a temporary csv file  
        s3.download_file(bucket, png_csv, 'temp.csv')
        df = pd.read_csv('temp.csv')
        
        # perform cleaning operations on read dataframe
        out_df, prior_scaler, prior_cik = clean_wrapper(df, text_dictionary, base_file, fileName, 
                                                        prior_scaler, prior_cik)
        
        # writing data frame to .csv file
        out_df.to_csv(fileName, index=False)

        # save contents to AWS S3 bucket
        with open(fileName, 'rb') as data:
            s3.put_object(Bucket=bucket, Key=png_output_folder + fileName, Body=data)

        # remove local file after it has been used
        os.remove(fileName)
        os.remove('temp.csv')
        
    print('\n\n\nAll .csv files are cleaned and primed')
# Out:
# Cleaning the 1146184-2004-03-01.csv file
# 	We converted to numeric figures for 1146184-2004-03-01.csv
#                                                   0             1
# 0               Corporate stock (cost $586,245,565)  6.007086e+08
# 1                       Options (cost $680,481,365)  7.040185e+08
# 2                         Cash and cash equivalents  4.108522e+07
# 3              Receivables from brokers and dealers  6.282187e+08
# 4   Receivables from futures and OTC counterparties  6.217130e+05
# 5                              Dividends receivable  1.158454e+06
# 6                     Exchange memberships, at cost  9.000000e+06
# 7                                      Other assets  2.825000e+06
# 8                                      Total assets  1.987636e+09
# 12        Corporate stock (proceeds $1,261,282,922)  1.291545e+09
# 13                  Options (proceeds $565,083,855)  5.463230e+08
# 14                                Dividends payable  4.160910e+05
# 15                           Payables to affiliates  2.495030e+05
# 16                                Total liabilities  1.838533e+09
# 17                                 Members' capital  1.491028e+08
# 18           Total liabilities and members' capital  1.987636e+09
#
# Cleaning the 1146184-2006-03-01.csv file
# 	We converted to numeric figures for 1146184-2006-03-01.csv
#                                                     0             1
# 0                           Cash and cash equivalents  3.238739e+08
# 1                     Receivables from broker-dealers  1.005689e+08
# 2           Receivables from futures clearing brokers  1.291574e+08
# 4                                     Corporate stock  2.103089e+09
# 5                          Corporate debt obligations  6.233000e+04
# 6                                             Options  3.046181e+09
# 7                                           Exchanges  1.269221e+07
# 8                   Interest and dividends receivable  8.366594e+06
# 9                                 Securities borrowed  5.257076e+06
# 10  Exchange memberships, at cost (market value $4...  3.657860e+07
# 11                                       Other assets  3.788907e+06
# 12                                       Total assets  5.769615e+09
# 13                         Payables to broker-dealers  2.271537e+06
# 14                  Payable to clearing organizations  2.039574e+06
# 16                                    Corporate stock  2.532995e+09
# 17                         Corporate debt obligations  2.765100e+04
# 18                                            Options  2.646988e+09
# 19                     Interest and dividends payable  1.914006e+06
# 20                                  Securities loaned  3.985650e+05
# 21                              Payable to affiliates  5.701569e+06
# 22                                  Other liabilities  3.227953e+06
# 23                                  Total liabilities  5.195564e+09
# 24                                   Members' capital  5.740517e+08
# 25             Total liabilities and members' capital  5.769615e+09
#
# Cleaning the 1146184-2007-02-26.csv file
# 	We converted to numeric figures for 1146184-2007-02-26.csv
#                                                     0             1
# 0                           Cash and cash equivalents  7.418900e+07
# 1          Securities owned, held at clearing brokers  5.224232e+09
# 2      Securities purchased under agreement to resell  2.801160e+08
# 3   Receivables from broker-dealers, clearing orga...  2.814400e+07
# 4                                Dividends receivable  3.923000e+06
# 5                           Receivable from affiliate  3.669700e+07
# 6   Exchange memberships, at cost (market value $5...  3.954900e+07
# 7                                               Other  4.413000e+06
# 8                                        Total assets  5.691263e+09
# 10                 Securities sold, not yet purchased  4.707712e+09
# 11                          Payable to broker-dealers  3.017850e+08
# 12                                  Securities loaned  7.687000e+06
# 13                                  Dividends payable  4.422000e+06
# 14                               Payable to affiliate  2.592000e+06
# 15                                              Other  3.264000e+06
# 16                                  Total liabilities  5.027462e+09
# 17                                   Members' capital  6.638010e+08
# 18             Total liabilities and members' capital  5.691263e+09
#
# Cleaning the 1146184-2008-02-29.csv file
# 	We converted to numeric figures for 1146184-2008-02-29.csv
#                                                     0             1
# 0                           Cash and cash equivalents  5.914400e+07
# 1          Securities owned, held at clearing brokers  5.263591e+09
# 2      Securities purchased under agreement to resell  2.820370e+08
# 3   Receivables from brokers and dealers, clearing...  1.065548e+09
# 4                                Dividends receivable  4.011000e+06
# 5                           Receivable from affiliate  2.742100e+07
# 6   Exchange memberships, at cost (fair value $69,...  4.560200e+07
# 7                                        Other assets  1.512700e+07
# 8                                        Total assets  6.762481e+09
# 11                 Securities sold, not yet purchased  5.864432e+09
# 12                                  Dividends payable  5.941000e+06
# 13                              Payable to affiliates  1.926300e+07
# 14                                  Other liabilities  1.326300e+07
# 15                                  Total liabilities  5.902899e+09
# 16                                   Members' capital  8.595820e+08
# 17             Total liabilities and members' capital  6.762481e+09
#
# Cleaning the 1146184-2009-03-02.csv file
# 	We converted to numeric figures for 1146184-2009-03-02.csv
#                                                     0             1
# 0                           Cash and cash equivalents  4.005170e+08
# 1                                    Securities owned  6.594092e+09
# 2     Securities purchased under agreements to resell  3.874800e+07
# 3   Receivable from brokers, dealers, clearing org...  2.490330e+08
# 4                                 Securities borrowed  5.220054e+09
# 5    Collateral held under securities loan agreements  4.107820e+08
# 6                                Dividends receivable  9.937000e+06
# 7                          Receivable from affiliates  5.204000e+06
# 8   Exchange memberships and trading rights, at co...  5.647800e+07
# 9                                        Other assets  6.713000e+06
# 10                                       Total assets  1.299156e+10
# 13                 Securities sold, not yet purchased  5.849511e+09
# 14     Securities sold under agreements to repurchase  5.974370e+08
# 15  Payable to brokers, dealers and clearing organ...  3.512240e+08
# 16                                  Securities loaned  4.483463e+09
# 17                                  Dividends payable  3.553000e+06
# 18                              Payable to affiliates  4.095870e+08
# 19                                  Other liabilities  2.619000e+07
# 20  Total liabilities before subordinated borrowin...  1.172096e+10
# 21             Subordinated borrowings from affiliate  1.200000e+08
# 22                                  Total liabilities  1.184096e+10
# 23                                   Members' capital  1.150593e+09
# 24             Total liabilities and members' capital  1.299156e+10
#
# Cleaning the 1146184-2010-02-25.csv file
# 	We converted to numeric figures for 1146184-2010-02-25.csv
#                                                     0             1
# 0                                 Securities borrowed  1.121101e+10
# 1    Collateral held under securities loan agreements  5.885790e+09
# 2                          Receivable from affiliates  2.902000e+06
# 3                                        Other assets  1.522100e+07
# 6                  Securities sold, not yet purchased  5.542263e+09
# 7      Securities sold under agreements to repurchase  3.200847e+09
# 8   Payable to brokers, dealers and clearing organ...  9.733000e+06
# 9                                   Securities loaned  1.390256e+10
# 10                                  Dividends payable  1.665000e+06
# 11      Payable to affiliates for clearing activities  1.103630e+08
# 12                              Payable to affiliates  1.919000e+06
# 13                                   Interest payable  8.709000e+06
# 14                                  Other liabilities  3.479100e+07
# 15                                  Total liabilities  2.281285e+10
# 16                                   Members' capital  1.079220e+09
# 17             Total liabilities and members' capital  2.389207e+10
#
# Cleaning the 1146184-2011-02-25.csv file
# 	We converted to numeric figures for 1146184-2011-02-25.csv
#                                                     0             1
# 0    Collateral held under securities loan agreements  6.991504e+09
# 1                Receivable from affiliated customers  4.336000e+06
# 2                           Receivable from customers  3.141000e+06
# 3                           Receivable for order flow  1.412200e+07
# 4                                 Interest receivable  1.032700e+07
# 5                                        Other assets  8.776000e+06
# 7                  Securities sold, not yet purchased  5.532722e+09
# 8   Payable to brokers, dealers, clearing organiza...  1.706707e+09
# 9                                   Securities loaned  1.534327e+10
# 10                             Payable for order flow  3.444300e+07
# 11                    Payable to affiliated customers  1.356000e+06
# 12                              Payable to affiliates  4.009500e+07
# 13                                   Interest payable  9.946000e+06
# 14                                  Dividends payable  3.894000e+06
# 15                                  Other liabilities  1.382400e+07
# 16                                  Total liabilities  2.772440e+10
# 17                                   Members' capital  9.495880e+08
# 18             Total liabilities and members' capital  2.867399e+10
#
# Cleaning the 1146184-2012-02-28.csv file
# 	We converted to numeric figures for 1146184-2012-02-28.csv
#                                                     0             1
# 0                                                Cash  3.815740e+08
# 1            Cash segregated under federal regulation  2.900000e+07
# 2                                    Securities owned  5.912079e+09
# 3     Securities purchased under agreements to resell  3.135300e+07
# 4   Receivable from brokers, dealers, clearing org...  1.353670e+08
# 5                                 Securities borrowed  1.915982e+10
# 6    Collateral held under securities loan agreements  7.528316e+09
# 7                Receivable from affiliated customers  5.268000e+06
# 8                          Receivable from affiliates  1.241800e+07
# 9   Exchange memberships and trading rights (fair ...  2.885100e+07
# 10                          Receivable for order flow  6.257000e+06
# 11                               Dividends receivable  8.110000e+06
# 12                                       Other assets  7.615000e+06
# 13                                       Total assets  3.324603e+10
# 16                 Securities sold, not yet purchased  4.345136e+09
# 17     Securities sold under agreements to repurchase  5.114066e+09
# 18  Payable to brokers, dealers, and futures commi...  1.272518e+09
# 19                                  Securities loaned  2.143108e+10
# 20                             Payable for order flow  3.028800e+07
# 21                              Payable to affiliates  5.486700e+07
# 22                                   Interest payable  2.412000e+06
# 23                                  Dividends payable  2.380000e+06
# 24                                  Other liabilities  1.464400e+07
# 25                                  Total liabilities  3.226739e+10
# 26                                   Member's capital  9.786350e+08
# 27             Total liabilities and member's capital  3.324603e+10
#
# Cleaning the 1146184-2015-02-25.csv file
# 	We converted to numeric figures for 1146184-2015-02-25.csv
#                                                     0             1
# 0                                                Cash  3.198920e+08
# 1            Cash segregated under federal regulation  2.710000e+07
# 2                                 Securities borrowed  2.736980e+10
# 3                     Securities owned, at fair value  9.494325e+09
# 4    Collateral held under securities loan agreements  8.019006e+09
# 5   Receivable from clearing organizations and cus...  1.370850e+08
# 6                 Receivable from brokers and dealers  4.295000e+06
# 7                           Receivable for order flow  2.494700e+07
# 8   Exchange memberships and trading rights (fair ...  1.551900e+07
# 9                                        Other assets  1.516900e+07
# 10    Securities purchased under agreements to resell  1.416300e+07
# 11                               Dividends receivable  1.067700e+07
# 12               Receivable from affiliated customers  6.876000e+06
# 13                                       Total assets  4.545885e+10
# 15                                  Securities loaned  2.960582e+10
# 16  Securities sold, not yet purchased, at fair value  6.003822e+09
# 17     Securities sold under agreements to repurchase  5.614427e+09
# 18                     Payable to brokers and dealers  3.070631e+09
# 19                  Payable to clearing organizations  2.501700e+07
# 20                             Payable for order flow  5.361300e+07
# 21                              Payable to affiliates  3.703000e+07
# 22   Exchange, clearance, and regulatory fees payable  1.895500e+07
# 23                                   Interest payable  3.483000e+06
# 24                                  Other liabilities  3.042000e+06
# 25                                  Dividends payable  2.803000e+06
# 26                                  Total liabilities  4.443864e+10
# 27                                   Member's capital  1.020209e+09
# 28             Total liabilities and member's capital  4.545885e+10
#
# Cleaning the 1146184-2016-02-24.csv file
# 	We converted to numeric figures for 1146184-2016-02-24.csv
#                                                     0             1
# 0                                                Cash  4.771690e+08
# 1            Cash segregated under federal regulation  4.100000e+06
# 2                     Securities owned, at fair value  5.972924e+09
# 3                 Receivable from brokers and dealers  1.003487e+09
# 4                                 Securities borrowed  9.455890e+08
# 5   Receivable from clearing organizations and cus...  3.788790e+08
# 6                           Receivable for order flow  2.592900e+07
# 7                                        Other assets  1.571300e+07
# 8   Exchange memberships and trading rights (fair ...  1.513100e+07
# 9     Securities purchased under agreements to resell  9.593000e+06
# 10                               Dividends receivable  5.118000e+06
# 11                                       Total assets  8.853632e+09
# 14  Securities sold, not yet purchased, at fair value  6.464142e+09
# 15     Securities sold under agreements to repurchase  1.236536e+09
# 16                             Payable for order flow  6.432600e+07
# 17                              Payable to affiliates  4.600900e+07
# 18                                  Securities loaned  2.920300e+07
# 19  Payable to brokers, dealers, and clearing orga...  1.877100e+07
# 20   Exchange, clearance, and regulatory fees payable  1.705600e+07
# 21                                  Dividends payable  3.437000e+06
# 22                                  Other liabilities  3.225000e+06
# 23                                  Total liabilities  7.882705e+09
# 24                                   Member's capital  9.709270e+08
# 25             Total liabilities and member's capital  8.853632e+09
#
# Cleaning the 1146184-2017-02-24.csv file
# 	We converted to numeric figures for 1146184-2017-02-24.csv
#                                                     0             1
# 1                                                Cash  4.494620e+08
# 2                     Securities owned, at fair value  9.252290e+09
# 3                                 Securities borrowed  1.388434e+09
# 4   Receivable from clearing organizations and cus...  4.698190e+08
# 5                 Receivable from brokers and dealers  4.624440e+08
# 6                           Receivable for order flow  3.680700e+07
# 7   Exchange memberships and trading rights (fair ...  2.896100e+07
# 8                                        Other assets  1.064900e+07
# 9     Securities purchased under agreements to resell  7.749000e+06
# 10                               Dividends receivable  3.669000e+06
# 11                                       Total assets  1.211028e+10
# 14  Securities sold, not yet purchased, at fair value  7.298121e+09
# 15  Payable to brokers, dealers, clearing organiza...  2.311836e+09
# 16     Securities sold under agreements to repurchase  1.308321e+09
# 17                             Payable for order flow  7.544700e+07
# 18                              Payable to affiliates  6.672900e+07
# 19                                  Other liabilities  2.435400e+07
# 20   Exchange, clearance, and regulatory fees payable  2.405600e+07
# 21                                  Securities loaned  2.083700e+07
# 22                                  Dividends payable  8.785000e+06
# 23                                  Total liabilities  1.113849e+10
# 24                                   Member's capital  9.717980e+08
# 25             Total liabilities and member's capital  1.211028e+10
#
# Cleaning the 1146184-2018-02-27.csv file
# 	We converted to numeric figures for 1146184-2018-02-27.csv
#                                                     0             1
# 1   Securities sold, not yet purchased, at fair value  1.724591e+10
# 2   Payable to brokers, dealers, clearing organiza...  9.443405e+09
# 3      Securities sold under agreements to repurchase  4.378857e+09
# 4                Payable for liquidity and order flow  8.892000e+07
# 5                               Payable to affiliates  6.969100e+07
# 6                                   Securities loaned  5.858100e+07
# 7    Exchange, clearance, and regulatory fees payable  3.202700e+07
# 8                                    Interest payable  2.494400e+07
# 9                                   Dividends payable  1.834200e+07
# 10                                  Other liabilities  1.185000e+06
# 11  Total liabilities before subordinated loans an...  3.136186e+10
# 12            Subordinated loans and accrued interest  3.545750e+08
# 13                                  Total liabilities  3.171644e+10
# 14                                   Member's capital  9.765350e+08
# 15             Total liabilities and member's capital  3.269298e+10
#
# Cleaning the 1146184-2019-02-28.csv file
# 	We converted to numeric figures for 1146184-2019-02-28.csv
#                                                     0             1
# 0                                                Cash  6.170000e+08
# 1                     Securities owned, at fair value  3.023700e+10
# 2                                 Securities borrowed  1.861000e+09
# 3     Securities purchased under agreements to resell  9.380000e+08
# 4                 Receivable from brokers and dealers  8.410000e+08
# 5   Receivable from clearing organizations and cus...  3.080000e+08
# 6                                 Interest receivable  5.700000e+07
# 7                                        Other assets  3.500000e+07
# 8   Exchange memberships and trading rights (fair ...  2.200000e+07
# 9                                Dividends receivable  1.600000e+07
# 10                                       Total assets  3.493200e+10
# 13  Securities sold, not yet purchased, at fair value  2.235700e+10
# 14     Securities sold under agreements to repurchase  7.663000e+09
# 15  Payable to brokers, dealers, and clearing orga...  2.764000e+09
# 16                              Payable to affiliates  6.600000e+07
# 17               Payable for liquidity and order flow  6.400000e+07
# 18   Exchange, clearance, and regulatory fees payable  2.900000e+07
# 19                                   Interest payable  2.300000e+07
# 20                                  Other liabilities  1.800000e+07
# 21                                  Securities loaned  1.700000e+07
# 22                                  Dividends payable  8.000000e+06
# 23  Total liabilities before subordinated loans an...  3.300900e+10
# 24            Subordinated loans and accrued interest  3.570000e+08
# 25                                  Total liabilities  3.336600e+10
# 26                                   Member's capital  1.566000e+09
# 27             Total liabilities and member's capital  3.493200e+10
#
# Cleaning the 1146184-2020-02-28.csv file
# 	We converted to numeric figures for 1146184-2020-02-28.csv
#                                                     0             1
# 1   Securities sold, not yet purchased, at fair value  2.527000e+10
# 2      Securities sold under agreements to repurchase  6.352000e+09
# 3   Payable to brokers, dealers, and clearing orga...  3.870000e+08
# 4                          Loans payable to affiliate  3.910000e+08
# 5                               Payable to affiliates  8.800000e+07
# 6                Payable for liquidity and order flow  8.800000e+07
# 7                                   Securities loaned  4.600000e+07
# 8    Exchange, clearance, and regulatory fees payable  3.100000e+07
# 9                                   Other liabilities  3.700000e+07
# 10                                  Total liabilities  3.269000e+10
# 11                                   Member's capital  1.656000e+09
# 12             Total liabilities and member's capital  3.434600e+10
#
# Cleaning the 1146184-2021-02-25.csv file
# 	We converted to numeric figures for 1146184-2021-02-25.csv
#                                                     0             1
# 0                                        Other assets  1.650000e+08
# 3   Securities sold, not yet purchased, at fair value  5.750600e+10
# 4      Securities sold under agreements to repurchase  4.472000e+09
# 5   Payable to brokers, dealers, and clearing orga...  2.847000e+09
# 6             Loans and interest payable to affiliate  1.653000e+09
# 7                                   Securities loaned  8.670000e+08
# 8                                   Other liabilities  3.420000e+08
# 9                               Payable to affiliates  1.680000e+08
# 10                                  Total liabilities  6.785500e+10
# 11                                   Member's capital  3.149000e+09
# 12             Total liabilities and member's capital  7.100400e+10
#
# Cleaning the 1215680-2004-03-01.csv file
# 	We converted to numeric figures for 1215680-2004-03-01.csv
#                                                     0          1
# 0                           Cash and cash equivalents   377386.0
# 1                                    Prepaid expenses   101467.0
# 2   Fixed assets, net of accumulated depreciation ...   171659.0
# 3                                        Other assets     9653.0
# 4                                        Total assets   660165.0
# 6         Accounts payable and other accrued expenses    63000.0
# 7                                       Deferred rent    10952.0
# 8                                   Total liabilities    73952.0
# 10  Preferred units; par value $10,000 per share -...  1420000.0
# 11  Common units; par value $10,000 per share - au...    10000.0
# 12       Deficit accumulated during development stage  -843787.0
# 13                              Total members' equity   586213.0
# 14              Total liabilities and members' equity   660165.0
#
# Cleaning the 1215680-2005-03-01.csv file
# 	We converted to numeric figures for 1215680-2005-03-01.csv
#                                                     0             1
# 0                           Cash and cash equivalents  3.633603e+06
# 1     Securities purchased under agreements to resell  6.766156e+09
# 3         all are pledged to a clearing organization)  5.990500e+07
# 4                Deposits with clearing organizations  2.791913e+06
# 5             Receivable from a clearing organization  4.189250e+05
# 6   Fixed assets, net of $49,763 accumulated depre...  1.662130e+05
# 7                   Prepaid expenses and other assets  3.183400e+04
# 8                                        Total assets  6.833104e+09
# 11     Securities sold under agreements to repurchase  6.541488e+09
# 12                                    Payable to FICC  9.167042e+07
# 13                                   Accrued expenses  1.486908e+06
# 14                                  Total liabilities  6.634645e+09
# 15                                    Member's Equity  1.984587e+08
# 16              Total liabilities and member's equity  6.833104e+09
#
# Cleaning the 1215680-2006-03-01.csv file
# 	We converted to numeric figures for 1215680-2006-03-01.csv
#                                                     0             1
# 0                                                Cash  1.133769e+06
# 1                Deposits with clearing organizations  6.650000e+05
# 2     Securities purchased under agreements to resell  6.771563e+09
# 3   Financial instruments owned, at market value (...  3.266510e+09
# 4              Receivable from clearing organizations  1.245136e+08
# 5                                   Fixed assets, net  1.083730e+05
# 6                   Prepaid expenses and other assets  1.807360e+05
# 7                                        Total assets  1.016467e+10
# 10     Securities sold under agreements to repurchase  9.896225e+09
# 11                                   Accrued expenses  1.994942e+06
# 12                                  Total liabilities  9.898220e+09
# 13                                    Member's Equity  2.664548e+08
# 14              Total liabilities and member's equity  1.016467e+10
#
# Cleaning the 1215680-2007-03-01.csv file
# 	We converted to numeric figures for 1215680-2007-03-01.csv
#                                                   0             1
# 0                                              Cash  7.442100e+05
# 1               Deposits with clearing organization  5.000000e+05
# 2             Receivable from clearing organization  6.655840e+05
# 3   Securities purchased under agreements to resell  1.187168e+09
# 4      Receivable from customers and counterparties  1.062200e+04
# 5                                 Fixed assets, net  4.470300e+04
# 6                 Prepaid expenses and other assets  3.986730e+05
# 7                                      Total assets  1.189532e+09
# 10   Securities sold under agreements to repurchase  1.046391e+09
# 11                 Payable to clearing organization  2.681330e+05
# 12                                 Accrued expenses  1.273309e+06
# 13                                Total liabilities  1.047932e+09
# 14                                  Member's Equity  1.415997e+08
# 15            Total liabilities and member's equity  1.189532e+09
#
# Cleaning the 1215680-2008-02-29.csv file
# 	We converted to numeric figures for 1215680-2008-02-29.csv
#                                                     0             1
# 0                                                Cash  3.874280e+05
# 1   Receivable and deposits with clearing organiza...  1.450477e+06
# 2     Securities purchased under agreements to resell  2.025028e+09
# 3                                   Fixed assets, net  1.853300e+04
# 4                                        Other assets  4.131230e+05
# 5                                        Total assets  2.027297e+09
# 8      Securities sold under agreements to repurchase  1.887163e+09
# 9                                    Accrued expenses  9.966010e+05
# 10                                  Total liabilities  1.888160e+09
# 11                                    Member's Equity  1.391370e+08
# 12              Total liabilities and member's equity  2.027297e+09
#
# Cleaning the 1215680-2009-03-04.csv file
# 	We converted to numeric figures for 1215680-2009-03-04.csv
#                                                   0             1
# 0                                              Cash  3.594267e+06
# 1               Deposits with clearing organization  5.500352e+06
# 2   Securities purchased under agreements to resell  4.865547e+09
# 3                                 Fixed assets, net  6.757000e+03
# 4                                      Other assets  6.111390e+05
# 5                                      Total assets  4.875260e+09
# 8    Securities sold under agreements to repurchase  4.719654e+09
# 9                  Payable to clearing organization  6.063210e+05
# 10                                 Accrued expenses  1.340390e+06
# 11                                Total liabilities  4.721601e+09
# 12                                  Member's Equity  1.536591e+08
# 13            Total liabilities and member's equity  4.875260e+09
#
# Cleaning the 1215680-2010-02-26.csv file
# 	We converted to numeric figures for 1215680-2010-02-26.csv
#                                                     0             1
# 0                                                Cash  1.126610e+05
# 1   Receivable and deposits with clearing organiza...  6.492440e+06
# 2   Financial instruments owned, at market value (...  1.534211e+08
# 3     Securities purchased under agreements to resell  5.609789e+09
# 4                                   Fixed assets, net  3.244000e+03
# 5                                        Other assets  2.937940e+05
# 6                                        Total assets  5.770112e+09
# 9      Securities sold under agreements to repurchase  5.617167e+09
# 10                   Payable to clearing organization  1.078548e+07
# 11                                   Accrued expenses  1.458454e+06
# 12                                  Total liabilities  5.629411e+09
# 13                                    Member's equity  1.407014e+08
# 14              Total liabilities and member's equity  5.770112e+09
# Cleaning the 1215680-2011-03-01.csv file
# 	We converted to numeric figures for 1215680-2011-03-01.csv
#                                                     0             1
# 0                                                Cash  8.597620e+05
# 1   Receivable and deposits with clearing organiza...  3.908551e+07
# 2   Financial instruments owned, at market value (...  5.556508e+07
# 3     Securities purchased under agreements to resell  8.281872e+09
# 4                                        Other assets  2.795140e+05
# 5                                        Total assets  8.377662e+09
# 8      Securities sold under agreements to repurchase  8.316894e+09
# 9                                    Accrued expenses  5.166650e+05
# 10                                  Total liabilities  8.317410e+09
# 11                                    Member's equity  6.025189e+07
# 12              Total liabilities and member's equity  8.377662e+09
#
# Cleaning the 1215680-2012-02-29.csv file
# 	Fixed the merged rows for 1215680-2012-02-29.csv
# 	We converted to numeric figures for 1215680-2012-02-29.csv
#                                                     0             1
# 0                                                Cash  7.509614e+06
# 1   Receivable and deposits with clearing organiza...  2.451586e+08
# 2   Financial instruments owned, at market value (...  1.024962e+07
# 3     Securities purchased under agreements to resell  1.190936e+10
# 4                                        Other assets  2.513030e+05
# 5                                        Total assets  1.217252e+10
# 8      Securities sold under agreements to repurchase  1.210663e+10
# 9                                    Accrued expenses  9.688350e+05
# 10                                  Total liabilities  1.210760e+10
# 11                                    Member's equity  6.492592e+07
# 0                                   Total liabilities  1.000000e+00
# 0               Total liabilities and member's equity  2.217252e+10
#
# Cleaning the 1215680-2013-03-01.csv file
# 	We converted to numeric figures for 1215680-2013-03-01.csv
#                                                     0             1
# 0                                                Cash  1.358046e+07
# 1   Receivable and deposits with clearing organiza...  3.040284e+07
# 2     Securities purchased under agreements to resell  1.365964e+10
# 3                                        Other assets  3.095490e+05
# 4                                        Total assets  1.370394e+10
# 7      Securities sold under agreements to repurchase  1.360090e+10
# 8                                    Accrued expenses  9.814310e+05
# 9                                   Total liabilities  1.360188e+10
# 10                                    Member's equity  1.020589e+08
# 11              Total liabilities and member's equity  1.370394e+10
#
# Cleaning the 1215680-2014-02-28.csv file
# 	We converted to numeric figures for 1215680-2014-02-28.csv
#                                                     0             1
# 0                                                Cash  1.096222e+07
# 1   Financial instruments owned, at market value (...  7.187895e+08
# 2   Receivable and deposits with clearing organiza...  1.832666e+08
# 3     Securities purchased under agreements to resell  1.836599e+10
# 4                         Accrued interest receivable  9.566040e+05
# 5                                        Other assets  2.857470e+05
# 6                                        Total assets  1.928025e+10
# 9      Securities sold under agreements to repurchase  1.916942e+10
# 10                                   Accrued expenses  1.317950e+06
# 11                                  Total liabilities  1.917074e+10
# 12                                    Member's equity  1.095138e+08
# 13              Total liabilities and member's equity  1.928025e+10
#
# Cleaning the 1215680-2015-02-27.csv file
# 	We converted to numeric figures for 1215680-2015-02-27.csv
#                                                     0             1
# 0                                                Cash  9.744699e+06
# 1   Financial instruments owned, at market value (...  1.646185e+09
# 2   Receivable and deposits with clearing organiza...  1.986360e+07
# 3     Securities purchased under agreements to resell  1.968733e+10
# 4                         Accrued interest receivable  9.125370e+05
# 5                                        Other assets  2.359120e+05
# 6                                        Total assets  2.136427e+10
# 9      Securities sold under agreements to repurchase  2.119248e+10
# 10                   Payable to clearing organization  5.239884e+07
# 11                            Other trading liability  3.118768e+06
# 12                                   Accrued expenses  1.089233e+06
# 13                                  Total liabilities  2.124909e+10
# 14                                    Member's equity  1.151822e+08
# 15              Total liabilities and member's equity  2.136427e+10
#
# Cleaning the 1215680-2016-06-16.csv file
# 	We converted to numeric figures for 1215680-2016-06-16.csv
#                                                     0             1
# 0                                                Cash  4.676024e+06
# 1   Financial instruments owned, at fair value (co...  8.015332e+08
# 3             (includes $6,554,333,293 at fair value)  2.451413e+10
# 4   Receivables and deposits with brokers, dealers...  2.382054e+07
# 5                         Accrued interest receivable  8.521630e+05
# 6                                        Other assets  6.392960e+05
# 7                                        Total assets  2.534565e+10
# 11              (includes $783,419,799 at fair value)  2.513250e+10
# 12  Payables to brokers, dealers and clearing orga...  7.932411e+07
# 13                            Other trading liability  4.041959e+06
# 14                                   Accrued expenses  1.299343e+06
# 15                                  Total liabilities  2.521717e+10
# 16                                    Member's equity  1.284810e+08
# 17              Total liabilities and member's equity  2.534565e+10
#
# Cleaning the 1215680-2017-03-07.csv file
# 	We converted to numeric figures for 1215680-2017-03-07.csv
#                                                     0             1
# 0                                                Cash  2.779283e+07
# 1   Financial instruments owned, at fair value (co...  7.003552e+08
# 3            (includes $11,756,761,353 at fair value)  2.852252e+10
# 4   Receivables and deposits with brokers, dealers...  1.218385e+07
# 5                                Other trading assets  3.402457e+06
# 6                         Accrued interest receivable  1.085293e+06
# 7                                        Other assets  6.345100e+05
# 8                                        Total assets  2.926798e+10
# 12              (includes $348,908,859 at fair value)  2.897275e+10
# 13                   Payable to clearing organization  1.278326e+08
# 14                                   Accrued expenses  5.941474e+06
# 15                                  Total liabilities  2.910653e+10
# 16                                    Member's equity  1.614499e+08
# 17              Total liabilities and member's equity  2.926798e+10
#
# Cleaning the 1215680-2018-03-01.csv file
# 	We converted to numeric figures for 1215680-2018-03-01.csv
#                                                     0             1
# 0                           Cash and cash equivalents  3.584631e+06
# 1   Financial instruments owned, at fair value (co...  3.986065e+08
# 3            (includes $11,517,661,962 at fair value)  3.157680e+10
# 4   Receivables and deposits with brokers, dealers...  1.493704e+07
# 5                                Other trading assets  1.033394e+07
# 6                         Accrued interest receivable  7.532750e+05
# 7                                        Other assets  2.191460e+06
# 8                                        Total assets  3.200720e+10
# 12               (includes $998,496,84 at fair value)  3.171499e+10
# 13                   Payable to clearing organization  1.120447e+08
# 14                                   Accrued expenses  2.330817e+06
# 15                                  Total liabilities  3.182936e+10
# 16                                    Member's equity  1.778435e+08
# 17              Total liabilities and member's equity  3.200720e+10
#
# Cleaning the 1215680-2019-03-01.csv file
# 	We converted to numeric figures for 1215680-2019-03-01.csv
#                                                     0             1
# 0                                                Cash  1.429130e+07
# 1   Financial instruments owned, at fair value (co...  2.403770e+08
# 2   Securities purchased under agreements to resel...  3.502251e+10
# 3   Deposits with brokers, dealers and clearing or...  3.213662e+07
# 4                                Other trading assets  3.588811e+06
# 5                         Accrued interest receivable  1.116018e+06
# 6                                        Other assets  2.245994e+06
# 7                                        Total assets  3.531627e+10
# 10     Securities sold under agreements to repurchase  3.511628e+10
# 11                   Payable to clearing organization  1.756528e+07
# 12                          Other trading liabilities  3.583267e+06
# 13                                   Accrued expenses  2.889253e+06
# 14                                  Total liabilities  3.514032e+10
# 15                                    Member's equity  1.759478e+08
# 16              Total liabilities and member's equity  3.531627e+10
# Cleaning the 1215680-2020-03-02.csv file
# 	We converted to numeric figures for 1215680-2020-03-02.csv
#                                                     0             1
# 0                                                Cash  8.959392e+06
# 1   Financial instruments owned, at fair value (co...  3.497010e+08
# 2   Securities purchased under agreements to resel...  3.938046e+10
# 3   Deposits with brokers, dealers and clearing or...  2.093520e+07
# 4                                Other trading assets  7.024954e+06
# 5                         Accrued interest receivable  1.435156e+06
# 6                                        Other assets  1.887922e+06
# 7                                  Right of use asset  8.877089e+06
# 8                                        Total assets  3.977928e+10
# 12              (includes $355,728,597 at fair value)  3.953062e+10
# 13                   Payable to clearing organization  1.682195e+07
# 14                          Other trading liabilities  1.001204e+07
# 15                                   Accrued expenses  7.026399e+06
# 16                                    Lease liability  9.354057e+06
# 17                                  Total liabilities  3.957383e+10
# 19                                    Member's equity  2.054512e+08
# 20              Total liabilities and member's equity  3.977928e+10
#
# Cleaning the 1215680-2021-03-02.csv file
# 	We converted to numeric figures for 1215680-2021-03-02.csv
#                                                     0             1
# 0                                                Cash  1.369519e+07
# 1   Securities purchased under agreements to resel...  3.573163e+10
# 2   Deposits with brokers, dealers and clearing or...  1.981625e+07
# 3                                Other trading assets  4.983149e+07
# 4                                  Right of use asset  7.972526e+06
# 5                                        Other assets  1.588927e+06
# 6                                        Total assets  3.582454e+10
# 10              (includes $300,155,028 at fair value)  3.543881e+10
# 11                   Payable to clearing organization  4.988534e+07
# 12                          Other trading liabilities  7.866158e+07
# 13                                    Lease liability  8.461641e+06
# 14                                   Accrued expenses  8.125893e+06
# 15                                  Total liabilities  3.558395e+10
# 17                                    Member's equity  2.405911e+08
# 18              Total liabilities and member's equity  3.582454e+10
#
# Cleaning the 1224385-2004-03-01.csv file
# 	We converted to numeric figures for 1224385-2004-03-01.csv
#                                                     0             1
# 0                                                Cash  1.760000e+05
# 1     Cash segregated pursuant to federal regulations  7.500000e+07
# 2     Securities purchased under agreements to resell  7.944113e+09
# 3   Securities owned, at market value ($8,769,300 ...  9.075170e+09
# 4   Receivable from broker-dealers and clearing or...  4.049708e+09
# 5                           Receivable from customers  5.124600e+07
# 6                         Accrued interest receivable  4.445700e+07
# 7   Property, equipment, and leasehold improvement...  1.106700e+07
# 8                                       Goodwill, net  6.112000e+06
# 9                                        Other assets  2.527380e+08
# 10                                       Total assets  2.150979e+10
# 13     Securities sold under agreements to repurchase  1.360247e+10
# 14  Securities sold, not yet purchased, at market ...  3.686980e+09
# 15  Payable to broker-dealers and clearing organiz...  1.886438e+09
# 16                               Payable to customers  4.498400e+07
# 17                           Accrued interest payable  2.759500e+07
# 18                                  Other liabilities  4.669010e+08
# 19                                  Total liabilities  1.971537e+10
# 20                            Subordinated borrowings  5.385000e+08
# 22                             Member's contributions  1.216068e+09
# 23                               Accumulated earnings  3.984900e+07
# 24                              Total member's equity  1.255917e+09
# 25              Total liabilities and member's equity  2.150979e+10
#
# Cleaning the 1224385-2005-03-01.csv file
# 	We converted to numeric figures for 1224385-2005-03-01.csv
#                                                     0             1
# 0                                                Cash  1.007700e+07
# 1     Securities purchased under agreements to resell  1.192898e+10
# 2   Securities owned, at market value ($14,878,096...  1.598734e+10
# 3   Receivable from broker-dealers and clearing or...  7.080574e+09
# 4                           Receivable from customers  1.165720e+08
# 5                         Accrued interest receivable  1.529670e+08
# 6   Property, equipment, and leasehold improvement...  1.026700e+07
# 7                                       Goodwill, net  6.112000e+06
# 8                                        Other assets  3.187630e+08
# 9                                        Total assets  3.561166e+10
# 12     Securities sold under agreements to repurchase  2.143051e+10
# 13  Securities sold, not yet purchased, at market ...  6.775259e+09
# 14  Payable to broker-dealers and clearing organiz...  3.316738e+09
# 15                               Payable to customers  7.526600e+07
# 16                           Accrued interest payable  8.379900e+07
# 17                                  Other liabilities  6.388790e+08
# 18                                  Total liabilities  3.232045e+10
# 19                            Subordinated borrowings  1.183500e+09
# 21                              Total member's equity  2.107707e+09
# 22              Total liabilities and member's equity  3.561166e+10
#
# Cleaning the 1224385-2006-03-01.csv file
# 	We converted to numeric figures for 1224385-2006-03-01.csv
#                                                     0             1
# 0                                                Cash  2.565500e+07
# 1     Securities purchased under agreements to resell  6.812438e+09
# 2   Securities owned, at market value ($10,215,308...  1.166421e+10
# 3   Receivable from broker-dealers and clearing or...  4.909150e+09
# 4                           Receivable from customers  1.121510e+08
# 5                         Accrued interest receivable  1.129070e+08
# 6   Property, equipment, and leasehold improvement...  1.284500e+07
# 7                                       Goodwill, net  6.112000e+06
# 8                                        Other assets  3.740250e+08
# 9                                        Total assets  2.402949e+10
# 12     Securities sold under agreements to repurchase  1.202697e+10
# 13  Securities sold, not yet purchased, at market ...  5.059406e+09
# 14  Payable to broker-dealers and clearing organiz...  2.199031e+09
# 15                               Payable to customers  1.138800e+07
# 16                           Accrued interest payable  5.932100e+07
# 17                                  Other liabilities  7.619370e+08
# 18                                  Total liabilities  2.011806e+10
# 19                            Subordinated borrowings  1.183500e+09
# 21                              Total member's equity  2.727933e+09
# 22              Total liabilities and member's equity  2.402949e+10
#
# Cleaning the 1224385-2007-03-01.csv file
# 	We converted to numeric figures for 1224385-2007-03-01.csv
#                                                     0             1
# 0                                                Cash  7.480000e+05
# 1     Securities purchased under agreements to resell  4.249897e+09
# 2   Securities owned, at market value ($10,253,591...  1.154806e+10
# 3   Receivable from broker-dealers and clearing or...  4.451402e+09
# 4                           Receivable from customers  2.199900e+07
# 5                         Accrued interest receivable  1.165430e+08
# 6   Property, equipment, and leasehold improvement...  1.146400e+07
# 7                                       Goodwill, net  6.112000e+06
# 8                                        Other assets  4.737010e+08
# 9                                        Total assets  2.087992e+10
# 12     Securities sold under agreements to repurchase  9.294056e+09
# 13  Securities sold, not yet purchased, at market ...  4.241568e+09
# 14  Payable to broker-dealers and clearing organiz...  1.885365e+09
# 15                                   Payable to banks  2.536000e+06
# 16                               Payable to customers  1.435400e+07
# 17                           Accrued interest payable  7.549700e+07
# 18                                  Other liabilities  9.854950e+08
# ...
# 23             Total liabilities and members' capital  2.036271e+10
#
# Cleaning the 922792-2014-03-04.csv file
# 	We converted to numeric figures for 922792-2014-03-04.csv
#                                                     0             1
# 0                           Cash and cash equivalents  7.931730e+08
# 1   Cash and securities - segregated for regulator...  1.254800e+10
# 2                                 Securities borrowed  1.684027e+09
# 3     Securities purchased under agreements to resell  3.863010e+08
# 4                  Deposit with clearing organization  2.500000e+06
# 6   Customers (net of allowance for doubtful accou...  1.353561e+10
# 7         Brokers, dealers and clearing organizations  3.270760e+08
# 8                                          Affiliates  5.971000e+06
# 9                                            Interest  2.037500e+07
# 10                                       Other assets  1.473310e+08
# 11                                       Total assets  2.945036e+10
# 13                               Payable to customers  2.481758e+10
# 14                                  Securities loaned  1.847406e+09
# 15     Securities sold under agreements to repurchase  1.303670e+08
# 17        Brokers, dealers and clearing organizations  2.204250e+08
# 18  Accounts payable, accrued expenses and other l...  3.387900e+07
# 19                                         Affiliates  6.062300e+07
# 20                                           Interest  5.400000e+04
# 21                                   Members' capital  2.340028e+09
# 22             Total liabilities and members' capital  2.945036e+10
#
# Cleaning the 922792-2015-03-02.csv file
# 	We converted to numeric figures for 922792-2015-03-02.csv
#                                                     0             1
# 1                           Cash and cash equivalents  8.037690e+08
# 2   Cash and securities - segregated for regulator...  1.393661e+10
# 3                                 Securities borrowed  3.518400e+09
# 4     Securities purchased under agreements to resell  3.861940e+08
# 5                  Deposit with clearing organization  2.000000e+06
# 7   Customers (net of allowance for doubtful accou...  1.685863e+10
# 8         Brokers, dealers and clearing organizations  5.994470e+08
# 9                                          Affiliates  1.926300e+07
# 10                                           Interest  3.216800e+07
# 11                                       Other assets  3.315100e+07
# 12                                       Total assets  3.618962e+10
# 14                               Payable to customers  3.015406e+10
# 15                                  Securities loaned  2.608882e+09
# 16     Securities sold under agreements to repurchase  1.712240e+08
# 18        Brokers, dealers and clearing organizations  2.790580e+08
# 19  Accounts payable, accrued expenses and other l...  3.367600e+07
# 20                                         Affiliates  5.735900e+07
# 21                                           Interest  1.486000e+06
# 22                                   Members' capital  2.883884e+09
# 23             Total liabilities and members' capital  3.618962e+10
#
# Cleaning the 922792-2016-02-29.csv file
# 	We converted to numeric figures for 922792-2016-02-29.csv
#                                                     0             1
# 0                           Cash and cash equivalents  1.119000e+09
# 1   Cash and securities - segregated for regulator...  1.855500e+10
# 2                                 Securities borrowed  3.013000e+09
# 3     Securities purchased under agreements to resell  1.950000e+08
# 4                  Deposit with clearing organization  4.590000e+08
# 6   Customers (net of allowance for doubtful accou...  1.628900e+10
# 7         Brokers, dealers and clearing organizations  2.460000e+08
# 8                                          Affiliates  2.180000e+08
# 9                                            Interest  5.900000e+07
# 10                                       Other assets  3.500000e+07
# 11                                       Total assets  4.018800e+10
# 13                               Payable to customers  3.374800e+10
# 14                                  Securities loaned  2.828000e+09
# 15     Securities sold under agreements to repurchase  1.950000e+08
# 17        Brokers, dealers and clearing organizations  1.130000e+08
# 18  Accounts payable, accrued expenses and other l...  3.700000e+07
# 19                                         Affiliates  5.300000e+07
# 20                                   Members' capital  3.214000e+09
# 21             Total liabilities and members' capital  4.018800e+10
# Cleaning the 922792-2017-03-01.csv file
# 	We converted to numeric figures for 922792-2017-03-01.csv
#                                                     0             1
# 0                           Cash and cash equivalents  1.444000e+09
# 1   Cash and securities - segregated for regulator...  2.023200e+10
# 2                                 Securities borrowed  2.881000e+09
# 3     Securities purchased under agreements to resell  1.110000e+08
# 5                         Financial instruments owned  4.990000e+08
# 6   Financial instruments owned and pledged as col...  3.230000e+08
# 8   Customers (net of allowance for doubtful accou...  1.808800e+10
# 9         Brokers, dealers and clearing organizations  2.900000e+08
# 10                                         Affiliates  2.360000e+08
# 11                                           Interest  4.900000e+07
# 12                                       Other assets  3.200000e+07
# 13                                       Total assets  4.418500e+10
# 15                               Payable to customers  3.715600e+10
# 16                                  Securities loaned  2.850000e+09
# 17  Financial instruments sold, but not yet purcha...  1.160000e+08
# 18     Securities sold under agreements to repurchase  1.010000e+08
# 20        Brokers, dealers and clearing organizations  1.310000e+08
# 21  Accounts payable, accrued expenses and other l...  4.900000e+07
# 22                                         Affiliates  5.500000e+07
# 23                                           Interest  3.000000e+06
# 24                                   Members' capital  3.724000e+09
# 25             Total liabilities and members' capital  4.418500e+10
#
# Cleaning the 922792-2018-03-01.csv file
# 	We converted to numeric figures for 922792-2018-03-01.csv
#                                                     0             1
# 0                           Cash and cash equivalents  1.160000e+09
# 1   Cash and securities - segregated for regulator...  1.528300e+10
# 2                                 Securities borrowed  3.022000e+09
# 3     Securities purchased under agreements to resell  2.035000e+09
# 5                         Financial instruments owned  4.510000e+08
# 6   Financial instruments owned and pledged as col...  5.900000e+08
# 8   Customers (net of allowance for doubtful accou...  2.828100e+10
# 9         Brokers, dealers and clearing organizations  5.360000e+08
# 10                                         Affiliates  1.230000e+08
# 11                                           Interest  1.010000e+08
# 12                                       Other assets  3.100000e+07
# 13                                       Total assets  5.161300e+10
# 15                              Payables to customers  4.134300e+10
# 16                                  Securities loaned  3.715000e+09
# 17     Securities sold under agreements to repurchase  1.407000e+09
# 18  Financial instruments sold, but not yet purcha...  4.070000e+08
# 20        Brokers, dealers and clearing organizations  2.050000e+08
# 21  Accounts payable, accrued expenses and other l...  6.100000e+07
# 22                                         Affiliates  5.800000e+07
# 23                                           Interest  1.600000e+07
# 24                                   Members' capital  4.401000e+09
# 25             Total liabilities and members' capital  5.161300e+10
#
# Cleaning the 922792-2019-02-28.csv file
# 	We converted to numeric figures for 922792-2019-02-28.csv
#                                                     0             1
# 0                           Cash and cash equivalents  1.783000e+09
# 1           Cash - segregated for regulatory purposes  1.673000e+09
# 2     Securities - segregated for regulatory purposes  1.559500e+10
# 3                                 Securities borrowed  2.731000e+09
# 4     Securities purchased under agreements to resell  1.242000e+09
# 6                         Financial instruments owned  1.389000e+09
# 7   Financial instruments owned and pledged as col...  2.900000e+07
# 8    Total financial instruments owned, at fair value  1.418000e+09
# 10  Customers (net of allowance for doubtful accou...  2.561100e+10
# 11        Brokers, dealers and clearing organizations  5.590000e+08
# 12                                         Affiliates  8.700000e+07
# 13                                           Interest  1.230000e+08
# 14                                  Total receivables  2.638000e+10
# 15                                       Other assets  3.000000e+07
# 16                                       Total assets  5.085200e+10
# 19                              Short-term borrowings  1.700000e+07
# 20                              Payables to customers  4.128300e+10
# 21                                  Securities loaned  3.584000e+09
# 22     Securities sold under agreements to repurchase  3.100000e+07
# 23  Financial instruments sold, but not yet purcha...  3.220000e+08
# 25        Brokers, dealers and clearing organizations  1.910000e+08
# 26  A ccounts payable, accrued expenses and other ...  5.900000e+07
# 27                                        A ffiliates  7.200000e+07
# 28                                           Interest  3.200000e+07
# 29                               Total other payables  3.540000e+08
# 30                                  Total liabilities  4.559100e+10
# 31                                   Members' capital  5.261000e+09
# 32             Total liabilities and members' capital  5.085200e+10
#
# Cleaning the 922792-2019-03-01.csv file
# 	We converted to numeric figures for 922792-2019-03-01.csv
#                                                     0             1
# 0                           Cash and cash equivalents  1.783000e+09
# 1           Cash - segregated for regulatory purposes  1.673000e+09
# 2     Securities - segregated for regulatory purposes  1.559500e+10
# 3                                 Securities borrowed  2.731000e+09
# 4     Securities purchased under agreements to resell  1.242000e+09
# 6                         Financial instruments owned  1.389000e+09
# 7   Financial instruments owned and pledged as col...  2.900000e+07
# 8    Total financial instruments owned, at fair value  1.418000e+09
# 10  Customers (net of allowance for doubtful accou...  2.561100e+10
# 11        Brokers, dealers and clearing organizations  5.590000e+08
# 12                                         Affiliates  8.700000e+07
# 13                                           Interest  1.230000e+08
# 14                                  Total receivables  2.638000e+10
# 15                                       Other assets  3.000000e+07
# 16                                       Total assets  5.085200e+10
# 19                              Short-term borrowings  1.700000e+07
# 20                              Payables to customers  4.128300e+10
# 21                                  Securities loaned  3.584000e+09
# 22     Securities sold under agreements to repurchase  3.100000e+07
# 23  Financial instruments sold, but not yet purcha...  3.220000e+08
# 25        Brokers, dealers and clearing organizations  1.910000e+08
# 26  Accounts payable, accrued expenses and other l...  5.900000e+07
# 27                                         Affiliates  7.200000e+07
# 28                                           Interest  3.200000e+07
# 29                               Total other payables  3.540000e+08
# 30                                  Total liabilities  4.559100e+10
# 31                                   Members' capital  5.261000e+09
# 32             Total liabilities and members' capital  5.085200e+10
#
# Cleaning the 922792-2020-02-28.csv file
# 	We converted to numeric figures for 922792-2020-02-28.csv
#                                                     0             1
# 0                           Cash and cash equivalents  1.710000e+09
# 1           Cash - segregated for regulatory purposes  2.213000e+09
# 2     Securities - segregated for regulatory purposes  1.782400e+10
# 3                                 Securities borrowed  3.412000e+09
# 4     Securities purchased under agreements to resell  3.111000e+09
# 5          Financial instruments owned, at fair value  1.315000e+09
# 7   Customers (net of allowance for doubtful accou...  2.985000e+10
# 8         Brokers, dealers and clearing organizations  5.850000e+08
# 9                                          Affiliates  1.890000e+08
# 10                                           Interest  1.390000e+08
# 11                                  Total receivables  3.076300e+10
# 12                                       Other assets  4.700000e+07
# 13                                       Total assets  6.039500e+10
# 16                              Short-term borrowings  1.600000e+07
# 17                              Payables to customers  4.842800e+10
# 18                                  Securities loaned  3.740000e+09
# 19     Securities sold under agreements to repurchase  1.921000e+09
# 20  Financial instruments sold, but not yet purcha...  2.490000e+08
# 22        Brokers, dealers and clearing organizations  1.000000e+08
# 23  Accounts payable, accrued expenses and other l...  8.200000e+07
# 24                                         Affiliates  7.400000e+07
# 25                                           Interest  2.600000e+07
# 26                               Total other payables  2.820000e+08
# 27                                  Total liabilities  5.463600e+10
# 28                                   Members' capital  5.759000e+09
# 29             Total liabilities and members' capital  6.039500e+10
#
# Cleaning the 922792-2021-02-26.csv file
# 	We converted to numeric figures for 922792-2021-02-26.csv
#                                                     0             1
# 1                           Cash and cash equivalents  2.638000e+09
# 2           Cash - segregated for regulatory purposes  3.330000e+09
# 3     Securities - segregated for regulatory purposes  2.782100e+10
# 4                                 Securities borrowed  4.383000e+09
# 5     Securities purchased under agreements to resell  7.920000e+08
# 6          Financial instruments owned, at fair value  1.000000e+07
# 8   Customers (net of allowance for credit losses ...  3.722300e+10
# 9         Brokers, dealers and clearing organizations  1.044000e+09
# 10                                         Affiliates  1.000000e+07
# 11                                           Interest  9.500000e+07
# 12                                  Total receivables  3.837200e+10
# 13                                       Other assets  5.800000e+07
# 14                                       Total assets  7.740400e+10
# 17                              Short-term borrowings  2.200000e+07
# 18                              Payables to customers  6.269500e+10
# 19                                  Securities loaned  8.739000e+09
# 20     Securities sold under agreements to repurchase  0.000000e+00
# 21  Financial instruments sold, but not yet purcha...  6.000000e+06
# 23        Brokers, dealers and clearing organizations  1.190000e+08
# 24  Accounts payable, accrued expenses and other l...  5.300000e+07
# 25                                         Affiliates  1.150000e+08
# 26                                           Interest  7.000000e+06
# 27                               Total other payables  2.940000e+08
# 28                                  Total liabilities  7.175600e+10
# 29                                   Members' capital  5.648000e+09
# 30             Total liabilities and members' capital  7.740400e+10
#
#
#
# All .csv files are cleaned and primed

# %%
# a = set(map(lambda x: x.split('/')[-1].split('.')[0], pdf_paths))
# b = set(text_dictionary.keys())
# np.array(list(map(lambda x: 'Input/X-17A-5-PDF-SUBSETS/{}-subset.pdf'.format(x), a - b)))

# %%
# # open a single corresponding csv
# s3 = boto3.client('s3')
# session = Session()

# s3.download_file('ran-s3-systemic-risk', 'Output/X-17A-5-PNG-RAW/890203-2015-03-02.csv', 'temp.csv')
# df = pd.read_csv('temp.csv')
# os.remove('temp.csv')

# # retrieving text JSON file from s3 bucket and store to temp 
# s3.download_file('ran-s3-systemic-risk', 'Temp/X17A5-TEXT.json', 'temp2.json')
# with open('temp2.json', 'r') as f: text_dictionary = json.loads(f.read())  
# os.remove('temp2.json')

# prior_scaler = 1.0
# prior_cik = np.nan

# clean_wrapper(df, text_dictionary, '890203-2015-03-02', '890203-2015-03-02.csv', prior_scaler, prior_cik)
