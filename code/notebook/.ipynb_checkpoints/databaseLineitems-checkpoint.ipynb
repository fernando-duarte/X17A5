# %%
import os
import re
import boto3
import json

import pandas as pd
import numpy as np

from sagemaker.session import Session

# %% [markdown]
# # Extract Asset and Liability Line Items
# **We divide asset and liability line items according to a regex parse**

# %%
def bsSplit(array: np.ndarray) -> tuple:
    """
    Function splits an array by bisection, into asset and liability & equity terms. Assumes that line items
    are recorded according to standard accounting practices in orientation. 
    ------------------------------------------------------------------------------------
    :param: (type numpy.ndarray)
        An array of balance sheet line items for a given broker-dealer
        
    :return: (type tuple)
        Return a tuple of arrays; index 1 is the asset items, index 2 is the liability & equity items and
        index 3 is the index where the split occured
        
    NOTE: We make the assumption that liability line items always fall below asset line items and each 
          balance sheet has both asset and liability line items. If either are missing we avoid balance sheet
    """
    stop_idx1 = 0
    stop_idx2 = array.size        # default to length of line items array
    
    asset_idx = 0        # asset and liability identifiers
    liable_idx = 0
    
    # iterate through the line items as provided by the array
    for i, item in enumerate(array):
        # search string for presence of word 'assets' and liabilites
        val1 = re.search('assets', item, flags=re.I)
        val2 = re.search('liability|liabilities', item, flags=re.I)
        
        # if we find the term "asset" we count this index
        if val1 is not None:
            asset_idx = i + 1    
        
        # if we find the term "liability" we count this index
        if val2 is not None:
            liable_idx = i + 1
        
        # in the event we find an asset and liability term, we check to see if the asset index appears before
        # the liability index, this is to prevent the JP Morgan 2012/2013 Textract Error
        if (asset_idx != 0) and (liable_idx != 0):
            
            if asset_idx < liable_idx:
                stop_idx1 = asset_idx
                stop_idx2 = liable_idx
                
    # we should always keep track of the asset term (this is our primary splitter)
    if (asset_idx != 0) and (liable_idx == 0):
        stop_idx1 = asset_idx

    # check the very last, in event our liability term created an early cut-off (e.g. 42352-2003-01-28)
    if (val1 is None) & (val2 is None):
        stop_idx2 = array.size
    
    # partition the array by the enumerated index for asset and liability portions
    lhs = array[:stop_idx1]
    rhs = array[stop_idx1:stop_idx2]
    
    # if either asset or liability side missing, we return None
    if lhs.size == 0 or rhs.size == 0:
        return None
    else:
        return (lhs, rhs, stop_idx1, stop_idx2)

# %%
def lineItems(vector:np.ndarray, df:pd.DataFrame):
    """
    Retrieving balance sheet information line item names for s3 files
    ------------------------------------------------------------------------------------
    :param vector: (type numpy.ndarray)
        An array of file names for .csv files from s3 to iterate through
        
    :return: (type tuple)
        Return a tuple of arrays; left is the asset items, and right is the liability & equity items 
    """
    
    # retrieve the asset and liability & equity terms from the dataframe
    response = bsSplit(vector)
    print(vector)
    
    # if response is present we continue 
    if response is not None:
        lhs, rhs, index1, index2 = response      # decompose response object to retrieve index
        
        print('\tAsset Lineitems')
        print(lhs)
        print('\tLiability & Equity Lineitems')
        print(rhs)
        
        # save contents of asset and liability splits to AWS S3 bucket
        dfA = df.iloc[:index1]                  # asset dataframe
        dfL = df.iloc[index1:index2]            # liability and equity dataframe
        
        return (dfA, dfL)
    else:
        return None

# %% [markdown]
# ## Final Main Execution

# %%
if __name__ == "__main__":
    
    # initiate s3 bucket and corresponding data folder
    bucket = "ran-s3-systemic-risk"
    
    pdf_data_folder ="Output/X-17A-5-CLEAN-PDFS/"
    png_data_folder ="Output/X-17A-5-CLEAN-PNGS/"
    
    pdf_output_folder = 'Output/X-17A-5-SPLIT-PDFS/'
    png_output_folder = 'Output/X-17A-5-SPLIT-PNGS/'
        
    # Amazon Textract client and Sagemaker session
    s3 = boto3.client('s3')
    session = Session()
    
    # discover all of the data that you want to parse (both PDFS and PNGS)
    pdf_paths = np.array(session.list_s3_files(bucket, pdf_data_folder))[1:]
    pdf_asset_split = np.array(session.list_s3_files(bucket, pdf_output_folder + 'Assets/'))
    pdf_liability_split = np.array(session.list_s3_files(bucket, pdf_output_folder + 'Liability & Equity/'))
    
    png_paths = np.array(session.list_s3_files(bucket, png_data_folder))[1:]
    png_asset_split = np.array(session.list_s3_files(bucket, png_output_folder + 'Assets/'))
    png_liability_split = np.array(session.list_s3_files(bucket, png_output_folder + 'Liability & Equity/'))
    
    # --------------------------------------------------------------------------------------------------
    # PDF PROCESSING (LINE-ITEM SPLIT)
    # --------------------------------------------------------------------------------------------------
    
    # iterate through files from s3 bucket 
    for file in pdf_paths:
        print('\n', file)
        fileName = file.split('/')[-1]                                          # file-name for a given path
        asset_name = pdf_output_folder + 'Assets/' + fileName                   # export path to assets
        liability_name = pdf_output_folder + 'Liability & Equity/' + fileName   # export path to liability and equity
        
        # check to see presence of split files 
        if (asset_name not in pdf_asset_split) or (liability_name not in pdf_liability_split) or True:
        
            # download temporary file from s3 bucket
            s3.download_file(bucket, file, 'temp.csv')
            df = pd.read_csv('temp.csv')

            n = df.columns.size   # the number of columns in read dataframe    

            if n > 1: # if there is more than 1 column we continue examination 

                # all line item for balance sheet (first column)
                arr = df[df.columns[0]].dropna().values     

                # extract line items if possible for both asset and liability terms
                response = lineItems(arr, df)

                # if response not None we decompose each
                if response is not None:
                    # unpack the response object to component parts
                    df_asset, df_liability = response

                    # writing data frame to .csv file (we overwrite file name to save space)
                    df_asset.to_csv(fileName, index=False)
                    with open(fileName, 'rb') as data:
                        s3.put_object(Bucket=bucket, Key=asset_name, Body=data)

                    df_liability.to_csv(fileName, index=False)
                    with open(fileName, 'rb') as data:
                        s3.put_object(Bucket=bucket, Key=liability_name, Body=data)

                    # remove local file after it has been created
                    os.remove(fileName)

            else:
                print('{} incomplete dataframe'.format(file))
                
        else:
            print("We've already downloaded {}".format(fileName))
    
    # --------------------------------------------------------------------------------------------------
    # PNG PROCESSING (LINE-ITEM SPLIT)
    # --------------------------------------------------------------------------------------------------
    
    # iterate through files from s3 bucket 
    for file in png_paths:
        print('\n', file)
        fileName = file.split('/')[-1]                                          # file-name for a given path
        asset_name = png_output_folder + 'Assets/' + fileName                   # export path to assets
        liability_name = png_output_folder + 'Liability & Equity/' + fileName   # export path to liability and equity
        
        # check to see presence of split files 
        if (asset_name not in png_asset_split) or (liability_name not in png_liability_split) or True:
        
            # download temporary file from s3 bucket
            s3.download_file(bucket, file, 'temp.csv')
            df = pd.read_csv('temp.csv')

            n = df.columns.size   # the number of columns in read dataframe    

            if n > 1: # if there is more than 1 column we continue examination 

                # all line item for balance sheet (first column)
                arr = df[df.columns[0]].dropna().values     

                # extract line items if possible for both asset and liability terms
                response = lineItems(arr, df)

                # if response not None we decompose each
                if response is not None:
                    # unpack the response object to component parts
                    df_asset, df_liability = response

                    # writing data frame to .csv file (we overwrite file name to save space)
                    df_asset.to_csv(fileName, index=False)
                    with open(fileName, 'rb') as data:
                        s3.put_object(Bucket=bucket, Key=asset_name, Body=data)

                    df_liability.to_csv(fileName, index=False)
                    with open(fileName, 'rb') as data:
                        s3.put_object(Bucket=bucket, Key=liability_name, Body=data)

                    # remove local file after it has been created
                    os.remove(fileName)

            else:
                print('{} incomplete dataframe'.format(file))
                
        else:
            print("We've already downloaded {}".format(fileName))
    
    # remove local file for storing cleaned data  
    os.remove('temp.csv')
    print('\nAll X-17A-5 files have been downloaded and split between Asset and Liability & Equity terms')
# Out:
#  Output/X-17A-5-CLEAN-PDFS/1146184-2004-03-01.csv
# ['Corporate stock (cost $586,245,565)' 'Options (cost $680,481,365)'
#  'Cash and cash equivalents' 'Receivables from brokers and dealers'
#  'Receivables from futures and OTC counterparties' 'Dividends receivable'
#  'Exchange memberships, at cost' 'Other assets' 'Total assets'
#  'Corporate stock (proceeds $1,261,282,922)'
#  'Options (proceeds $565,083,855)' 'Dividends payable'
#  'Payables to affiliates' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Corporate stock (cost $586,245,565)' 'Options (cost $680,481,365)'
#  'Cash and cash equivalents' 'Receivables from brokers and dealers'
#  'Receivables from futures and OTC counterparties' 'Dividends receivable'
#  'Exchange memberships, at cost' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Corporate stock (proceeds $1,261,282,922)'
#  'Options (proceeds $565,083,855)' 'Dividends payable'
#  'Payables to affiliates' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2006-03-01.csv
# ['Cash and cash equivalents' 'Receivables from broker-dealers'
#  'Receivables from futures clearing brokers' 'Corporate stock'
#  'Corporate debt obligations' 'Options' 'Exchanges'
#  'Interest and dividends receivable' 'Securities borrowed'
#  'Exchange memberships, at cost (market value $41,177,600)' 'Other assets'
#  'Total assets' 'Payables to broker-dealers'
#  'Payable to clearing organizations' 'Corporate stock'
#  'Corporate debt obligations' 'Options' 'Interest and dividends payable'
#  'Securities loaned' 'Payable to affiliates' 'Other liabilities'
#  'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Receivables from broker-dealers'
#  'Receivables from futures clearing brokers' 'Corporate stock'
#  'Corporate debt obligations' 'Options' 'Exchanges'
#  'Interest and dividends receivable' 'Securities borrowed'
#  'Exchange memberships, at cost (market value $41,177,600)' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Payables to broker-dealers' 'Payable to clearing organizations'
#  'Corporate stock' 'Corporate debt obligations' 'Options'
#  'Interest and dividends payable' 'Securities loaned'
#  'Payable to affiliates' 'Other liabilities' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2007-02-26.csv
# ['Cash and cash equivalents' 'Securities owned, held at clearing brokers'
#  'Securities purchased under agreement to resell'
#  'Receivables from broker-dealers, clearing organization and futures clearing brokers'
#  'Dividends receivable' 'Receivable from affiliate'
#  'Exchange memberships, at cost (market value $50,765)' 'Other'
#  'Total assets' 'Securities sold, not yet purchased'
#  'Payable to broker-dealers' 'Securities loaned' 'Dividends payable'
#  'Payable to affiliate' 'Other' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Securities owned, held at clearing brokers'
#  'Securities purchased under agreement to resell'
#  'Receivables from broker-dealers, clearing organization and futures clearing brokers'
#  'Dividends receivable' 'Receivable from affiliate'
#  'Exchange memberships, at cost (market value $50,765)' 'Other'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased' 'Payable to broker-dealers'
#  'Securities loaned' 'Dividends payable' 'Payable to affiliate' 'Other'
#  'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2008-02-29.csv
# ['Cash and cash equivalents' 'Securities owned, held at clearing brokers'
#  'Securities purchased under agreement to resell'
#  'Receivables from brokers and dealers, clearing organization and futures clearing brokers'
#  'Dividends receivable' 'Receivable from affiliate'
#  'Exchange memberships, at cost (fair value $69,363)' 'Other assets'
#  'Total assets' 'Securities sold, not yet purchased' 'Dividends payable'
#  'Payable to affiliates' 'Other liabilities' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Securities owned, held at clearing brokers'
#  'Securities purchased under agreement to resell'
#  'Receivables from brokers and dealers, clearing organization and futures clearing brokers'
#  'Dividends receivable' 'Receivable from affiliate'
#  'Exchange memberships, at cost (fair value $69,363)' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased' 'Dividends payable'
#  'Payable to affiliates' 'Other liabilities' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2009-03-02.csv
# ['Cash and cash equivalents' 'Securities owned'
#  'Securities purchased under agreements to resell'
#  'Receivable from brokers, dealers, clearing organizations and futures clearing brokers'
#  'Securities borrowed' 'Collateral held under securities loan agreements'
#  'Dividends receivable' 'Receivable from affiliates'
#  'Exchange memberships and trading rights, at cost (fair value $60,805)'
#  'Other assets' 'Total assets' 'Securities sold, not yet purchased'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers and clearing organizations'
#  'Securities loaned' 'Dividends payable' 'Payable to affiliates'
#  'Other liabilities'
#  'Total liabilities before subordinated borrowings from affiliate'
#  'Subordinated borrowings from affiliate' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Securities owned'
#  'Securities purchased under agreements to resell'
#  'Receivable from brokers, dealers, clearing organizations and futures clearing brokers'
#  'Securities borrowed' 'Collateral held under securities loan agreements'
#  'Dividends receivable' 'Receivable from affiliates'
#  'Exchange memberships and trading rights, at cost (fair value $60,805)'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers and clearing organizations'
#  'Securities loaned' 'Dividends payable' 'Payable to affiliates'
#  'Other liabilities'
#  'Total liabilities before subordinated borrowings from affiliate'
#  'Subordinated borrowings from affiliate' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2010-02-25.csv
# ['Securities borrowed' 'Collateral held under securities loan agreements'
#  'Receivable from affiliates' 'Other assets'
#  'Securities sold, not yet purchased'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers and clearing organizations'
#  'Securities loaned' 'Dividends payable'
#  'Payable to affiliates for clearing activities' 'Payable to affiliates'
#  'Interest payable' 'Other liabilities' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Securities borrowed' 'Collateral held under securities loan agreements'
#  'Receivable from affiliates' 'Other assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers and clearing organizations'
#  'Securities loaned' 'Dividends payable'
#  'Payable to affiliates for clearing activities' 'Payable to affiliates'
#  'Interest payable' 'Other liabilities' 'Total liabilities'
#  "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2011-02-25.csv
# ['Collateral held under securities loan agreements'
#  'Receivable from affiliated customers' 'Receivable from customers'
#  'Receivable for order flow' 'Interest receivable' 'Other assets'
#  'Securities sold, not yet purchased'
#  'Payable to brokers, dealers, clearing organizations, and futures commission merchants'
#  'Securities loaned' 'Payable for order flow'
#  'Payable to affiliated customers' 'Payable to affiliates'
#  'Interest payable' 'Dividends payable' 'Other liabilities'
#  'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Collateral held under securities loan agreements'
#  'Receivable from affiliated customers' 'Receivable from customers'
#  'Receivable for order flow' 'Interest receivable' 'Other assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased'
#  'Payable to brokers, dealers, clearing organizations, and futures commission merchants'
#  'Securities loaned' 'Payable for order flow'
#  'Payable to affiliated customers' 'Payable to affiliates'
#  'Interest payable' 'Dividends payable' 'Other liabilities'
#  'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2012-02-28.csv
# ['Cash' 'Cash segregated under federal regulation' 'Securities owned'
#  'Securities purchased under agreements to resell'
#  'Receivable from brokers, dealers, clearing organizations, and futures commission merchants'
#  'Securities borrowed' 'Collateral held under securities loan agreements'
#  'Receivable from affiliated customers' 'Receivable from affiliates'
#  'Exchange memberships and trading rights (fair value $30,090) (Note 2)'
#  'Receivable for order flow' 'Dividends receivable' 'Other assets'
#  'Total assets' 'Securities sold, not yet purchased'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and futures commission merchants'
#  'Securities loaned' 'Payable for order flow' 'Payable to affiliates'
#  'Interest payable' 'Dividends payable' 'Other liabilities'
#  'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
# 	Asset Lineitems
# ['Cash' 'Cash segregated under federal regulation' 'Securities owned'
#  'Securities purchased under agreements to resell'
#  'Receivable from brokers, dealers, clearing organizations, and futures commission merchants'
#  'Securities borrowed' 'Collateral held under securities loan agreements'
#  'Receivable from affiliated customers' 'Receivable from affiliates'
#  'Exchange memberships and trading rights (fair value $30,090) (Note 2)'
#  'Receivable for order flow' 'Dividends receivable' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and futures commission merchants'
#  'Securities loaned' 'Payable for order flow' 'Payable to affiliates'
#  'Interest payable' 'Dividends payable' 'Other liabilities'
#  'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2015-02-25.csv
# ['Cash' 'Cash segregated under federal regulation' 'Securities borrowed'
#  'Securities owned, at fair value'
#  'Collateral held under securities loan agreements'
#  'Receivable from clearing organizations and custodians'
#  'Receivable from brokers and dealers' 'Receivable for order flow'
#  'Exchange memberships and trading rights (fair value $12,799) (Note 2)'
#  'Other assets' 'Securities purchased under agreements to resell'
#  'Dividends receivable' 'Receivable from affiliated customers'
#  'Total assets' 'Securities loaned'
#  'Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers and dealers' 'Payable to clearing organizations'
#  'Payable for order flow' 'Payable to affiliates'
#  'Exchange, clearance, and regulatory fees payable' 'Interest payable'
#  'Other liabilities' 'Dividends payable' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
# 	Asset Lineitems
# ['Cash' 'Cash segregated under federal regulation' 'Securities borrowed'
#  'Securities owned, at fair value'
#  'Collateral held under securities loan agreements'
#  'Receivable from clearing organizations and custodians'
#  'Receivable from brokers and dealers' 'Receivable for order flow'
#  'Exchange memberships and trading rights (fair value $12,799) (Note 2)'
#  'Other assets' 'Securities purchased under agreements to resell'
#  'Dividends receivable' 'Receivable from affiliated customers'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities loaned' 'Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers and dealers' 'Payable to clearing organizations'
#  'Payable for order flow' 'Payable to affiliates'
#  'Exchange, clearance, and regulatory fees payable' 'Interest payable'
#  'Other liabilities' 'Dividends payable' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2016-02-24.csv
# ['Cash' 'Cash segregated under federal regulation'
#  'Securities owned, at fair value' 'Receivable from brokers and dealers'
#  'Securities borrowed'
#  'Receivable from clearing organizations and custodians'
#  'Receivable for order flow' 'Other assets'
#  'Exchange memberships and trading rights (fair value $13,984) (Note: 2)'
#  'Securities purchased under agreements to resell' 'Dividends receivable'
#  'Total assets' 'Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase' 'Payable for order flow'
#  'Payable to affiliates' 'Securities loaned'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Exchange, clearance, and regulatory fees payable' 'Dividends payable'
#  'Other liabilities' 'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
# 	Asset Lineitems
# ['Cash' 'Cash segregated under federal regulation'
#  'Securities owned, at fair value' 'Receivable from brokers and dealers'
#  'Securities borrowed'
#  'Receivable from clearing organizations and custodians'
#  'Receivable for order flow' 'Other assets'
#  'Exchange memberships and trading rights (fair value $13,984) (Note: 2)'
#  'Securities purchased under agreements to resell' 'Dividends receivable'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase' 'Payable for order flow'
#  'Payable to affiliates' 'Securities loaned'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Exchange, clearance, and regulatory fees payable' 'Dividends payable'
#  'Other liabilities' 'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2017-02-24.csv
# ['Cash' 'Securities owned, at fair value' 'Securities borrowed'
#  'Receivable from clearing organizations and custodians'
#  'Receivable from brokers and dealers' 'Receivable for order flow'
#  'Exchange memberships and trading rights (fair value $29,110) (Note 2)'
#  'Other assets' 'Securities purchased under agreements to resell'
#  'Dividends receivable' 'Total assets'
#  'Securities sold, not yet purchased, at fair value'
#  'Payable to brokers, dealers, clearing organizations, and custodians'
#  'Securities sold under agreements to repurchase' 'Payable for order flow'
#  'Payable to affiliates' 'Other liabilities'
#  'Exchange, clearance, and regulatory fees payable' 'Securities loaned'
#  'Dividends payable' 'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
# 	Asset Lineitems
# ['Cash' 'Securities owned, at fair value' 'Securities borrowed'
#  'Receivable from clearing organizations and custodians'
#  'Receivable from brokers and dealers' 'Receivable for order flow'
#  'Exchange memberships and trading rights (fair value $29,110) (Note 2)'
#  'Other assets' 'Securities purchased under agreements to resell'
#  'Dividends receivable' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased, at fair value'
#  'Payable to brokers, dealers, clearing organizations, and custodians'
#  'Securities sold under agreements to repurchase' 'Payable for order flow'
#  'Payable to affiliates' 'Other liabilities'
#  'Exchange, clearance, and regulatory fees payable' 'Securities loaned'
#  'Dividends payable' 'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2018-02-27.csv
# ['Securities sold, not yet purchased, at fair value'
#  'Payable to brokers, dealers, clearing organizations, and custodians'
#  'Securities sold under agreements to repurchase'
#  'Payable for liquidity and order flow' 'Payable to affiliates'
#  'Securities loaned' 'Exchange, clearance, and regulatory fees payable'
#  'Interest payable' 'Dividends payable' 'Other liabilities'
#  'Total liabilities before subordinated loans and accrued interest'
#  'Subordinated loans and accrued interest' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2019-02-28.csv
# ['Cash' 'Securities owned, at fair value' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Receivable from brokers and dealers'
#  'Receivable from clearing organizations and custodians'
#  'Interest receivable' 'Other assets'
#  'Exchange memberships and trading rights (fair value $21) (Note 2)'
#  'Dividends receivable' 'Total assets'
#  'Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Payable to affiliates' 'Payable for liquidity and order flow'
#  'Exchange, clearance, and regulatory fees payable' 'Interest payable'
#  'Other liabilities' 'Securities loaned' 'Dividends payable'
#  'Total liabilities before subordinated loans and accrued interest'
#  'Subordinated loans and accrued interest' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
# 	Asset Lineitems
# ['Cash' 'Securities owned, at fair value' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Receivable from brokers and dealers'
#  'Receivable from clearing organizations and custodians'
#  'Interest receivable' 'Other assets'
#  'Exchange memberships and trading rights (fair value $21) (Note 2)'
#  'Dividends receivable' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Payable to affiliates' 'Payable for liquidity and order flow'
#  'Exchange, clearance, and regulatory fees payable' 'Interest payable'
#  'Other liabilities' 'Securities loaned' 'Dividends payable'
#  'Total liabilities before subordinated loans and accrued interest'
#  'Subordinated loans and accrued interest' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2020-02-28.csv
# ['Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Loans payable to affiliate' 'Payable to affiliates'
#  'Payable for liquidity and order flow' 'Securities loaned'
#  'Exchange, clearance, and regulatory fees payable' 'Other liabilities'
#  'Total liabilities' "Member's capital"
#  "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1146184-2021-02-25.csv
# ['Other assets' 'Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Loans and interest payable to affiliate' 'Securities loaned'
#  'Other liabilities' 'Payable to affiliates' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
# 	Asset Lineitems
# ['Other assets']
# 	Liability & Equity Lineitems
# ['Securities sold, not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Payable to brokers, dealers, and clearing organizations'
#  'Loans and interest payable to affiliate' 'Securities loaned'
#  'Other liabilities' 'Payable to affiliates' 'Total liabilities'
#  "Member's capital" "Total liabilities and member's capital"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2004-03-01.csv
# ['Cash and cash equivalents' 'Prepaid expenses'
#  'Fixed assets, net of accumulated depreciation and amortization of $2,731'
#  'Other assets' 'Total assets'
#  'Accounts payable and other accrued expenses' 'Deferred rent'
#  'Total liabilities'
#  'Preferred units; par value $10,000 per share - authorized 400 shares; issued and outstanding 142 shares'
#  'Common units; par value $10,000 per share - authorized 100 shares; issued and outstanding 1 share'
#  'Deficit accumulated during development stage' "Total members' equity"
#  "Total liabilities and members' equity"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Prepaid expenses'
#  'Fixed assets, net of accumulated depreciation and amortization of $2,731'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Accounts payable and other accrued expenses' 'Deferred rent'
#  'Total liabilities'
#  'Preferred units; par value $10,000 per share - authorized 400 shares; issued and outstanding 142 shares'
#  'Common units; par value $10,000 per share - authorized 100 shares; issued and outstanding 1 share'
#  'Deficit accumulated during development stage' "Total members' equity"
#  "Total liabilities and members' equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2005-03-01.csv
# ['Cash and cash equivalents'
#  'Securities purchased under agreements to resell'
#  'all are pledged to a clearing organization)'
#  'Deposits with clearing organizations'
#  'Receivable from a clearing organization'
#  'Fixed assets, net of $49,763 accumulated depreciation and amortization'
#  'Prepaid expenses and other assets' 'Total assets'
#  'Securities sold under agreements to repurchase' 'Payable to FICC'
#  'Accrued expenses' 'Total liabilities' "Member's Equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Securities purchased under agreements to resell'
#  'all are pledged to a clearing organization)'
#  'Deposits with clearing organizations'
#  'Receivable from a clearing organization'
#  'Fixed assets, net of $49,763 accumulated depreciation and amortization'
#  'Prepaid expenses and other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Payable to FICC'
#  'Accrued expenses' 'Total liabilities' "Member's Equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2006-03-01.csv
# ['Cash' 'Deposits with clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned, at market value (of which all is pledged to FICC)'
#  'Receivable from clearing organizations' 'Fixed assets, net'
#  'Prepaid expenses and other assets' 'Total assets'
#  'Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's Equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Deposits with clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned, at market value (of which all is pledged to FICC)'
#  'Receivable from clearing organizations' 'Fixed assets, net'
#  'Prepaid expenses and other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's Equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2007-03-01.csv
# ['Cash' 'Deposits with clearing organization'
#  'Receivable from clearing organization'
#  'Securities purchased under agreements to resell'
#  'Receivable from customers and counterparties' 'Fixed assets, net'
#  'Prepaid expenses and other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's Equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Deposits with clearing organization'
#  'Receivable from clearing organization'
#  'Securities purchased under agreements to resell'
#  'Receivable from customers and counterparties' 'Fixed assets, net'
#  'Prepaid expenses and other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's Equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2008-02-29.csv
# ['Cash' 'Receivable and deposits with clearing organization'
#  'Securities purchased under agreements to resell' 'Fixed assets, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's Equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Receivable and deposits with clearing organization'
#  'Securities purchased under agreements to resell' 'Fixed assets, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's Equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2009-03-04.csv
# ['Cash' 'Deposits with clearing organization'
#  'Securities purchased under agreements to resell' 'Fixed assets, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's Equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Deposits with clearing organization'
#  'Securities purchased under agreements to resell' 'Fixed assets, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's Equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2010-02-26.csv
# ['Cash' 'Receivable and deposits with clearing organization'
#  'Financial instruments owned, at market value (cost $153,433,267)'
#  'Securities purchased under agreements to resell' 'Fixed assets, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Receivable and deposits with clearing organization'
#  'Financial instruments owned, at market value (cost $153,433,267)'
#  'Securities purchased under agreements to resell' 'Fixed assets, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2011-03-01.csv
# ['Cash' 'Receivable and deposits with clearing organizations'
#  'Financial instruments owned, at market value (cost $55,563,490)'
#  'Securities purchased under agreements to resell' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Receivable and deposits with clearing organizations'
#  'Financial instruments owned, at market value (cost $55,563,490)'
#  'Securities purchased under agreements to resell' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2012-02-29.csv
# ['Cash' 'Receivable and deposits with clearing organizations'
#  'Financial instruments owned, at market value (cost $10,249,807)'
#  'Securities purchased under agreements to resell' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  'Total liabilities' "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Receivable and deposits with clearing organizations'
#  'Financial instruments owned, at market value (cost $10,249,807)'
#  'Securities purchased under agreements to resell' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's equity" 'Total liabilities'
#  "Total liabilities and member's equity"]
#  Output/X-17A-5-CLEAN-PDFS/1215680-2013-03-01.csv
# ['Cash' 'Receivable and deposits with clearing organizations'
#  'Securities purchased under agreements to resell' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Receivable and deposits with clearing organizations'
#  'Securities purchased under agreements to resell' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2014-02-28.csv
# ['Cash' 'Financial instruments owned, at market value (cost $718,988,257)'
#  'Receivable and deposits with clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Accrued interest receivable' 'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Financial instruments owned, at market value (cost $718,988,257)'
#  'Receivable and deposits with clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Accrued interest receivable' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase' 'Accrued expenses'
#  'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2015-02-27.csv
# ['Cash'
#  'Financial instruments owned, at market value (cost $1,646,535,825)'
#  'Receivable and deposits with clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Accrued interest receivable' 'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Other trading liability'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash'
#  'Financial instruments owned, at market value (cost $1,646,535,825)'
#  'Receivable and deposits with clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Accrued interest receivable' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Other trading liability'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2016-06-16.csv
# ['Cash' 'Financial instruments owned, at fair value (cost $802,638,783)'
#  '(includes $6,554,333,293 at fair value)'
#  'Receivables and deposits with brokers, dealers and clearing organizations'
#  'Accrued interest receivable' 'Other assets' 'Total assets'
#  '(includes $783,419,799 at fair value)'
#  'Payables to brokers, dealers and clearing organization'
#  'Other trading liability' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Financial instruments owned, at fair value (cost $802,638,783)'
#  '(includes $6,554,333,293 at fair value)'
#  'Receivables and deposits with brokers, dealers and clearing organizations'
#  'Accrued interest receivable' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['(includes $783,419,799 at fair value)'
#  'Payables to brokers, dealers and clearing organization'
#  'Other trading liability' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2017-03-07.csv
# ['Cash' 'Financial instruments owned, at fair value (cost $701,258,884)'
#  '(includes $11,756,761,353 at fair value)'
#  'Receivables and deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Total assets' '(includes $348,908,859 at fair value)'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Financial instruments owned, at fair value (cost $701,258,884)'
#  '(includes $11,756,761,353 at fair value)'
#  'Receivables and deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['(includes $348,908,859 at fair value)'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2018-03-01.csv
# ['Cash and cash equivalents'
#  'Financial instruments owned, at fair value (cost $400,464,141)'
#  '(includes $11,517,661,962 at fair value)'
#  'Receivables and deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Total assets' '(includes $998,496,84 at fair value)'
#  'Payable to clearing organization' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Financial instruments owned, at fair value (cost $400,464,141)'
#  '(includes $11,517,661,962 at fair value)'
#  'Receivables and deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['(includes $998,496,84 at fair value)' 'Payable to clearing organization'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2019-03-01.csv
# ['Cash' 'Financial instruments owned, at fair value (cost $239,616,880)'
#  'Securities purchased under agreements to resell (includes $7,390,896,062 at fair value, before netting)'
#  'Deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Other trading liabilities'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Financial instruments owned, at fair value (cost $239,616,880)'
#  'Securities purchased under agreements to resell (includes $7,390,896,062 at fair value, before netting)'
#  'Deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Payable to clearing organization' 'Other trading liabilities'
#  'Accrued expenses' 'Total liabilities' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2020-03-02.csv
# ['Cash' 'Financial instruments owned, at fair value (cost $344,506,566)'
#  'Securities purchased under agreements to resell (includes $4,494,696,636 at fair value)'
#  'Deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Right of use asset' 'Total assets'
#  '(includes $355,728,597 at fair value)'
#  'Payable to clearing organization' 'Other trading liabilities'
#  'Accrued expenses' 'Lease liability' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Financial instruments owned, at fair value (cost $344,506,566)'
#  'Securities purchased under agreements to resell (includes $4,494,696,636 at fair value)'
#  'Deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Accrued interest receivable' 'Other assets'
#  'Right of use asset' 'Total assets']
# 	Liability & Equity Lineitems
# ['(includes $355,728,597 at fair value)'
#  'Payable to clearing organization' 'Other trading liabilities'
#  'Accrued expenses' 'Lease liability' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1215680-2021-03-02.csv
# ['Cash'
#  'Securities purchased under agreements to resell (includes $10,220,238,629 at fair value)'
#  'Deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Right of use asset' 'Other assets' 'Total assets'
#  '(includes $300,155,028 at fair value)'
#  'Payable to clearing organization' 'Other trading liabilities'
#  'Lease liability' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash'
#  'Securities purchased under agreements to resell (includes $10,220,238,629 at fair value)'
#  'Deposits with brokers, dealers and clearing organization'
#  'Other trading assets' 'Right of use asset' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['(includes $300,155,028 at fair value)'
#  'Payable to clearing organization' 'Other trading liabilities'
#  'Lease liability' 'Accrued expenses' 'Total liabilities'
#  "Member's equity" "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1224385-2004-03-01.csv
# ['Cash' 'Cash segregated pursuant to federal regulations'
#  'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($8,769,300 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's contributions"
#  'Accumulated earnings' "Total member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Cash segregated pursuant to federal regulations'
#  'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($8,769,300 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's contributions"
#  'Accumulated earnings' "Total member's equity"
#  "Total liabilities and member's equity"]
#  Output/X-17A-5-CLEAN-PDFS/1224385-2005-03-01.csv
# ['Cash' 'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($14,878,096 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Total member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($14,878,096 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Total member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1224385-2006-03-01.csv
# ['Cash' 'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($10,215,308 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Total member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($10,215,308 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Total member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1224385-2007-03-01.csv
# ['Cash' 'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($10,253,591 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets'
#  'Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations' 'Payable to banks'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's contributions"
#  'Accumulated earnings' "Total member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Securities purchased under agreements to resell'
#  'Securities owned, at market value ($10,253,591 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Receivable from customers' 'Accrued interest receivable'
#  'Property, equipment, and leasehold improvements, net' 'Goodwill, net'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations' 'Payable to banks'
#  'Payable to customers' 'Accrued interest payable' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's contributions"
#  'Accumulated earnings' "Total member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1224385-2008-02-29.csv
# ['Cash'
#  'Securities owned, at market value ($11,000,065 pledged as collateral)'
#  'Securities purchased under agreements to resell'
#  'Receivable from broker-dealers and clearing organizations'
#  'Accrued interest receivable' 'Receivable from customers'
#  'Property, equipment, and leasehold improvements, net' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Accrued interest payable' 'Payable to customers' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's contributions"
#  'Accumulated earnings' "Total member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash'
#  'Securities owned, at market value ($11,000,065 pledged as collateral)'
#  'Securities purchased under agreements to resell'
#  'Receivable from broker-dealers and clearing organizations'
#  'Accrued interest receivable' 'Receivable from customers'
#  'Property, equipment, and leasehold improvements, net' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Accrued interest payable' 'Payable to customers' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's contributions"
#  'Accumulated earnings' "Total member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1224385-2009-03-02.csv
# ['Cash'
#  'Securities owned, at market value ($3,198,593 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Accrued interest receivable' 'Receivable from customers'
#  'Property, equipment, and leasehold improvements, net' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Accrued interest payable' 'Payable to customers' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's equity"
#  "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash'
#  'Securities owned, at market value ($3,198,593 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Securities purchased under agreements to resell'
#  'Accrued interest receivable' 'Receivable from customers'
#  'Property, equipment, and leasehold improvements, net' 'Other assets'
#  'Total assets']
# 	Liability & Equity Lineitems
# ['Securities sold under agreements to repurchase'
#  'Securities sold, not yet purchased, at market value'
#  'Payable to broker-dealers and clearing organizations'
#  'Accrued interest payable' 'Payable to customers' 'Other liabilities'
#  'Total liabilities' 'Subordinated borrowings' "Member's equity"
#  "Total liabilities and member's equity"]
#
#  Output/X-17A-5-CLEAN-PDFS/1224385-2010-03-12.csv
# ['Cash' 'Cash segregated pursuant to federal regulations'
#  'Financial instruments owned, at fair value ($7,693,394 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Securities purchased under agreements to resell' 'Goodwill'
#  'Receivable from customers'
#  'Property, equipment, and leasehold improvements, net' 'Other assets'
#  'Total assets' 'Securities sold under agreements to repurchase'
#  'Financial instruments sold, not yet purchased, at fair value'
#  'Payable to broker-dealers and clearing organizations'
#  'Payable to customers' 'Other liabilities' 'Total liabilities'
#  'Subordinated borrowings' "Member's contributions" 'Accumulated loss'
#  "Total member's equity" "Total liabilities and member's equity"]
# 	Asset Lineitems
# ['Cash' 'Cash segregated pursuant to federal regulations'
#  'Financial instruments owned, at fair value ($7,693,394 pledged as collateral)'
#  'Receivable from broker-dealers and clearing organizations'
#  'Securities purchased under agreements to resell' 'Goodwill'
#  'Receivable from customers'
# ...
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposits with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $3,332,071)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2014-03-04.csv
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposit with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $67,999)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets' 'Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposit with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $67,999)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
#  Output/X-17A-5-CLEAN-PNGS/922792-2015-03-02.csv
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposit with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $6,613)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets' 'Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposit with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $6,613)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2016-02-29.csv
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposit with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $125)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets' 'Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Deposit with clearing organization'
#  'Customers (net of allowance for doubtful accounts of $125)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Payable to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2017-03-01.csv
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Customers (net of allowance for doubtful accounts of $97)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets' 'Payable to customers' 'Securities loaned'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Customers (net of allowance for doubtful accounts of $97)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Payable to customers' 'Securities loaned'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Securities sold under agreements to repurchase'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2018-03-01.csv
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Customers (net of allowance for doubtful accounts of $39)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets' 'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value:'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents'
#  'Cash and securities - segregated for regulatory purposes'
#  'Securities borrowed' 'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Customers (net of allowance for doubtful accounts of $39)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value:'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' "Members' capital" "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2019-02-28.csv
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Total financial instruments owned, at fair value'
#  'Customers (net of allowance for doubtful accounts of $40)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets' 'Short-term borrowings'
#  'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Brokers, dealers and clearing organizations'
#  'A ccounts payable, accrued expenses and other liabilities' 'A ffiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Total financial instruments owned, at fair value'
#  'Customers (net of allowance for doubtful accounts of $40)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Short-term borrowings' 'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Brokers, dealers and clearing organizations'
#  'A ccounts payable, accrued expenses and other liabilities' 'A ffiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2019-03-01.csv
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Total financial instruments owned, at fair value'
#  'Customers (net of allowance for doubtful accounts of $40)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets' 'Short-term borrowings'
#  'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned'
#  'Financial instruments owned and pledged as collateral'
#  'Total financial instruments owned, at fair value'
#  'Customers (net of allowance for doubtful accounts of $40)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Short-term borrowings' 'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2020-02-28.csv
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned, at fair value'
#  'Customers (net of allowance for doubtful accounts of $68)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets' 'Short-term borrowings'
#  'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned, at fair value'
#  'Customers (net of allowance for doubtful accounts of $68)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Short-term borrowings' 'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fair value'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
#  Output/X-17A-5-CLEAN-PNGS/922792-2021-02-26.csv
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned, at fair value'
#  'Customers (net of allowance for credit losses accounts of $12)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets' 'Short-term borrowings'
#  'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fairvalue'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
# 	Asset Lineitems
# ['Cash and cash equivalents' 'Cash - segregated for regulatory purposes'
#  'Securities - segregated for regulatory purposes' 'Securities borrowed'
#  'Securities purchased under agreements to resell'
#  'Financial instruments owned, at fair value'
#  'Customers (net of allowance for credit losses accounts of $12)'
#  'Brokers, dealers and clearing organizations' 'Affiliates' 'Interest'
#  'Total receivables' 'Other assets' 'Total assets']
# 	Liability & Equity Lineitems
# ['Short-term borrowings' 'Payables to customers' 'Securities loaned'
#  'Securities sold under agreements to repurchase'
#  'Financial instruments sold, but not yet purchased, at fairvalue'
#  'Brokers, dealers and clearing organizations'
#  'Accounts payable, accrued expenses and other liabilities' 'Affiliates'
#  'Interest' 'Total other payables' 'Total liabilities' "Members' capital"
#  "Total liabilities and members' capital"]
#
# All X-17A-5 files have been downloaded and split between Asset and Liability & Equity terms

# %%
# # runnning singular analysis on a particular dataset
# # s3.download_file('ran-s3-systemic-risk', 'Output/X-17A-5-CLEAN-PNGS/782124-2014-03-05.csv', 'temp.csv')
# # s3.download_file('ran-s3-systemic-risk', 'Output/X-17A-5-CLEAN-PDFS/42352-2003-01-28.csv', 'temp.csv')
# s3.download_file('ran-s3-systemic-risk', 'Output/X-17A-5-CLEAN-PDFS/782124-2013-03-01.csv', 'temp.csv')

# df = pd.read_csv('temp.csv')
# os.remove('temp.csv')

# # all line item for balance sheet (first column)
# arr = df[df.columns[0]].dropna().values     

# # extract line items if possible for both asset and liability terms
# response = lineItems(arr, df)
