# %%
# Run on first instance to install required libraries
# %pip install smart_open minecart textract-trp
# Out:
# Collecting smart_open
#   Downloading smart_open-5.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.2 MB/s eta 0:00:011
# Collecting minecart
#   Downloading minecart-0.3.0-py3-none-any.whl (23 kB)
# Collecting textract-trp
#   Downloading textract_trp-0.1.3-py3-none-any.whl (5.8 kB)
# Collecting pdfminer3k
#   Downloading pdfminer3k-1.3.4-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 6.0 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from minecart) (1.15.0)
# Requirement already satisfied: ply in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pdfminer3k->minecart) (3.11)
# Installing collected packages: pdfminer3k, textract-trp, smart-open, minecart
# Successfully installed minecart-0.3.0 pdfminer3k-1.3.4 smart-open-5.1.0 textract-trp-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import time 
import re
import os
import trp
import boto3
import minecart
import json
import logging 

import numpy as np
import pandas as pd

from smart_open import open
from sagemaker.session import Session

# %% [markdown]
# # AWS Asynchronous Textract Script (requesting Job)
# **Content modified from Amazon AWS Textract repository (refer to [URL](https://github.com/aws-samples/amazon-textract-code-samples/blob/master/python/12-pdf-text.py) below)**

# %%
def startJob(s3BucketName:str, objectName:str) -> str:
    """
    Starts a Textract job on AWS server 
    """
    # initialize return and client object
    response = None                         
    client = boto3.client('textract')
    
    # issue response to AWS to start Textract job for table analysis 
    response = client.start_document_analysis(
        DocumentLocation={
            'S3Object': {
                'Bucket': s3BucketName,     # location of data to be read from s3 bucket 
                'Name': objectName}},       # file name to be read from Textract  
        FeatureTypes=['FORMS', 'TABLES']    # selecting FORMS (key-values) and TABLES from the OCR
    )
    
    # return response job ID for service
    return response["JobId"]

# %%
def isJobComplete(jobId:str) -> str:
    """
    Tracks the completion status of the Textract job when queued
    """
    # allow for interal sleep timer (efficiency)
    time.sleep(1)                               
    
    client = boto3.client('textract')
    response = client.get_document_analysis(JobId=jobId)
    
    # job-status of the response object 
    status = response["JobStatus"]                        
    print("Job status: {}".format(status))
    
    # if job still running check current status every 5 seconds
    while(status == "IN_PROGRESS"):
        
        # time lag before reporting status
        time.sleep(5)                                         
        response = client.get_document_analysis(JobId=jobId)
        
        # job-status of the response object
        status = response["JobStatus"]                        
        print("Job status: {}".format(status))
    
    return status

# %%
def getJobResults(jobId:str) -> list:
    """
    Returns the contents of the Textract job, after job status is completed
    """
    # initialize list object to track pages read
    pages = []                    

    client = boto3.client('textract')
    response = client.get_document_analysis(JobId=jobId)
    
    # add first page response to list (length of pages will be arbitrary) 
    pages.append(response)      
    print("Resultset page recieved: {}".format(len(pages)))
    
    # if NextToken present we have a pointer to page (e.g. Response -> Page) 
    nextToken = None
    if('NextToken' in response):
        nextToken = response['NextToken']
    
    # iterate through the pages and append to response figure (assuming nextToken not None)
    while(nextToken):
        response = client.get_document_analysis(JobId=jobId, NextToken=nextToken)
        pages.append(response)
        print("Resultset page recieved: {}".format(len(pages)))
        
        # move along linked-list for presence of NextToken response
        nextToken = None
        if('NextToken' in response):
            nextToken = response['NextToken']
    
    # return amalgamation of all page responses 
    return pages

# %%
def runJob(bucket:str, key:str):
    """
    Function designed to call an AWS Textract job (implements helper function above)
    """
    jobId = startJob(bucket, key)   
    print("Started job with id: {}".format(jobId))

    # if job is complete on AWS return page responses 
    if(isJobComplete(jobId)):
        response = getJobResults(jobId)
        
    return response

# %% [markdown]
# # AWS Extraction Scripts (Key-Value Pairs)
# **The content was modified from AWS to extract key-value pairs in form documents from Block objects that are stored in a map. (refer to [URL](https://docs.aws.amazon.com/textract/latest/dg/examples-extract-kvp.html))**

# %%
def find_value_block(key_block, value_map):
    """
    Retrieving value block from AWS textract job, this contains the value text 
    """
    # iterate through the key blocks in the FORM relationships (should have a VALUE and CHILD type, n=2)
    for relationship in key_block['Relationships']:
        
        # if our key block object type is a VALUE we examine the relationship ID
        # NOTE WE SHOULD HAVE ONLY ONE ID FOR THE VALUE RELATIONSHIP TYPE
        if relationship['Type'] == 'VALUE':
            
            # singular ID item stored in list object (return value block object)
            for value_id in relationship['Ids']:
                value_block = value_map[value_id]
            
    # return all corresponding value series
    return value_block

# %%
def get_kv_relationship(key_map, value_map, block_map):
    """
    Retrieving the Key-Value relationship from FORM OCR Textract 
    """
    # initialize key-map dictionary for lineitems and corresponding accounting values
    key_value_map = {}
    
    # unpack the key_map to retrieve the block id and key names
    for block_id, key_block in key_map.items():

        # retrieve value block provided the key_block from each block id
        value_block = find_value_block(key_block, value_map)

        # get text value from key and value blocks
        key = get_text(key_block, block_map)
        val = get_text(value_block, block_map)
        
        # map the key and value pairs (e.g. {'Total Assets':'$ 189,232'})
        key_value_map[key] = val
        
    return key_value_map

# %%
def get_text(result, blocks_map):
    """
    Retrieving text values from given block object
    """
    # initialize container for text
    text = ''
    
    # if relationships header exists we can extract CHILD header
    if 'Relationships' in result:
        
        # relationship maps to a list (iterate through to reveal a dictionary)
        # e.g. 'Relationships' : [{'Type' : 'CHILD', 'Ids': ['e2b3b12f-ebb7-4f6e-914f-97b315672530']}]
        for relationship in result['Relationships']:
            
            # if relationship type is CHILD we explore job-id (indicates good fit)
            if relationship['Type'] == 'CHILD':
                
                # iterate through Ids list
                for child_id in relationship['Ids']:
                    
                    # select corresponding CHILD_ID from block map, this is sub-dictionary
                    word = blocks_map[child_id]
                    
                    # if block type is a word then we append with a space
                    if word['BlockType'] == 'WORD':
                        text += word['Text'] + ' '
                        
                    # if block type is a selection element (e.g. an option button/mark)
                    # note we treat these cases with an X to denote an optional field 
                    if word['BlockType'] == 'SELECTION_ELEMENT':
                        if word['SelectionStatus'] == 'SELECTED':
                            text += 'X '    
    
    # return string corresponding with word 
    return text

# %% [markdown]
# # OCR Wrapper Functions
# **The scripts perform an OCR job from AWS Textract, and returning well formated data**

# %%
def trp2df(table:trp.Table) -> pd.DataFrame:
    """
    Function designed to convert a trp table into a dataframe Complexity -> O(n^2) approx.
    ------------------------------------------------------------------------------------------
    Input
        :param table: (type trp.Table)
            A trp table object parsed from a pdf using AWS Textract  
    
    Output
        :return: type pandas.DataFrame
            A DataFrame object that is constructed by deconstructed a Textract trp table
    """
    N = len(table.rows)               # number of rows in table
    M = len(table.rows[0].cells)      # number of columns in table
    arr = [0]*N                       # initialize matrix container
    
    # iterate through each row within the provided table
    for row in np.arange(N):
        
        # strip the text from the cell references to construct (N X M) matrix
        arr[row] = [table.rows[row].cells[col].text.strip() for col in np.arange(M)]    # move column-wise to get text
        
    return pd.DataFrame(arr)

# %%
def readTable(response:list) -> tuple:
    """
    Function to transform AWS Textract object to a dataframe, by searching for tables
     ------------------------------------------------------------------------------------------
    Input
        :param response: (type list)
            An AWS Textract response object corresponding to pages of a given document page 
    
    Output
        :return: type tuple
            A (3x1) tuple is returned, storing the concated dataframe at the first index, and the accompanying 
            trp page objects for where the balance sheet was determined to reside at the second index
    """
    
    catDF = []          # in the event multiple tables detected on one page (concat them)
    page_series = []    # keep track of page objects where balance sheet was flagged
    page_nums = []
    page_count = 0
    
    # format the Textract response type 
    doc = trp.Document(response)
    
    # iterate through document pages
    for page in doc.pages:
        
        # itterate through page tables
        for table in page.tables: 
            
            # convert trp-table into dataframe object
            df = trp2df(table)
            
            # remove columns that are completely empty
            empty_cols = [col for col in df.columns if (df[col] == '').all()]
            df = df.drop(empty_cols, axis=1)
  
            # number of columns in dataframe
            n = df.columns.size
            
            # reset the column names (avoid the column names)
            df.columns = np.arange(n)
            
            ##############################################################
            #                           NOTES
            #          a good dataframe should have 2-3 columns
            #      anything more or less is a reading error we ignore
            ##############################################################
            
            # if the dataframe has more than 3 columns then we most likley have an issue in parsing
            if n > 3:
                pass
            
            elif n > 1:
                
                ##############################
                # Balance Sheet Assummptions
                ##############################
                
                # this is the column with all line items (e.g. Cash, Total Assets, Total Liabilites)
                lineIndex = df.columns[0]

                # check for the word "cash" in a string at the begining, ignoring case sensitivity (asset check)
                assetCheck = df[lineIndex].str.contains('^Cash', regex=True, flags=re.IGNORECASE)

                # check for the word "Liabilities" in a string at the end, ignoring case sensitivity (liability check)
                debtCheck1 = df[lineIndex].str.contains('Liabilities$|^Liabilities', regex=True, flags=re.IGNORECASE)
                debtCheck2 = df[lineIndex].str.contains('Liability$|^Liability', regex=True, flags=re.IGNORECASE)
                
                # check for the presence of $ sign, we assume the balance sheet items should have at least one $ sign
                # this check is used to avoid reading the table of contents, which was flagged in prior reads
                dollarCheck = df[df.columns[1]].str.contains('\$[^\]]+', regex=True, flags=re.IGNORECASE)
                
                ##############################
                # Balance Sheet Determination
                ##############################
                
                # check if the key words have been found 
                check1 = df[assetCheck | debtCheck1 | debtCheck2].empty      # check for line item terms
                check2 = df[dollarCheck == True].empty                       # check for presence of '$' sign  
                check3 = df[debtCheck1 == True].empty                        # debt check for Liabilities
                check4 = df[debtCheck2 == True].empty                        # debt check for Liability 
                
                # if either asset term or liability term is found, with a $ sign we append the dataframe
                if not check1 and not check2:
                    
                    # we append pages since asset and liablility tables are often seperate
                    # there is no loss of generality if asset and liability terms are in one table
                    catDF.append(df)                
                    
                    # we want to keep track of pages that have been deemed as balance sheet
                    if page not in page_series:
                        page_series.append(page)   # only append if page isn't already recorded
                        page_nums.append(page_count)
                        
                    if not check3 or not check4:
                        # if liability table was found on the first iteration we simply concat data frames 
                        return (pd.concat(catDF), page_series, page_nums)
                    
        page_count += 1

# %%
def readPNG(pages:list, png_path:str, bucket='ran-s3-systemic-risk') -> tuple:
    """
    Function to transform AWS Textract object to a dataframe, by searching for tables
     ------------------------------------------------------------------------------------------
    Input
        :param response: (type list)
            
    
    Output
        :return: type tuple
          
    """
    subfolder = png_path.split('/')[-2]      # subfolder where PNG files are stored
    
    # construct PNG directories with relevant pages
    textract_paths = [png_path + subfolder + '-p{}.png'.format(idx) for idx in pages]
    
    catDF = []          # in the event multiple pages we concat them
    
    # path iterates through each png image matching the page numbers found in PDFs
    for path in textract_paths:
        
        try:
            # temporary data frame object for balance sheet information
            res = runJob(bucket, path)
            
            # if Textract job did not fail we continue extraction
            if res[0]['JobStatus'] != 'FAILED':

                # format the Textract response type 
                doc = trp.Document(res)

                # iterate through document pages
                for page in doc.pages:
                    
                    # itterate through page tables
                    for table in page.tables: 

                        # convert trp-table into dataframe object
                        df = trp2df(table)
                        
                        # remove columns that are completely empty
                        empty_cols = [col for col in df.columns if (df[col] == '').all()]
                        df = df.drop(empty_cols, axis=1)

                        # number of columns in dataframe
                        n = df.columns.size

                        # reset the column names (avoid the column names)
                        df.columns = np.arange(n)
                        
                        ##############################################################
                        #                           NOTES
                        #          a good dataframe should have 2-3 columns
                        #      anything more or less is a reading error we ignore
                        ##############################################################

                        # if the dataframe has more than 3 columns then we most likley have an issue in parsing
                        if n > 3:
                            pass 

                        elif n > 1:

                            ##############################
                            # Balance Sheet Assummptions
                            ##############################

                            # this is the column with all line items (e.g. Cash, Total Assets, Total Liabilites)
                            lineIndex = df.columns[0]

                            # check for the word "cash" in a string at the begining, ignoring case sensitivity 
                            assetCheck = df[lineIndex].str.contains('^Cash', regex=True, flags=re.IGNORECASE)

                            # check for the word "Liabilities" in a string at the end, ignoring case sensitivity 
                            debtCheck1 = df[lineIndex].str.contains('Liabilities$|^Liabilities', 
                                                                    regex=True, flags=re.IGNORECASE)
                            debtCheck2 = df[lineIndex].str.contains('Liability$|^Liability', 
                                                                    regex=True, flags=re.IGNORECASE)

                            # check for the presence of $ sign, we assume the balance sheet items should have 
                            # this check is used to avoid reading the table of contents, which was flagged in prior reads
                            dollarCheck = df[df.columns[1]].str.contains('\$[^\]]+', regex=True, flags=re.IGNORECASE)

                            ##############################
                            # Balance Sheet Determination
                            ##############################

                            # check if the key words have been found 
                            check1 = df[assetCheck | debtCheck1 | debtCheck2].empty      # check for line item terms
                            check2 = df[dollarCheck == True].empty                       # check for presence of '$' sign  
                            check3 = df[debtCheck1 == True].empty                        # debt check for Liabilities
                            check4 = df[debtCheck2 == True].empty                        # debt check for Liability 

                            # if either asset term or liability term is found, with a $ sign we append the dataframe
                            if not check1 and not check2:

                                # we append pages since asset and liablility tables are often seperate
                                # there is no loss of generality if asset and liability terms are in one table
                                catDF.append(df)                

                                if not check3 or not check4:
                                    # if liability table was found on the first iteration we simply concat data frames 
                                    return pd.concat(catDF)
        
        # broad exeption to catch Textract parsing errors
        except:
            pass
    
    # default return None
    return None

# %%
def readForm(doc_pages:list) -> dict:
    """
    Function to transform AWS Textract object to a dictionary, by searching for key value pairs
    ------------------------------------------------------------------------------------------
    Input
        :param doc_pages: (type list)
            TRP page(s) for a AWS Textract response object corresponding to pages of a given document page 
    
    Output
        :return: type dict
            A python dictionary that maps KEYS (line items) with VALUES (corresponding records) for broker
            dealers balance sheet (e.g. {'Cash and cash equivalents : $ 12,513})
    """
    
    # initializing dictionary maps for KEY and VALUE pairs
    key_map = {}
    value_map = {}
    block_map = {}

    # iterate through document pages
    for page in doc_pages:

        # itterate through page tables
        for block in page.blocks: 

            # store the block id in map to retrive information later
            block_id = block['Id']
            block_map[block_id] = block

            # if Key-value set has been seen we deconstruct each KEY and VALUE map
            if block['BlockType'] == "KEY_VALUE_SET":

                # if KEY is labeled as entity type then we found Key, else we found VALUE
                if 'KEY' in block['EntityTypes']:
                    key_map[block_id] = block
                else:
                    value_map[block_id] = block
    
    # convert block objects to text dictionary map
    return get_kv_relationship(key_map, value_map, block_map)

# %%
def readText(doc_pages:list) -> dict:
    """
    Function to transform AWS Textract object to a dictionary of text values and confidence 
    ------------------------------------------------------------------------------------------
    Input
        :param doc_pages: (type list)
            TRP page(s) for a AWS Textract response object corresponding to pages of a given document page
    
    Output
        :return: type dict
            A python dictionary that maps TEXT (line items) with corresponding confidence figures as reported
            by AWS Textract object (e.g. {'Cash and cash equivalents : 99.97891})
    """
    # initializing dictionary maps for text
    text_map = {}
    
    # iterate through document pages
    for page in doc_pages:
        
        # itterate through page tables
        for block in page.blocks: 
            
            # if our block type is a line, we map the line text and confidence
            if block['BlockType'] == "LINE":
                text_map[block['Text']] = block['Confidence']
    
    # return completed text to confidence map
    return text_map

# %% [markdown]
# ## Extract Balance Sheet information

# %%
def textractParse(pdf_path:str, png_path:str, bucket:str) -> dict:
    """
    Function runs a Textract job and saves Balance Sheet information to .csv file in s3 folder 
    """
    errors = ''
    
    # temporary data frame object for balance sheet information
    res = runJob(bucket, pdf_path)
    
    # if Textract job did not fail we continue extraction
    if res[0]['JobStatus'] != 'FAILED':

        # perform OCR and return balance sheet with corresponding page object(s)
        tb_response = readTable(res)           
        
        # checks for type of return, if none then we log an error
        if type(tb_response) == tuple:
            
            # deconstruct the table response tuple into dataframe and page object parts
            df1, page_obj, page_num = tb_response
            print('\nPage number(s) for extraction in PNG are {}\n'.format(page_num))
            
            # try to extract from a PNG (we can still return a None here)
            df2 = readPNG(page_num, png_path)
            
            # provided balance sheet page number we select FORM and TEXT data
            forms_data = readForm(page_obj)      
            text_data = readText(page_obj)        
            
            print('\nTextract-PDF dataframe')
            print(df1)
            
            print('\nTextract-PNG dataframe')
            print(df2)
            
            return (df1, df2, forms_data, text_data, None)
        else:
            error = 'No Balance Sheet found, or parsing error'
            return (None, None, None, None, error)
    else:
        error = 'Could not parse, JOB FAILED'
        return (None, None, None, None, error)

# %% [markdown]
# ## Main File Execution

# %%
if __name__ == "__main__":

    # Amazon Textract client and Sagemaker session
    textract = boto3.client('textract')
    s3 = boto3.client('s3')
    session = Session()
    
    # initiate s3 bucket and corresponding data/output folder
    bucket = 'ran-s3-systemic-risk'
    
    data_png_folder = 'Input/X-17A-5-PNG-SUBSETS/'
    data_pdf_folder = 'Input/X-17A-5-PDF-SUBSETS/'
    
    output_png_folder = 'Output/X-17A-5-PNG-RAW/'
    output_pdf_folder = 'Output/X-17A-5-PDF-RAW/'
    
    temp_folder = 'Temp/'
    
    # csv directory where we store balance sheet information 
    output_png_csvs = np.array(session.list_s3_files(bucket, output_png_folder))
    output_pdf_csvs = np.array(session.list_s3_files(bucket, output_pdf_folder))
    
    # temp directory where JSON files is stored
    temp = np.array(session.list_s3_files(bucket, temp_folder))
    
    # pdf directory where we store the broker-dealer information 
    pdf_files = np.array(session.list_s3_files(bucket, data_pdf_folder))[1:]
    png_files = np.array(session.list_s3_files(bucket, data_png_folder))[1:]
    png_file_directory = list(set((map(lambda x: '/'.join(x.split('/')[:-1]), png_files))))
    
    # ===========================================================================
    # Load in Temp JSON files if present (FORM, TEXT, ERROR)
    # ===========================================================================
    
    if 'Temp/X17A5-FORMS.json' in temp:
        # retrieving downloaded files from s3 bucket
        s3.download_file(bucket, 'Temp/X17A5-FORMS.json', 'temp1.json')
        
        # read data on KEY-VALUE dictionary (i.e Textract FORMS) 
        with open('temp1.json', 'r') as f: forms_dictionary = json.loads(f.read())
        
        # remove local files for JSON
        os.remove('temp1.json')
    else:
        forms_dictionary = {}
    
    if 'Temp/X17A5-TEXT.json' in temp:
        # retrieving downloaded files from s3 bucket
        s3.download_file(bucket, 'Temp/X17A5-TEXT.json', 'temp2.json')
        
        # read data on TEXT-Confidence dictionary
        with open('temp2.json', 'r') as f: text_dictionary = json.loads(f.read())  
            
        # remove local files for JSON
        os.remove('temp2.json')
    else:
        text_dictionary = {}
    
    if 'Temp/ERROR-TEXTRACT.json' in temp:
        # retrieving downloaded files from s3 bucket
        s3.download_file(bucket, 'Temp/ERROR-TEXTRACT.json', 'temp3.json')
        
        # read data on errors derived from Textract
        with open('temp3.json', 'r') as f: error_dictionary = json.loads(f.read()) 
            
        # remove local files for JSON
        os.remove('temp3.json')
    else:
        error_dictionary = {}
    
    # ===========================================================================
    # Perform Textract analysis on PDFs and PNGs
    # ===========================================================================
    
    # e.g. ['Input/X-17A-5-PDF-SUBSETS/42352-2012-02-29-subset.pdf'] otherwise pdf_files (full sample)
    select_sample = ['Input/X-17A-5-PDF-SUBSETS/1146184-2010-02-25-subset.pdf']

    for pdf_paths in pdf_files:
        
        # baseFile name to name export .csv file e.g. 1224385-2004-03-01.csv
        basefile = pdf_paths.split('/')[-1].split('-subset')[0]
        fileName = basefile + '.csv'
        print('\nPerforming OCR for {}'.format(fileName))
        
        # if file is not found in directory we extract the balance sheet
        # WE LOOK TO AVOID RE-RUNNING OLD TEXTRACT PARSES TO SAVE TIME
        if (output_pdf_folder + fileName not in output_pdf_csvs):
            
            # run Textract OCR job and extract the parsed data 
            png_paths = data_png_folder + basefile + '/'
            df1, df2, forms_data, text_data, error = textractParse(pdf_paths, png_paths, bucket)

            # if no error is reported we save FORMS, TEXT, DataFrame
            if error is None:

                # store accompanying information for JSONs
                forms_dictionary[basefile] = forms_data
                text_dictionary[basefile]  = text_data
                print(text_data)
                
                # writing data frame to .csv file
                df1.to_csv(fileName, index=False)

                # save contents to AWS S3 bucket
                with open(fileName, 'rb') as data:
                    s3.put_object(Bucket=bucket, Key=output_pdf_folder + fileName, Body=data)
                
                # writing data frame to .csv file extracted from PNG
                if df2 is not None:
                    df2.to_csv(fileName, index=False)
                    
                    with open(fileName, 'rb') as data:
                        s3.put_object(Bucket=bucket, Key=output_png_folder + fileName, Body=data)
    
                # remove local file after it has been created
                os.remove(fileName)

                print('-----------------------------------------------------')
                print('Saved {} file to s3 bucket'.format(fileName))
            
            else:
                error_dictionary[basefile] = error
                
        else:
            print('{} has been downloaded'.format(fileName))
    
    # ===========================================================================
    # Save JSON files for updated figures (FORM, TEXT, ERROR)
    # ===========================================================================
    
    # write to a JSON file for FORMS 
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-FORMS.json', 'w') as file: 
        json.dump(forms_dictionary, file)
        file.close()
    
    # save contents to AWS S3 bucket
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-FORMS.json', 'rb') as data: 
        s3.upload_fileobj(data, bucket, 'Temp/X17A5-FORMS.json')
    
    # ---------------------------------------------------------------------------
    
    # write to a JSON file for TEXT 
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-TEXT.json', 'w') as file: 
        json.dump(text_dictionary, file)
        file.close()
    
    # save contents to AWS S3 bucket
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-TEXT.json', 'rb') as data: 
        s3.upload_fileobj(data, bucket, 'Temp/X17A5-TEXT.json')
    
    # ---------------------------------------------------------------------------
    
    # write to a JSON file for FORMS 
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/ERROR-TEXTRACT.json', 'w') as file: 
        json.dump(error_dictionary, file)
        file.close()
    
    # save contents to AWS S3 bucket
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/ERROR-TEXTRACT.json', 'rb') as data: 
        s3.upload_fileobj(data, bucket, 'Temp/ERROR-TEXTRACT.json')
# Out:
# Performing OCR for 1101180-2002-02-28.csv
# 1101180-2002-02-28.csv has been downloaded
#
# Performing OCR for 1101180-2003-02-28.csv
# 1101180-2003-02-28.csv has been downloaded
#
# Performing OCR for 1101180-2004-02-25.csv
# 1101180-2004-02-25.csv has been downloaded
#
# Performing OCR for 1101180-2005-03-02.csv
# 1101180-2005-03-02.csv has been downloaded
#
# Performing OCR for 1101180-2006-03-01.csv
# 1101180-2006-03-01.csv has been downloaded
#
# Performing OCR for 1101180-2007-03-02.csv
# Started job with id: 992e88f537bdde1ae96520051366bc994dc2e3e1a54605cdedece103b7013f3c
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Performing OCR for 1101180-2008-02-29.csv
# 1101180-2008-02-29.csv has been downloaded
#
# Performing OCR for 1101180-2009-05-12.csv
# 1101180-2009-05-12.csv has been downloaded
#
# Performing OCR for 1101180-2009-07-20.csv
# 1101180-2009-07-20.csv has been downloaded
#
# Performing OCR for 1101180-2010-03-02.csv
# 1101180-2010-03-02.csv has been downloaded
#
# Performing OCR for 1101180-2011-03-22.csv
# Started job with id: a567388dd20d31b51bc29c5ce6c1b25b22e4bb7dd579d9d7d6ee4da9d587a707
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Page number(s) for extraction in PNG are [4]
#
# Started job with id: 287aa37ea12e18c35f4026a15c73c19538f00e02a6f6b7c7e96814f715a9fb1e
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                   0          1
# 0                         Cash and cash equivalents  $ 292,959
# 1   Securities purchased under agreements to resell     61,945
# 2              Deposits with clearing organizations     28,815
# 3                                      Other assets        579
# 4                                      Total assets  $ 384,298
# 5                  Liabilities and Member's Capital
# 6                                       Liabilities
# 7            Accrued expenses and other liabilities    $ 1,576
# 8                                 Total liabilities      1,576
# 9                                  Member's Capital
# 10                                 Member's Capital    375,150
# 11                                Retained earnings      7,572
# 12                           Total member's capital    382,722
# 13           Total liabilities and member's capital  $ 384,298
#
# Textract-PNG dataframe
#                                                   0          1
# 0                         Cash and cash equivalents  $ 292,959
# 1   Securities purchased under agreements to resell     61,945
# 2              Deposits with clearing organizations     28,815
# 3                                      Other assets        579
# 4                                      Total assets  $ 384,298
# 5                  Liabilities and Member's Capital
# 6                                       Liabilities
# 7            Accrued expenses and other liabilities    $ 1,576
# 8                                 Total liabilities      1,576
# 9                                  Member's Capital
# 10                                 Member's Capital    375,150
# 11                                Retained earnings      7,572
# 12                           Total member's capital    382,722
# 13           Total liabilities and member's capital  $ 384,298
# {'Fortis Securities LLC': 99.90083312988281, '(An indirectly wholly owned subsidiary of BNP PARIBAS)': 99.63843536376953, 'Statement of Financial Condition': 99.90623474121094, 'As of December 31, 2010': 99.94666290283203, '(in thousands)': 99.95812225341797, 'Assets': 99.97830963134766, 'Cash and cash equivalents': 99.96875762939453, '$': 99.83275604248047, '292,959': 99.93819427490234, 'Securities purchased under agreements to resell': 99.98494720458984, '61,945': 99.90375518798828, 'Deposits with clearing organizations': 99.98123931884766, '28,815': 98.57072448730469, 'Other assets': 99.9804916381836, '579': 99.9573974609375, 'Total assets': 99.97567749023438, '384,298': 99.67919921875, "Liabilities and Member's Capital": 99.94227600097656, 'Liabilities': 99.86359405517578, 'Accrued expenses and other liabilities': 99.97615814208984, '1,576': 99.91443634033203, 'Total liabilities': 99.955810546875, "Member's Capital": 99.9415512084961, '375,150': 99.805419921875, 'Retained earnings': 99.97384643554688, '7,572': 99.90205383300781, "Total member's capital": 99.95640563964844, '382,722': 99.76554107666016, "Total liabilities and member's capital": 99.93333435058594, 'The accompanying notes are an integral part of these financial statements.': 99.84173583984375, '2': 99.78627014160156}
# -----------------------------------------------------
# Saved 1101180-2011-03-22.csv file to s3 bucket
#
# Performing OCR for 1146184-2004-03-01.csv
# 1146184-2004-03-01.csv has been downloaded
#
# Performing OCR for 1146184-2005-03-02.csv
# Started job with id: 0e663baa8641a9badfef1fc3d6e12b05d48612b88a4ce82f24d73f469ae7ecc8
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
#
# Performing OCR for 1146184-2006-03-01.csv
# 1146184-2006-03-01.csv has been downloaded
#
# Performing OCR for 1146184-2007-02-26.csv
# 1146184-2007-02-26.csv has been downloaded
#
# Performing OCR for 1146184-2008-02-29.csv
# 1146184-2008-02-29.csv has been downloaded
#
# Performing OCR for 1146184-2009-03-02.csv
# 1146184-2009-03-02.csv has been downloaded
#
# Performing OCR for 1146184-2010-02-25.csv
# 1146184-2010-02-25.csv has been downloaded
#
# Performing OCR for 1146184-2010-03-09.csv
# Started job with id: 56b99977b6f5b22b3dd727f6c76d19d897ae057085054a0b55765523b924de0a
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
#
# Performing OCR for 1146184-2011-02-25.csv
# 1146184-2011-02-25.csv has been downloaded
#
# Performing OCR for 1146184-2012-02-28.csv
# 1146184-2012-02-28.csv has been downloaded
#
# Performing OCR for 1146184-2013-02-26.csv
# Started job with id: 173472a5a055457cf4dbbbbd19feecfe00f9d1762e36dad14ad2d8eb4f7288b2
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Page number(s) for extraction in PNG are [4]
#
# Started job with id: f227cec25d54b94bc1c554752fb38f06fe63fa3fc37107a9a08aa658be083f95
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0             1
# 0                                                Cash     $ 307,099
# 1            Cash segregated under federal regulation        29,000
# 2                                    Securities owned     4,856,249
# 3                                 Securities borrowed    20,427,089
# 4    Collateral held under securities loan agreements     8,338,402
# 5   Receivable from brokers, dealers, clearing org...       602,796
# 6   Exchange memberships and trading rights (fair ...        29,203
# 7     Securities purchased under agreements to resell        19,698
# 8                Receivable from affiliated customers        12,254
# 9                           Receivable for order flow        10,325
# 10                                       Other assets         9,292
# 11                           Receivable from customer         8,840
# 12                               Dividends receivable         4,288
# 13                         Receivable from affiliates           573
# 14                                       Total assets  $ 34,655,108
# 15                   LIABILITIES AND MEMBER'S CAPITAL
# 16                                       Liabilities:
# 17                 Securities sold, not yet purchased   $ 4,980,047
# 18                                  Securities loaned    22,360,782
# 19     Securities sold under agreements to repurchase     6,242,309
# 20                             Payable for order flow        36,553
# 21  Payable to brokers, dealers, and clearing orga...        32,768
# 22                              Payable to affiliates        17,102
# 23    Exchange, clearance and regulatory fees payable        14,468
# 24                                  Other liabilities         6,522
# 25                                  Dividends payable         1,708
# 26                                   Interest payable         1,614
# 27                    Payable to affiliated customers           170
# 28                                  Total liabilities    33,694,043
#
# Textract-PNG dataframe
#                                                     0            1
# 0                                                Cash    $ 307,099
# 1            Cash segregated under federal regulation       29,000
# 2                                    Securities owned    4,856,249
# 3                                 Securities borrowed   20,427,089
# 4    Collateral held under securities loan agreements    8,338,402
# 5   Receivable from brokers, dealers, clearing org...      602,796
# 6   Exchange memberships and trading rights (fair ...       29,203
# 7     Securities purchased under agreements to resell       19,698
# 8                Receivable from affiliated customers       12,254
# 9                           Receivable for order flow       10,325
# 10                                       Other assets        9,292
# 11
# 12
# 13                         Receivable from affiliates          573
# 14
# 15
# 16                                       Liabilities:
# 17                 Securities sold, not yet purchased  $ 4,980,047
# 18
# 19     Securities sold under agreements to repurchase    6,242,309
# 20                             Payable for order flow       36,553
# 21
# 22                              Payable to affiliates       17,102
# 23
# {'CITADEL SECURITIES LLC': 99.71380615234375, 'STATEMENT OF FINANCIAL CONDITION': 99.82308959960938, 'December 31, 2012': 99.86322021484375, '(Expressed in U.S. dollars in thousands)': 99.92182922363281, 'ASSETS': 99.86835479736328, 'Assets:': 99.74604034423828, 'Cash': 99.96946716308594, '$': 96.5488510131836, '307,099': 99.92047119140625, 'Cash segregated under federal regulation': 99.93785858154297, '29,000': 99.87367248535156, 'Securities owned': 99.9774398803711, '4,856,249': 99.82002258300781, 'Securities borrowed': 99.97492980957031, '20,427,089': 99.89397430419922, 'Collateral held under securities loan agreements': 99.96453094482422, '8,338,402': 99.87393188476562, 'Receivable from brokers, dealers, clearing organizations, custodians and futures': 99.80711364746094, 'commission merchants': 99.90621948242188, '602,796': 99.92202758789062, 'Exchange memberships and trading rights (fair value $22,264) (Note 2)': 99.58221435546875, '29,203': 99.92166900634766, 'Securities purchased under agreements to resell': 99.9369888305664, '19,698': 99.9372329711914, 'Receivable from affiliated customers': 99.96229553222656, '12,254': 99.88966369628906, 'Receivable for order flow': 99.97712707519531, '10,325': 99.7151107788086, 'Other assets': 99.97272491455078, '9,292': 99.8940200805664, 'Receivable from customer': 99.97091674804688, '8,840': 99.87969970703125, 'Dividends receivable': 99.98069763183594, '4,288': 99.77276611328125, 'Receivable from affiliates': 99.953125, '573': 99.95420837402344, 'Total assets': 99.91720581054688, '34,655,108': 99.5406723022461, "LIABILITIES AND MEMBER'S CAPITAL": 99.80074310302734, 'Liabilities:': 98.82612609863281, 'Securities sold, not yet purchased': 99.90282440185547, '4,980,047': 99.88050842285156, 'Securities loaned': 99.97006225585938, '22,360,782': 99.11679077148438, 'Securities sold under agreements to repurchase': 99.96088409423828, '6,242,309': 99.789794921875, 'Payable for order flow': 99.96939086914062, '36,553': 99.85208129882812, 'Payable to brokers, dealers, and clearing organizations': 99.44686889648438, '32,768': 99.8879165649414, 'Payable to affiliates': 99.94758605957031, '17,102': 99.61576080322266, 'Exchange, clearance and regulatory fees payable': 99.95640563964844, '14,468': 99.91633605957031, '-': 83.37643432617188, 'Other liabilities': 99.9527816772461, '6,522': 99.93128204345703, 'Dividends payable': 99.97694396972656, '1,708': 99.89258575439453, 'Interest payable': 99.97360229492188, '1,614': 99.89862823486328, 'Payable to affiliated customers': 99.95783233642578, '170': 99.98455810546875, 'Total liabilities': 99.85253143310547, '33,694,043': 99.65917205810547, "Member's capital": 99.95734405517578, '961,065': 99.86186218261719, "Total liabilities and member's capital": 99.93019104003906, 'See notes to statement of financial condition.': 99.87141418457031, '-2-': 99.72679138183594}
# -----------------------------------------------------
# Saved 1146184-2013-02-26.csv file to s3 bucket
#
# Performing OCR for 1146184-2014-02-28.csv
# Started job with id: 2ed4d3167e8bcd606a766b620191e72718783ac6a482c8a4717c0f0ba76d0903
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Page number(s) for extraction in PNG are [5]
#
# Started job with id: 1e2af55a9cbf259f2fd9b19593b0b98c9bd48297bedb2704b048f0f20c4b4d21
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0           1
# 0                                                Cash   $ 424,221
# 1            Cash segregated under federal regulation      26,000
# 2                                 Securities borrowed  21,382,571
# 3                     Securities owned, at fair value   8,991,529
# 4    Collateral held under securities loan agreements   9,223,910
# 5   Receivable from clearing organizations custodians      75,431
# 6   Receivable from brokers, dealers, and futures ...      39,665
# 7   Exchange memberships and trading rights (fair ...      14,077
# 8     Securities purchased under agreements to resell      13,094
# 9                                Dividends receivable      12,017
# 10                          Receivable for order flow      10,547
# 11                                       Other assets       8,899
# 12               Receivable from affiliated customers       5,433
# 13
# 14
# 15                                       Liabilities:
# 16
# 17  Securities sold, not yet purchased, at fair value   4,749,801
# 18
# 19  Payable to brokers, dealers, and futures commi...   3,814,113
# 20                              Payable to affiliates     105,556
# 21                             Payable for order flow      39,934
# 22   Exchange, clearance, and regulatory fees payable      16,800
#
# Textract-PNG dataframe
#                                                     0             1
# 0                                                Cash     $ 424,221
# 1            Cash segregated under federal regulation        26,000
# 2                                 Securities borrowed    21,382,571
# 3                     Securities owned, at fair value     8,991,529
# 4    Collateral held under securities loan agreements     9,223,910
# 5   Receivable from clearing organizations custodians        75,431
# 6   Receivable from brokers, dealers, and futures ...        39,665
# 7   Exchange memberships and trading rights (fair ...        14,077
# 8     Securities purchased under agreements to resell        13,094
# 9                                Dividends receivable        12,017
# 10                          Receivable for order flow        10,547
# 11                                       Other assets         8,899
# 12               Receivable from affiliated customers         5,433
# 13                                       Total assets  $ 40,227,394
# 14                   LIABILITIES AND MEMBER'S CAPITAL
# 15                                       Liabilities:
# {'CITADEL SECURITIES LLC': 99.76828002929688, 'STATEMENT OF FINANCIAL CONDITION': 99.85688018798828, 'December 31, 2013': 99.90298461914062, '(Expressed in U.S. dollars in thousands)': 99.92591094970703, 'ASSETS': 99.86907196044922, 'Assets:': 99.94612121582031, 'Cash': 99.96440124511719, '$': 99.8272933959961, '424,221': 99.13911437988281, 'Cash segregated under federal regulation': 99.96385955810547, '26,000': 99.80785369873047, 'Securities borrowed': 99.96395111083984, '21,382,571': 99.41455078125, 'Securities owned, at fair value': 99.75308227539062, '8,991,529': 99.82649993896484, 'Collateral held under securities loan agreements': 99.96054077148438, '9,223,910': 99.24410247802734, 'Receivable from clearing organizations custodians': 99.91124725341797, '75,431': 99.87857055664062, 'Receivable from brokers, dealers, and futures commission merchants': 94.66114044189453, '39,665': 99.91802215576172, 'Exchange memberships and trading rights (fair value $14,346) (Note 2)': 99.56257629394531, '14,077': 99.90303802490234, 'Securities purchased under agreements to resell': 99.96693420410156, '13,094': 99.86139678955078, 'Dividends receivable': 99.98042297363281, '12,017': 99.89237213134766, 'Receivable for order flow': 99.96508026123047, '10,547': 99.90375518798828, 'Other assets': 99.94281005859375, '8,899': 99.92252349853516, 'Receivable from affiliated customers': 99.96271514892578, '5,433': 99.80632019042969, 'Total assets': 99.96305847167969, '40,227,394': 99.06999969482422, "LIABILITIES AND MEMBER'S CAPITAL": 99.7922592163086, 'Liabilities:': 98.90552520751953, 'Securities loaned': 99.95610046386719, '23,393,622': 99.73339080810547, 'Securities sold, not yet purchased, at fair value': 99.93282318115234, '4,749,801': 99.7418441772461, 'Securities sold under agreements to repurchase': 99.96331024169922, '7,155,987': 99.83556365966797, 'Payable to brokers, dealers, and futures commission merchants': 99.86415100097656, '3,814,113': 99.79264831542969, 'Payable to affiliates': 99.92079162597656, '105,556': 99.92660522460938, 'Payable for order flow': 99.95817565917969, '39,934': 99.68568420410156, 'Exchange, clearance, and regulatory fees payable': 99.778076171875, '16,800': 99.9056396484375, 'Other liabilities': 99.96363830566406, '4,009': 99.83024597167969, 'Interest payable': 99.94857025146484, '2,260': 99.79358673095703, 'Dividends payable': 99.97211456298828, '1,705': 99.64680480957031, 'Total liabilities': 99.89606475830078, '39,283,787': 99.06466674804688, "Member's capital": 99.95541381835938, '943,607': 98.60015869140625, "Total liabilities and member's capital": 99.92156982421875, 'See notes to statement of financial condition.': 99.88211059570312, '-2-': 99.50543975830078}
# -----------------------------------------------------
# Saved 1146184-2014-02-28.csv file to s3 bucket
#
# Performing OCR for 1146184-2015-02-25.csv
# 1146184-2015-02-25.csv has been downloaded
#
# Performing OCR for 1146184-2016-02-24.csv
# 1146184-2016-02-24.csv has been downloaded
#
# Performing OCR for 1146184-2017-02-24.csv
# 1146184-2017-02-24.csv has been downloaded
#
# Performing OCR for 1146184-2018-02-27.csv
# 1146184-2018-02-27.csv has been downloaded
#
# Performing OCR for 1146184-2019-02-28.csv
# 1146184-2019-02-28.csv has been downloaded
#
# Performing OCR for 1146184-2020-02-28.csv
# 1146184-2020-02-28.csv has been downloaded
#
# Performing OCR for 1146184-2021-02-25.csv
# 1146184-2021-02-25.csv has been downloaded
#
# Performing OCR for 1215680-2004-03-01.csv
# 1215680-2004-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2005-03-01.csv
# 1215680-2005-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2006-03-01.csv
# 1215680-2006-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2007-03-01.csv
# 1215680-2007-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2008-02-29.csv
# 1215680-2008-02-29.csv has been downloaded
#
# Performing OCR for 1215680-2009-03-04.csv
# 1215680-2009-03-04.csv has been downloaded
#
# Performing OCR for 1215680-2010-02-26.csv
# 1215680-2010-02-26.csv has been downloaded
#
# Performing OCR for 1215680-2011-03-01.csv
# 1215680-2011-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2012-02-29.csv
# 1215680-2012-02-29.csv has been downloaded
#
# Performing OCR for 1215680-2013-03-01.csv
# 1215680-2013-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2014-02-28.csv
# 1215680-2014-02-28.csv has been downloaded
#
# Performing OCR for 1215680-2015-02-27.csv
# 1215680-2015-02-27.csv has been downloaded
#
# Performing OCR for 1215680-2016-06-16.csv
# 1215680-2016-06-16.csv has been downloaded
#
# Performing OCR for 1215680-2017-03-07.csv
# 1215680-2017-03-07.csv has been downloaded
#
# Performing OCR for 1215680-2018-03-01.csv
# 1215680-2018-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2019-03-01.csv
# 1215680-2019-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2020-03-02.csv
# 1215680-2020-03-02.csv has been downloaded
#
# Performing OCR for 1215680-2021-03-02.csv
# 1215680-2021-03-02.csv has been downloaded
#
# Performing OCR for 1224385-2004-03-01.csv
# 1224385-2004-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2005-03-01.csv
# 1224385-2005-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2006-03-01.csv
# 1224385-2006-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2007-03-01.csv
# 1224385-2007-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2008-02-29.csv
# 1224385-2008-02-29.csv has been downloaded
#
# Performing OCR for 1224385-2009-03-02.csv
# 1224385-2009-03-02.csv has been downloaded
#
# Performing OCR for 1224385-2010-03-12.csv
# 1224385-2010-03-12.csv has been downloaded
#
# Performing OCR for 1224385-2011-03-01.csv
# 1224385-2011-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2012-02-29.csv
# 1224385-2012-02-29.csv has been downloaded
#
# Performing OCR for 1224385-2013-03-01.csv
# 1224385-2013-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2014-03-04.csv
# 1224385-2014-03-04.csv has been downloaded
#
# Performing OCR for 1224385-2015-03-02.csv
# 1224385-2015-03-02.csv has been downloaded
#
# Performing OCR for 1224385-2016-02-29.csv
# 1224385-2016-02-29.csv has been downloaded
#
# Performing OCR for 1224385-2017-03-01.csv
# 1224385-2017-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2018-02-28.csv
# 1224385-2018-02-28.csv has been downloaded
#
# Performing OCR for 1224385-2019-02-28.csv
# 1224385-2019-02-28.csv has been downloaded
#
# Performing OCR for 1224385-2020-02-28.csv
# 1224385-2020-02-28.csv has been downloaded
#
# Performing OCR for 1224385-2021-02-26.csv
# 1224385-2021-02-26.csv has been downloaded
#
# Performing OCR for 1261467-2005-03-08.csv
# 1261467-2005-03-08.csv has been downloaded
#
# Performing OCR for 1261467-2006-03-01.csv
# 1261467-2006-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2007-03-02.csv
# 1261467-2007-03-02.csv has been downloaded
#
# Performing OCR for 1261467-2008-02-29.csv
# 1261467-2008-02-29.csv has been downloaded
#
# Performing OCR for 1261467-2009-03-02.csv
# 1261467-2009-03-02.csv has been downloaded
#
# Performing OCR for 1261467-2010-03-01.csv
# 1261467-2010-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2011-03-01.csv
# 1261467-2011-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2012-02-29.csv
# 1261467-2012-02-29.csv has been downloaded
#
# Performing OCR for 1261467-2013-03-01.csv
# 1261467-2013-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2014-03-04.csv
# 1261467-2014-03-04.csv has been downloaded
#
# Performing OCR for 1261467-2015-03-02.csv
# 1261467-2015-03-02.csv has been downloaded
#
# Performing OCR for 1261467-2016-03-01.csv
# 1261467-2016-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2017-03-01.csv
# 1261467-2017-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2018-02-28.csv
# 1261467-2018-02-28.csv has been downloaded
#
# Performing OCR for 1261467-2018-04-13.csv
# 1261467-2018-04-13.csv has been downloaded
#
# Performing OCR for 1261467-2019-03-01.csv
# 1261467-2019-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2020-03-02.csv
# Started job with id: e61bce523025d1ce914b32a2df52d0ab40099a646c6b31ec496b58575cc2301b
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Performing OCR for 1261467-2021-03-01.csv
# 1261467-2021-03-01.csv has been downloaded
#
# Performing OCR for 1591458-2015-02-20.csv
# 1591458-2015-02-20.csv has been downloaded
#
# Performing OCR for 1591458-2016-02-18.csv
# Started job with id: b7a194974b0ea9994e3f06873c726846d30a3d743746feda9778f0b1e37709d1
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
#
# Performing OCR for 1591458-2017-01-23.csv
# Started job with id: f0ecb40c51f22e9ae0553692e8ad467917c2c4f1802e459e67c65b93f372144b
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Page number(s) for extraction in PNG are [10, 12]
#
# Started job with id: 428adefb9b9ea53b3169d69af25a29f71a54c9bed165e00edf584359ab16ab2c
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Started job with id: 605896562df52601415ac5c24186182c5c2c91814bcc7339261d9d67f8425c45
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0             1
# 0                                          Net income   $ 1,043,672
# 1   Adjustments to reconcile net income to net cas...
# 2           Change in receivable from clearing broker       120,957
# 3                          Change in securities owned           515
# 4                          Change in prepaid expenses      (40,228)
# 5                                  Change in deposits       (2,579)
# 6                          Change in accounts payable         8,060
# 7                Change in payable to clearing broker         3,227
# 8                           Change in due to affilate        59,485
# 9           NET CASH PROVIDED BY OPERATING ACTIVITIES     1,193,109
# 10  CASH FLOWS FROM FINANCING ACTIVITIES: Members'...    24,000,000
# 11          NET CASH PROVIDED BY FINANCING ACTIVITIES    24,000,000
# 12                               NET INCREASE IN CASH    25,193,109
# 13     CASH AND CASH EQUIVALENTS: Beginning of period       302,397
# 14                                      End of period  $ 25,495,506
# 0                           Cash and cash equivalents  $ 25,495,506
# 1           Securities owned, at estimated fair value       499,210
# 2                                    Prepaid expenses        86,854
# 3                                            Deposits         4,108
# 4                                        Total assets  $ 26,085,678
# 5                     LIABILITIES AND MEMBERS' EQUITY
# 6                                         LIABILITIES
# 7                                    Accounts payable      $ 18,987
# 8                          Payable to clearing broker         3,227
# 9                                    Due to affiliate        86,967
# 10                                  Total liabilities       109,181
# 11                                    Members' equity    25,976,497
# 12              Total liabilities and members' equity  $ 26,085,678
#
# Textract-PNG dataframe
#                                                     0             1
# 0                                           Netincome   $ 1,043,672
# 1   Adjustments to reconcile net income to net cas...
# 2           Change in receivable from clearing broker       120,957
# 3                          Change in securities owned           515
# 4                          Change in prepaid expenses      (40,228)
# 5                                  Change in deposits       (2,579)
# 6                          Change in accounts payable         8,060
# 7                Change in payable to clearing broker         3,227
# 8                           Change in due to affilate        59,485
# 9           NET CASH PROVIDED BY OPERATING ACTIVITIES     1,193,109
# 10  CASH FLOWS FROM FINANCING ACTIVITIES: Members'...    24,000,000
# 11          NET CASH PROVIDED BY FINANCING ACTIVITIES    24,000,000
# 12                               NET INCREASE IN CASH    25,193,109
# 13     CASH AND CASH EQUIVALENTS: Beginning of period       302,397
# 14                                      End of period  $ 25,495,506
# 0                           Cash and cash equivalents  $ 25,495,506
# 1           Securities owned, at estimated fair value       499,210
# 2                                    Prepaid expenses        86,854
# 3                                            Deposits         4,108
# 4                                        Total assets  $ 26,085,678
# 5                     LIABILITIES AND MEMBERS' EQUITY
# 6                                         LIABILITIES
# 7                                    Accounts payable      $ 18,987
# 8                          Payable to clearing broker         3,227
# 9                                    Due to affiliate        86,967
# 10                                  Total liabilities       109,181
# 11                                    Members' equity    25,976,497
# 12              Total liabilities and members' equity  $ 26,085,678
# {'CURVATURE SECURITIES, LLC': 99.3059310913086, 'STATEMENT OF CASH FLOWS': 99.84015655517578, 'FOR THE YEAR ENDED DECEMBER 31, 2016': 99.84480285644531, 'CASH FLOWS FROM OPERATING ACTIVITIES:': 99.69803619384766, 'Net income': 99.86552429199219, '$': 99.82231903076172, '1,043,672': 98.7874755859375, 'Adjustments to reconcile net income to net cash provided by operating activities:': 99.87068939208984, 'Change in receivable from clearing broker': 99.86377716064453, '120,957': 99.73384857177734, 'Change in securities owned': 99.7847671508789, '515': 99.9595947265625, 'Change in prepaid expenses': 99.73184204101562, '(40,228)': 99.14999389648438, 'Change in deposits': 99.72254943847656, '(2,579)': 99.52979278564453, 'Change in accounts payable': 99.7978286743164, '8,060': 99.75679016113281, 'Change in payable to clearing broker': 99.83611297607422, '3,227': 99.47727966308594, 'Change in due to affilate': 99.81194305419922, '59,485': 99.6126480102539, 'NET CASH PROVIDED BY OPERATING ACTIVITIES': 99.75820922851562, '1,193,109': 99.00572204589844, 'CASH FLOWS FROM FINANCING ACTIVITIES:': 99.67143249511719, "Members' contributions": 98.03955841064453, '24,000,000': 98.46857452392578, 'NET CASH PROVIDED BY FINANCING ACTIVITIES': 99.69660949707031, 'NET INCREASE IN CASH': 99.81643676757812, '25,193,109': 98.99971771240234, 'CASH AND CASH EQUIVALENTS:': 98.93177032470703, 'Beginning of period': 99.91172790527344, '302,397': 98.75080108642578, 'End of period': 99.92129516601562, '25,495,506': 99.78582000732422, 'See accompanying notes': 99.91594696044922, '5': 99.73228454589844, 'STATEMENT OF FINANCIAL CONDITION': 99.75958251953125, 'DECEMBER 31, 2016': 99.81642150878906, 'ASSETS': 98.88489532470703, 'Cash and cash equivalents': 99.90889739990234, 'Securities owned, at estimated fair value': 99.88800811767578, '499,210': 99.31674194335938, 'Prepaid expenses': 99.90404510498047, '86,854': 99.74363708496094, 'Deposits': 99.79576110839844, '4,108': 99.5479736328125, 'Total assets': 99.83856201171875, '26,085,678': 98.98380279541016, "LIABILITIES AND MEMBERS' EQUITY": 97.574462890625, 'LIABILITIES': 98.91206359863281, 'Accounts payable': 99.94328308105469, '18,987': 99.71086120605469, 'Payable to clearing broker': 99.92703247070312, 'Due to affiliate': 99.79401397705078, '86,967': 99.6263656616211, 'Total liabilities': 99.86178588867188, '109,181': 99.44873046875, "Members' equity": 97.73271942138672, '25,976,497': 98.52386474609375, "Total liabilities and members' equity": 99.23628234863281, '2': 99.71345520019531}
# -----------------------------------------------------
# Saved 1591458-2017-01-23.csv file to s3 bucket
#
# Performing OCR for 1591458-2018-02-28.csv
# 1591458-2018-02-28.csv has been downloaded
#
# Performing OCR for 1591458-2019-02-28.csv
# 1591458-2019-02-28.csv has been downloaded
#
# Performing OCR for 1591458-2020-02-28.csv
# 1591458-2020-02-28.csv has been downloaded
#
# Performing OCR for 1591458-2021-02-26.csv
# 1591458-2021-02-26.csv has been downloaded
#
# Performing OCR for 1616344-2016-02-24.csv
# 1616344-2016-02-24.csv has been downloaded
#
# Performing OCR for 1616344-2017-02-24.csv
# 1616344-2017-02-24.csv has been downloaded
#
# Performing OCR for 1616344-2018-02-27.csv
# Started job with id: 3a975bada72df0e0c85960bf4a062a55f74e408a1c31a94b9dea0e46db42fd3c
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Page number(s) for extraction in PNG are [10]
#
# Started job with id: 2c43623cbe4f1ce4bd543bd75a008351447b03b2feb6dcef5fba1948caa5fb59
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0             1
# 0                                             Assets:
# 1                                                Cash     $ 473,865
# 2            Cash segregated under federal regulation        28,100
# 3                                 Securities borrowed    25,140,310
# 4    Collateral held under securities loan agreements    13,046,641
# 5   Receivable from brokers, dealers, and clearing...       172,266
# 6                                        Other assets         7,240
# 7                 Receivable from affiliated customer           894
# 8                                        Total assets  $ 38,869,316
# 9                    LIABILITIES AND MEMBER'S CAPITAL
# 10                                       Liabilities:
# 11                                  Securities loaned  $ 30,436,927
# 12     Securities sold under agreements to repurchase     7,907,863
# 13                     Payable to brokers and dealers         1,721
# 14              Clearance and regulatory fees payable         2,714
# 15                    Payable to affiliated customers         5,398
# 16                               Payable to affiliate           605
# 17                                  Other liabilities           412
# 18                                  Total liabilities    38,355,640
# 19                                   Member's capital       513,676
# 20             Total liabilities and member's capital  $ 38,869,316
#
# Textract-PNG dataframe
#                                                     0             1
# 0                                             Assets:
# 1                                                Cash     $ 473,865
# 2            Cash segregated under federal regulation        28,100
# 3                                 Securities borrowed    25,140,310
# 4    Collateral held under securities loan agreements    13,046,641
# 5   Receivable from brokers, dealers, and clearing...       172,266
# 6                                        Other assets         7,240
# 7                 Receivable from affiliated customer           894
# 8                                        Total assets  $ 38,869,316
# 9                    LIABILITIES AND MEMBER'S CAPITAL
# 10                                       Liabilities:
# 11                                  Securities loaned  $ 30,436,927
# 12     Securities sold under agreements to repurchase     7,907,863
# 13                     Payable to brokers and dealers         1,721
# 14              Clearance and regulatory fees payable         2,714
# 15                    Payable to affiliated customers         5,398
# 16                               Payable to affiliate           605
# 17                                  Other liabilities           412
# 18                                  Total liabilities    38,355,640
# 19                                   Member's capital       513,676
# 20             Total liabilities and member's capital  $ 38,869,316
# {'CITADEL CLEARING LLC': 99.71263122558594, 'STATEMENT OF FINANCIAL CONDITION': 99.7457046508789, 'December 31, 2017': 99.90064239501953, '(Expressed in U.S. dollars in thousands)': 99.9193344116211, 'ASSETS': 99.6697006225586, 'Assets:': 99.86168670654297, 'Cash': 99.90426635742188, '$': 99.86322784423828, '473,865': 99.78624725341797, 'Cash segregated under federal regulation': 99.95112609863281, '28,100': 99.2711181640625, 'Securities borrowed': 99.93054962158203, '25,140,310': 98.2502212524414, 'Collateral held under securities loan agreements': 99.93040466308594, '13,046,641': 99.4695053100586, 'Receivable from brokers, dealers, and clearing organizations': 99.84400939941406, '172,266': 99.8349380493164, 'Other assets': 99.95222473144531, '7,240': 99.72557067871094, 'Receivable from affiliated customer': 99.93509674072266, '894': 99.88592529296875, 'Total assets': 99.89478302001953, '38,869,316': 98.87840270996094, "LIABILITIES AND MEMBER'S CAPITAL": 99.71182250976562, 'Liabilities:': 99.27294921875, 'Securities loaned': 99.9240493774414, '30,436,927': 99.60657501220703, 'Securities sold under agreements to repurchase': 99.9345474243164, '7,907,863': 99.70769500732422, 'Payable to brokers and dealers': 99.8954086303711, '1,721': 99.50720977783203, 'Clearance and regulatory fees payable': 99.93522644042969, '2,714': 99.70756530761719, 'Payable to affiliated customers': 99.87699890136719, '5,398': 99.856689453125, 'Payable to affiliate': 99.76921081542969, '605': 99.96466064453125, 'Other liabilities': 99.94718933105469, '412': 99.82902526855469, 'Total liabilities': 99.9017562866211, '38,355,640': 99.2358627319336, "Member's capital": 99.9365005493164, '513,676': 99.60597229003906, "Total liabilities and member's capital": 99.87967681884766, 'See notes to statement of financial condition.': 99.90404510498047, '-2-': 99.56256866455078}
# -----------------------------------------------------
# Saved 1616344-2018-02-27.csv file to s3 bucket
#
# Performing OCR for 1616344-2019-02-28.csv
# 1616344-2019-02-28.csv has been downloaded
#
# Performing OCR for 1616344-2020-02-27.csv
# 1616344-2020-02-27.csv has been downloaded
#
# Performing OCR for 1616344-2021-02-25.csv
# 1616344-2021-02-25.csv has been downloaded
#
# Performing OCR for 1675365-2021-03-01.csv
# 1675365-2021-03-01.csv has been downloaded
#
# Performing OCR for 200565-2002-03-01.csv
# 200565-2002-03-01.csv has been downloaded
#
# Performing OCR for 200565-2003-03-03.csv
# 200565-2003-03-03.csv has been downloaded
#
# Performing OCR for 200565-2004-03-01.csv
# 200565-2004-03-01.csv has been downloaded
#
# Performing OCR for 200565-2005-03-01.csv
# 200565-2005-03-01.csv has been downloaded
#
# Performing OCR for 200565-2006-03-03.csv
# 200565-2006-03-03.csv has been downloaded
#
# Performing OCR for 200565-2007-03-01.csv
# 200565-2007-03-01.csv has been downloaded
#
# Performing OCR for 200565-2008-03-03.csv
# 200565-2008-03-03.csv has been downloaded
#
# Performing OCR for 200565-2008-04-03.csv
# 200565-2008-04-03.csv has been downloaded
#
# Performing OCR for 200565-2009-03-02.csv
# 200565-2009-03-02.csv has been downloaded
#
# Performing OCR for 200565-2010-03-01.csv
# 200565-2010-03-01.csv has been downloaded
#
# Performing OCR for 200565-2011-03-02.csv
# 200565-2011-03-02.csv has been downloaded
#
# Performing OCR for 200565-2012-02-29.csv
# 200565-2012-02-29.csv has been downloaded
#
# Performing OCR for 200565-2013-03-05.csv
# 200565-2013-03-05.csv has been downloaded
#
# Performing OCR for 200565-2014-03-04.csv
# 200565-2014-03-04.csv has been downloaded
#
# Performing OCR for 200565-2015-03-02.csv
# 200565-2015-03-02.csv has been downloaded
#
# Performing OCR for 200565-2016-04-07.csv
# 200565-2016-04-07.csv has been downloaded
#
# Performing OCR for 200565-2017-03-03.csv
# 200565-2017-03-03.csv has been downloaded
#
# Performing OCR for 200565-2018-03-02.csv
# 200565-2018-03-02.csv has been downloaded
#
# Performing OCR for 200565-2019-03-01.csv
# Started job with id: ab2c383f50520a5a24d702fd2d1bb8bc0e7e274dbfd1677b5ef94f19dfef8052
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Performing OCR for 200565-2020-03-03.csv
# 200565-2020-03-03.csv has been downloaded
#
# Performing OCR for 200565-2021-03-01.csv
# 200565-2021-03-01.csv has been downloaded
#
# Performing OCR for 230611-2002-03-01.csv
# 230611-2002-03-01.csv has been downloaded
#
# Performing OCR for 230611-2003-03-03.csv
# 230611-2003-03-03.csv has been downloaded
#
# Performing OCR for 230611-2004-03-01.csv
# 230611-2004-03-01.csv has been downloaded
#
# Performing OCR for 230611-2005-03-01.csv
# 230611-2005-03-01.csv has been downloaded
#
# Performing OCR for 230611-2006-03-01.csv
# 230611-2006-03-01.csv has been downloaded
#
# Performing OCR for 230611-2007-03-01.csv
# 230611-2007-03-01.csv has been downloaded
#
# Performing OCR for 230611-2008-02-29.csv
# 230611-2008-02-29.csv has been downloaded
#
# Performing OCR for 230611-2009-03-02.csv
# 230611-2009-03-02.csv has been downloaded
#
# Performing OCR for 230611-2009-03-09.csv
# 230611-2009-03-09.csv has been downloaded
#
# Performing OCR for 230611-2010-03-01.csv
# Started job with id: a8c91ee6c9746100e5d320bb222e50ea06b60431b640cbe2b9b04a572d2095c8
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Performing OCR for 230611-2011-03-01.csv
# 230611-2011-03-01.csv has been downloaded
#
# Performing OCR for 230611-2012-02-29.csv
# 230611-2012-02-29.csv has been downloaded
#
# Performing OCR for 230611-2013-03-01.csv
# Started job with id: 689564199e83406ddcb6658a8cfb5237a082f639b7f1213bc7caa38fa336c55b
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Performing OCR for 230611-2014-03-06.csv
# 230611-2014-03-06.csv has been downloaded
#
# Performing OCR for 230611-2015-03-02.csv
# 230611-2015-03-02.csv has been downloaded
#
# Performing OCR for 230611-2016-02-29.csv
# 230611-2016-02-29.csv has been downloaded
#
# Performing OCR for 230611-2017-03-03.csv
# 230611-2017-03-03.csv has been downloaded
#
# Performing OCR for 230611-2018-03-01.csv
# 230611-2018-03-01.csv has been downloaded
#
# Performing OCR for 230611-2019-03-01.csv
# Started job with id: 21500b874c84597caea605ea7148607ae02a1bf95af02da9bc2b82d930c90d06
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Performing OCR for 230611-2020-03-03.csv
# 230611-2020-03-03.csv has been downloaded
#
# Performing OCR for 230611-2021-03-01.csv
# 230611-2021-03-01.csv has been downloaded
#
# Performing OCR for 26617-2002-05-30.csv
# 26617-2002-05-30.csv has been downloaded
#
# Performing OCR for 26617-2003-06-02.csv
# 26617-2003-06-02.csv has been downloaded
#
# Performing OCR for 26617-2004-05-27.csv
# 26617-2004-05-27.csv has been downloaded
#
# Performing OCR for 26617-2005-05-26.csv
# 26617-2005-05-26.csv has been downloaded
#
# Performing OCR for 26617-2006-05-26.csv
# 26617-2006-05-26.csv has been downloaded
#
# Performing OCR for 26617-2007-05-29.csv
# 26617-2007-05-29.csv has been downloaded
#
# Performing OCR for 26617-2008-05-29.csv
# 26617-2008-05-29.csv has been downloaded
#
# Performing OCR for 26617-2009-05-29.csv
# 26617-2009-05-29.csv has been downloaded
#
# Performing OCR for 26617-2009-06-08.csv
# ...
# 17        Brokers, dealers and clearing organizations      7,584
# 18                                              Other      1,070
# 19                                                        16,228
# 20  Property, equipment and leasehold improvements...        354
# 21                                           Goodwill        145
# 22                                       Other assets      5,417
# 23                                       Total assets  $ 262,257
# 0                                          Affiliates    $ 5,532
# 1                Other (including $447 at fair value)      1,276
# 2                                                          6,808
# 3   Securities loaned or sold under agreements to ...    141,640
# 4                        Trading account liabilities:
# 5         U.S. Treasury and federal agency securities     18,862
# 6                           Corporate debt securities      3,541
# 7                                   Equity securities      1,814
# 8                                         Derivatives      1,448
# 9                       Foreign government securities        477
# 10                              Other debt securities         94
# 11                                                        26,236
# 12                  Payables and accrued liabilities:
# 13                                          Customers     37,059
# 14  Obligations to return securities received as c...      7,424
# 15        Brokers, dealers and clearing organizations      4,038
# 16                                              Other      4,763
# 17                                                        53,284
# 18      Long-term debt (including $137 at fair value)     14,637
# 19                                  Total liabilities    242,605
# 20         Commitments, contingencies and guarantees:
# 21                          Subordinated indebtedness     10,445
# 22                              Stockholder's equity:
# 23  Common stock ($10,000 par value, 1,000 shares ...         10
# 24                         Additional paid-in capital      9,198
# 25                                Accumulated deficit        (1)
# 26                         Total stockholder's equity      9,207
# 27         Total liabilities and stockholder's equity  $ 262,257
# {'CITIGROUP GLOBAL MARKETS INC. AND SUBSIDIARIES': 99.72312927246094, '(An indirect wholly owned subsidiary of Citigroup Global Markets Holdings Inc.)': 99.91761016845703, 'Consolidated Statement of Financial Condition': 99.9710464477539, 'December 31, 2014': 99.24970245361328, '(Dollars in millions)': 99.90116882324219, 'Assets': 99.95632934570312, 'Cash and cash equivalents': 99.97401428222656, '$': 99.8389892578125, '444': 99.92620849609375, 'Cash segregated under federal and other regulations': 99.97606658935547, '4,190': 99.9268569946289, 'Securities borrowed or purchased under agreements to resell (including $105,173': 99.9672622680664, 'at fair value)': 99.93504333496094, '157,439': 99.88259887695312, 'Trading account assets ($23,977 pledged as collateral):': 99.9142074584961, 'Mortgage-backed securities': 99.6731948852539, '29,014': 99.8376693725586, 'U.S. Treasury and federal agency securities': 99.9700698852539, '14,963': 99.91667175292969, 'Equity securities': 99.97419738769531, '12,330': 99.92432403564453, 'Corporate debt securities': 99.9722900390625, '7,049': 99.94490051269531, 'Asset-backed securities': 99.85470581054688, '4,121': 99.88612365722656, 'Derivatives': 99.87055969238281, '1,623': 99.83839416503906, 'Foreign government securities': 99.97803497314453, '919': 99.97425079345703, 'State and municipal securities': 99.9761962890625, '594': 99.94220733642578, 'Other debt securities': 99.9787826538086, '3': 99.48907470703125, '70,616': 99.87508392333984, 'Securities received as collateral, at fair value (all pledged to counterparties)': 99.87628173828125, '7,424': 99.86778259277344, 'Receivables:': 99.87442779541016, 'Customers': 99.95401763916016, '7,574': 99.90821838378906, 'Brokers, dealers and clearing organizations': 99.94967651367188, '7,584': 99.899658203125, 'Other': 99.99360656738281, '1,070': 99.93804931640625, '16,228': 99.802001953125, 'Property, equipment and leasehold improvements, net of accumulated depreciation': 99.77388763427734, 'and amortization of $1,619': 99.84159851074219, '354': 99.91573333740234, 'Goodwill': 99.9576644897461, '145': 99.94426727294922, 'Other assets': 99.98822021484375, '5,417': 99.7964096069336, 'Total assets': 99.96565246582031, '262,257': 99.71826934814453, 'See accompanying notes to consolidated statement of financial condition.': 99.9262466430664, 'I': 57.29831314086914, "Liabilities and Stockholder's Equity": 99.93202209472656, 'Short-term borrowings:': 99.85021209716797, 'Affiliates': 99.92916870117188, '5,532': 99.9331283569336, 'Other (including $447 at fair value)': 99.9247055053711, '1,276': 99.90330505371094, '6,808': 99.8912124633789, 'Securities loaned or sold under agreements to repurchase (including $2,562 at fair value)': 99.9343032836914, '141,640': 99.90984344482422, 'Trading account liabilities:': 99.81205749511719, '18,862': 99.92052459716797, '3,541': 99.85025787353516, '1,814': 99.91850280761719, '1,448': 99.90080261230469, '477': 99.96102142333984, '94': 99.96147918701172, '26,236': 99.90171813964844, 'Payables and accrued liabilities:': 99.86478424072266, '37,059': 99.88712310791016, 'Obligations to return securities received as collateral, at fair value': 99.95616149902344, '4,038': 99.72322845458984, '4,763': 99.86251831054688, '53,284': 99.77838897705078, 'Long-term debt (including $137 at fair value)': 99.89549255371094, '14,637': 99.82310485839844, 'Total liabilities': 99.96076202392578, '242,605': 99.70543670654297, 'Commitments, contingencies and guarantees:': 99.77371215820312, 'Subordinated indebtedness': 99.9452133178711, '10,445': 99.89874267578125, "Stockholder's equity:": 99.93399810791016, 'Common stock ($10,000 par value, 1,000 shares authorized, issued and outstanding)': 99.89376831054688, '10': 99.98328399658203, 'Additional paid-in capital': 99.90878295898438, '9,198': 99.86784362792969, 'Accumulated deficit': 99.96233367919922, '(1)': 98.49327087402344, "Total stockholder's equity": 99.95463562011719, '9,207': 99.801940917968 ...
# -----------------------------------------------------
# Saved 91154-2015-03-02.csv file to s3 bucket
#
# Performing OCR for 91154-2016-03-01.csv
# 91154-2016-03-01.csv has been downloaded
#
# Performing OCR for 91154-2017-03-02.csv
# 91154-2017-03-02.csv has been downloaded
#
# Performing OCR for 91154-2018-03-05.csv
# 91154-2018-03-05.csv has been downloaded
#
# Performing OCR for 91154-2019-03-05.csv
# 91154-2019-03-05.csv has been downloaded
#
# Performing OCR for 91154-2020-03-02.csv
# 91154-2020-03-02.csv has been downloaded
#
# Performing OCR for 920417-2015-03-02.csv
# 920417-2015-03-02.csv has been downloaded
#
# Performing OCR for 920417-2016-02-29.csv
# 920417-2016-02-29.csv has been downloaded
#
# Performing OCR for 920417-2017-03-01.csv
# 920417-2017-03-01.csv has been downloaded
#
# Performing OCR for 920417-2018-02-27.csv
# 920417-2018-02-27.csv has been downloaded
#
# Performing OCR for 920417-2019-02-28.csv
# 920417-2019-02-28.csv has been downloaded
#
# Performing OCR for 920417-2020-02-28.csv
# 920417-2020-02-28.csv has been downloaded
#
# Performing OCR for 920417-2021-03-01.csv
# 920417-2021-03-01.csv has been downloaded
#
# Performing OCR for 922792-2002-03-04.csv
# 922792-2002-03-04.csv has been downloaded
#
# Performing OCR for 922792-2003-03-03.csv
# 922792-2003-03-03.csv has been downloaded
#
# Performing OCR for 922792-2004-03-01.csv
# 922792-2004-03-01.csv has been downloaded
#
# Performing OCR for 922792-2005-03-01.csv
# 922792-2005-03-01.csv has been downloaded
#
# Performing OCR for 922792-2006-03-01.csv
# 922792-2006-03-01.csv has been downloaded
#
# Performing OCR for 922792-2007-03-01.csv
# 922792-2007-03-01.csv has been downloaded
#
# Performing OCR for 922792-2008-02-29.csv
# 922792-2008-02-29.csv has been downloaded
#
# Performing OCR for 922792-2009-03-02.csv
# 922792-2009-03-02.csv has been downloaded
#
# Performing OCR for 922792-2010-03-02.csv
# 922792-2010-03-02.csv has been downloaded
#
# Performing OCR for 922792-2011-03-01.csv
# Started job with id: d3e48f18518106317c5430630481fb55e3101b4ba71f49c95c07f974e9d2c148
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Page number(s) for extraction in PNG are [5]
#
# Started job with id: 0d8ee0b4170f5be2e1b3243d932b679a050eff8875d2353ba608c891bcf1b636
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0                 1
# 0                                              Assets
# 1                           Cash and cash equivalents     $ 688,235,112
# 2   Cash and securities - segregated for regulator...     7,458,130,237
# 3                                 Securities borrowed       930,738,331
# 4     Securities purchased under agreements to resell       208,401,736
# 5                 Deposits with clearing organization        27,997,270
# 6                                  Other receivables:
# 7   Customers (net of allowance for doubtful accou...     6,972,979,236
# 8         Brokers, dealers and clearing organizations       832,295,760
# 9                                          Affiliates        53,063,772
# 10                                           Interest        13,907,547
# 11                                       Other assets        29,587,818
# 12                                       Total assets  $ 17,215,336,819
# 13                   Liabilities and members' capital
# 14                                       Liabilities:
# 15                               Payable to customers  $ 15,059,739,561
# 16                                  Securities loaned       649,311,419
# 17                                    Other payables:
# 18        Brokers, dealers and clearing organizations       144,587,679
# 19  Accounts payable, accrued expenses and other l...        30,721,155
# 20                                         Affiliates        41,877,778
# 21                                           Interest         3,711,875
# 22                                                       15,929,949,467
# 23                                   Members' capital     1,285,387,352
# 24             Total liabilities and members' capital  $ 17,215,336,819
#
# Textract-PNG dataframe
#                                                     0                 1
# 0                                              Assets
# 1                           Cash and cash equivalents     $ 688,235,112
# 2   Cash and securities - segregated for regulator...     7,458,130,237
# 3                                 Securities borrowed       930,738,331
# 4     Securities purchased under agreements to resell       208,401,736
# 5                 Deposits with clearing organization        27,997,270
# 6                                  Other receivables:
# 7   Customers (net of allowance for doubtful accou...     6,972,979,236
# 8         Brokers, dealers and clearing organizations       832,295,760
# 9                                          Affiliates        53,063,772
# 10                                           Interest        13,907,547
# 11                                       Other assets        29,587,818
# 12                                       Total assets  $ 17,215,336,819
# 13                   Liabilities and members' capital
# 14                                       Liabilities:
# 15                               Payable to customers  $ 15,059,739,561
# 16                                  Securities loaned       649,311,419
# 17                                    Other payables:
# 18        Brokers, dealers and clearing organizations       144,587,679
# 19  Accounts payable, accrued expenses and other l...        30,721,155
# 20                                         Affiliates        41,877,778
# 21                                           Interest         3,711,875
# 22                                                       15,929,949,467
# 23                                   Members' capital     1,285,387,352
# 24             Total liabilities and members' capital  $ 17,215,336,819
# {'INTERACTIVE BROKERS LLC AND SUBSIDIARY': 99.76744842529297, 'CONSOLIDATED STATEMENT OF FINANCIAL CONDITION': 99.77142333984375, 'As of December 31, 2010': 99.50263977050781, 'Assets': 99.96435546875, 'Cash and cash equivalents': 99.94659423828125, '$': 99.9018783569336, '688,235,112': 99.85517120361328, 'Cash and securities - segregated for regulatory purposes': 99.44459533691406, '7,458,130,237': 99.30974578857422, 'Securities borrowed': 99.97048950195312, '930,738,331': 99.72638702392578, 'Securities purchased under agreements to resell': 99.95491790771484, '208,401,736': 99.78170776367188, 'Deposits with clearing organization': 99.97335815429688, '27,997,270': 99.7740707397461, 'Other receivables:': 99.37603759765625, 'Customers (net of allowance for doubtful accounts of $17,871,465)': 99.93383026123047, '6,972,979,236': 99.77742004394531, 'Brokers, dealers and clearing organizations': 99.95748901367188, '832,295,760': 99.77813720703125, 'Affiliates': 99.90546417236328, '53,063,772': 99.68791961669922, 'Interest': 99.92462921142578, '13,907,547': 99.8960952758789, 'Other assets': 99.86173248291016, '29,587,818': 99.73616027832031, 'Total assets': 99.94623565673828, '17,215,336,819': 99.64736938476562, "Liabilities and members' capital": 99.44580078125, 'Liabilities:': 99.00884246826172, 'Payable to customers': 99.94619750976562, '$ 15,059,739,561': 99.63426208496094, 'Securities loaned': 99.94448852539062, '649,311,419': 99.86418151855469, 'Other payables:': 99.93736267089844, '144,587,679': 99.88383483886719, 'Accounts payable, accrued expenses and other liabilities': 99.95931243896484, '30,721,155': 99.92654418945312, '41,877,778': 99.86274719238281, '3,711,875': 99.88736724853516, '15,929,949,467': 99.80143737792969, "Members' capital": 99.30726623535156, '1,285,387,352': 99.59642028808594, "Total liabilities and members' capital": 99.63323211669922, 'See accompanying notes to the consolidated statement of financial condition.': 99.84455108642578, '-2-': 85.68488311767578}
# -----------------------------------------------------
# Saved 922792-2011-03-01.csv file to s3 bucket
#
# Performing OCR for 922792-2012-02-29.csv
# 922792-2012-02-29.csv has been downloaded
#
# Performing OCR for 922792-2014-03-04.csv
# 922792-2014-03-04.csv has been downloaded
#
# Performing OCR for 922792-2015-03-02.csv
# 922792-2015-03-02.csv has been downloaded
#
# Performing OCR for 922792-2016-02-29.csv
# 922792-2016-02-29.csv has been downloaded
#
# Performing OCR for 922792-2017-03-01.csv
# 922792-2017-03-01.csv has been downloaded
#
# Performing OCR for 922792-2018-03-01.csv
# 922792-2018-03-01.csv has been downloaded
#
# Performing OCR for 922792-2019-02-28.csv
# 922792-2019-02-28.csv has been downloaded
#
# Performing OCR for 922792-2019-03-01.csv
# 922792-2019-03-01.csv has been downloaded
#
# Performing OCR for 922792-2020-02-28.csv
# 922792-2020-02-28.csv has been downloaded
#
# Performing OCR for 922792-2021-02-26.csv
# 922792-2021-02-26.csv has been downloaded

# %%
# # single reading for testing purposes and debugging Textract results e.g. 853784-2002-03-01
# textractParse('Input/X-17A-5-PDF-SUBSETS/89562-2005-01-31-subset.pdf', 
#               'Input/X-17A-5-PNG-SUBSETS/89562-2005-01-31/', 'ran-s3-systemic-risk')
# Out:
# Started job with id: 4fbf117fc4b905d0524fccd453dd5c70949261df4147dc4bcebbfac78ea26b76
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
# Resultset page recieved: 8
#
# Page number(s) for extraction in PNG are [5, 6]
#
# Started job with id: 0800e428dc38e2e44144eca94befb6d7d9be1f00f68d0ff0efb2ea5b9bad51d5
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Started job with id: d3437b694f5f851a709f529fe15a545387e6458447596906d451a73186e5b327
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0         1
# 0                                              Assets
# 1                           Cash and cash equivalents     $ 924
# 2   Cash and securities segregated and on deposit ...     1,633
# 3   Securities and other inventory positions owned...    80,575
# 4                   Securities received as collateral     1,202
# 5                          Collateralized agreements:
# 6     Securities purchased under agreements to resell    64,168
# 7                                 Securities borrowed    94,818
# 8                                        Receivables:
# 9         Brokers, dealers and clearing organizations     5,066
# 10                                          Customers     8,934
# 11                                         Affiliates    15,748
# 12                                             Others       147
# 13  Property, equipment and leasehold improvements...       168
# 14                                       Other assets       584
# 15  Identifiable intangible assets and goodwill (n...       133
# 16                                       Total assets  $274,100
# 0                Liabilities and stockholder's equity
# 1                               Short-term financings     $ 429
# 2   Securities and other inventory positions sold ...    58,719
# 3   Obligation to return securities received as co...     1,202
# 4                           Collateralized financing:
# 5      Securities sold under agreements to repurchase    99,945
# 6                                   Securities loaned    61,312
# 7                            Other secured borrowings     1,817
# 8         Advances from Holdings and other affiliates    20,251
# 9                                           Payables:
# 10        Brokers, dealers and clearing organizations     3,047
# 11                                          Customers    11,896
# 12             Accrued liabilities and other payables     4,366
# 13                                    Long-term debt:
# 14                                       Senior notes     2,170
# 15                          Subordinated indebtedness     5,665
# 16                                  Total liabilities   270,819
#
# Textract-PNG dataframe
#                                                     0         1
# 0                                              Assets
# 1                           Cash and cash equivalents     $ 924
# 2   Cash and securities segregated and on deposit ...     1,633
# 3   Securities and other inventory positions owned...    80,575
# 4                   Securities received as collateral     1,202
# 5                          Collateralized agreements:
# 6     Securities purchased under agreements to resell    64,168
# 7                                 Securities borrowed    94,818
# 8                                        Receivables:
# 9         Brokers, dealers and clearing organizations     5,066
# 10                                          Customers     8,934
# 11                                         Affiliates    15,748
# 12                                             Others       147
# 13  Property, equipment and leasehold improvements...       168
# 14                                       Other assets       584
# 15  Identifiable intangible assets and goodwill (n...       133
# 16                                       Total assets  $274,100
# 0                Liabilities and stockholder's equity
# 1                               Short-term financings     $ 429
# 2   Securities and other inventory positions sold ...    58,719
# 3   Obligation to return securities received as co...     1,202
# 4                           Collateralized financing:
# 5      Securities sold under agreements to repurchase    99,945
# 6                                   Securities loaned    61,312
# 7                            Other secured borrowings     1,817
# 8         Advances from Holdings and other affiliates    20,251
# 9                                           Payables:
# 10        Brokers, dealers and clearing organizations     3,047
# 11                                          Customers    11,896
# 12             Accrued liabilities and other payables     4,366
# 13                                    Long-term debt:
# 14                                       Senior notes     2,170
# 15                          Subordinated indebtedness     5,665
# 16                                  Total liabilities   270,819
# (                                                    0         1
#  0                                              Assets
#  1                           Cash and cash equivalents     $ 924
#  2   Cash and securities segregated and on deposit ...     1,633
#  3   Securities and other inventory positions owned...    80,575
#  4                   Securities received as collateral     1,202
#  5                          Collateralized agreements:
#  6     Securities purchased under agreements to resell    64,168
#  7                                 Securities borrowed    94,818
#  8                                        Receivables:
#  9         Brokers, dealers and clearing organizations     5,066
#  10                                          Customers     8,934
#  11                                         Affiliates    15,748
#  12                                             Others       147
#  13  Property, equipment and leasehold improvements...       168
#  14                                       Other assets       584
#  15  Identifiable intangible assets and goodwill (n...       133
#  16                                       Total assets  $274,100
#  0                Liabilities and stockholder's equity
#  1                               Short-term financings     $ 429
#  2   Securities and other inventory positions sold ...    58,719
#  3   Obligation to return securities received as co...     1,202
#  4                           Collateralized financing:
#  5      Securities sold under agreements to repurchase    99,945
#  6                                   Securities loaned    61,312
#  7                            Other secured borrowings     1,817
#  8         Advances from Holdings and other affiliates    20,251
#  9                                           Payables:
#  10        Brokers, dealers and clearing organizations     3,047
#  11                                          Customers    11,896
#  12             Accrued liabilities and other payables     4,366
#  13                                    Long-term debt:
#  14                                       Senior notes     2,170
#  15                          Subordinated indebtedness     5,665
#  16                                  Total liabilities   270,819,
#                                                      0         1
#  0                                              Assets
#  1                           Cash and cash equivalents     $ 924
#  2   Cash and securities segregated and on deposit ...     1,633
#  3   Securities and other inventory positions owned...    80,575
#  4                   Securities received as collateral     1,202
#  5                          Collateralized agreements:
#  6     Securities purchased under agreements to resell    64,168
#  7                                 Securities borrowed    94,818
#  8                                        Receivables:
#  9         Brokers, dealers and clearing organizations     5,066
#  10                                          Customers     8,934
#  11                                         Affiliates    15,748
#  12                                             Others       147
#  13  Property, equipment and leasehold improvements...       168
#  14                                       Other assets       584
#  15  Identifiable intangible assets and goodwill (n...       133
#  16                                       Total assets  $274,100
#  0                Liabilities and stockholder's equity
#  1                               Short-term financings     $ 429
#  2   Securities and other inventory positions sold ...    58,719
#  3   Obligation to return securities received as co...     1,202
#  4                           Collateralized financing:
#  5      Securities sold under agreements to repurchase    99,945
#  6                                   Securities loaned    61,312
#  7                            Other secured borrowings     1,817
#  8         Advances from Holdings and other affiliates    20,251
#  9                                           Payables:
#  10        Brokers, dealers and clearing organizations     3,047
#  11                                          Customers    11,896
#  12             Accrued liabilities and other payables     4,366
#  13                                    Long-term debt:
#  14                                       Senior notes     2,170
#  15                          Subordinated indebtedness     5,665
#  16                                  Total liabilities   270,819,
#  {'Total assets ': '$274,100 ',
#   'Brokers, dealers and clearing organizations ': '3,047 ',
#   'Customers ': '11,896 ',
#   'Cash and cash equivalents ': '$ 924 ',
#   'Affiliates ': '15,748 ',
#   'Securities borrowed ': '94,818 ',
#   'Securities received as collateral ': '1,202 ',
#   'Cash and securities segregated and on deposit for regulatory and other purposes ': '1,633 ',
#   'Others ': '147 ',
#   'Other assets ': '584 ',
#   'Identifiable intangible assets and goodwill (net of accumulated amortization of $139) ': '133 ',
#   'Securities and other inventory positions owned (includes $31,003 pledged as collateral) ': '80,575 ',
#   'Property, equipment and leasehold improvements (net of accumulated depreciation and amortization of $186) ': '168 ',
#   "Total liabilities and stockholder's equity ": '$274,100 ',
#   'Total liabilities ': '270,819 ',
#   "Total stockholder's equity ": '3,281 ',
#   'Advances from Holdings and other affiliates ': '20,251 ',
#   'Retained earnings ': '1,488 ',
#   'Accumulated other comprehensive income (net of tax) ': '5 ',
#   'Senior notes ': '2,170 ',
#   'Additional paid-in capital ': '1,788 ',
#   'Subordinated indebtedness ': '5,665 ',
#   'Other secured borrowings ': '1,817 ',
#   'Accrued liabilities and other payables ': '4,366 ',
#   'Short-term financings ': '$ 429 ',
#   'Securities and other inventory positions sold but not yet purchased ': '58,719 ',
#   'Obligation to return securities received as collateral ': '1,202 ',
#   'Securities loaned ': '61,312 ',
#   'Securities sold under agreements to repurchase ': '99,945 '},
#  {'Lehman Brothers Inc. and Subsidiaries': 99.9020004272461,
#   'Consolidated Statement of Financial Condition': 99.93247985839844,
#   'In millions': 99.87939453125,
#   'November 30, 2004': 99.1608657836914,
#   'Assets': 99.94197845458984,
#   'Cash and cash equivalents': 99.91175842285156,
#   '$ 924': 96.28491973876953,
#   'Cash and securities segregated and on deposit for regulatory and other purposes': 99.96643829345703,
#   '1,633': 99.76836395263672,
#   'Securities and other inventory positions owned (includes $31,003 pledged as collateral)': 99.77249145507812,
#   '80,575': 99.86515808105469,
#   'Securities received as collateral': 96.48145294189453,
#   '1,202': 99.88284301757812,
#   'Collateralized agreements:': 99.37969207763672,
#   'Securities purchased under agreements to resell': 99.93665313720703,
#   '64,168': 99.57111358642578,
#   'Securities borrowed': 99.91846466064453,
#   '94,818': 96.76945495605469,
#   'Receivables:': 99.4984359741211,
#   'Brokers, dealers and clearing organizations': 99.82125854492188,
#   '5,066': 99.85798645019531,
#   'Customers': 99.73907470703125,
#   '8,934': 99.28448486328125,
#   'Affiliates': 99.88922119140625,
#   '15,748': 99.64036560058594,
#   'Others': 99.9691162109375,
#   '147': 99.96324157714844,
#   'Property, equipment and leasehold improvements (net of accumulated depreciation': 95.57099914550781,
#   'and amortization of $186)': 99.8469467163086,
#   '168': 99.94657897949219,
#   'Other assets': 99.68325805664062,
#   '584': 99.91417694091797,
#   'Identifiable intangible assets and goodwill (net of accumulated amortization of $139)': 99.89443969726562,
#   '133': 99.91320037841797,
#   'Total assets': 99.93647003173828,
#   '$274,100': 99.70391082763672,
#   'See Notes to Consolidated Statement of Financial Condition.': 97.0558853149414,
#   '-1- -': 75.48866271972656,
#   'Consolidated Statement of Financial Condition (continued)': 99.95807647705078,
#   'In millions except per share data': 99.94650268554688,
#   "Liabilities and stockholder's equity": 99.92295837402344,
#   'Short-term financings': 99.7529067993164,
#   '$ 429': 99.87654113769531,
#   'Securities and other inventory positions sold but not yet purchased': 99.94595336914062,
#   '58,719': 99.60417175292969,
#   'Obligation to return securities received as collateral': 99.9301986694336,
#   'Collateralized financing:': 97.091796875,
#   'Securities sold under agreements to repurchase': 99.95539855957031,
#   '99,945': 99.71476745605469,
#   'Securities loaned': 99.95458984375,
#   '61,312': 99.8245849609375,
#   'Other secured borrowings': 99.97219848632812,
#   '1,817': 99.74810028076172,
#   'Advances from Holdings and other affiliates': 99.97045135498047,
#   '20,251': 99.90017700195312,
#   'Payables:': 99.40279388427734,
#   '3,047': 99.77455139160156,
#   '11,896': 99.89766693115234,
#   'Accrued liabilities and other payables': 99.87489318847656,
#   '4,366': 99.44652557373047,
#   'Long-term debt:': 99.59525299072266,
#   'Senior notes': 99.91756439208984,
#   '2,170': 99.91358947753906,
#   'Subordinated indebtedness': 99.92085266113281,
#   '5,665': 99.62735748291016,
#   'Total liabilities': 99.86132049560547,
#   '270,819': 99.84947204589844,
#   'Commitments and contingencies': 99.82689666748047,
#   "Stockholder's equity": 99.92247009277344,
#   'Preferred stock, $0.10 par value; 10,000 shares authorized; none outstanding': 97.91191101074219,
#   'Common stock, $0.10 par value; 10,000 shares authorized; 1,006 shares issued and outstanding': 98.55272674560547,
#   'Additional paid-in capital': 99.77493286132812,
#   '1,788': 99.87073516845703,
#   'Accumulated other comprehensive income (net of tax)': 99.80451202392578,
#   '5': 99.89944458007812,
#   'Retained earnings': 99.91502380371094,
#   '1,488': 99.80140686035156,
#   "Total stockholder's equity": 99.9355697631836,
#   '3,281': 91.09475708007812,
#   "Total liabilities and stockholder's equity": 99.95182800292969,
#   '-2- -': 86.29072570800781},
#  None)
