# %%
# Run on first instance to install required libraries
# %pip install smart_open minecart textract-trp
# Out:
# Collecting smart_open
#   Downloading smart_open-5.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.0 MB/s eta 0:00:011
# Collecting minecart
#   Downloading minecart-0.3.0-py3-none-any.whl (23 kB)
# Collecting textract-trp
#   Downloading textract_trp-0.1.3-py3-none-any.whl (5.8 kB)
# Collecting pdfminer3k
#   Downloading pdfminer3k-1.3.4-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 6.6 MB/s ta 0:00:011
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from minecart) (1.15.0)
# Requirement already satisfied: ply in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pdfminer3k->minecart) (3.11)
# Installing collected packages: pdfminer3k, textract-trp, smart-open, minecart
# Successfully installed minecart-0.3.0 pdfminer3k-1.3.4 smart-open-5.1.0 textract-trp-0.1.3
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import time 
import re
import os
import trp
import boto3
import minecart
import json
import logging 

import numpy as np
import pandas as pd

from smart_open import open
from sagemaker.session import Session

# %% [markdown]
# # AWS Asynchronous Textract Script (requesting Job)
# **Content modified from Amazon AWS Textract repository (refer to [URL](https://github.com/aws-samples/amazon-textract-code-samples/blob/master/python/12-pdf-text.py) below)**

# %%
def startJob(s3BucketName:str, objectName:str) -> str:
    """
    Starts a Textract job on AWS server 
    """
    # initialize return and client object
    response = None                         
    client = boto3.client('textract')
    
    # issue response to AWS to start Textract job for table analysis 
    response = client.start_document_analysis(
        DocumentLocation={
            'S3Object': {
                'Bucket': s3BucketName,     # location of data to be read from s3 bucket 
                'Name': objectName}},       # file name to be read from Textract  
        FeatureTypes=['FORMS', 'TABLES']    # selecting FORMS (key-values) and TABLES from the OCR
    )
    
    # return response job ID for service
    return response["JobId"]

# %%
def isJobComplete(jobId:str) -> str:
    """
    Tracks the completion status of the Textract job when queued
    """
    # allow for interal sleep timer (efficiency)
    time.sleep(1)                               
    
    client = boto3.client('textract')
    response = client.get_document_analysis(JobId=jobId)
    
    # job-status of the response object 
    status = response["JobStatus"]                        
    print("Job status: {}".format(status))
    
    # if job still running check current status every 5 seconds
    while(status == "IN_PROGRESS"):
        
        # time lag before reporting status
        time.sleep(5)                                         
        response = client.get_document_analysis(JobId=jobId)
        
        # job-status of the response object
        status = response["JobStatus"]                        
        print("Job status: {}".format(status))
    
    return status

# %%
def getJobResults(jobId:str) -> list:
    """
    Returns the contents of the Textract job, after job status is completed
    """
    # initialize list object to track pages read
    pages = []                    

    client = boto3.client('textract')
    response = client.get_document_analysis(JobId=jobId)
    
    # add first page response to list (length of pages will be arbitrary) 
    pages.append(response)      
    print("Resultset page recieved: {}".format(len(pages)))
    
    # if NextToken present we have a pointer to page (e.g. Response -> Page) 
    nextToken = None
    if('NextToken' in response):
        nextToken = response['NextToken']
    
    # iterate through the pages and append to response figure (assuming nextToken not None)
    while(nextToken):
        response = client.get_document_analysis(JobId=jobId, NextToken=nextToken)
        pages.append(response)
        print("Resultset page recieved: {}".format(len(pages)))
        
        # move along linked-list for presence of NextToken response
        nextToken = None
        if('NextToken' in response):
            nextToken = response['NextToken']
    
    # return amalgamation of all page responses 
    return pages

# %%
def runJob(bucket:str, key:str):
    """
    Function designed to call an AWS Textract job (implements helper function above)
    """
    jobId = startJob(bucket, key)   
    print("Started job with id: {}".format(jobId))

    # if job is complete on AWS return page responses 
    if(isJobComplete(jobId)):
        response = getJobResults(jobId)
        
    return response

# %% [markdown]
# # AWS Extraction Scripts (Key-Value Pairs)
# **The content was modified from AWS to extract key-value pairs in form documents from Block objects that are stored in a map. (refer to [URL](https://docs.aws.amazon.com/textract/latest/dg/examples-extract-kvp.html))**

# %%
def find_value_block(key_block, value_map):
    """
    Retrieving value block from AWS textract job, this contains the value text 
    """
    # iterate through the key blocks in the FORM relationships (should have a VALUE and CHILD type, n=2)
    for relationship in key_block['Relationships']:
        
        # if our key block object type is a VALUE we examine the relationship ID
        # NOTE WE SHOULD HAVE ONLY ONE ID FOR THE VALUE RELATIONSHIP TYPE
        if relationship['Type'] == 'VALUE':
            
            # singular ID item stored in list object (return value block object)
            for value_id in relationship['Ids']:
                value_block = value_map[value_id]
            
    # return all corresponding value series
    return value_block

# %%
def get_kv_relationship(key_map, value_map, block_map):
    """
    Retrieving the Key-Value relationship from FORM OCR Textract 
    """
    # initialize key-map dictionary for lineitems and corresponding accounting values
    key_value_map = {}
    
    # unpack the key_map to retrieve the block id and key names
    for block_id, key_block in key_map.items():

        # retrieve value block provided the key_block from each block id
        value_block = find_value_block(key_block, value_map)

        # get text value from key and value blocks
        key = get_text(key_block, block_map)
        val = get_text(value_block, block_map)
        
        # map the key and value pairs (e.g. {'Total Assets':'$ 189,232'})
        key_value_map[key] = val
        
    return key_value_map

# %%
def get_text(result, blocks_map):
    """
    Retrieving text values from given block object
    """
    # initialize container for text
    text = ''
    
    # if relationships header exists we can extract CHILD header
    if 'Relationships' in result:
        
        # relationship maps to a list (iterate through to reveal a dictionary)
        # e.g. 'Relationships' : [{'Type' : 'CHILD', 'Ids': ['e2b3b12f-ebb7-4f6e-914f-97b315672530']}]
        for relationship in result['Relationships']:
            
            # if relationship type is CHILD we explore job-id (indicates good fit)
            if relationship['Type'] == 'CHILD':
                
                # iterate through Ids list
                for child_id in relationship['Ids']:
                    
                    # select corresponding CHILD_ID from block map, this is sub-dictionary
                    word = blocks_map[child_id]
                    
                    # if block type is a word then we append with a space
                    if word['BlockType'] == 'WORD':
                        text += word['Text'] + ' '
                        
                    # if block type is a selection element (e.g. an option button/mark)
                    # note we treat these cases with an X to denote an optional field 
                    if word['BlockType'] == 'SELECTION_ELEMENT':
                        if word['SelectionStatus'] == 'SELECTED':
                            text += 'X '    
    
    # return string corresponding with word 
    return text

# %% [markdown]
# # OCR Wrapper Functions
# **The scripts perform an OCR job from AWS Textract, and returning well formated data**

# %%
def trp2df(table:trp.Table) -> pd.DataFrame:
    """
    Function designed to convert a trp table into a dataframe Complexity -> O(n^2) approx.
    ------------------------------------------------------------------------------------------
    Input
        :param table: (type trp.Table)
            A trp table object parsed from a pdf using AWS Textract  
    
    Output
        :return: type pandas.DataFrame
            A DataFrame object that is constructed by deconstructed a Textract trp table
    """
    N = len(table.rows)               # number of rows in table
    M = len(table.rows[0].cells)      # number of columns in table
    arr = [0]*N                       # initialize matrix container
    
    # iterate through each row within the provided table
    for row in np.arange(N):
        
        # strip the text from the cell references to construct (N X M) matrix
        arr[row] = [table.rows[row].cells[col].text.strip() for col in np.arange(M)]    # move column-wise to get text
    
    df = pd.DataFrame(arr)
    
    # remove columns that are completely empty
    empty_cols = [col for col in df.columns if (df[col] == '').all()]
    df = df.drop(empty_cols, axis=1)

    # reset the column names (avoid the column names)
    df.columns = np.arange(df.columns.size)
    
    return df

# %%
def check_dollar_sign(row):
    """
    Determines if there exists a dollar sign present within a given row
    ------------------------------------------------------------------------------------------
    Input:
        :param: row (type nd.array)
            A given row from a dataframe
    Return:
        This function returns a bollean sequence
    """
    
    def re_dollar_check(x):
        # we search for the presence of a dollar sign ($) in a string followed by character
        dollar_search = re.search('\$[^\]]+', x, flags=re.IGNORECASE)
        
        if dollar_search is not None: return True
        return False

    vFunc = np.vectorize(re_dollar_check)      # vectorize function to apply to numpy array
    cleanValue = vFunc(row)                    # apply vector function
    
    # search each vector return for presence of True
    # if True we have found a dollar '$' character
    series = np.argwhere(cleanValue == True)
    if len(series) > 0: 
        return True
    
    return False

# %%
def get_balance_sheet(df:pd.DataFrame) -> tuple:
    """
    Determines if a read table is a balance sheet term
    ------------------------------------------------------------------------------------------
    Input:
        :param: df (type pd.DataFrame)
            A given dataframe table
    Return:
        This function returns a dataframe that fits the balance sheet parameters
    """
    
    # number of columns in dataframe
    n = df.columns.size
    
    ##############################################################
    #                           NOTES
    #          a good dataframe should have 2-3 columns
    #      anything more or less is a reading error we ignore
    ##############################################################

    # if the dataframe has more than 3 columns then we most likley have an issue in parsing, avoid
    if n > 3: 
        return None

    elif n > 1:

        ##############################
        # Balance Sheet Assummptions
        ##############################

        # this is the first column which should have all line items (e.g. Cash, Total Assets, Total Liabilites)
        lineIndex = df.columns[0]

        # check for the word "cash" in a string at the begining, ignoring case sensitivity (asset check)
        assetCheck = df[lineIndex].str.contains('^Cash', regex=True, flags=re.IGNORECASE)

        # check for the word "Liabilities" in a string at the end, ignoring case sensitivity (liability check)
        debtCheck1 = df[lineIndex].str.contains('Liabilities$|^Liabilities', regex=True, flags=re.IGNORECASE)
        debtCheck2 = df[lineIndex].str.contains('Liability$|^Liability', regex=True, flags=re.IGNORECASE)

        # check for the presence of $ sign, we assume the balance sheet items should have at least one $ sign
        # this check is used to avoid reading the table of contents, which was flagged in prior reads
        dollarCheck = df.apply(check_dollar_sign, axis=1)

        ##############################
        # Balance Sheet Determination
        ##############################

        check1 = df[assetCheck == True].empty                  # check for asset table
        check2 = df[debtCheck1 | debtCheck2].empty             # check for liability & equity table
        check3 = df[dollarCheck == True].empty                 # check for presence of '$' sign  

        # make sure the cash term appears toward the top of the balance sheet
        if np.argmax(assetCheck==True) < assetCheck.shape[0]/2:

            # if either asset term or liability term is found, with a $ sign we append the dataframe
            if (check1 == False or check2 == False) and (check3 == False):
                return (df, check1, check2)

# %%
def readTable(response:list) -> tuple:
    """
    Function to transform AWS Textract object to a dataframe, by searching for tables
     ------------------------------------------------------------------------------------------
    Input
        :param response: (type list)
            An AWS Textract response object corresponding to pages of a given document page 
    
    Output
        :return: type tuple
            A (3x1) tuple is returned, storing the concated dataframe at the first index, and the accompanying 
            trp page objects for where the balance sheet was determined to reside at the second index
    """
    
    catDF = []          # in the event multiple tables detected on one page (concat them)
    page_series = []    # keep track of page objects where balance sheet was flagged
    page_nums = []      # keep track of page numbers where balance sheet was found
    page_count = 0
    
    tb_diff_c1 = 0      # flag to help indicate if tables, immediately precede one another 
    tb_diff_c2 = 0
    
    prior_c1 = True     # keep track of previous asset flag 
    prior_c2 = True     # keep track of previous liability flag
    
    # format the Textract response type 
    doc = trp.Document(response)
    
    # iterate through document pages
    for page in doc.pages:
        
        # itterate through page tables
        for table in page.tables: 
            
            # convert trp-table into dataframe object
            df = trp2df(table)
            
            # retrieve balance sheet from table
            balance_sheet = get_balance_sheet(df)
            
            if type(balance_sheet) is tuple:
                
                bs, c1, c2 = balance_sheet      # unpack the return object
                
                # we append pages since asset and liablility tables are often seperate
                # there is no loss of generality if asset and liability terms are in one table
                catDF.append(bs)                

                # we want to keep track of pages that have been deemed as balance sheet
                # this helps speed up the runtime for Text, Forms and PNG
                if page not in page_series:
                    page_series.append(page)      
                    page_nums.append(page_count)
                
                ##############################
                # Flag for split tables 
                ##############################
                
                # indicates no liability term read, no previous asset term was read
                # we are currenlty reading the asset term of the balance sheet
                if c2 == True and prior_c1 == True and prior_c2 == True and c1 == False:
                    print('Balance sheet line items have been split across table\n')
                    prior_c1 = False
                    tb_diff_c1 = 0
                    
                # indicates no asset term read, no previous asset term was read
                # we are currenlty reading the liability term of the balance sheet
                elif c1 == True and prior_c1 == True and c2 == False:
                    print('Asset line items may be read after liability line items\n')
                    prior_c2 = False
                    tb_diff_c2 = 0
                    
                ##############################
                # Balance Sheet Exportation 
                ##############################

                # 1) indicates both assets and liability terms were found in table
                if (c2 == False and c1 == False) or (c2 == False and prior_c1 == False and tb_diff_c1 == 1):
                    return (pd.concat(catDF), page_series, page_nums)
                
                # 2) indicates liability term read before assets 
                elif prior_c2 == False and c1 == False and tb_diff_c2 == 1:
                    catDF.reverse()
                    return (pd.concat(catDF), page_series, page_nums)
                    
                else: pass
            
            # table scope iteration
            tb_diff_c1 += 1
            tb_diff_c2 += 1
        
        # page scope iteration
        page_count += 1

# %%
def readPNG(pages:list, png_path:str, bucket='ran-s3-systemic-risk') -> tuple:
    """
    Function to transform AWS Textract object to a dataframe, by searching for tables
     ------------------------------------------------------------------------------------------
    Input
        :param response: (type list)
            
    
    Output
        :return: type tuple
          
    """
    subfolder = png_path.split('/')[-2]      # subfolder where PNG files are stored
    
    # construct PNG directories with relevant pages
    textract_paths = [png_path + subfolder + '-p{}.png'.format(idx) for idx in pages]
    
    ##############################
    # Initialzie Variables
    ##############################
            
    catDF = []          
    prior_c1 = True     
    prior_c2 = True     
    
    # path iterates through each png image matching the page numbers found in PDFs
    for path in textract_paths:
        
        try:
            # temporary data frame object for balance sheet information
            res = runJob(bucket, path)
            
            # if Textract job did not fail we continue extraction
            if res[0]['JobStatus'] != 'FAILED':

                # format the Textract response type 
                doc = trp.Document(res)

                # iterate through document pages
                for page in doc.pages:
                    
                    # itterate through page tables
                    for table in page.tables: 
                        
                        # convert trp-table into dataframe object
                        df = trp2df(table)
                        
                        # retrieve balance sheet from table
                        balance_sheet = get_balance_sheet(df)
                        
                        if type(balance_sheet) is tuple:
                
                            bs, c1, c2 = balance_sheet      # unpack the return object
                            
                            # we append pages since asset and liablility tables are often seperate
                            # there is no loss of generality if asset and liability terms are in one table
                            catDF.append(bs)            
                            
                            ##############################
                            # Flag for split tables 
                            ##############################

                            # indicates no asset or liability term was read
                            # we are currenlty reading the asset term of the balance sheet
                            if c2 == True and prior_c1 == True and prior_c2 == True and c1 == False:
                                print('Balance sheet line items have been split across table\n')
                                prior_c1 = False

                            # indicates no asset term read, no previous asset term was read
                            # we are currenlty reading the liability term of the balance sheet
                            elif c1 == True and prior_c1 == True and c2 == False:
                                print('Asset line items may be read after liability line items\n')
                                prior_c2 = False

                            ##############################
                            # Balance Sheet Exportation 
                            ##############################

                            # 1) indicates both assets and liability terms were found in table
                            if (c2 == False and c1 == False) or (c2 == False and prior_c1 == False):
                                return pd.concat(catDF)

                            # 2) indicates liability term read before assets 
                            elif prior_c2 == False and c1 == False:
                                catDF.reverse()
                                return pd.concat(catDF)

                            else: pass
            
        # broad exeption to catch Textract parsing errors
        except:pass
    
    return None

# %%
def readForm(doc_pages:list) -> dict:
    """
    Function to transform AWS Textract object to a dictionary, by searching for key value pairs
    ------------------------------------------------------------------------------------------
    Input
        :param doc_pages: (type list)
            TRP page(s) for a AWS Textract response object corresponding to pages of a given document page 
    
    Output
        :return: type dict
            A python dictionary that maps KEYS (line items) with VALUES (corresponding records) for broker
            dealers balance sheet (e.g. {'Cash and cash equivalents : $ 12,513})
    """
    
    # initializing dictionary maps for KEY and VALUE pairs
    key_map = {}
    value_map = {}
    block_map = {}

    # iterate through document pages
    for page in doc_pages:

        # itterate through page tables
        for block in page.blocks: 

            # store the block id in map to retrive information later
            block_id = block['Id']
            block_map[block_id] = block

            # if Key-value set has been seen we deconstruct each KEY and VALUE map
            if block['BlockType'] == "KEY_VALUE_SET":

                # if KEY is labeled as entity type then we found Key, else we found VALUE
                if 'KEY' in block['EntityTypes']:
                    key_map[block_id] = block
                else:
                    value_map[block_id] = block
    
    # convert block objects to text dictionary map
    return get_kv_relationship(key_map, value_map, block_map)

# %%
def readText(doc_pages:list) -> dict:
    """
    Function to transform AWS Textract object to a dictionary of text values and confidence 
    ------------------------------------------------------------------------------------------
    Input
        :param doc_pages: (type list)
            TRP page(s) for a AWS Textract response object corresponding to pages of a given document page
    
    Output
        :return: type dict
            A python dictionary that maps TEXT (line items) with corresponding confidence figures as reported
            by AWS Textract object (e.g. {'Cash and cash equivalents : 99.97891})
    """
    # initializing dictionary maps for text
    text_map = {}
    
    # iterate through document pages
    for page in doc_pages:
        
        # itterate through page tables
        for block in page.blocks: 
            
            # if our block type is a line, we map the line text and confidence
            if block['BlockType'] == "LINE":
                text_map[block['Text']] = block['Confidence']
    
    # return completed text to confidence map
    return text_map

# %% [markdown]
# ## Extract Balance Sheet information

# %%
def textractParse(pdf_path:str, png_path:str, bucket:str) -> dict:
    """
    Function runs a Textract job and saves Balance Sheet information to .csv file in s3 folder 
    """
    errors = ''
    
    # temporary data frame object for balance sheet information
    res = runJob(bucket, pdf_path)
    
    # if Textract job did not fail we continue extraction
    if res[0]['JobStatus'] != 'FAILED':

        # perform OCR and return balance sheet with corresponding page object(s)
        tb_response = readTable(res)           
        
        # checks for type of return, if none then we log an error
        if type(tb_response) == tuple:
            
            # deconstruct the table response tuple into dataframe and page object parts
            df1, page_obj, page_num = tb_response
            print('\nPage number(s) for extraction in PNG are {}\n'.format(page_num))
            
            # try to extract from a PNG (we can still return a None here)
            df2 = readPNG(page_num, png_path)
            
            # provided balance sheet page number we select FORM and TEXT data
            forms_data = readForm(page_obj)      
            text_data = readText(page_obj)        
            
            print('\nTextract-PDF dataframe')
            print(df1)
            
            print('\nTextract-PNG dataframe')
            print(df2)
            
            return (df1, df2, forms_data, text_data, None)
        else:
            error = 'No Balance Sheet found, or parsing error'
            return (None, None, None, None, error)
    else:
        error = 'Could not parse, JOB FAILED'
        return (None, None, None, None, error)

# %% [markdown]
# ## Main File Execution

# %%
if __name__ == "__main__":

    # Amazon Textract client and Sagemaker session
    textract = boto3.client('textract')
    s3 = boto3.client('s3')
    session = Session()
    
    # initiate s3 bucket and corresponding data/output folder
    bucket = 'ran-s3-systemic-risk'
    
    data_png_folder = 'Input/X-17A-5-PNG-SUBSETS/'
    data_pdf_folder = 'Input/X-17A-5-PDF-SUBSETS/'
    
    output_png_folder = 'Output/X-17A-5-PNG-RAW/'
    output_pdf_folder = 'Output/X-17A-5-PDF-RAW/'
    
    temp_folder = 'Temp/'
    
    # csv directory where we store balance sheet information 
    output_png_csvs = np.array(session.list_s3_files(bucket, output_png_folder))
    output_pdf_csvs = np.array(session.list_s3_files(bucket, output_pdf_folder))
    
    # temp directory where JSON files is stored
    temp = np.array(session.list_s3_files(bucket, temp_folder))
    
    # pdf directory where we store the broker-dealer information 
    pdf_files = np.array(session.list_s3_files(bucket, data_pdf_folder))[1:]
    png_files = np.array(session.list_s3_files(bucket, data_png_folder))[1:]
    png_file_directory = list(set((map(lambda x: '/'.join(x.split('/')[:-1]), png_files))))
    
    # ===========================================================================
    # Load in Temp JSON files if present (FORM, TEXT, ERROR)
    # ===========================================================================
    
    if 'Temp/X17A5-FORMS.json' in temp:
        # retrieving downloaded files from s3 bucket
        s3.download_file(bucket, 'Temp/X17A5-FORMS.json', 'temp1.json')
        
        # read data on KEY-VALUE dictionary (i.e Textract FORMS) 
        with open('temp1.json', 'r') as f: forms_dictionary = json.loads(f.read())
        
        # remove local files for JSON
        os.remove('temp1.json')
    else:
        forms_dictionary = {}
    
    if 'Temp/X17A5-TEXT.json' in temp:
        # retrieving downloaded files from s3 bucket
        s3.download_file(bucket, 'Temp/X17A5-TEXT.json', 'temp2.json')
        
        # read data on TEXT-Confidence dictionary
        with open('temp2.json', 'r') as f: text_dictionary = json.loads(f.read())  
            
        # remove local files for JSON
        os.remove('temp2.json')
    else:
        text_dictionary = {}
    
    if 'Temp/ERROR-TEXTRACT.json' in temp:
        # retrieving downloaded files from s3 bucket
        s3.download_file(bucket, 'Temp/ERROR-TEXTRACT.json', 'temp3.json')
        
        # read data on errors derived from Textract
        with open('temp3.json', 'r') as f: error_dictionary = json.loads(f.read()) 
            
        # remove local files for JSON
        os.remove('temp3.json')
    else:
        error_dictionary = {}
    
    # ===========================================================================
    # Perform Textract analysis on PDFs and PNGs
    # ===========================================================================
    
    # e.g. ['Input/X-17A-5-PDF-SUBSETS/42352-2012-02-29-subset.pdf'] otherwise pdf_files (full sample)
    select_sample = ['Input/X-17A-5-PDF-SUBSETS/808379-2017-03-01-subset.pdf',
                     'Input/X-17A-5-PDF-SUBSETS/808379-2018-03-01-subset.pdf', 
                     'Input/X-17A-5-PDF-SUBSETS/808379-2020-02-20-subset.pdf', 
                     'Input/X-17A-5-PDF-SUBSETS/808379-2021-03-02-subset.pdf']

    for pdf_paths in pdf_files:
        
        # baseFile name to name export .csv file e.g. 1224385-2004-03-01.csv
        basefile = pdf_paths.split('/')[-1].split('-subset')[0]
        fileName = basefile + '.csv'
        print('\nPerforming OCR for {}'.format(fileName))
        
        # if file is not found in directory we extract the balance sheet
        # WE LOOK TO AVOID RE-RUNNING OLD TEXTRACT PARSES TO SAVE TIME
        if (output_pdf_folder + fileName not in output_pdf_csvs):
            
            # run Textract OCR job and extract the parsed data 
            png_paths = data_png_folder + basefile + '/'
            df1, df2, forms_data, text_data, error = textractParse(pdf_paths, png_paths, bucket)

            # if no error is reported we save FORMS, TEXT, DataFrame
            if error is None:

                # store accompanying information for JSONs
                forms_dictionary[basefile] = forms_data
                text_dictionary[basefile]  = text_data
                print(text_data)
                
                # writing data frame to .csv file
                df1.to_csv(fileName, index=False)

                # save contents to AWS S3 bucket
                with open(fileName, 'rb') as data:
                    s3.put_object(Bucket=bucket, Key=output_pdf_folder + fileName, Body=data)
                
                # writing data frame to .csv file extracted from PNG
                if df2 is not None:
                    df2.to_csv(fileName, index=False)
                    
                    with open(fileName, 'rb') as data:
                        s3.put_object(Bucket=bucket, Key=output_png_folder + fileName, Body=data)
    
                # remove local file after it has been created
                os.remove(fileName)

                print('-----------------------------------------------------')
                print('Saved {} file to s3 bucket'.format(fileName))
            
            else:
                error_dictionary[basefile] = error
                
        else:
            print('{} has been downloaded'.format(fileName))
    
    # ===========================================================================
    # Save JSON files for updated figures (FORM, TEXT, ERROR)
    # ===========================================================================
    
    # write to a JSON file for FORMS 
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-FORMS.json', 'w') as file: 
        json.dump(forms_dictionary, file)
        file.close()
    
    # save contents to AWS S3 bucket
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-FORMS.json', 'rb') as data: 
        s3.upload_fileobj(data, bucket, 'Temp/X17A5-FORMS.json')
    
    # ---------------------------------------------------------------------------
    
    # write to a JSON file for TEXT 
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-TEXT.json', 'w') as file: 
        json.dump(text_dictionary, file)
        file.close()
    
    # save contents to AWS S3 bucket
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/X17A5-TEXT.json', 'rb') as data: 
        s3.upload_fileobj(data, bucket, 'Temp/X17A5-TEXT.json')
    
    # ---------------------------------------------------------------------------
    
    # write to a JSON file for FORMS 
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/ERROR-TEXTRACT.json', 'w') as file: 
        json.dump(error_dictionary, file)
        file.close()
    
    # save contents to AWS S3 bucket
    with open('/home/ec2-user/SageMaker/SEC_X17A5/temp/ERROR-TEXTRACT.json', 'rb') as data: 
        s3.upload_fileobj(data, bucket, 'Temp/ERROR-TEXTRACT.json')

    print('\n\nFinished performing OCR on parsed FOCUS reports.')
# Out:
# Performing OCR for 1101180-2002-02-28.csv
# 1101180-2002-02-28.csv has been downloaded
#
# Performing OCR for 1101180-2003-02-28.csv
# 1101180-2003-02-28.csv has been downloaded
#
# Performing OCR for 1101180-2004-02-25.csv
# 1101180-2004-02-25.csv has been downloaded
#
# Performing OCR for 1101180-2005-03-02.csv
# 1101180-2005-03-02.csv has been downloaded
#
# Performing OCR for 1101180-2006-03-01.csv
# 1101180-2006-03-01.csv has been downloaded
#
# Performing OCR for 1101180-2007-03-02.csv
# Started job with id: 6cda3ca66c36f332fb066e6507fd36ab76e47b00d8b98c70bb787e21e59abc0f
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Performing OCR for 1101180-2008-02-29.csv
# 1101180-2008-02-29.csv has been downloaded
#
# Performing OCR for 1101180-2009-05-12.csv
# 1101180-2009-05-12.csv has been downloaded
#
# Performing OCR for 1101180-2009-07-20.csv
# 1101180-2009-07-20.csv has been downloaded
#
# Performing OCR for 1101180-2010-03-02.csv
# 1101180-2010-03-02.csv has been downloaded
#
# Performing OCR for 1101180-2011-03-22.csv
# 1101180-2011-03-22.csv has been downloaded
#
# Performing OCR for 1146184-2004-03-01.csv
# 1146184-2004-03-01.csv has been downloaded
#
# Performing OCR for 1146184-2005-03-02.csv
# Started job with id: ebca1eff2213367f1a8d8b3212718b5a18628486763af1ff8606736901dca471
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
#
# Performing OCR for 1146184-2006-03-01.csv
# 1146184-2006-03-01.csv has been downloaded
#
# Performing OCR for 1146184-2007-02-26.csv
# 1146184-2007-02-26.csv has been downloaded
#
# Performing OCR for 1146184-2008-02-29.csv
# 1146184-2008-02-29.csv has been downloaded
#
# Performing OCR for 1146184-2009-03-02.csv
# 1146184-2009-03-02.csv has been downloaded
#
# Performing OCR for 1146184-2010-02-25.csv
# 1146184-2010-02-25.csv has been downloaded
#
# Performing OCR for 1146184-2010-03-09.csv
# Started job with id: 9a075183554730553b2625c8512ab2fb17d147763f6604ebcaef407482605faf
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
#
# Performing OCR for 1146184-2011-02-25.csv
# 1146184-2011-02-25.csv has been downloaded
#
# Performing OCR for 1146184-2012-02-28.csv
# 1146184-2012-02-28.csv has been downloaded
#
# Performing OCR for 1146184-2013-02-26.csv
# 1146184-2013-02-26.csv has been downloaded
#
# Performing OCR for 1146184-2014-02-28.csv
# Started job with id: 1a3b3f0b5f8d3d0ade00a4d793c1c1a2d402ed6e314025f9263689ef319d1b29
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
#
# Page number(s) for extraction in PNG are [5]
#
# Started job with id: d63e21c503fb8498f162a0f275771f042b2f4d6d9576f26d737c101d54587bb3
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Textract-PDF dataframe
#                                                     0           1
# 0                                                Cash   $ 424,221
# 1            Cash segregated under federal regulation      26,000
# 2                                 Securities borrowed  21,382,571
# 3                     Securities owned, at fair value   8,991,529
# 4    Collateral held under securities loan agreements   9,223,910
# 5   Receivable from clearing organizations custodians      75,431
# 6   Receivable from brokers, dealers, and futures ...      39,665
# 7   Exchange memberships and trading rights (fair ...      14,077
# 8     Securities purchased under agreements to resell      13,094
# 9                                Dividends receivable      12,017
# 10                          Receivable for order flow      10,547
# 11                                       Other assets       8,899
# 12               Receivable from affiliated customers       5,433
# 13
# 14
# 15                                       Liabilities:
# 16
# 17  Securities sold, not yet purchased, at fair value   4,749,801
# 18
# 19  Payable to brokers, dealers, and futures commi...   3,814,113
# 20                              Payable to affiliates     105,556
# 21                             Payable for order flow      39,934
# 22   Exchange, clearance, and regulatory fees payable      16,800
#
# Textract-PNG dataframe
#                                                     0             1
# 0                                                Cash     $ 424,221
# 1            Cash segregated under federal regulation        26,000
# 2                                 Securities borrowed    21,382,571
# 3                     Securities owned, at fair value     8,991,529
# 4    Collateral held under securities loan agreements     9,223,910
# 5   Receivable from clearing organizations custodians        75,431
# 6   Receivable from brokers, dealers, and futures ...        39,665
# 7   Exchange memberships and trading rights (fair ...        14,077
# 8     Securities purchased under agreements to resell        13,094
# 9                                Dividends receivable        12,017
# 10                          Receivable for order flow        10,547
# 11                                       Other assets         8,899
# 12               Receivable from affiliated customers         5,433
# 13                                       Total assets  $ 40,227,394
# 14                   LIABILITIES AND MEMBER'S CAPITAL
# 15                                       Liabilities:
# {'CITADEL SECURITIES LLC': 99.76828002929688, 'STATEMENT OF FINANCIAL CONDITION': 99.85688018798828, 'December 31, 2013': 99.90298461914062, '(Expressed in U.S. dollars in thousands)': 99.92591094970703, 'ASSETS': 99.86907196044922, 'Assets:': 99.94612121582031, 'Cash': 99.96440124511719, '$': 99.8272933959961, '424,221': 99.13911437988281, 'Cash segregated under federal regulation': 99.96385955810547, '26,000': 99.80785369873047, 'Securities borrowed': 99.96395111083984, '21,382,571': 99.41455078125, 'Securities owned, at fair value': 99.75308227539062, '8,991,529': 99.82649993896484, 'Collateral held under securities loan agreements': 99.96054077148438, '9,223,910': 99.24410247802734, 'Receivable from clearing organizations custodians': 99.91124725341797, '75,431': 99.87857055664062, 'Receivable from brokers, dealers, and futures commission merchants': 94.66114044189453, '39,665': 99.91802215576172, 'Exchange memberships and trading rights (fair value $14,346) (Note 2)': 99.56249237060547, '14,077': 99.90303802490234, 'Securities purchased under agreements to resell': 99.96693420410156, '13,094': 99.86139678955078, 'Dividends receivable': 99.98042297363281, '12,017': 99.89237213134766, 'Receivable for order flow': 99.96508026123047, '10,547': 99.90375518798828, 'Other assets': 99.94281005859375, '8,899': 99.92252349853516, 'Receivable from affiliated customers': 99.96271514892578, '5,433': 99.80632019042969, 'Total assets': 99.96305847167969, '40,227,394': 99.06999969482422, "LIABILITIES AND MEMBER'S CAPITAL": 99.7922592163086, 'Liabilities:': 98.90552520751953, 'Securities loaned': 99.95610046386719, '23,393,622': 99.73339080810547, 'Securities sold, not yet purchased, at fair value': 99.93282318115234, '4,749,801': 99.7418441772461, 'Securities sold under agreements to repurchase': 99.96331024169922, '7,155,987': 99.83556365966797, 'Payable to brokers, dealers, and futures commission merchants': 99.86415100097656, '3,814,113': 99.79264831542969, 'Payable to affiliates': 99.92079162597656, '105,556': 99.92660522460938, 'Payable for order flow': 99.95817565917969, '39,934': 99.68568420410156, 'Exchange, clearance, and regulatory fees payable': 99.778076171875, '16,800': 99.9056396484375, 'Other liabilities': 99.96363830566406, '4,009': 99.83024597167969, 'Interest payable': 99.94857025146484, '2,260': 99.79358673095703, 'Dividends payable': 99.97211456298828, '1,705': 99.64680480957031, 'Total liabilities': 99.89606475830078, '39,283,787': 99.06466674804688, "Member's capital": 99.95541381835938, '943,607': 98.60015869140625, "Total liabilities and member's capital": 99.92156982421875, 'See notes to statement of financial condition.': 99.88211059570312, '-2-': 99.50543975830078}
# -----------------------------------------------------
# Saved 1146184-2014-02-28.csv file to s3 bucket
#
# Performing OCR for 1146184-2015-02-25.csv
# 1146184-2015-02-25.csv has been downloaded
#
# Performing OCR for 1146184-2016-02-24.csv
# 1146184-2016-02-24.csv has been downloaded
#
# Performing OCR for 1146184-2017-02-24.csv
# 1146184-2017-02-24.csv has been downloaded
#
# Performing OCR for 1146184-2018-02-27.csv
# Started job with id: de8dcde61087f965eddcb4c38c935d9cbb820710c52b8f282173d70c7b854c9d
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
# Resultset page recieved: 8
# Resultset page recieved: 9
# Resultset page recieved: 10
# Resultset page recieved: 11
# Resultset page recieved: 12
# Resultset page recieved: 13
# Asset line items may be read after liability line items
#
#
# Page number(s) for extraction in PNG are [7]
#
# Started job with id: e473b78203edbdbdc4b8fa0b1849f535a4f0d43afea5d64b416c9c1976eac903
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Asset line items may be read after liability line items
#
#
# Textract-PDF dataframe
#                                                     0             1
# 0                                             Assets:
# 1                                                Cash     $ 467,092
# 2                     Securities owned, at fair value    25,688,918
# 3     Securities purchased under agreements to resell     3,607,668
# 4                                 Securities borrowed     2,184,243
# 5              Receivable from clearing organizations       323,471
# 6                 Receivable from brokers and dealers       288,947
# 7          Liquidity rebate and order flow receivable        39,627
# 8                                 Interest receivable        30,067
# 9                                        Other assets        27,282
# 10  Exchange memberships and trading rights (fair ...        24,606
# 11                               Dividends receivable        11,054
# 12                                       Total assets  $ 32,692,975
# 0                                        Liabilities:
# 1   Securities sold, not yet purchased, at fair value  $ 17,245,913
# 2   Payable to brokers, dealers, clearing organiza...     9,443,405
# 3      Securities sold under agreements to repurchase     4,378,857
# 4                Payable for liquidity and order flow        88,920
# 5                               Payable to affiliates        69,691
# 6                                   Securities loaned        58,581
# 7    Exchange, clearance, and regulatory fees payable        32,027
# 8                                    Interest payable        24,944
# 9                                   Dividends payable        18,342
# 10                                  Other liabilities         1,185
# 11  Total liabilities before subordinated loans an...    31,361,865
# 12            Subordinated loans and accrued interest       354,575
# 13                                  Total liabilities    31,716,440
# 14                                   Member's capital       976,535
# 15             Total liabilities and member's capital  $ 32,692,975
#
# Textract-PNG dataframe
#                                                     0             1
# 0                                             Assets:
# 1                                                Cash     $ 467,092
# 2                     Securities owned, at fair value    25,688,918
# 3     Securities purchased under agreements to resell     3,607,668
# 4                                 Securities borrowed     2,184,243
# 5              Receivable from clearing organizations       323,471
# 6                 Receivable from brokers and dealers       288,947
# 7          Liquidity rebate and order flow receivable        39,627
# 8                                 Interest receivable        30,067
# 9                                        Other assets        27,282
# 10  Exchange memberships and trading rights (fair ...        24,606
# 11                               Dividends receivable        11,054
# 12                                       Total assets  $ 32,692,975
# 0                                        Liabilities:
# 1   Securities sold, not yet purchased, at fair value  $ 17,245,913
# 2   Payable to brokers, dealers, clearing organiza...     9,443,405
# 3      Securities sold under agreements to repurchase     4,378,857
# 4                Payable for liquidity and order flow        88,920
# 5                               Payable to affiliates        69,691
# 6                                   Securities loaned        58,581
# 7    Exchange, clearance, and regulatory fees payable        32,027
# 8                                    Interest payable        24,944
# 9                                   Dividends payable        18,342
# 10                                  Other liabilities         1,185
# 11  Total liabilities before subordinated loans an...    31,361,865
# 12            Subordinated loans and accrued interest       354,575
# 13                                  Total liabilities    31,716,440
# 14                                   Member's capital       976,535
# 15             Total liabilities and member's capital  $ 32,692,975
# {'CITADEL SECURITIES LLC': 99.6484375, 'Statement of Financial Condition': 99.77030944824219, '(Expressed in U.S. dollars in thousands)': 99.87438201904297, 'ASSETS': 99.48526763916016, 'As of December 31, 2017': 99.67564392089844, 'Assets:': 99.73113250732422, 'Cash': 99.90309143066406, '$': 99.87285614013672, '467,092': 99.15291595458984, 'Securities owned, at fair value': 99.91744995117188, '25,688,918': 99.30237579345703, 'Securities purchased under agreements to resell': 99.94718170166016, '3,607,668': 96.47393035888672, 'Securities borrowed': 99.9122314453125, '2,184,243': 98.97218322753906, 'Receivable from clearing organizations': 99.76284790039062, '323,471': 99.44904327392578, 'Receivable from brokers and dealers': 99.92876434326172, '288,947': 99.48175048828125, 'Liquidity rebate and order flow receivable': 99.95490264892578, '39,627': 99.245361328125, 'Interest receivable': 99.88167572021484, '30,067': 99.52403259277344, 'Other assets': 99.97826385498047, '27,282': 99.1493911743164, 'Exchange memberships and trading rights (fair value $24,517) (Note 2)': 99.74413299560547, '24,606': 99.57296752929688, 'Dividends receivable': 99.95306396484375, '11,054': 99.42019653320312, 'Total assets': 99.92805480957031, '$ 32,692,975': 99.15361022949219, "LIABILITIES AND MEMBER'S CAPITAL": 99.63607025146484, 'Liabilities:': 99.48938751220703, 'Securities sold, not yet purchased, at fair value': 99.96134948730469, '$ 17,245,913': 99.45892333984375, 'Payable to brokers, dealers, clearing organizations, and custodians': 99.7511978149414, '9,443,405': 99.47821807861328, 'Securities sold under agreements to repurchase': 99.93743133544922, '4,378,857': 99.73693084716797, 'Payable for liquidity and order flow': 99.95474243164062, '88,920': 99.5390625, 'Payable to affiliates': 99.82032012939453, '69,691': 99.30265808105469, 'Securities loaned': 99.9245834350586, '58,581': 99.84818267822266, 'Exchange, clearance, and regulatory fees payable': 99.42579650878906, '32,027': 99.61235046386719, 'Interest payable': 99.57076263427734, '24,944': 99.37239074707031, 'Dividends payable': 99.9609146118164, '18,342': 99.69581604003906, 'Other liabilities': 99.90373229980469, '1,185': 99.86946868896484, 'Total liabilities before subordinated loans and accrued interest': 99.95801544189453, '31,361,865': 99.2468032836914, 'Subordinated loans and accrued interest': 99.95404815673828, '354,575': 99.88719940185547, 'Total liabilities': 99.87651062011719, '31,716,440': 98.32624816894531, "Member's capital": 99.82958221435547, '976,535': 99.52116394042969, "Total liabilities and member's capital": 99.91192626953125, 'See notes to statement of financial condition.': 99.83472442626953, '2': 99.71189880371094}
# -----------------------------------------------------
# Saved 1146184-2018-02-27.csv file to s3 bucket
#
# Performing OCR for 1146184-2019-02-28.csv
# 1146184-2019-02-28.csv has been downloaded
#
# Performing OCR for 1146184-2020-02-28.csv
# Started job with id: 13cb021fcc40decadb90782a1b183b2c80923c94404b3a0798dec87f7b2f96af
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
# Resultset page recieved: 8
# Resultset page recieved: 9
# Resultset page recieved: 10
# Resultset page recieved: 11
# Resultset page recieved: 12
# Asset line items may be read after liability line items
#
#
# Page number(s) for extraction in PNG are [7]
#
# Started job with id: 7ce1b3aa57126942b8f57bb99722895d39e2ecf0fef17d180a39bf2c0e264b4e
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Asset line items may be read after liability line items
#
#
# Textract-PDF dataframe
#                                                     0                        1
# 0                                              ASSETS  As of December 31, 2019
# 1                                             Assets:
# 2                                                Cash                    $ 438
# 3                     Securities owned, at fair value                   28,634
# 4                                 Securities borrowed                    3,070
# 5                 Receivable from brokers and dealers                    1,195
# 6   Receivable from clearing organizations and cus...                      556
# 7     Securities purchased under agreements to resell                      328
# 8                                        Other assets                       77
# 9                                 Interest receivable                       34
# 10                               Dividends receivable                       14
# 11                                       Total assets                 $ 34,346
# 0                                        Liabilities:
# 1   Securities sold, not yet purchased, at fair value                 $ 25,270
# 2      Securities sold under agreements to repurchase                    6,352
# 3   Payable to brokers, dealers, and clearing orga...                      387
# 4                          Loans payable to affiliate                      391
# 5                               Payable to affiliates                       88
# 6                Payable for liquidity and order flow                       88
# 7                                   Securities loaned                       46
# 8    Exchange, clearance, and regulatory fees payable                       31
# 9                                   Other liabilities                       37
# 10                                  Total liabilities                   32,690
# 11                                   Member's capital                    1,656
# 12             Total liabilities and member's capital                 $ 34,346
#
# Textract-PNG dataframe
#                                                     0                        1
# 0                                              ASSETS  As of December 31, 2019
# 1                                             Assets:
# 2                                                Cash                    $ 438
# 3                     Securities owned, at fair value                   28,634
# 4                                 Securities borrowed                    3,070
# 5                 Receivable from brokers and dealers                    1,195
# 6   Receivable from clearing organizations and cus...                      556
# 7     Securities purchased under agreements to resell                      328
# 8                                        Other assets                       77
# 9                                 Interest receivable                       34
# 10                               Dividends receivable                       14
# 11                                       Total assets                 $ 34,346
# 0                                        Liabilities:
# 1   Securities sold, not yet purchased, at fair value                 $ 25,270
# 2      Securities sold under agreements to repurchase                    6,352
# 3   Payable to brokers, dealers, and clearing orga...                      387
# 4                          Loans payable to affiliate                      391
# 5                               Payable to affiliates                       88
# 6                Payable for liquidity and order flow                       88
# 7                                   Securities loaned                       46
# 8    Exchange, clearance, and regulatory fees payable                       31
# 9                                   Other liabilities                       37
# 10                                  Total liabilities                   32,690
# 11                                   Member's capital                    1,656
# 12             Total liabilities and member's capital                 $ 34,346
# {'CITADEL SECURITIES LLC': 99.60930633544922, 'Statement of Financial Condition': 99.7064208984375, '(Expressed in U.S. dollars in millions)': 99.65506744384766, 'ASSETS': 99.32245635986328, 'As of December 31, 2019': 99.8286361694336, 'Assets:': 99.72042083740234, 'Cash': 99.93551635742188, '$': 99.86894989013672, '438': 99.77271270751953, 'Securities owned, at fair value': 99.84732055664062, '28,634': 98.7904052734375, 'Securities borrowed': 99.83426666259766, '3,070': 99.45799255371094, 'Receivable from brokers and dealers': 99.91328430175781, '1,195': 99.80379486083984, 'Receivable from clearing organizations and custodian': 99.86131286621094, '556': 99.90985107421875, 'Securities purchased under agreements to resell': 99.86854553222656, '328': 99.79891967773438, 'Other assets': 99.92154693603516, '77': 99.94991302490234, 'Interest receivable': 99.09158325195312, '34': 99.89775848388672, 'Dividends receivable': 99.9461898803711, '14': 99.87661743164062, 'Total assets': 99.79974365234375, '34,346': 99.14874267578125, "LIABILITIES AND MEMBER'S CAPITAL": 99.58992004394531, 'Liabilities:': 98.57286071777344, 'Securities sold, not yet purchased, at fair value': 99.86446380615234, '25,270': 99.18316650390625, 'Securities sold under agreements to repurchase': 99.89691162109375, '6,352': 99.73595428466797, 'Payable to brokers, dealers, and clearing organizations': 99.71376037597656, '387': 99.76416778564453, 'Loans payable to affiliate': 99.82263946533203, '391': 99.77838897705078, 'Payable to affiliates': 99.8095703125, '88': 99.8765640258789, 'Payable for liquidity and order flow': 99.92961883544922, 'Securities loaned': 99.86552429199219, '46': 99.91126251220703, 'Exchange, clearance, and regulatory fees payable': 99.22058868408203, '31': 99.9222412109375, 'Other liabilities': 99.9244384765625, '37': 99.88802337646484, 'Total liabilities': 99.85411834716797, '32,690': 99.53235626220703, "Member's capital": 99.77099609375, '1,656': 99.38665771484375, "Total liabilities and member's capital": 99.84049987792969, 'See notes to statement of financial condition.': 99.7499008178711, '1': 99.29940032958984}
# -----------------------------------------------------
# Saved 1146184-2020-02-28.csv file to s3 bucket
#
# Performing OCR for 1146184-2021-02-25.csv
# 1146184-2021-02-25.csv has been downloaded
#
# Performing OCR for 1215680-2004-03-01.csv
# 1215680-2004-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2005-03-01.csv
# 1215680-2005-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2006-03-01.csv
# 1215680-2006-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2007-03-01.csv
# 1215680-2007-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2008-02-29.csv
# 1215680-2008-02-29.csv has been downloaded
#
# Performing OCR for 1215680-2009-03-04.csv
# 1215680-2009-03-04.csv has been downloaded
#
# Performing OCR for 1215680-2010-02-26.csv
# 1215680-2010-02-26.csv has been downloaded
#
# Performing OCR for 1215680-2011-03-01.csv
# 1215680-2011-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2012-02-29.csv
# 1215680-2012-02-29.csv has been downloaded
#
# Performing OCR for 1215680-2013-03-01.csv
# 1215680-2013-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2014-02-28.csv
# 1215680-2014-02-28.csv has been downloaded
#
# Performing OCR for 1215680-2015-02-27.csv
# 1215680-2015-02-27.csv has been downloaded
#
# Performing OCR for 1215680-2016-06-16.csv
# 1215680-2016-06-16.csv has been downloaded
#
# Performing OCR for 1215680-2017-03-07.csv
# 1215680-2017-03-07.csv has been downloaded
#
# Performing OCR for 1215680-2018-03-01.csv
# 1215680-2018-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2019-03-01.csv
# 1215680-2019-03-01.csv has been downloaded
#
# Performing OCR for 1215680-2020-03-02.csv
# 1215680-2020-03-02.csv has been downloaded
#
# Performing OCR for 1215680-2021-03-02.csv
# 1215680-2021-03-02.csv has been downloaded
#
# Performing OCR for 1224385-2004-03-01.csv
# 1224385-2004-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2005-03-01.csv
# 1224385-2005-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2006-03-01.csv
# 1224385-2006-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2007-03-01.csv
# 1224385-2007-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2008-02-29.csv
# 1224385-2008-02-29.csv has been downloaded
#
# Performing OCR for 1224385-2009-03-02.csv
# 1224385-2009-03-02.csv has been downloaded
#
# Performing OCR for 1224385-2010-03-12.csv
# 1224385-2010-03-12.csv has been downloaded
#
# Performing OCR for 1224385-2011-03-01.csv
# 1224385-2011-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2012-02-29.csv
# 1224385-2012-02-29.csv has been downloaded
#
# Performing OCR for 1224385-2013-03-01.csv
# 1224385-2013-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2014-03-04.csv
# 1224385-2014-03-04.csv has been downloaded
#
# Performing OCR for 1224385-2015-03-02.csv
# 1224385-2015-03-02.csv has been downloaded
#
# Performing OCR for 1224385-2016-02-29.csv
# 1224385-2016-02-29.csv has been downloaded
#
# Performing OCR for 1224385-2017-03-01.csv
# 1224385-2017-03-01.csv has been downloaded
#
# Performing OCR for 1224385-2018-02-28.csv
# 1224385-2018-02-28.csv has been downloaded
#
# Performing OCR for 1224385-2019-02-28.csv
# 1224385-2019-02-28.csv has been downloaded
#
# Performing OCR for 1224385-2020-02-28.csv
# 1224385-2020-02-28.csv has been downloaded
#
# Performing OCR for 1224385-2021-02-26.csv
# 1224385-2021-02-26.csv has been downloaded
#
# Performing OCR for 1261467-2005-03-08.csv
# 1261467-2005-03-08.csv has been downloaded
#
# Performing OCR for 1261467-2006-03-01.csv
# 1261467-2006-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2007-03-02.csv
# 1261467-2007-03-02.csv has been downloaded
#
# Performing OCR for 1261467-2008-02-29.csv
# 1261467-2008-02-29.csv has been downloaded
#
# Performing OCR for 1261467-2009-03-02.csv
# 1261467-2009-03-02.csv has been downloaded
#
# Performing OCR for 1261467-2010-03-01.csv
# 1261467-2010-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2011-03-01.csv
# 1261467-2011-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2012-02-29.csv
# 1261467-2012-02-29.csv has been downloaded
#
# Performing OCR for 1261467-2013-03-01.csv
# 1261467-2013-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2014-03-04.csv
# 1261467-2014-03-04.csv has been downloaded
#
# Performing OCR for 1261467-2015-03-02.csv
# 1261467-2015-03-02.csv has been downloaded
#
# Performing OCR for 1261467-2016-03-01.csv
# 1261467-2016-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2017-03-01.csv
# 1261467-2017-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2018-02-28.csv
# 1261467-2018-02-28.csv has been downloaded
#
# Performing OCR for 1261467-2018-04-13.csv
# 1261467-2018-04-13.csv has been downloaded
#
# Performing OCR for 1261467-2019-03-01.csv
# 1261467-2019-03-01.csv has been downloaded
#
# Performing OCR for 1261467-2020-03-02.csv
# Started job with id: ab47a80dd62de9ef1cbfbab6dc6c08dbad9a21635103df3c9760896529713e36
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Performing OCR for 1261467-2021-03-01.csv
# 1261467-2021-03-01.csv has been downloaded
#
# Performing OCR for 1591458-2015-02-20.csv
# 1591458-2015-02-20.csv has been downloaded
#
# Performing OCR for 1591458-2016-02-18.csv
# 1591458-2016-02-18.csv has been downloaded
#
# Performing OCR for 1591458-2017-01-23.csv
# 1591458-2017-01-23.csv has been downloaded
#
# Performing OCR for 1591458-2018-02-28.csv
# 1591458-2018-02-28.csv has been downloaded
#
# Performing OCR for 1591458-2019-02-28.csv
# 1591458-2019-02-28.csv has been downloaded
#
# Performing OCR for 1591458-2020-02-28.csv
# 1591458-2020-02-28.csv has been downloaded
#
# Performing OCR for 1591458-2021-02-26.csv
# 1591458-2021-02-26.csv has been downloaded
#
# Performing OCR for 1616344-2016-02-24.csv
# 1616344-2016-02-24.csv has been downloaded
#
# Performing OCR for 1616344-2017-02-24.csv
# 1616344-2017-02-24.csv has been downloaded
#
# Performing OCR for 1616344-2018-02-27.csv
# 1616344-2018-02-27.csv has been downloaded
#
# Performing OCR for 1616344-2019-02-28.csv
# 1616344-2019-02-28.csv has been downloaded
#
# Performing OCR for 1616344-2020-02-27.csv
# 1616344-2020-02-27.csv has been downloaded
#
# Performing OCR for 1616344-2021-02-25.csv
# 1616344-2021-02-25.csv has been downloaded
#
# Performing OCR for 1675365-2021-03-01.csv
# 1675365-2021-03-01.csv has been downloaded
#
# Performing OCR for 200565-2002-03-01.csv
# 200565-2002-03-01.csv has been downloaded
#
# Performing OCR for 200565-2003-03-03.csv
# 200565-2003-03-03.csv has been downloaded
#
# Performing OCR for 200565-2004-03-01.csv
# 200565-2004-03-01.csv has been downloaded
#
# Performing OCR for 200565-2005-03-01.csv
# 200565-2005-03-01.csv has been downloaded
#
# Performing OCR for 200565-2006-03-03.csv
# 200565-2006-03-03.csv has been downloaded
#
# Performing OCR for 200565-2007-03-01.csv
# 200565-2007-03-01.csv has been downloaded
#
# Performing OCR for 200565-2008-03-03.csv
# 200565-2008-03-03.csv has been downloaded
#
# Performing OCR for 200565-2008-04-03.csv
# 200565-2008-04-03.csv has been downloaded
#
# Performing OCR for 200565-2009-03-02.csv
# 200565-2009-03-02.csv has been downloaded
#
# Performing OCR for 200565-2010-03-01.csv
# 200565-2010-03-01.csv has been downloaded
#
# Performing OCR for 200565-2011-03-02.csv
# 200565-2011-03-02.csv has been downloaded
#
# Performing OCR for 200565-2012-02-29.csv
# 200565-2012-02-29.csv has been downloaded
#
# Performing OCR for 200565-2013-03-05.csv
# 200565-2013-03-05.csv has been downloaded
#
# Performing OCR for 200565-2014-03-04.csv
# 200565-2014-03-04.csv has been downloaded
#
# Performing OCR for 200565-2015-03-02.csv
# 200565-2015-03-02.csv has been downloaded
#
# Performing OCR for 200565-2016-04-07.csv
# 200565-2016-04-07.csv has been downloaded
#
# Performing OCR for 200565-2017-03-03.csv
# 200565-2017-03-03.csv has been downloaded
#
# Performing OCR for 200565-2018-03-02.csv
# 200565-2018-03-02.csv has been downloaded
#
# Performing OCR for 200565-2019-03-01.csv
# Started job with id: 50beabb29b3bb22090546e27a8fbe70d38a1e833ec7618bdad734ae160f5d790
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
#
# Performing OCR for 200565-2020-03-03.csv
# 200565-2020-03-03.csv has been downloaded
#
# Performing OCR for 200565-2021-03-01.csv
# 200565-2021-03-01.csv has been downloaded
#
# Performing OCR for 230611-2002-03-01.csv
# 230611-2002-03-01.csv has been downloaded
#
# Performing OCR for 230611-2003-03-03.csv
# 230611-2003-03-03.csv has been downloaded
#
# Performing OCR for 230611-2004-03-01.csv
# 230611-2004-03-01.csv has been downloaded
#
# Performing OCR for 230611-2005-03-01.csv
# 230611-2005-03-01.csv has been downloaded
#
# Performing OCR for 230611-2006-03-01.csv
# 230611-2006-03-01.csv has been downloaded
#
# Performing OCR for 230611-2007-03-01.csv
# 230611-2007-03-01.csv has been downloaded
#
# Performing OCR for 230611-2008-02-29.csv
# 230611-2008-02-29.csv has been downloaded
#
# Performing OCR for 230611-2009-03-02.csv
# 230611-2009-03-02.csv has been downloaded
#
# Performing OCR for 230611-2009-03-09.csv
# 230611-2009-03-09.csv has been downloaded
#
# Performing OCR for 230611-2010-03-01.csv
# 230611-2010-03-01.csv has been downloaded
#
# Performing OCR for 230611-2011-03-01.csv
# 230611-2011-03-01.csv has been downloaded
#
# Performing OCR for 230611-2012-02-29.csv
# 230611-2012-02-29.csv has been downloaded
#
# Performing OCR for 230611-2013-03-01.csv
# 230611-2013-03-01.csv has been downloaded
#
# Performing OCR for 230611-2014-03-06.csv
# 230611-2014-03-06.csv has been downloaded
#
# Performing OCR for 230611-2015-03-02.csv
# 230611-2015-03-02.csv has been downloaded
#
# Performing OCR for 230611-2016-02-29.csv
# 230611-2016-02-29.csv has been downloaded
#
# Performing OCR for 230611-2017-03-03.csv
# 230611-2017-03-03.csv has been downloaded
#
# Performing OCR for 230611-2018-03-01.csv
# 230611-2018-03-01.csv has been downloaded
#
# Performing OCR for 230611-2019-03-01.csv
# 230611-2019-03-01.csv has been downloaded
#
# Performing OCR for 230611-2020-03-03.csv
# 230611-2020-03-03.csv has been downloaded
#
# Performing OCR for 230611-2021-03-01.csv
# 230611-2021-03-01.csv has been downloaded
#
# Performing OCR for 26617-2002-05-30.csv
# 26617-2002-05-30.csv has been downloaded
#
# Performing OCR for 26617-2003-06-02.csv
# 26617-2003-06-02.csv has been downloaded
#
# Performing OCR for 26617-2004-05-27.csv
# 26617-2004-05-27.csv has been downloaded
#
# Performing OCR for 26617-2005-05-26.csv
# 26617-2005-05-26.csv has been downloaded
#
# Performing OCR for 26617-2006-05-26.csv
# 26617-2006-05-26.csv has been downloaded
#
# Performing OCR for 26617-2007-05-29.csv
# 26617-2007-05-29.csv has been downloaded
#
# Performing OCR for 26617-2008-05-29.csv
# 26617-2008-05-29.csv has been downloaded
#
# Performing OCR for 26617-2009-05-29.csv
# 26617-2009-05-29.csv has been downloaded
#
# Performing OCR for 26617-2009-06-08.csv
# 26617-2009-06-08.csv has been downloaded
#
# Performing OCR for 26617-2010-05-28.csv
# 26617-2010-05-28.csv has been downloaded
#
# Performing OCR for 26617-2011-05-31.csv
# 26617-2011-05-31.csv has been downloaded
#
# Performing OCR for 26617-2012-05-30.csv
# 26617-2012-05-30.csv has been downloaded
#
# Performing OCR for 26617-2013-05-30.csv
# 26617-2013-05-30.csv has been downloaded
#
# Performing OCR for 26617-2014-05-29.csv
# 26617-2014-05-29.csv has been downloaded
#
# Performing OCR for 26617-2015-06-01.csv
# 26617-2015-06-01.csv has been downloaded
#
# Performing OCR for 26617-2016-05-31.csv
# 26617-2016-05-31.csv has been downloaded
#
# Performing OCR for 26617-2017-05-30.csv
# 26617-2017-05-30.csv has been downloaded
#
# Performing OCR for 26617-2018-05-30.csv
# 26617-2018-05-30.csv has been downloaded
#
# Performing OCR for 26617-2019-05-30.csv
# 26617-2019-05-30.csv has been downloaded
#
# Performing OCR for 26617-2020-06-01.csv
# 26617-2020-06-01.csv has been downloaded
#
# Performing OCR for 276523-2002-03-01.csv
# 276523-2002-03-01.csv has been downloaded
#
# Performing OCR for 276523-2003-03-03.csv
# 276523-2003-03-03.csv has been downloaded
#
# Performing OCR for 276523-2004-03-04.csv
# 276523-2004-03-04.csv has been downloaded
#
# Performing OCR for 276523-2005-03-01.csv
# 276523-2005-03-01.csv has been downloaded
#
# Performing OCR for 276523-2006-08-08.csv
# 276523-2006-08-08.csv has been downloaded
#
# Performing OCR for 276523-2007-03-02.csv
# 276523-2007-03-02.csv has been downloaded
#
# Performing OCR for 276523-2008-02-29.csv
# 276523-2008-02-29.csv has been downloaded
#
# Performing OCR for 276523-2009-03-02.csv
# 276523-2009-03-02.csv has been downloaded
#
# Performing OCR for 29648-2003-03-03.csv
# 29648-2003-03-03.csv has been downloaded
#
# Performing OCR for 29648-2004-03-01.csv
# 29648-2004-03-01.csv has been downloaded
#
# Performing OCR for 29648-2005-03-01.csv
# 29648-2005-03-01.csv has been downloaded
#
# Performing OCR for 29648-2006-03-01.csv
# 29648-2006-03-01.csv has been downloaded
#
# Performing OCR for 29648-2007-03-01.csv
# 29648-2007-03-01.csv has been downloaded
#
# Performing OCR for 29648-2008-02-29.csv
# 29648-2008-02-29.csv has been downloaded
#
# Performing OCR for 29648-2008-04-07.csv
# 29648-2008-04-07.csv has been downloaded
#
# Performing OCR for 29648-2008-05-13.csv
# 29648-2008-05-13.csv has been downloaded
#
# Performing OCR for 29648-2009-03-02.csv
# 29648-2009-03-02.csv has been downloaded
#
# Performing OCR for 29648-2010-03-01.csv
# 29648-2010-03-01.csv has been downloaded
#
# Performing OCR for 29648-2011-03-01.csv
# 29648-2011-03-01.csv has been downloaded
#
# Performing OCR for 29648-2011-03-30.csv
# 29648-2011-03-30.csv has been downloaded
#
# Performing OCR for 29648-2012-02-29.csv
# 29648-2012-02-29.csv has been downloaded
#
# Performing OCR for 29648-2013-03-01.csv
# 29648-2013-03-01.csv has been downloaded
#
# Performing OCR for 29648-2014-02-28.csv
# 29648-2014-02-28.csv has been downloaded
#
# Performing OCR for 29648-2015-03-02.csv
# 29648-2015-03-02.csv has been downloaded
#
# Performing OCR for 29648-2016-02-29.csv
# 29648-2016-02-29.csv has been downloaded
#
# Performing OCR for 29648-2017-03-01.csv
# 29648-2017-03-01.csv has been downloaded
#
# Performing OCR for 29648-2018-03-01.csv
# 29648-2018-03-01.csv has been downloaded
#
# Performing OCR for 29648-2019-03-01.csv
# 29648-2019-03-01.csv has been downloaded
#
# Performing OCR for 29648-2021-02-26.csv
# 29648-2021-02-26.csv has been downloaded
#
# Performing OCR for 318336-2003-03-03.csv
# 318336-2003-03-03.csv has been downloaded
#
# Performing OCR for 318336-2004-02-27.csv
# 318336-2004-02-27.csv has been downloaded
#
# Performing OCR for 318336-2004-04-07.csv
# 318336-2004-04-07.csv has been downloaded
#
# Performing OCR for 318336-2005-03-01.csv
# 318336-2005-03-01.csv has been downloaded
#
# Performing OCR for 318336-2006-03-01.csv
# 318336-2006-03-01.csv has been downloaded
#
# Performing OCR for 318336-2007-03-01.csv
# 318336-2007-03-01.csv has been downloaded
#
# Performing OCR for 318336-2008-03-26.csv
# 318336-2008-03-26.csv has been downloaded
#
# Performing OCR for 318336-2009-03-02.csv
# 318336-2009-03-02.csv has been downloaded
#
# Performing OCR for 318336-2010-03-01.csv
# Started job with id: aca835b0405721c7b4eb1e3131e23e5a82af400dc8c55d75ad53dd5725a20010
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
#
# Performing OCR for 318336-2010-03-03.csv
# 318336-2010-03-03.csv has been downloaded
#
# Performing OCR for 318336-2011-03-01.csv
# 318336-2011-03-01.csv has been downloaded
#
# Performing OCR for 318336-2012-02-29.csv
# 318336-2012-02-29.csv has been downloaded
#
# Performing OCR for 318336-2013-03-01.csv
# 318336-2013-03-01.csv has been downloaded
#
# Performing OCR for 318336-2014-03-05.csv
# 318336-2014-03-05.csv has been downloaded
#
# Performing OCR for 318336-2015-03-02.csv
# 318336-2015-03-02.csv has been downloaded
#
# Performing OCR for 318336-2016-02-29.csv
# 318336-2016-02-29.csv has been downloaded
#
# Performing OCR for 318336-2017-03-06.csv
# 318336-2017-03-06.csv has been downloaded
#
# Performing OCR for 318336-2018-03-01.csv
# 318336-2018-03-01.csv has been downloaded
#
# Performing OCR for 318336-2019-03-08.csv
# 318336-2019-03-08.csv has been downloaded
#
# Performing OCR for 318336-2020-02-28.csv
# 318336-2020-02-28.csv has been downloaded
#
# Performing OCR for 318336-2021-03-01.csv
# 318336-2021-03-01.csv has been downloaded
#
# Performing OCR for 356628-2002-02-25.csv
# 356628-2002-02-25.csv has been downloaded
#
# Performing OCR for 356628-2003-02-24.csv
# 356628-2003-02-24.csv has been downloaded
#
# Performing OCR for 356628-2004-03-01.csv
# 356628-2004-03-01.csv has been downloaded
#
# Performing OCR for 356628-2005-03-01.csv
# 356628-2005-03-01.csv has been downloaded
#
# Performing OCR for 356628-2006-03-02.csv
# 356628-2006-03-02.csv has been downloaded
#
# Performing OCR for 356628-2007-03-01.csv
# 356628-2007-03-01.csv has been downloaded
#
# Performing OCR for 356628-2008-02-29.csv
# 356628-2008-02-29.csv has been downloaded
#
# Performing OCR for 356628-2009-03-02.csv
# 356628-2009-03-02.csv has been downloaded
#
# Performing OCR for 356628-2010-06-11.csv
# 356628-2010-06-11.csv has been downloaded
#
# Performing OCR for 356628-2011-03-02.csv
# 356628-2011-03-02.csv has been downloaded
#
# Performing OCR for 356628-2012-02-27.csv
# 356628-2012-02-27.csv has been downloaded
#
# Performing OCR for 356628-2013-02-25.csv
# 356628-2013-02-25.csv has been downloaded
#
# Performing OCR for 356628-2014-02-21.csv
# 356628-2014-02-21.csv has been downloaded
#
# Performing OCR for 356628-2015-02-26.csv
# 356628-2015-02-26.csv has been downloaded
#
# Performing OCR for 356628-2016-02-24.csv
# 356628-2016-02-24.csv has been downloaded
#
# Performing OCR for 356628-2017-02-24.csv
# 356628-2017-02-24.csv has been downloaded
#
# Performing OCR for 356628-2018-02-23.csv
# 356628-2018-02-23.csv has been downloaded
#
# Performing OCR for 356628-2019-02-25.csv
# 356628-2019-02-25.csv has been downloaded
#
# Performing OCR for 356628-2021-02-25.csv
# 356628-2021-02-25.csv has been downloaded
#
# Performing OCR for 42352-2002-01-30.csv
# 42352-2002-01-30.csv has been downloaded
#
# Performing OCR for 42352-2003-01-28.csv
# 42352-2003-01-28.csv has been downloaded
#
# Performing OCR for 42352-2004-01-27.csv
# 42352-2004-01-27.csv has been downloaded
#
# Performing OCR for 42352-2005-01-25.csv
# 42352-2005-01-25.csv has been downloaded
#
# Performing OCR for 42352-2006-01-24.csv
# 42352-2006-01-24.csv has been downloaded
#
# Performing OCR for 42352-2007-01-23.csv
# 42352-2007-01-23.csv has been downloaded
#
# Performing OCR for 42352-2008-01-29.csv
# 42352-2008-01-29.csv has been downloaded
#
# Performing OCR for 42352-2009-01-27.csv
# 42352-2009-01-27.csv has been downloaded
#
# Performing OCR for 42352-2010-03-01.csv
# 42352-2010-03-01.csv has been downloaded
#
# Performing OCR for 42352-2010-03-03.csv
# Started job with id: 0a9fb2aaf829f6aef184f7a3bdf58d2fb4da7e63969901cd2bbc8706385c0e40
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
#
# Performing OCR for 42352-2011-03-01.csv
# 42352-2011-03-01.csv has been downloaded
#
# Performing OCR for 42352-2012-02-29.csv
# 42352-2012-02-29.csv has been downloaded
#
# Performing OCR for 42352-2013-03-01.csv
# 42352-2013-03-01.csv has been downloaded
#
# Performing OCR for 42352-2014-07-31.csv
# 42352-2014-07-31.csv has been downloaded
#
# Performing OCR for 42352-2015-03-10.csv
# 42352-2015-03-10.csv has been downloaded
#
# Performing OCR for 42352-2016-02-23.csv
# 42352-2016-02-23.csv has been downloaded
#
# Performing OCR for 42352-2017-03-01.csv
# 42352-2017-03-01.csv has been downloaded
#
# Performing OCR for 42352-2018-02-27.csv
# 42352-2018-02-27.csv has been downloaded
#
# Performing OCR for 42352-2019-03-01.csv
# 42352-2019-03-01.csv has been downloaded
#
# Performing OCR for 42352-2020-02-28.csv
# Started job with id: 5f3f25363db14754a0c72af9a38be9ca4c7eb54858168af97d10791ce2145843
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
#
# Performing OCR for 42352-2021-02-25.csv
# 42352-2021-02-25.csv has been downloaded
#
# Performing OCR for 48966-2002-03-04.csv
# 48966-2002-03-04.csv has been downloaded
#
# Performing OCR for 48966-2003-03-03.csv
# 48966-2003-03-03.csv has been downloaded
#
# Performing OCR for 48966-2004-03-01.csv
# 48966-2004-03-01.csv has been downloaded
#
# Performing OCR for 48966-2005-03-08.csv
# 48966-2005-03-08.csv has been downloaded
#
# Performing OCR for 48966-2006-03-02.csv
# 48966-2006-03-02.csv has been downloaded
#
# Performing OCR for 48966-2007-03-01.csv
# 48966-2007-03-01.csv has been downloaded
#
# Performing OCR for 48966-2008-02-29.csv
# 48966-2008-02-29.csv has been downloaded
#
# Performing OCR for 48966-2009-03-02.csv
# 48966-2009-03-02.csv has been downloaded
#
# Performing OCR for 48966-2010-03-01.csv
# 48966-2010-03-01.csv has been downloaded
#
# Performing OCR for 48966-2010-03-02.csv
# Started job with id: 1a2b3680de4be916b2d72f36467444757ec8847bba506bb2a5acc7566a5d711f
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
#
# Performing OCR for 48966-2011-03-01.csv
# 48966-2011-03-01.csv has been downloaded
#
# Performing OCR for 48966-2012-03-01.csv
# 48966-2012-03-01.csv has been downloaded
#
# Performing OCR for 48966-2013-03-04.csv
# 48966-2013-03-04.csv has been downloaded
#
# Performing OCR for 48966-2014-03-04.csv
# 48966-2014-03-04.csv has been downloaded
#
# Performing OCR for 48966-2015-02-27.csv
# 48966-2015-02-27.csv has been downloaded
#
# Performing OCR for 48966-2016-02-29.csv
# 48966-2016-02-29.csv has been downloaded
#
# Performing OCR for 48966-2017-02-28.csv
# 48966-2017-02-28.csv has been downloaded
#
# Performing OCR for 48966-2018-03-01.csv
# 48966-2018-03-01.csv has been downloaded
#
# Performing OCR for 48966-2018-03-06.csv
# 48966-2018-03-06.csv has been downloaded
#
# Performing OCR for 48966-2019-03-01.csv
# 48966-2019-03-01.csv has been downloaded
#
# Performing OCR for 48966-2020-02-28.csv
# 48966-2020-02-28.csv has been downloaded
#
# Performing OCR for 48966-2021-02-26.csv
# 48966-2021-02-26.csv has been downloaded
#
# Performing OCR for 58056-2002-03-01.csv
# 58056-2002-03-01.csv has been downloaded
#
# Performing OCR for 58056-2003-03-03.csv
# 58056-2003-03-03.csv has been downloaded
#
# ...
# 7                Liabilities and Stockholder's Equity
# 8                                      Drafts payable     $ 361
# 9   Payables to brokers, dealers and clearing orga...     1,468
# 10                      Payables to brokerage clients    27,083
# 11             Accrued expenses and other liabilities       584
# 12                             Payables to affiliates        20
# 13                                     Long-term debt       134
# 14                                  Total liabilities    29,650
# 15  Subordinated borrowings from The Charles Schwa...       220
# 16                              Stockholder's equity:
# 17  Preferred stock - 3,000,000 shares authorized;...         -
# 18  Common stock - 7,000,000 shares authorized; $....         -
# 19                         Additional paid-in capital       564
# 20                                  Retained earnings     1,258
# 21                         Total stockholder's equity     1,822
# 22                                              Total  $ 31,692
# {'CHARLES SCHWAB & CO., INC.': 97.86222076416016, 'CONSOLIDATED STATEMENT OF FINANCIAL CONDITION': 99.81922912597656, 'DECEMBER 31, 2004 (In millions, except share and per share amounts)': 99.7120361328125, 'Assets': 99.97872924804688, 'Cash and cash equivalents': 99.97261810302734, '$': 99.8328628540039, '889': 99.9521713256836, 'Cash and investments segregated and on deposit for federal or': 99.97579956054688, 'other regulatory purposes (1) (including resale agreements of $13,102)': 99.17898559570312, '19,089': 99.93348693847656, 'Receivables from brokers, dealers and clearing organizations': 99.85391235351562, '478': 99.95903015136719, 'Receivables from brokerage clients - net': 98.99512481689453, '9,833': 99.4822769165039, 'Securities owned - at market value (including securities pledged of $8)': 99.22085571289062, '385': 99.95565795898438, 'Equipment, office facilities and property - net': 99.79072570800781, '710': 99.97602081298828, 'Other assets': 99.95578002929688, '308': 99.97068786621094, 'Total': 99.96492767333984, '$ 31,692': 98.1509017944336, "Liabilities and Stockholder's Equity": 99.92831420898438, 'Drafts payable': 99.95702362060547, '361': 99.9639663696289, 'Payables to brokers, dealers and clearing organizations': 99.92633819580078, '1,468': 99.89568328857422, 'Payables to brokerage clients': 99.92413330078125, '27,083': 99.8119125366211, 'Accrued expenses and other liabilities': 99.98243713378906, '584': 99.93951416015625, 'Payables to affiliates': 99.83631134033203, '20': 99.95048522949219, 'Long-term debt': 99.66902160644531, '134': 99.9454116821289, 'Total liabilities': 99.97190856933594, '29,650': 99.87637329101562, 'Subordinated borrowings from The Charles Schwab Corporation': 99.96458435058594, '220': 99.97113800048828, "Stockholder's equity:": 99.8794174194336, 'Preferred stock - 3,000,000 shares authorized; $.10 par value': 99.45975494384766, 'per share; none issued': 99.97113800048828, '-': 98.14945220947266, 'Common stock - 7,000,000 shares authorized; $.10 par value': 99.48394012451172, 'per share; 2,823,000 shares issued and outstanding': 99.83021545410156, 'Additional paid-in capital': 99.9477310180664, '564': 99.94603729248047, 'Retained earnings': 99.97604370117188, '1,258': 99.79312133789062, "Total stockholder's equity": 99.96343231201172, '1,822': 97.04315185546875, '(1)': 98.98640441894531, 'Amount included represents actual balance on deposit, whereas cash and investments required to be': 99.96129608154297, 'segregated for federal or other regulatory purposes were $19,118 million, including $200 million of': 99.91834259033203, 'related-party resale agreements. On January 4, 2005, Charies Schwab & Co., Inc. deposited': 97.19133758544922, '$426 million into its segregated reserve bank accounts.': 97.35108947753906, 'See Notes to Consolidated Statement of Financial Condition.': 99.09930419921875, '2': 99.88349151611328}
# -----------------------------------------------------
# Saved 87634-2005-02-28.csv file to s3 bucket
#
# Performing OCR for 87634-2006-02-28.csv
# 87634-2006-02-28.csv has been downloaded
#
# Performing OCR for 87634-2006-09-21.csv
# 87634-2006-09-21.csv has been downloaded
#
# Performing OCR for 87634-2007-03-01.csv
# 87634-2007-03-01.csv has been downloaded
#
# Performing OCR for 87634-2008-03-03.csv
# 87634-2008-03-03.csv has been downloaded
#
# Performing OCR for 87634-2009-02-27.csv
# 87634-2009-02-27.csv has been downloaded
#
# Performing OCR for 87634-2010-03-01.csv
# 87634-2010-03-01.csv has been downloaded
#
# Performing OCR for 87634-2011-02-28.csv
# 87634-2011-02-28.csv has been downloaded
#
# Performing OCR for 87634-2012-02-27.csv
# 87634-2012-02-27.csv has been downloaded
#
# Performing OCR for 87634-2012-03-05.csv
# 87634-2012-03-05.csv has been downloaded
#
# Performing OCR for 87634-2013-02-26.csv
# 87634-2013-02-26.csv has been downloaded
#
# Performing OCR for 87634-2014-02-26.csv
# 87634-2014-02-26.csv has been downloaded
#
# Performing OCR for 87634-2015-02-25.csv
# 87634-2015-02-25.csv has been downloaded
#
# Performing OCR for 87634-2016-02-25.csv
# 87634-2016-02-25.csv has been downloaded
#
# Performing OCR for 87634-2017-02-27.csv
# 87634-2017-02-27.csv has been downloaded
#
# Performing OCR for 87634-2018-02-27.csv
# 87634-2018-02-27.csv has been downloaded
#
# Performing OCR for 87634-2019-02-26.csv
# 87634-2019-02-26.csv has been downloaded
#
# Performing OCR for 87634-2020-02-27.csv
# 87634-2020-02-27.csv has been downloaded
#
# Performing OCR for 87634-2021-02-26.csv
# 87634-2021-02-26.csv has been downloaded
#
# Performing OCR for 877559-2002-03-01.csv
# 877559-2002-03-01.csv has been downloaded
#
# Performing OCR for 877559-2003-03-03.csv
# 877559-2003-03-03.csv has been downloaded
#
# Performing OCR for 877559-2004-03-01.csv
# 877559-2004-03-01.csv has been downloaded
#
# Performing OCR for 877559-2005-03-01.csv
# 877559-2005-03-01.csv has been downloaded
#
# Performing OCR for 877559-2006-03-01.csv
# 877559-2006-03-01.csv has been downloaded
#
# Performing OCR for 877559-2007-03-01.csv
# 877559-2007-03-01.csv has been downloaded
#
# Performing OCR for 877559-2008-02-29.csv
# 877559-2008-02-29.csv has been downloaded
#
# Performing OCR for 877559-2009-03-02.csv
# 877559-2009-03-02.csv has been downloaded
#
# Performing OCR for 877559-2010-03-01.csv
# 877559-2010-03-01.csv has been downloaded
#
# Performing OCR for 877559-2011-03-01.csv
# 877559-2011-03-01.csv has been downloaded
#
# Performing OCR for 877559-2012-02-29.csv
# 877559-2012-02-29.csv has been downloaded
#
# Performing OCR for 877559-2013-03-01.csv
# 877559-2013-03-01.csv has been downloaded
#
# Performing OCR for 877559-2014-03-04.csv
# 877559-2014-03-04.csv has been downloaded
#
# Performing OCR for 877559-2015-03-02.csv
# 877559-2015-03-02.csv has been downloaded
#
# Performing OCR for 877559-2016-02-29.csv
# 877559-2016-02-29.csv has been downloaded
#
# Performing OCR for 877559-2016-04-25.csv
# 877559-2016-04-25.csv has been downloaded
#
# Performing OCR for 877559-2018-04-02.csv
# 877559-2018-04-02.csv has been downloaded
#
# Performing OCR for 877559-2018-04-05.csv
# 877559-2018-04-05.csv has been downloaded
#
# Performing OCR for 877559-2019-03-01.csv
# 877559-2019-03-01.csv has been downloaded
#
# Performing OCR for 877559-2020-03-02.csv
# 877559-2020-03-02.csv has been downloaded
#
# Performing OCR for 877559-2021-03-01.csv
# 877559-2021-03-01.csv has been downloaded
#
# Performing OCR for 890203-2002-03-01.csv
# 890203-2002-03-01.csv has been downloaded
#
# Performing OCR for 890203-2003-02-28.csv
# 890203-2003-02-28.csv has been downloaded
#
# Performing OCR for 890203-2004-05-03.csv
# 890203-2004-05-03.csv has been downloaded
#
# Performing OCR for 890203-2005-02-22.csv
# 890203-2005-02-22.csv has been downloaded
#
# Performing OCR for 890203-2006-02-28.csv
# 890203-2006-02-28.csv has been downloaded
#
# Performing OCR for 890203-2007-05-30.csv
# 890203-2007-05-30.csv has been downloaded
#
# Performing OCR for 890203-2008-05-30.csv
# 890203-2008-05-30.csv has been downloaded
#
# Performing OCR for 890203-2009-05-28.csv
# 890203-2009-05-28.csv has been downloaded
#
# Performing OCR for 890203-2010-05-28.csv
# 890203-2010-05-28.csv has been downloaded
#
# Performing OCR for 890203-2010-11-23.csv
# Started job with id: 1011ea95bd202d336adededb6b639689809efaad4a683c6e1d9b41fa08349396
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
#
# Performing OCR for 890203-2011-05-31.csv
# 890203-2011-05-31.csv has been downloaded
#
# Performing OCR for 890203-2012-05-30.csv
# 890203-2012-05-30.csv has been downloaded
#
# Performing OCR for 890203-2013-05-29.csv
# 890203-2013-05-29.csv has been downloaded
#
# Performing OCR for 890203-2014-02-28.csv
# 890203-2014-02-28.csv has been downloaded
#
# Performing OCR for 890203-2015-03-02.csv
# 890203-2015-03-02.csv has been downloaded
#
# Performing OCR for 890203-2016-02-26.csv
# 890203-2016-02-26.csv has been downloaded
#
# Performing OCR for 890203-2017-03-15.csv
# 890203-2017-03-15.csv has been downloaded
#
# Performing OCR for 890203-2018-03-01.csv
# 890203-2018-03-01.csv has been downloaded
#
# Performing OCR for 890203-2019-03-07.csv
# 890203-2019-03-07.csv has been downloaded
#
# Performing OCR for 890203-2020-03-02.csv
# 890203-2020-03-02.csv has been downloaded
#
# Performing OCR for 890203-2020-03-05.csv
# 890203-2020-03-05.csv has been downloaded
#
# Performing OCR for 890203-2021-03-01.csv
# 890203-2021-03-01.csv has been downloaded
#
# Performing OCR for 895502-1998-11-13.csv
# 895502-1998-11-13.csv has been downloaded
#
# Performing OCR for 895502-2002-02-28.csv
# 895502-2002-02-28.csv has been downloaded
#
# Performing OCR for 895502-2002-12-30.csv
# 895502-2002-12-30.csv has been downloaded
#
# Performing OCR for 895502-2004-08-05.csv
# 895502-2004-08-05.csv has been downloaded
#
# Performing OCR for 895502-2005-01-21.csv
# 895502-2005-01-21.csv has been downloaded
#
# Performing OCR for 895502-2005-12-29.csv
# 895502-2005-12-29.csv has been downloaded
#
# Performing OCR for 895502-2006-12-28.csv
# 895502-2006-12-28.csv has been downloaded
#
# Performing OCR for 895502-2007-12-31.csv
# 895502-2007-12-31.csv has been downloaded
#
# Performing OCR for 895502-2008-02-15.csv
# 895502-2008-02-15.csv has been downloaded
#
# Performing OCR for 895502-2009-12-30.csv
# 895502-2009-12-30.csv has been downloaded
#
# Performing OCR for 895502-2011-07-05.csv
# 895502-2011-07-05.csv has been downloaded
#
# Performing OCR for 895502-2011-12-29.csv
# 895502-2011-12-29.csv has been downloaded
#
# Performing OCR for 895502-2012-12-28.csv
# 895502-2012-12-28.csv has been downloaded
#
# Performing OCR for 895502-2014-01-02.csv
# 895502-2014-01-02.csv has been downloaded
#
# Performing OCR for 895502-2014-12-29.csv
# 895502-2014-12-29.csv has been downloaded
#
# Performing OCR for 895502-2015-12-30.csv
# 895502-2015-12-30.csv has been downloaded
#
# Performing OCR for 895502-2016-12-28.csv
# 895502-2016-12-28.csv has been downloaded
#
# Performing OCR for 895502-2017-12-26.csv
# 895502-2017-12-26.csv has been downloaded
#
# Performing OCR for 895502-2019-06-17.csv
# 895502-2019-06-17.csv has been downloaded
#
# Performing OCR for 895502-2019-12-23.csv
# 895502-2019-12-23.csv has been downloaded
#
# Performing OCR for 89562-2002-01-29.csv
# 89562-2002-01-29.csv has been downloaded
#
# Performing OCR for 89562-2003-01-29.csv
# 89562-2003-01-29.csv has been downloaded
#
# Performing OCR for 89562-2004-01-29.csv
# 89562-2004-01-29.csv has been downloaded
#
# Performing OCR for 89562-2005-01-31.csv
# 89562-2005-01-31.csv has been downloaded
#
# Performing OCR for 89562-2006-01-30.csv
# 89562-2006-01-30.csv has been downloaded
#
# Performing OCR for 89562-2007-01-29.csv
# 89562-2007-01-29.csv has been downloaded
#
# Performing OCR for 89562-2008-01-29.csv
# 89562-2008-01-29.csv has been downloaded
#
# Performing OCR for 91154-2002-03-01.csv
# 91154-2002-03-01.csv has been downloaded
#
# Performing OCR for 91154-2003-03-03.csv
# 91154-2003-03-03.csv has been downloaded
#
# Performing OCR for 91154-2004-02-27.csv
# 91154-2004-02-27.csv has been downloaded
#
# Performing OCR for 91154-2005-03-01.csv
# 91154-2005-03-01.csv has been downloaded
#
# Performing OCR for 91154-2006-03-01.csv
# Started job with id: 3747561f8010151adfb830b8bda4029e8d3842fb4e0e897361b63f0d0c764f5d
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
# Resultset page recieved: 8
#
# Performing OCR for 91154-2007-03-01.csv
# 91154-2007-03-01.csv has been downloaded
#
# Performing OCR for 91154-2008-02-29.csv
# 91154-2008-02-29.csv has been downloaded
#
# Performing OCR for 91154-2009-03-02.csv
# 91154-2009-03-02.csv has been downloaded
#
# Performing OCR for 91154-2010-03-02.csv
# 91154-2010-03-02.csv has been downloaded
#
# Performing OCR for 91154-2011-03-01.csv
# 91154-2011-03-01.csv has been downloaded
#
# Performing OCR for 91154-2012-02-29.csv
# 91154-2012-02-29.csv has been downloaded
#
# Performing OCR for 91154-2013-03-01.csv
# 91154-2013-03-01.csv has been downloaded
#
# Performing OCR for 91154-2014-03-04.csv
# 91154-2014-03-04.csv has been downloaded
#
# Performing OCR for 91154-2015-03-02.csv
# 91154-2015-03-02.csv has been downloaded
#
# Performing OCR for 91154-2016-03-01.csv
# 91154-2016-03-01.csv has been downloaded
#
# Performing OCR for 91154-2017-03-02.csv
# 91154-2017-03-02.csv has been downloaded
#
# Performing OCR for 91154-2018-03-05.csv
# 91154-2018-03-05.csv has been downloaded
#
# Performing OCR for 91154-2019-03-05.csv
# 91154-2019-03-05.csv has been downloaded
#
# Performing OCR for 91154-2020-03-02.csv
# 91154-2020-03-02.csv has been downloaded
#
# Performing OCR for 920417-2015-03-02.csv
# 920417-2015-03-02.csv has been downloaded
#
# Performing OCR for 920417-2016-02-29.csv
# 920417-2016-02-29.csv has been downloaded
#
# Performing OCR for 920417-2017-03-01.csv
# 920417-2017-03-01.csv has been downloaded
#
# Performing OCR for 920417-2018-02-27.csv
# 920417-2018-02-27.csv has been downloaded
#
# Performing OCR for 920417-2019-02-28.csv
# 920417-2019-02-28.csv has been downloaded
#
# Performing OCR for 920417-2020-02-28.csv
# 920417-2020-02-28.csv has been downloaded
#
# Performing OCR for 920417-2021-03-01.csv
# 920417-2021-03-01.csv has been downloaded
#
# Performing OCR for 922792-2002-03-04.csv
# 922792-2002-03-04.csv has been downloaded
#
# Performing OCR for 922792-2003-03-03.csv
# 922792-2003-03-03.csv has been downloaded
#
# Performing OCR for 922792-2004-03-01.csv
# 922792-2004-03-01.csv has been downloaded
#
# Performing OCR for 922792-2005-03-01.csv
# 922792-2005-03-01.csv has been downloaded
#
# Performing OCR for 922792-2006-03-01.csv
# 922792-2006-03-01.csv has been downloaded
#
# Performing OCR for 922792-2007-03-01.csv
# 922792-2007-03-01.csv has been downloaded
#
# Performing OCR for 922792-2008-02-29.csv
# 922792-2008-02-29.csv has been downloaded
#
# Performing OCR for 922792-2009-03-02.csv
# 922792-2009-03-02.csv has been downloaded
#
# Performing OCR for 922792-2010-03-02.csv
# 922792-2010-03-02.csv has been downloaded
#
# Performing OCR for 922792-2011-03-01.csv
# 922792-2011-03-01.csv has been downloaded
#
# Performing OCR for 922792-2012-02-29.csv
# 922792-2012-02-29.csv has been downloaded
#
# Performing OCR for 922792-2014-03-04.csv
# 922792-2014-03-04.csv has been downloaded
#
# Performing OCR for 922792-2015-03-02.csv
# 922792-2015-03-02.csv has been downloaded
#
# Performing OCR for 922792-2016-02-29.csv
# 922792-2016-02-29.csv has been downloaded
#
# Performing OCR for 922792-2017-03-01.csv
# 922792-2017-03-01.csv has been downloaded
#
# Performing OCR for 922792-2018-03-01.csv
# 922792-2018-03-01.csv has been downloaded
#
# Performing OCR for 922792-2019-02-28.csv
# 922792-2019-02-28.csv has been downloaded
#
# Performing OCR for 922792-2019-03-01.csv
# 922792-2019-03-01.csv has been downloaded
#
# Performing OCR for 922792-2020-02-28.csv
# 922792-2020-02-28.csv has been downloaded
#
# Performing OCR for 922792-2021-02-26.csv
# 922792-2021-02-26.csv has been downloaded
#
#
# Finished performing OCR on parsed FOCUS reports.

# %%
# # single reading for testing purposes and debugging Textract results e.g. 853784-2002-03-01, 808379-2017-03-01
# textractParse('Input/X-17A-5-PDF-SUBSETS/808379-2021-03-02-subset.pdf', 
#               'Input/X-17A-5-PNG-SUBSETS/808379-2021-03-02/', 'ran-s3-systemic-risk')

# %%
# readPNG([4], 'Input/X-17A-5-PNG-SUBSETS/808379-2020-02-20/')

# %%
# # temporary data frame object for balance sheet information
# res = runJob('ran-s3-systemic-risk', 'Input/bs_test1.pdf')

# # if Textract job did not fail we continue extraction
# if res[0]['JobStatus'] != 'FAILED':
    
#     print(readTable(res))

# %%
# # temporary data frame object for balance sheet information
# res = runJob('ran-s3-systemic-risk', 'Input/X-17A-5-PDF-SUBSETS/808379-2018-03-01-subset.pdf')

# # if Textract job did not fail we continue extraction
# if res[0]['JobStatus'] != 'FAILED':
    
#     print(readTable(res))

# %%
# # temporary data frame object for balance sheet information
# res = runJob('ran-s3-systemic-risk', 'Input/X-17A-5-PDF-SUBSETS/1146184-2019-02-28-subset.pdf')

# # if Textract job did not fail we continue extraction
# if res[0]['JobStatus'] != 'FAILED':
    
#     print(readTable(res))
